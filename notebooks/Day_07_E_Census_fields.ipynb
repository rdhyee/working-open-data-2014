# %%
# %pylab --no-import-all inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
#  import useful classes of pandas
import pandas as pd
from pandas import Series, DataFrame, Index

# %%
import settings
import census

c = census.Census(key=settings.CENSUS_KEY)

# %% [markdown]
# # Fields in SF1

# %%
sf1_fields = c.sf1.fields(year=2010)

# %%
sorted(sf1_fields.keys())
# Out:
# ['Geographic Characteristics',
#  'H1. Housing Units [1]',
#  'H10. TOTAL POPULATION IN OCCUPIED HOUSING UNITS [1]',
#  'H11. TOTAL POPULATION IN OCCUPIED HOUSING UNITS BY TENURE [4]',
#  'H11A. TOTAL POPULATION IN OCCUPIED HOUSING UNITS BY TENURE (WHITE ALONE HOUSEHOLDER) [4]',
#  'H11B. TOTAL POPULATION IN OCCUPIED HOUSING UNITS BY TENURE (BLACK OR AFRICAN AMERICAN ALONE HOUSEHOLDER) [4]',
#  'H11C. TOTAL POPULATION IN OCCUPIED HOUSING UNITS BY TENURE (AMERICAN INDIAN AND ALASKA NATIVE ALONE HOUSEHOLDER) [4]',
#  'H11D. TOTAL POPULATION IN OCCUPIED HOUSING UNITS BY TENURE (ASIAN ALONE HOUSEHOLDER) [4]',
#  'H11E. TOTAL POPULATION IN OCCUPIED HOUSING UNITS BY TENURE (NATIVE HAWAIIAN AND OTHER PACIFIC ISLANDER ALONE HOUSEHOLDER) [4]',
#  'H11F. TOTAL POPULATION IN OCCUPIED HOUSING UNITS BY TENURE (SOME OTHER RACE ALONE HOUSEHOLDER) [4]',
#  'H11G. TOTAL POPULATION IN OCCUPIED HOUSING UNITS BY TENURE (TWO OR MORE RACES HOUSEHOLDER) [4]',
#  'H11H. TOTAL POPULATION IN OCCUPIED HOUSING UNITS BY TENURE (HISPANIC OR LATINO HOUSEHOLDER) [4]',
#  'H11I. TOTAL POPULATION IN OCCUPIED HOUSING UNITS BY TENURE (WHITE ALONE, NOT HISPANIC OR LATINO HOUSEHOLDER) [4]',
#  'H12. AVERAGE HOUSEHOLD SIZE OF OCCUPIED HOUSING UNITS BY TENURE [3] (2 expressed decimals)',
#  'H12A. AVERAGE HOUSEHOLD SIZE OF OCCUPIED HOUSING UNITS BY TENURE (WHITE ALONE HOUSEHOLDER) [3] (2 expressed decimals)',
#  'H12B. AVERAGE HOUSEHOLD SIZE OF OCCUPIED HOUSING UNITS BY TENURE (BLACK OR AFRICAN AMERICAN ALONE HOUSEHOLDER) [3] (2 expressed decimals)',
#  'H12C. AVERAGE HOUSEHOLD SIZE OF OCCUPIED HOUSING UNITS BY TENURE (AMERICAN INDIAN AND ALASKA NATIVE ALONE HOUSEHOLDER) [3] (2 expressed decimals)',
#  'H12D. AVERAGE HOUSEHOLD SIZE OF OCCUPIED HOUSING UNITS BY TENURE (ASIAN ALONE HOUSEHOLDER) [3] (2 expressed decimals)',
#  'H12E. AVERAGE HOUSEHOLD SIZE OF OCCUPIED HOUSING UNITS BY TENURE (NATIVE HAWAIIAN AND OTHER PACIFIC ISLANDER ALONE HOUSEHOLDER) [3] (2 expressed decimals)',
#  'H12F. AVERAGE HOUSEHOLD SIZE OF OCCUPIED HOUSING UNITS BY TENURE (SOME OTHER RACE ALONE HOUSEHOLDER) [3] (2 expressed decimals)',
#  'H12G. AVERAGE HOUSEHOLD SIZE OF OCCUPIED HOUSING UNITS BY TENURE (TWO OR MORE RACES HOUSEHOLDER) [3] (2 expressed decimals)',
#  'H12H. AVERAGE HOUSEHOLD SIZE OF OCCUPIED HOUSING UNITS BY TENURE (HISPANIC OR LATINO HOUSEHOLDER) [3] (2 expressed decimals)',
#  'H12I. AVERAGE HOUSEHOLD SIZE OF OCCUPIED HOUSING UNITS BY TENURE (WHITE ALONE, NOT HISPANIC OR LATINO HOUSEHOLDER) [3] (2 expressed decimals)',
#  'H13. Household Size [8]',
#  'H14. Tenure By Race Of Householder [17]',
#  'H15. TENURE BY HISPANIC OR LATINO ORIGIN OF HOUSEHOLDER [7]',
#  'H16. TENURE BY HOUSEHOLD SIZE [17]',
#  'H16A. TENURE BY HOUSEHOLD SIZE (WHITE ALONE HOUSEHOLDER) [17]',
#  'H16B. TENURE BY HOUSEHOLD SIZE (BLACK OR AFRICAN AMERICAN ALONE HOUSEHOLDER) [17]',
#  'H16C. TENURE BY HOUSEHOLD SIZE (AMERICAN INDIAN AND ALASKA NATIVE ALONE HOUSEHOLDER) [17]',
#  'H16D. TENURE BY HOUSEHOLD SIZE (ASIAN ALONE HOUSEHOLDER) [17]',
#  'H16E. TENURE BY HOUSEHOLD SIZE (NATIVE HAWAIIAN AND OTHER PACIFIC ISLANDER ALONE HOUSEHOLDER) [17]',
#  'H16F. TENURE BY HOUSEHOLD SIZE (SOME OTHER RACE ALONE HOUSEHOLDER) [17]',
#  'H16G. TENURE BY HOUSEHOLD SIZE (TWO OR MORE RACES HOUSEHOLDER) [17]',
#  'H16H. TENURE BY HOUSEHOLD SIZE (HISPANIC OR LATINO HOUSEHOLDER) [17]',
#  'H16I. TENURE BY HOUSEHOLD SIZE (WHITE ALONE, NOT HISPANIC OR LATINO HOUSEHOLDER) [17]',
#  'H17. TENURE BY AGE OF HOUSEHOLDER [21]',
#  'H17A. TENURE BY AGE OF HOUSEHOLDER (WHITE ALONE HOUSEHOLDER) [21]',
#  'H17B. TENURE BY AGE OF HOUSEHOLDER (BLACK OR AFRICAN AMERICAN ALONE HOUSEHOLDER) [21]',
#  'H17C. TENURE BY AGE OF HOUSEHOLDER (AMERICAN INDIAN AND ALASKA NATIVE ALONE HOUSEHOLDER) [21]',
#  'H17D. TENURE BY AGE OF HOUSEHOLDER (ASIAN ALONE HOUSEHOLDER) [21]',
#  'H17E. TENURE BY AGE OF HOUSEHOLDER (NATIVE HAWAIIAN AND OTHER PACIFIC ISLANDER ALONE HOUSEHOLDER) [21]',
#  'H17F. TENURE BY AGE OF HOUSEHOLDER (SOME OTHER RACE ALONE HOUSEHOLDER) [21]',
#  'H17G. TENURE BY AGE OF HOUSEHOLDER (TWO OR MORE RACES HOUSEHOLDER) [21]',
#  'H17H. TENURE BY AGE OF HOUSEHOLDER (HISPANIC OR LATINO HOUSEHOLDER) [21]',
#  'H17I. TENURE BY AGE OF HOUSEHOLDER (WHITE ALONE HOUSEHOLDER, NOT HISPANIC OR LATINO) [21]',
#  'H18. TENURE BY HOUSEHOLD TYPE BY AGE OF HOUSEHOLDER [69]',
#  'H19. TENURE BY PRESENCE OF PEOPLE UNDER 18 YEARS (EXCLUDING HOUSEHOLDERS, SPOUSES, AND UNMARRIED PARTNERS) [7]',
#  'H2. URBAN AND RURAL [6] (Urban/Rural Update only)',
#  'H20. OCCUPIED HOUSING UNITS SUBSTITUTED [3]',
#  'H21. ALLOCATION OF VACANCY STATUS [3]',
#  'H22. ALLOCATION OF TENURE [3]',
#  'H3. Occupancy Status [3]',
#  'H4. TENURE [4]',
#  'H5. VACANCY STATUS [8]',
#  'H6. Race Of Householder [8]',
#  'H7. HISPANIC OR LATINO ORIGIN OF HOUSEHOLDER BY RACE OF HOUSEHOLDER [17]',
#  'H8. Total Races Tallied For Householders [7]',
#  'H9. HISPANIC OR LATINO ORIGIN OF HOUSEHOLDERS BY TOTAL RACES TALLIED [15]',
#  'HCT1. TENURE BY HISPANIC OR LATINO ORIGIN OF HOUSEHOLDER BY RACE OF HOUSEHOLDER [35]',
#  'HCT2. TENURE BY PRESENCE AND AGE OF OWN CHILDREN [13]',
#  'HCT3. TENURE BY PRESENCE AND AGE OF RELATED CHILDREN [13]',
#  'HCT4. TENURE BY PRESENCE AND AGE OF PEOPLE UNDER 18 YEARS BY HOUSEHOLD TYPE (EXCLUDING HOUSEHOLDERS, SPOUSES, AND UNMARRIED PARTNERS) [13]',
#  'P1. Total Population [1]',
#  'P10. RACE FOR THE POPULATION 18 YEARS AND OVER [71]',
#  'P11. HISPANIC OR LATINO, AND NOT HISPANIC OR LATINO BY RACE FOR THE POPULATION 18 YEARS AND OVER [73]',
#  'P12. Sex By Age [49]',
#  'P12A. Sex By Age (White Alone) [49]',
#  'P12B. Sex By Age (Black Or African American Alone) [49]',
#  'P12C. Sex By Age (American Indian And Alaska Native Alone) [49]',
#  'P12D. Sex By Age (Asian Alone) [49]',
#  'P12E. Sex By Age (Native Hawaiian And Other Pacific Islander Alone) [49]',
#  'P12F. Sex By Age (Some Other Race Alone) [49]',
#  'P12G. Sex By Age (Two Or More Races) [49]',
#  'P12H. Sex By Age (Hispanic Or Latino) [49]',
#  'P12I. Sex By Age (White Alone, Not Hispanic Or Latino) [49]',
#  'P13. MEDIAN AGE BY SEX [3] (1 expressed decimal)',
#  'P13A. MEDIAN AGE BY SEX (WHITE ALONE) [3] (1 expressed decimal)',
#  'P13B. MEDIAN AGE BY SEX (BLACK OR AFRICAN AMERICAN ALONE) [3] (1 expressed decimal)',
#  'P13C. MEDIAN AGE BY SEX (AMERICAN INDIAN AND ALASKA NATIVE ALONE) [3] (1 expressed decimal)',
#  'P13D. MEDIAN AGE BY SEX (ASIAN ALONE) [3] (1 expressed decimal)',
#  'P13E. MEDIAN AGE BY SEX (NATIVE HAWAIIAN AND OTHER PACIFIC ISLANDER ALONE) [3] (1 expressed decimal)',
#  'P13F. MEDIAN AGE BY SEX (SOME OTHER RACE ALONE) [3] (1 expressed decimal)',
#  'P13G. MEDIAN AGE BY SEX (TWO OR MORE RACES) [3] (1 expressed decimal)',
#  'P13H. MEDIAN AGE BY SEX (HISPANIC OR LATINO) [3] (1 expressed decimal)',
#  'P13I. MEDIAN AGE BY SEX (WHITE ALONE, NOT HISPANIC OR LATINO) [3] (1 expressed decimal)',
#  'P14. Sex By Age For The Population Under 20 Years [43]',
#  'P15. HISPANIC OR LATINO ORIGIN OF HOUSEHOLDER BY RACE OF HOUSEHOLDER [17]',
#  'P16. POPULATION IN HOUSEHOLDS BY AGE [3]',
#  'P16A. POPULATION IN HOUSEHOLDS BY AGE (WHITE ALONE HOUSEHOLDER) [3]',
#  'P16B. POPULATION IN HOUSEHOLDS BY AGE (BLACK OR AFRICAN AMERICAN ALONE HOUSEHOLDER) [3]',
#  'P16C. POPULATION IN HOUSEHOLDS BY AGE (AMERICAN INDIAN AND ALASKA NATIVE ALONE HOUSEHOLDER) [3]',
#  'P16D. POPULATION IN HOUSEHOLDS BY AGE (ASIAN ALONE HOUSEHOLDER) [3]',
#  'P16E. POPULATION IN HOUSEHOLDS BY AGE (NATIVE HAWAIIAN AND OTHER PACIFIC ISLANDER ALONE HOUSEHOLDER) [3]',
#  'P16F. POPULATION IN HOUSEHOLDS BY AGE (SOME OTHER RACE ALONE HOUSEHOLDER) [3]',
#  'P16G. POPULATION IN HOUSEHOLDS BY AGE (TWO OR MORE RACES HOUSEHOLDER) [3]',
#  'P16H. POPULATION IN HOUSEHOLDS BY AGE (HISPANIC OR LATINO HOUSEHOLDER) [3]',
#  'P16I. POPULATION IN HOUSEHOLDS BY AGE (WHITE ALONE, NOT HISPANIC OR LATINO HOUSEHOLDER) [3]',
#  'P17. AVERAGE HOUSEHOLD SIZE BY AGE [3] (2 expressed decimals)',
#  'P17A. AVERAGE HOUSEHOLD SIZE BY AGE (WHITE ALONE HOUSEHOLDER) [3] (2 expressed decimals)',
#  'P17B. AVERAGE HOUSEHOLD SIZE BY AGE (BLACK OR AFRICAN AMERICAN ALONE HOUSEHOLDER) [3] (2 expressed decimals)',
#  'P17C. AVERAGE HOUSEHOLD SIZE BY AGE (AMERICAN INDIAN AND ALASKA NATIVE ALONE HOUSEHOLDER) [3] (2 expressed decimals)',
#  'P17D. AVERAGE HOUSEHOLD SIZE BY AGE (ASIAN ALONE HOUSEHOLDER) [3] (2 expressed decimals)',
#  'P17E. AVERAGE HOUSEHOLD SIZE BY AGE (NATIVE HAWAIIAN AND OTHER PACIFIC ISLANDER ALONE HOUSEHOLDER) [3] (2 expressed decimals)',
#  'P17F. AVERAGE HOUSEHOLD SIZE BY AGE (SOME OTHER RACE ALONE HOUSEHOLDER) [3] (2 expressed decimals)',
#  'P17G. AVERAGE HOUSEHOLD SIZE BY AGE (TWO OR MORERACES HOUSEHOLDER) [3] (2 expressed decimals)',
#  'P17H. AVERAGE HOUSEHOLD SIZE BY AGE (HISPANIC OR LATINO HOUSEHOLDER) [3] (2 expressed decimals)',
#  'P17I. AVERAGE HOUSEHOLD SIZE BY AGE (WHITE ALONE, NOT HISPANIC OR LATINO HOUSEHOLDER) [3] (2 expressed decimals)',
#  'P18. HOUSEHOLD TYPE [9]',
#  'P18A. HOUSEHOLD TYPE (WHITE ALONE HOUSEHOLDER) [9]',
#  'P18B. HOUSEHOLD TYPE (BLACK OR AFRICAN AMERICAN ALONE HOUSEHOLDER) [9]',
#  'P18C. HOUSEHOLD TYPE (AMERICAN INDIAN AND ALASKA NATIVE ALONE HOUSEHOLDER) [9]',
#  'P18D. HOUSEHOLD TYPE (ASIAN ALONE HOUSEHOLDER) [9]',
#  'P18E. HOUSEHOLD TYPE (NATIVE HAWAIIAN AND OTHER PACIFIC ISLANDER ALONE HOUSEHOLDER) [9]',
#  'P18F. HOUSEHOLD TYPE (SOME OTHER RACE ALONE HOUSEHOLDER) [9]',
#  'P18G. HOUSEHOLD TYPE (TWO OR MORE RACES HOUSEHOLDER) [9]',
#  'P18H. HOUSEHOLD TYPE (HISPANIC OR LATINO HOUSEHOLDER) [9]',
#  'P18I. HOUSEHOLD TYPE (WHITE ALONE, NOT HISPANIC OR LATINO HOUSEHOLDER) [9]',
#  'P19. HOUSEHOLD SIZE BY HOUSEHOLD TYPE BY PRESENCE OF OWN CHILDREN [19]',
#  'P2. Urban And Rural [6]',
#  'P20. HOUSEHOLDS BY PRESENCE OF PEOPLE UNDER 18 YEARS BY HOUSEHOLD TYPE BY AGE OF PEOPLE UNDER 18 YEARS [34]',
#  'P21. HOUSEHOLDS BY AGE OF HOUSEHOLDER BY HOUSEHOLD TYPE BY PRESENCE OF RELATED CHILDREN [31]',
#  'P22. HOUSEHOLD TYPE BY AGE OF HOUSEHOLDER [21]',
#  'P23. HOUSEHOLDS BY PRESENCE OF PEOPLE 60 YEARS AND OVER BY HOUSEHOLD TYPE [15]',
#  'P24. HOUSEHOLDS BY PRESENCE OF PEOPLE 60 YEARS AND OVER, HOUSEHOLD SIZE, AND HOUSEHOLD TYPE [11]',
#  'P25. HOUSEHOLDS BY PRESENCE OF PEOPLE 65 YEARS AND OVER, HOUSEHOLD SIZE, AND HOUSEHOLD TYPE [11]',
#  'P26. HOUSEHOLDS BY PRESENCE OF PEOPLE 75 YEARS AND OVER, HOUSEHOLD SIZE, AND HOUSEHOLD TYPE [11]',
#  'P27. HOUSEHOLDS BY PRESENCE OF NONRELATIVES [3]',
#  'P28. HOUSEHOLD TYPE BY HOUSEHOLD SIZE [16]',
#  'P28A. HOUSEHOLD TYPE BY HOUSEHOLD SIZE (WHITE ALONE HOUSEHOLDER) [16]',
#  'P28B. HOUSEHOLD TYPE BY HOUSEHOLD SIZE (BLACK OR AFRICAN AMERICAN ALONE HOUSEHOLDER) [16]',
#  'P28C. HOUSEHOLD TYPE BY HOUSEHOLD SIZE (AMERICAN INDIAN AND ALASKA NATIVE ALONE HOUSEHOLDER) [16]',
#  'P28D. HOUSEHOLD TYPE BY HOUSEHOLD SIZE (ASIAN ALONE HOUSEHOLDER) [16]',
#  'P28E. HOUSEHOLD TYPE BY HOUSEHOLD SIZE (NATIVE HAWAIIAN AND OTHER PACIFIC ISLANDER ALONE HOUSEHOLDER) [16]',
#  'P28F. HOUSEHOLD TYPE BY HOUSEHOLD SIZE (SOME OTHER RACE ALONE HOUSEHOLDER) [16]',
#  'P28G. HOUSEHOLD TYPE BY HOUSEHOLD SIZE (TWO OR MORE RACES HOUSEHOLDER) [16]',
#  'P28H. HOUSEHOLD TYPE BY HOUSEHOLD SIZE (HISPANIC OR LATINO HOUSEHOLDER) [16]',
#  'P28I. HOUSEHOLD TYPE BY HOUSEHOLD SIZE (WHITE ALONE, NOT HISPANIC OR LATINO HOUSEHOLDER) [16]',
#  'P29. HOUSEHOLD TYPE BY RELATIONSHIP [28]',
#  'P29A. HOUSEHOLD TYPE BY RELATIONSHIP (WHITE ALONE) [28]',
#  'P29B. HOUSEHOLD TYPE BY RELATIONSHIP (BLACK OR AFRICAN AMERICAN ALONE) [28]',
#  'P29C. HOUSEHOLD TYPE BY RELATIONSHIP (AMERICAN INDIAN AND ALASKA NATIVE ALONE) [28]',
#  'P29D. HOUSEHOLD TYPE BY RELATIONSHIP (ASIAN ALONE) [28]',
#  'P29E. HOUSEHOLD TYPE BY RELATIONSHIP (NATIVE HAWAIIAN AND OTHER PACIFIC ISLANDER ALONE) [28]',
#  'P29F. HOUSEHOLD TYPE BY RELATIONSHIP (SOME OTHER RACE ALONE) [28]',
#  'P29G. HOUSEHOLD TYPE BY RELATIONSHIP (TWO OR MORE RACES) [28]',
#  'P29H. HOUSEHOLD TYPE BY RELATIONSHIP (HISPANIC OR LATINO) [28]',
#  'P29I. HOUSEHOLD TYPE BY RELATIONSHIP (WHITE ALONE, NOT HISPANIC OR LATINO) [28]',
#  'P3. RACE [8]',
#  'P30. HOUSEHOLD TYPE FOR THE POPULATION IN HOUSEHOLDS [13]',
#  'P31. HOUSEHOLD TYPE BY RELATIONSHIP FOR THE POPULATION UNDER 18 YEARS [16]',
#  'P31A. HOUSEHOLD TYPE BY RELATIONSHIP FOR THE POPULATION UNDER 18 YEARS (WHITE ALONE) [16]',
#  'P31B. HOUSEHOLD TYPE BY RELATIONSHIP FOR THE POPULATION UNDER 18 YEARS (BLACK OR AFRICAN AMERICAN ALONE) [16]',
#  'P31C. HOUSEHOLD TYPE BY RELATIONSHIP FOR THE POPULATION UNDER 18 YEARS (AMERICAN INDIAN AND ALASKA NATIVE ALONE) [16]',
#  'P31D. HOUSEHOLD TYPE BY RELATIONSHIP FOR THE POPULATION UNDER 18 YEARS (ASIAN ALONE) [16]',
#  'P31E. HOUSEHOLD TYPE BY RELATIONSHIP FOR THE POPULATION UNDER 18 YEARS (NATIVE HAWAIIAN AND OTHER PACIFIC ISLANDER ALONE) [16]',
#  'P31F. HOUSEHOLD TYPE BY RELATIONSHIP FOR THE POPULATION UNDER 18 YEARS (SOME OTHER RACE ALONE) [16]',
#  'P31G. HOUSEHOLD TYPE BY RELATIONSHIP FOR THE POPULATION UNDER 18 YEARS (TWO OR MORE RACES) [16]',
#  'P31H. HOUSEHOLD TYPE BY RELATIONSHIP FOR THE POPULATION UNDER 18 YEARS (HISPANIC OR LATINO) [16]',
#  'P31I. HOUSEHOLD TYPE BY RELATIONSHIP FOR THE POPULATION UNDER 18 YEARS (WHITE ALONE, NOT HISPANIC OR LATINO) [16]',
#  'P32. HOUSEHOLD TYPE BY RELATIONSHIP BY AGE FOR THE POPULATION UNDER 18 YEARS [45]',
#  'P33. HOUSEHOLD TYPE FOR THE POPULATION UNDER 18 YEARS IN HOUSEHOLDS (EXCLUDING HOUSEHOLDERS, SPOUSES, AND UNMARRIED PARTNERS) [7]',
#  'P34. HOUSEHOLD TYPE BY RELATIONSHIP FOR THE POPULATION 65 YEARS AND OVER [22]',
#  'P34A. HOUSEHOLD TYPE BY RELATIONSHIP FOR THE POPULATION 65 YEARS AND OVER (WHITE ALONE) [22]',
#  'P34B. HOUSEHOLD TYPE BY RELATIONSHIP FOR THE POPULATION 65 YEARS AND OVER (BLACK OR AFRICAN AMERICAN ALONE) [22]',
#  'P34C. HOUSEHOLD TYPE BY RELATIONSHIP FOR THE POPULATION 65 YEARS AND OVER (AMERICAN INDIAN AND ALASKA NATIVE ALONE) [22]',
#  'P34D. HOUSEHOLD TYPE BY RELATIONSHIP FOR THE POPULATION 65 YEARS AND OVER (ASIAN ALONE) [22]',
#  'P34E. HOUSEHOLD TYPE BY RELATIONSHIP FOR THE POPULATION 65 YEARS AND OVER (NATIVE HAWAIIAN AND OTHER PACIFIC ISLANDER ALONE) [22]',
#  'P34F. HOUSEHOLD TYPE BY RELATIONSHIP FOR THE POPULATION 65 YEARS AND OVER (SOME OTHER RACE ALONE) [22]',
#  'P34G. HOUSEHOLD TYPE BY RELATIONSHIP FOR THE POPULATION 65 YEARS AND OVER (TWO OR MORE RACES) [22]',
#  'P34H. HOUSEHOLD TYPE BY RELATIONSHIP FOR THE POPULATION 65 YEARS AND OVER (HISPANIC OR LATINO) [22]',
#  'P34I. HOUSEHOLD TYPE BY RELATIONSHIP FOR THE POPULATION 65 YEARS AND OVER (WHITE ALONE, NOT HISPANIC OR LATINO) [22]',
#  'P35. FAMILIES [1]',
#  'P35A. FAMILIES (WHITE ALONE HOUSEHOLDER) [1]',
#  'P35B. FAMILIES (BLACK OR AFRICAN AMERICAN ALONE HOUSEHOLDER) [1]',
#  'P35C. FAMILIES (AMERICAN INDIAN AND ALASKA NATIVE ALONE HOUSEHOLDER) [1]',
#  'P35D. FAMILIES (ASIAN ALONE HOUSEHOLDER) [1]',
#  'P35E. FAMILIES (NATIVE HAWAIIAN AND OTHER PACIFIC ISLANDER ALONE HOUSEHOLDER) [1]',
#  'P35F. FAMILIES (SOME OTHER RACE ALONE HOUSEHOLDER) [1]',
#  'P35G. FAMILIES (TWO OR MORE RACES HOUSEHOLDER) [1]',
#  'P35H. FAMILIES (HISPANIC OR LATINO HOUSEHOLDER) [1]',
#  'P35I. FAMILIES (WHITE ALONE, NOT HISPANIC OR LATINO HOUSEHOLDER) [1]',
#  'P36. POPULATION IN FAMILIES BY AGE [3]',
#  'P36A. POPULATION IN FAMILIES BY AGE (WHITE ALONE HOUSEHOLDER) [3]',
#  'P36B. POPULATION IN FAMILIES BY AGE (BLACK OR AFRICAN AMERICAN ALONE HOUSEHOLDER) [3]',
#  'P36C. POPULATION IN FAMILIES BY AGE (AMERICAN INDIAN AND ALASKA NATIVE ALONE HOUSEHOLDER) [3]',
#  'P36D. POPULATION IN FAMILIES BY AGE (ASIAN ALONE HOUSEHOLDER) [3]',
#  'P36E. POPULATION IN FAMILIES BY AGE (NATIVE HAWAIIAN AND OTHER PACIFIC ISLANDER ALONE HOUSEHOLDER) [3]',
#  'P36F. POPULATION IN FAMILIES BY AGE (SOME OTHER RACE ALONE HOUSEHOLDER) [3]',
#  'P36G. POPULATION IN FAMILIES BY AGE (TWO OR MORE RACES HOUSEHOLDER) [3]',
#  'P36H. POPULATION IN FAMILIES BY AGE (HISPANIC OR LATINO HOUSEHOLDER) [3]',
#  'P36I. POPULATION IN FAMILIES BY AGE (WHITE ALONE, NOT HISPANIC OR LATINO HOUSEHOLDER) [3]',
#  'P37. AVERAGE FAMILY SIZE BY AGE [3] (2 expressed decimals)',
#  'P37A. AVERAGE FAMILY SIZE BY AGE (WHITE ALONE HOUSEHOLDER) [3] (2 expressed decimals)',
#  'P37B. AVERAGE FAMILY SIZE BY AGE (BLACK OR AFRICAN AMERICAN ALONE HOUSEHOLDER) [3]',
#  'P37C. AVERAGE FAMILY SIZE BY AGE (AMERICAN INDIAN AND ALASKA NATIVE ALONE HOUSEHOLDER) [3] (2 expressed decimals)',
#  'P37D. AVERAGE FAMILY SIZE BY AGE (ASIAN ALONE HOUSEHOLDER) [3] (2 expressed decimals)',
#  'P37E. AVERAGE FAMILY SIZE BY AGE (NATIVE HAWAIIAN AND OTHER PACIFIC ISLANDER ALONE HOUSEHOLDER) [3] (2 expressed decimals)',
#  'P37F. AVERAGE FAMILY SIZE BY AGE (SOME OTHER RACE ALONE HOUSEHOLDER) [3] (2 expressed decimals)',
#  'P37G. AVERAGE FAMILY SIZE BY AGE (TWO OR MORE RACES HOUSEHOLDER) [3] (2 expressed decimals)',
#  'P37H. AVERAGE FAMILY SIZE BY AGE (HISPANIC OR LATINO HOUSEHOLDER) [3] (2 expressed decimals)',
#  'P37I. AVERAGE FAMILY SIZE BY AGE (WHITE ALONE, NOT HISPANIC OR LATINO HOUSEHOLDER) [3] (2 expressed decimals)',
#  'P38. FAMILY TYPE BY PRESENCE AND AGE OF OWN CHILDREN [20]',
#  'P38A. FAMILY TYPE BY PRESENCE AND AGE OF OWN CHILDREN (WHITE ALONE HOUSEHOLDER) [20]',
#  'P38B. FAMILY TYPE BY PRESENCE AND AGE OF OWN CHILDREN (BLACK OR AFRICAN AMERICAN ALONE HOUSEHOLDER) [20]',
#  'P38C. FAMILY TYPE BY PRESENCE AND AGE OF OWN CHILDREN (AMERICAN INDIAN AND ALASKA NATIVE ALONE HOUSEHOLDER) [20]',
#  'P38D. FAMILY TYPE BY PRESENCE AND AGE OF OWN CHILDREN (ASIAN ALONE HOUSEHOLDER) [20]',
#  'P38E. FAMILY TYPE BY PRESENCE AND AGE OF OWN CHILDREN (NATIVE HAWAIIAN AND OTHER PACIFIC ISLANDER ALONE HOUSEHOLDER) [20]',
#  'P38F. FAMILY TYPE BY PRESENCE AND AGE OF OWN CHILDREN (SOME OTHER RACE ALONE HOUSEHOLDER) [20]',
#  'P38G. FAMILY TYPE BY PRESENCE AND AGE OF OWN CHILDREN (TWO OR MORE RACES HOUSEHOLDER) [20]',
#  'P38H. FAMILY TYPE BY PRESENCE AND AGE OF OWN CHILDREN (HISPANIC OR LATINO HOUSEHOLDER) [20]',
#  'P38I. FAMILY TYPE BY PRESENCE AND AGE OF OWN CHILDREN (WHITE ALONE, NOT HISPANIC OR LATINO HOUSEHOLDER) [20]',
#  'P39. FAMILY TYPE BY PRESENCE AND AGE OF RELATED CHILDREN [20]',
#  'P39A. FAMILY TYPE BY PRESENCE AND AGE OF RELATED CHILDREN (WHITE ALONE HOUSEHOLDER) [20]',
#  'P39B. FAMILY TYPE BY PRESENCE AND AGE OF RELATED CHILDREN (BLACK OR AFRICAN AMERICAN ALONE HOUSEHOLDER) [20]',
#  'P39C. FAMILY TYPE BY PRESENCE AND AGE OF RELATED CHILDREN (AMERICAN INDIAN AND ALASKA NATIVE ALONE HOUSEHOLDER) [20]',
#  'P39D. FAMILY TYPE BY PRESENCE AND AGE OF RELATED CHILDREN (ASIAN ALONE HOUSEHOLDER) [20]',
#  'P39E. FAMILY TYPE BY PRESENCE AND AGE OF RELATED CHILDREN (NATIVE HAWAIIAN AND OTHER PACIFIC ISLANDER ALONE HOUSEHOLDER) [20]',
#  'P39F. FAMILY TYPE BY PRESENCE AND AGE OF RELATED CHILDREN (SOME OTHER RACE ALONE HOUSEHOLDER) [20]',
#  'P39G. FAMILY TYPE BY PRESENCE AND AGE OF RELATED CHILDREN (TWO OR MORE RACES HOUSEHOLDER) [20]',
#  'P39H. FAMILY TYPE BY PRESENCE AND AGE OF RELATED CHILDREN (HISPANIC OR LATINO HOUSEHOLDER) [20]',
#  'P39I. FAMILY TYPE BY PRESENCE AND AGE OF RELATED CHILDREN (WHITE ALONE, NOT HISPANIC OR LATINO HOUSEHOLDER) [20]',
#  'P4. HISPANIC OR LATINO ORIGIN [3]',
#  'P40. FAMILY TYPE AND AGE FOR OWN CHILDREN UNDER 18 YEARS [20]',
#  'P41. AGE OF GRANDCHILDREN UNDER 18 YEARS LIVING WITH A GRANDPARENT HOUSEHOLDER [6]',
#  'P42. GROUP QUARTERS POPULATION BY GROUP QUARTERS TYPE [10]',
#  'P43. GROUP QUARTERS POPULATION BY SEX BY AGE BY GROUP QUARTERS TYPE [63]',
#  'P44. POPULATION SUBSTITUTED [3]',
#  'P45. ALLOCATION OF POPULATION ITEMS [3]',
#  'P46. ALLOCATION OF RACE [3]',
#  'P47. ALLOCATION OF HISPANIC OR LATINO ORIGIN [3]',
#  'P48. ALLOCATION OF SEX [3]',
#  'P49. ALLOCATION OF AGE [3]',
#  'P5. HISPANIC OR LATINO ORIGIN BY RACE [17]',
#  'P50. ALLOCATION OF RELATIONSHIP [3]',
#  'P51. ALLOCATION OF POPULATION ITEMS FOR THE POPULATION IN GROUP QUARTERS [3]',
#  'P6. RACE (TOTAL RACES TALLIED) [7]',
#  'P7. HISPANIC OR LATINO ORIGIN BY RACE (TOTAL RACES TALLIED) [15]',
#  'P8. RACE [71]',
#  'P9. HISPANIC OR LATINO, AND NOT HISPANIC OR LATINO BY RACE [73]',
#  'PCO1. GROUP QUARTERS POPULATION BY SEX BY AGE [39]',
#  'PCO10. GROUP QUARTERS POPULATION IN OTHER NONINSTITUTIONAL FACILITIES BY SEX BY AGE [39]',
#  'PCO2. GROUP QUARTERS POPULATION IN INSTITUTIONAL FACILITIES BY SEX BY AGE [39]',
#  'PCO3. GROUP QUARTERS POPULATION IN CORRECTIONAL FACILITIES FOR ADULTS BY SEX BY AGE [39]',
#  'PCO4. GROUP QUARTERS POPULATION IN JUVENILE FACILITIES BY SEX BY AGE [39]',
#  'PCO5. GROUP QUARTERS POPULATION IN NURSING FACILITIES/SKILLED-NURSING FACILITIES BY SEX BY AGE [39]',
#  'PCO6. GROUP QUARTERS POPULATION IN OTHER INSTITUTIONAL FACILITIES BY SEX BY AGE [39]',
#  'PCO7. GROUP QUARTERS POPULATION IN NONINSTITUTIONAL FACILITIES BY SEX BY AGE [39]',
#  'PCO8. GROUP QUARTERS POPULATION IN COLLEGE/UNIVERSITY STUDENT HOUSING BY SEX BY AGE [39]',
#  'PCO9. GROUP QUARTERS POPULATION IN MILITARY QUARTERS BY SEX BY AGE [39]',
#  'PCT1. AMERICAN INDIAN AND ALASKA NATIVE ALONE WITH ONE TRIBE REPORTED FOR SELECTED TRIBES [54]',
#  'PCT10. NATIVE HAWAIIAN AND OTHER PACIFIC ISLANDER ALONE OR IN COMBINATION WITH ONE OR MORE RACES, AND WITH ONE OR MORE NATIVE HAWAIIAN AND OTHER PACIFIC ISLANDER CATEGORIES FOR SELECTED GROUPS [14]',
#  'PCT11. Hispanic Or Latino By Specific Origin [31]',
#  'PCT12. Sex By Age [209]',
#  'PCT12A. Sex By Age (White Alone) [209]',
#  'PCT12B. Sex By Age (Black Or African American Alone) [209]',
#  'PCT12C. Sex By Age (American Indian And Alaska Native Alone) [209]',
#  'PCT12D. Sex By Age (Asian Alone) [209]',
#  'PCT12E. Sex By Age (Native Hawaiian And Other Pacific Islander Alone) [209]',
#  'PCT12F. Sex By Age (Some Other Race Alone) [209]',
#  'PCT12G. Sex By Age (Two Or More Races) [209]',
#  'PCT12H. Sex By Age (Hispanic Or Latino) [209]',
#  'PCT12I. SEX BY AGE (WHITE ALONE, NOT HISPANIC OR LATINO) [209]',
#  'PCT12J. Sex By Age (Black Or African American Alone, Not Hispanic Or Latino) [209]',
#  'PCT12K. SEX BY AGE (AMERICAN INDIAN AND ALASKA NATIVE ALONE, NOT HISPANIC OR LATINO) [209]',
#  'PCT12L. Sex By Age (Asian Alone, Not Hispanic Or Latino) [209]',
#  'PCT12M. Sex By Age (Native Hawaiian And Other Pacific Islander Alone, Not Hispanic Or Latino) [209]',
#  'PCT12N. Sex By Age (Some Other Race Alone, Not Hispanic Or Latino) [209]',
#  'PCT12O. Sex By Age (Two Or More Races, Not Hispanic Or Latino) [209]',
#  'PCT13. SEX BY AGE FOR THE POPULATION IN HOUSEHOLDS [49]',
#  'PCT13A. SEX BY AGE FOR THE POPULATION IN HOUSEHOLDS (WHITE ALONE) [49]',
#  'PCT13B. SEX BY AGE FOR THE POPULATION IN HOUSEHOLDS (BLACK OR AFRICAN AMERICAN ALONE) [49]',
#  'PCT13C. SEX BY AGE FOR THE POPULATION IN HOUSEHOLDS (AMERICAN INDIAN AND ALASKA NATIVE ALONE) [49]',
#  'PCT13D. SEX BY AGE FOR THE POPULATION IN HOUSEHOLDS (ASIAN ALONE) [49]',
#  'PCT13E. SEX BY AGE FOR THE POPULATION IN HOUSEHOLDS (NATIVE HAWAIIAN AND OTHER PACIFIC ISLANDER ALONE) [49]',
#  'PCT13F. SEX BY AGE FOR THE POPULATION IN HOUSEHOLDS (SOME OTHER RACE ALONE) [49]',
#  'PCT13G. SEX BY AGE FOR THE POPULATION IN HOUSEHOLDS (TWO OR MORE RACES) [49]',
#  'PCT13H. SEX BY AGE FOR THE POPULATION IN HOUSEHOLDS (HISPANIC OR LATINO) [49]',
#  'PCT13I. SEX BY AGE FOR THE POPULATION IN HOUSEHOLDS (WHITE ALONE, NOT HISPANIC OR LATINO) [49]',
#  'PCT14. PRESENCE OF MULTIGENERATIONAL HOUSEHOLDS [3]',
#  'PCT14A. PRESENCE OF MULTIGENERATIONAL HOUSEHOLDS (WHITE ALONE HOUSEHOLDER) [3]',
#  'PCT14B. PRESENCE OF MULTIGENERATIONAL HOUSEHOLDS (BLACK OR AFRICAN AMERICAN ALONE HOUSEHOLDER) [3]',
#  'PCT14C. PRESENCE OF MULTIGENERATIONAL HOUSEHOLDS (AMERICAN INDIAN AND ALASKA NATIVE ALONE HOUSEHOLDER) [3]',
#  'PCT14D. PRESENCE OF MULTIGENERATIONAL HOUSEHOLDS (ASIAN ALONE HOUSEHOLDER) [3]',
#  'PCT14E. PRESENCE OF MULTIGENERATIONAL HOUSEHOLDS (NATIVE HAWAIIAN AND OTHER PACIFIC ISLANDER ALONE HOUSEHOLDER) [3]',
#  'PCT14F. PRESENCE OF MULTIGENERATIONAL HOUSEHOLDS (SOME OTHER RACE ALONE HOUSEHOLDER) [3]',
#  'PCT14G. PRESENCE OF MULTIGENERATIONAL HOUSEHOLDS (TWO OR MORE RACES HOUSEHOLDER) [3]',
#  'PCT14H. PRESENCE OF MULTIGENERATIONAL HOUSEHOLDS (HISPANIC OR LATINO HOUSEHOLDER) [3]',
#  'PCT14I. PRESENCE OF MULTIGENERATIONAL HOUSEHOLDS (WHITE ALONE, NOT HISPANIC OR LATINO HOUSEHOLDER) [3]',
#  'PCT15. HUSBAND-WIFE AND UNMARRIED-PARTNER HOUSEHOLDS BY SEX OF PARTNER BY PRESENCE OF RELATED AND OWN CHILDREN UNDER 18 YEARS [34]',
#  'PCT16. HOUSEHOLD TYPE BY NUMBER OF PEOPLE UNDER 18 YEARS (EXCLUDING HOUSEHOLDERS, SPOUSES, AND UNMARRIED PARTNERS) [26]',
#  'PCT17. PRESENCE OF UNMARRIED PARTNER OF HOUSEHOLDER BY HOUSEHOLD TYPE FOR THE POPULATION UNDER 18 YEARS IN HOUSEHOLDS (EXCLUDING HOUSEHOLDERS, SPOUSES, AND UNMARRIED PARTNERS) [18]',
#  'PCT18. NONFAMILY HOUSEHOLDS BY SEX OF HOUSEHOLDER BY LIVING ALONE BY AGE OF HOUSEHOLDER [15]',
#  'PCT19. NONRELATIVES BY HOUSEHOLD TYPE [11]',
#  'PCT19A. NONRELATIVES BY HOUSEHOLD TYPE (WHITE ALONE) [11]',
#  'PCT19B. NONRELATIVES BY HOUSEHOLD TYPE (BLACK OR AFRICAN AMERICAN ALONE) [11]',
#  'PCT19C. NONRELATIVES BY HOUSEHOLD TYPE (AMERICAN INDIAN AND ALASKA NATIVE ALONE) [11]',
#  'PCT19D. NONRELATIVES BY HOUSEHOLD TYPE (ASIAN ALONE) [11]',
#  'PCT19E. NONRELATIVES BY HOUSEHOLD TYPE (NATIVE HAWAIIAN AND OTHER PACIFIC ISLANDER ALONE) [11]',
#  'PCT19F. NONRELATIVES BY HOUSEHOLD TYPE (SOME OTHER RACE ALONE) [11]',
#  'PCT19G. NONRELATIVES BY HOUSEHOLD TYPE (TWO OR MORE RACES) [11]',
#  'PCT19H. NONRELATIVES BY HOUSEHOLD TYPE (HISPANIC OR LATINO) [11]',
#  'PCT19I. NONRELATIVES BY HOUSEHOLD TYPE (WHITE ALONE, NOT HISPANIC OR LATINO) [11]',
#  'PCT2. AMERICAN INDIAN AND ALASKA NATIVE ALONE WITH ONE OR MORE TRIBES REPORTED FOR SELECTED TRIBES [54]',
#  'PCT20. GROUP QUARTERS POPULATION BY GROUP QUARTERS TYPE [32]',
#  'PCT20A. GROUP QUARTERS POPULATION BY GROUP QUARTERS TYPE (WHITE ALONE) [32]',
#  'PCT20B. GROUP QUARTERS POPULATION BY GROUP QUARTERS TYPE (BLACK OR AFRICAN AMERICAN ALONE) [32]',
#  'PCT20C. GROUP QUARTERS POPULATION BY GROUP QUARTERS TYPE (AMERICAN INDIAN AND ALASKA NATIVE ALONE) [32]',
#  'PCT20D. GROUP QUARTERS POPULATION BY GROUP QUARTERS TYPE (ASIAN ALONE) [32]',
#  'PCT20E. GROUP QUARTERS POPULATION BY GROUP QUARTERS TYPE (NATIVE HAWAIIAN AND OTHER PACIFIC ISLANDER ALONE) [32]',
#  'PCT20F. GROUP QUARTERS POPULATION BY GROUP QUARTERS TYPE (SOME OTHER RACE ALONE) [32]',
#  'PCT20G. GROUP QUARTERS POPULATION BY GROUP QUARTERS TYPE (TWO OR MORE RACES) [32]',
#  'PCT20H. GROUP QUARTERS POPULATION BY GROUP QUARTERS TYPE (HISPANIC OR LATINO) [32]',
#  'PCT20I. GROUP QUARTERS POPULATION BY GROUP QUARTERS TYPE (WHITE ALONE, NOT HISPANIC OR LATINO) [32]',
#  'PCT21. GROUP QUARTERS POPULATION BY SEX BY AGE BY GROUP QUARTERS TYPE [195]',
#  'PCT22. GROUP QUARTERS POPULATION BY SEX BY GROUP QUARTERS TYPE FOR THE POPULATION 18 YEARS AND OVER [21]',
#  'PCT22A. GROUP QUARTERS POPULATION BY SEX BY GROUP QUARTERS TYPE FOR THE POPULATION 18 YEARS AND OVER (WHITE ALONE)',
#  'PCT22B. GROUP QUARTERS POPULATION BY SEX BY GROUP QUARTERS TYPE FOR THE POPULATION 18 YEARS AND OVER (BLACK OR AFRICAN AMERICAN ALONE) [21]',
#  'PCT22C. GROUP QUARTERS POPULATION BY SEX BY GROUP QUARTERS TYPE FOR THE POPULATION 18 YEARS AND OVER (AMERICAN INDIAN AND ALASKA NATIVE ALONE) [21]',
#  'PCT22D. GROUP QUARTERS POPULATION BY SEX BY GROUP QUARTERS TYPE FOR THE POPULATION 18 YEARS AND OVER (ASIAN ALONE)',
#  'PCT22E. GROUP QUARTERS POPULATION BY SEX BY GROUP QUARTERS TYPE FOR THE POPULATION 18 YEARS AND OVER (NATIVEHAWAIIAN AND OTHER PACIFIC ISLANDER ALONE) [21]',
#  'PCT22F. GROUP QUARTERS POPULATION BY SEX BY GROUP QUARTERS TYPE FOR THE POPULATION 18 YEARS AND OVER (SOME OTHER RACE ALONE) [21]',
#  'PCT22G. GROUP QUARTERS POPULATION BY SEX BY GROUP QUARTERS TYPE FOR THE POPULATION 18 YEARS AND OVER (TWO OR MORE RACES) [21]',
#  'PCT22H. GROUP QUARTERS POPULATION BY SEX BY GROUP QUARTERS TYPE FOR THE POPULATION 18 YEARS AND OVER (HISPANIC OR LATINO) [21]',
#  'PCT22I. GROUP QUARTERS POPULATION BY SEX BY GROUP QUARTERS TYPE FOR THE POPULATION 18 YEARS AND OVER (WHITE ALONE, NOT HISPANIC OR LATINO) [21]',
#  'PCT3. AMERICAN INDIAN AND ALASKA NATIVE ALONE OR IN COMBINATION WITH ONE OR MORE OTHER RACES AND WITH ONE OR MORE TRIBES REPORTED FOR SELECTED TRIBES [54]',
#  'PCT4. American Indian And Alaska Native Alone Or In Combination With One Or More Other Races [9]',
#  'PCT5. ASIAN ALONE WITH ONE ASIAN CATEGORY FOR SELECTED GROUPS [22]',
#  'PCT6. ASIAN ALONE WITH ONE OR MORE ASIAN CATEGORIES FOR SELECTED GROUPS [22]',
#  'PCT7. ASIAN ALONE OR IN COMBINATION WITH ONE OR MORE OTHER RACES, AND WITH ONE OR MORE ASIAN CATEGORIES FOR SELECTED GROUPS [22]',
#  'PCT8. Native Hawaiian And Other Pacific Islander Alone With One Native Hawaiian And Other Pacific Islander Category For Selected Groups [14]',
#  'PCT9. Native Hawaiian And Other Pacific Islander Alone With One Or More Native Hawaiian And Other Pacific Islander Categories For Selected Groups [14]']

# %% [markdown]
# Let's parse more of pieces that are in the fields

# %%
# let's just parse sf1.xml ourselves to get the concepts
# http://lxml.de/parsing.html

from lxml import etree
from itertools import islice
import re

def parse_concept_name(concept_name):
    if concept_name != 'Geographic Characteristics':
        m = re.search("(.+\.)\s+(.*)\s+(\[\d+\])",concept_name)
        if m: 
           return {'label':m.group(1),
                  'clean_name':m.group(2),
                  'num_vars':re.search("\[(\d+)\]", m.group(3)).group(1)
                  }
       # print m.groups()
        else:
           m1 = re.search("(.+\.)\s+(.*)\s+",concept_name)
           return {'label':m1.group(1),
                  'clean_name':m1.group(2),
                  'num_vars':0
                 }
    else:
        return None
    
def concepts_2010_sf1():
    # http://www.census.gov/developers/data/sf1.xml
    SF1_XML_PATH  = "/Users/raymondyee/D/Document/Working_with_Open_Data/working-open-data-2014/data/sf1.xml"

    doc = etree.parse(SF1_XML_PATH)
    for concept in doc.findall("//concept"):
        concept_name = concept.attrib['name']
        
        if concept_name != 'Geographic Characteristics':
            m = re.search("(.+\.)\s+(.*)\s+(\[\d+\])",concept_name)
            if m: 
               yield {'label':m.group(1),
                      'clean_name':m.group(2),
                      'num_vars':re.search("\[(\d+)\]", m.group(3)).group(1)
                      }
           # print m.groups()
            else:
               m1 = re.search("(.+\.)\s+(.*)\s+",concept_name)
               yield {'label':m1.group(1),
                      'clean_name':m1.group(2),
                      'num_vars':0
                     }
            
k = list(concepts_2010_sf1())

# %%
df = DataFrame(k, columns=('label','clean_name','num_vars'))
df.head()
# Out:
#    label                                         clean_name num_vars
# 0    H1.                                      Housing Units        1
# 1   H10.         TOTAL POPULATION IN OCCUPIED HOUSING UNITS        1
# 2   H11.  TOTAL POPULATION IN OCCUPIED HOUSING UNITS BY ...        4
# 3  H11A.  TOTAL POPULATION IN OCCUPIED HOUSING UNITS BY ...        4
# 4  H11B.  TOTAL POPULATION IN OCCUPIED HOUSING UNITS BY ...        4
#
# [5 rows x 3 columns]

# %%
import re

def sort_label(label):
    (l1, l2, l3) = re.search("([A-Z,a-z]+)(\d+)([A-Z,a-z]*)\.",label).groups()
    return l1 + " " + "{l2:03d}".format(l2=int(l2)) + l3

df['sort_label'] = df.label.apply(sort_label)

# %%
df[df.label.str.startswith("P5")]
# Out:
#     label                                         clean_name num_vars  \
# 232   P5.                  HISPANIC OR LATINO ORIGIN BY RACE       17
# 233  P50.                         ALLOCATION OF RELATIONSHIP        3
# 234  P51.  ALLOCATION OF POPULATION ITEMS FOR THE POPULAT...        3
#
#     sort_label
# 232      P 005
# 233      P 050
# 234      P 051
#
# [3 rows x 4 columns]

# %%
# let's go right for the variables and generate a dict, DF

from lxml import etree
from itertools import islice
from collections import OrderedDict

SF1_XML_PATH  = "/Users/raymondyee/D/Document/Working_with_Open_Data/working-open-data-2014/data/sf1.xml"

doc = etree.parse(SF1_XML_PATH)
variables = doc.findall("//variable")

variables_dict = OrderedDict([(v.attrib['name'], 
                               {'concept':v.attrib['concept'],
                                'text': v.text
                                }) for v in variables])

# %%
variables_dict['P0050001']
# Out:
# {'concept': 'P5. HISPANIC OR LATINO ORIGIN BY RACE [17]',
#  'text': ' Total population '}

# %%
def P005_range(n0,n1): 
    return tuple(('P005'+ "{i:04d}".format(i=i) for i in xrange(n0,n1)))

P005_vars = P005_range(1,18)
P005_vars_str = ",".join(P005_vars)

[(v,variables_dict[v]['text']) for v in P005_vars]
# Out:
# [('P0050001', ' Total population '),
#  ('P0050002', ' Not Hispanic or Latino: '),
#  ('P0050003', ' Not Hispanic or Latino: !! White alone '),
#  ('P0050004', ' Not Hispanic or Latino: !! Black or African American alone '),
#  ('P0050005',
#   ' Not Hispanic or Latino: !! American Indian and Alaska Native alone '),
#  ('P0050006', ' Not Hispanic or Latino: !! Asian alone '),
#  ('P0050007',
#   ' Not Hispanic or Latino: !! Native Hawaiian and Other Pacific Islander alone '),
#  ('P0050008', ' Not Hispanic or Latino: !! Some Other Race alone '),
#  ('P0050009', ' Not Hispanic or Latino: !! Two or More Races '),
#  ('P0050010', ' Hispanic or Latino: '),
#  ('P0050011', ' Hispanic or Latino: !! White alone '),
#  ('P0050012', ' Hispanic or Latino: !! Black or African American alone '),
#  ('P0050013',
#   ' Hispanic or Latino: !! American Indian and Alaska Native alone '),
#  ('P0050014', ' Hispanic or Latino: !! Asian alone '),
#  ('P0050015',
#   ' Hispanic or Latino: !! Native Hawaiian and Other Pacific Islander alone '),
#  ('P0050016', ' Hispanic or Latino: !! Some Other Race alone '),
#  ('P0050017', ' Hispanic or Latino: !! Two or More Races ')]

# %%
variables_df = DataFrame(variables_dict)
variables_df.head()
# Out:
#                                                   AIANHHCC  \
# concept                         Geographic Characteristics
# text      FIPS American Indian Area/Alaska Native Area/...
#
#                                                   AIANHHFP  \
# concept                         Geographic Characteristics
# text      American Indian Area/Alaska Native Area/Hawai...
#
#                                                    AIHHTLI  \
# concept                         Geographic Characteristics
# text      American Indian Trust Land/Hawaiian Home Land...
#
#                                                 AITS  \
# concept                   Geographic Characteristics
# text      American Indian Tribal Subdivision (FIPS)
#
#                                                     AITSCC  \
# concept                         Geographic Characteristics
# text      FIPS American Indian Tribal Subdivision Class...
#
#                                                 AITSCE  \
# concept                     Geographic Characteristics
# text      American Indian Tribal Subdivision (Census)
#
#                                                 ANRC  \
# concept                   Geographic Characteristics
# text      Alaska Native Regional Corporation (FIPS)
#
#                                                    CBSAPCI  \
# concept                         Geographic Characteristics
# text      Metropolitan Statistical Area/Micropolitan St...
#
#                                              CD113  \
# concept                 Geographic Characteristics
# text      Congressional District - 113th Congress
#
#                                    CNECTA                       CONCITSC  \
# concept        Geographic Characteristics     Geographic Characteristics
# text      New England City and Town Area    Consolidated City Size Code
#
#                             GEOCOMP  \
# concept  Geographic Characteristics
# text          Geographic Component
#
#                                                   LOGRECNO  \
# concept                         Geographic Characteristics
# text      Logical Record Number (State Based Geography ...
#
#                                                MEMI  \
# concept                  Geographic Characteristics
# text      Metropolitan/Micropolitan Indicator Flag
#
#                              METDIV                        NAME  \
# concept  Geographic Characteristics  Geographic Characteristics
# text         Metropolitan Division        Geographic Area Name
#
#                                           NECTADIV  \
# concept                 Geographic Characteristics
# text      New England City and Town Area Division
#
#                                                   NECTAPCI  \
# concept                         Geographic Characteristics
# text      New England City and Town Area Principal City...
#
#                             PLACECC                               SLDL2
# concept  Geographic Characteristics          Geographic Characteristics ...
# text         FIPS Place Class Code    State Legislative District Lower  ...
#
# [2 rows x 8945 columns]

# %%
variables_df.T.concept.apply(parse_concept_name)
# Out:
# AIANHHCC    None
# AIANHHFP    None
# AIHHTLI     None
# AITS        None
# AITSCC      None
# AITSCE      None
# ANRC        None
# CBSAPCI     None
# CD113       None
# CNECTA      None
# CONCITSC    None
# GEOCOMP     None
# LOGRECNO    None
# MEMI        None
# METDIV      None
# ...
# PCT0080014    {u'clean_name': u'Native Hawaiian And Other Pa...
# PCT0090001    {u'clean_name': u'Native Hawaiian And Other Pa...
# PCT0090002    {u'clean_name': u'Native Hawaiian And Other Pa...
# PCT0090003    {u'clean_name': u'Native Hawaiian And Other Pa...
# PCT0090004    {u'clean_name': u'Native Hawaiian And Other Pa...
# PCT0090005    {u'clean_name': u'Native Hawaiian And Other Pa...
# PCT0090006    {u'clean_name': u'Native Hawaiian And Other Pa...
# PCT0090007    {u'clean_name': u'Native Hawaiian And Other Pa...
# PCT0090008    {u'clean_name': u'Native Hawaiian And Other Pa...
# PCT0090009    {u'clean_name': u'Native Hawaiian And Other Pa...
# PCT0090010    {u'clean_name': u'Native Hawaiian And Other Pa...
# PCT0090011    {u'clean_name': u'Native Hawaiian And Other Pa...
# PCT0090012    {u'clean_name': u'Native Hawaiian And Other Pa...
# PCT0090013    {u'clean_name': u'Native Hawaiian And Other Pa...
# PCT0090014    {u'clean_name': u'Native Hawaiian And Other Pa...
# Name: concept, Length: 8945, dtype: object

# %%
parse_concept_name(variables_dict['P0050001']['concept'])
# Out:
# {'clean_name': 'HISPANIC OR LATINO ORIGIN BY RACE',
#  'label': 'P5.',
#  'num_vars': '17'}

# %% [markdown]
# # api.json

# %%
# http://www.census.gov/developers/

import requests
url = "http://api.census.gov/data.json"
api_json = requests.get(url).json()
api_json
# Out:
# [{u'accessLevel': u'public',
#   u'c_dataset': [u'acs5'],
#   u'c_documentationLink': u'http://www.census.gov/developers/',
#   u'c_geographyLink': u'http://api.census.gov/data/2010/acs5/geography.json',
#   u'c_isAggregate': True,
#   u'c_tagsLink': u'http://api.census.gov/data/2010/acs5/tags.json',
#   u'c_variablesLink': u'http://api.census.gov/data/2010/acs5/variables.json',
#   u'c_vintage': 2010,
#   u'contactPoint': u'Census Bureau Call Center',
#   u'description': u"The American Community Survey (ACS) is a nationwide survey designed to provide communities a fresh look at how they are changing. The ACS replaced the decennial census long form in 2010 and thereafter by collecting long form type information throughout the decade rather than only once every 10 years.  Questionnaires are mailed to a sample of addresses to obtain information about households -- that is, about each person and the housing unit itself.  The American Community Survey produces demographic, social, housing and economic estimates in the form of 1-year, 3-year and 5-year estimates based on population thresholds. The strength of the ACS is in estimating population and housing characteristics. It produces estimates for small areas, including census tracts and population subgroups.  Although the ACS produces population, demographic and housing unit estimates,it is the Census Bureau's Population Estimates Program that produces and disseminates the official estimates of the population for the nation, states, counties, cities and towns, and estimates of housing units for states and counties.  For 2010 and other decennial census years, the Decennial Census provides the official counts of population and housing units.",
#   u'identifier': u'2010acs5',
#   u'mbox': u'pio@census.gov',
#   u'publisher': u'US Census Bureau',
#   u'references': [u'http://www.census.gov/developers/'],
#   u'spatial': u'US',
#   u'temporal': u'2010',
#   u'title': u'2010 American Community Survey: 5-Year Estimates',
#   u'webService': u'http://api.census.gov/data/2010/acs5'},
#  {u'accessLevel': u'public',
#   u'c_dataset': [u'sf1'],
#   u'c_documentationLink': u'http://www.census.gov/developers/',
#   u'c_geographyLink': u'http://api.census.gov/data/1990/sf1/geography.json',
#   u'c_isAggregate': True,
#   u'c_tagsLink': u'http://api.census.gov/data/1990/sf1/tags.json',
#   u'c_variablesLink': u'http://api.census.gov/data/1990/sf1/variables.json',
#   u'c_vintage': 1990,
#   u'contactPoint': u'Census Bureau Call Center',
#   u'description': u'Data files available from Census 2000 and the 2010 Census. This file presents 100-percent population and housing figures for the total population, for 63 race categories, and for many other race and Hispanic or Latino categories. This includes age, sex, households, household relationship, housing units, occupancy status, and tenure (whether the residence is owned or rented). Also included are selected characteristics for a limited number of race and Hispanic or Latino categories. The data are available for the U.S., regions, divisions, states, counties, county subdivisions, places, census tracts, block groups, blocks, metropolitan areas (2000), core based statistical areas (2010), American Indian and Alaska Native areas, tribal subdivisions, Hawaiian home lands, congressional districts, and ZIP Code Tabulation Areas. Data are available down to the block level for many tabulations, but only to the census-tract level for others. The 2010 Census SF 1 has some tables on the population in group quarters that are available only to the county level. Available on DVD and American FactFinder.  The Census 2000 Summary File 1 data were released in three stages. Individual state files and two national files were released. The state-level data were released first, followed by the Advance National File, which covered the same data subjects, but includes national level summary data for areas that cross state boundaries such as whole metropolitan areas, whole American Indian areas, etc. The Final National File contains the same data subjects and geographic areas as the Advance National File, but adds the first available urban/rural and urbanized area data. For the most current release dates for these files, see the "Census 2000 Release Schedule" link on the AFFAmerican FactFinder Main Page.  The 2010 Census Summaray File 1 data were released in stages. Individual state files and a national update were released in 2011. The SF 1 urban/rural update is planned for release in Fall 2012. This file contains the same data subjects as the previously released files, but for additional geography, including the urban and rural parts of the United States, regions, divisions, states, counties, and places; and urbanized areas and urban clusters. See the 2010 Census Data Products At A Glance',
#   u'identifier': u'1990sf1',
#   u'mbox': u'pio@census.gov',
#   u'publisher': u'U.S. Census Bureau',
#   u'references': [u'http://www.census.gov/developers/'],
#   u'spatial': u'US',
#   u'temporal': u'1990',
#   u'title': u'1990 Decennial: Summary File 1',
#   u'webService': u'http://api.census.gov/data/1990/sf1'},
#  {u'accessLevel': u'public',
#   u'c_dataset': [u'acs1', u'cd113'],
#   u'c_documentationLink': u'http://www.census.gov/developers/',
#   u'c_geographyLink': u'http://api.census.gov/data/2011/acs1/cd113/geography.json',
#   u'c_isAggregate': True,
#   u'c_tagsLink': u'http://api.census.gov/data/2011/acs1/cd113/tags.json',
#   u'c_variablesLink': u'http://api.census.gov/data/2011/acs1/cd113/variables.json',
#   u'c_vintage': 2011,
#   u'contactPoint': u'Census Bureau Call Center',
#   u'description': u"The American Community Survey (ACS) is a nationwide survey designed to provide communities a fresh look at how they are changing. The ACS replaced the decennial census long form in 2010 and thereafter by collecting long form type information throughout the decade rather than only once every 10 years.  Questionnaires are mailed to a sample of addresses to obtain information about households -- that is, about each person and the housing unit itself.  The American Community Survey produces demographic, social, housing and economic estimates in the form of 1-year, 3-year and 5-year estimates based on population thresholds. The strength of the ACS is in estimating population and housing characteristics. It produces estimates for small areas, including census tracts and population subgroups.  Although the ACS produces population, demographic and housing unit estimates,it is the Census Bureau's Population Estimates Program that produces and disseminates the official estimates of the population for the nation, states, counties, cities and towns, and estimates of housing units for states and counties.  For 2010 and other decennial census years, the Decennial Census provides the official counts of population and housing units.",
#   u'identifier': u'2011acs1cd113',
#   u'mbox': u'pio@census.gov',
#   u'publisher': u'US Census Bureau',
#   u'references': [u'http://www.census.gov/developers/'],
#   u'spatial': u'US',
#   u'temporal': u'2011',
#   u'title': u'2011 American Community Survey: 1-Year Estimates',
#   u'webService': u'http://api.census.gov/data/2011/acs1/cd113'},
#  {u'accessLevel': u'public',
#   u'c_dataset': [u'sf3'],
#   u'c_documentationLink': u'http://www.census.gov/developers/',
#   u'c_geographyLink': u'http://api.census.gov/data/1990/sf3/geography.json',
#   u'c_isAggregate': True,
#   u'c_tagsLink': u'http://api.census.gov/data/1990/sf3/tags.json',
#   u'c_variablesLink': u'http://api.census.gov/data/1990/sf3/variables.json',
#   u'c_vintage': 1990,
#   u'contactPoint': u'Census Bureau Call Center',
#   u'description': u'This Census 2000 file presents data on the population and housing long form subjects such as income and education. It includes population totals for ancestry groups. It also includes selected characteristics for a limited number of race and Hispanic or Latino categories. The data are available for the U.S., regions, divisions, states, counties, county subdivisions, places, census tracts, block groups, metropolitan areas, American Indian and Alaska Native areas, tribal subdivisions, Hawaiian home lands, congressional districts, and Zip Code Tabulation Areas. Available on CD-ROM, DVD, and American FactFinder.  After Census 2000, data on these subjects were produced from the American Community Survey or the Puerto Rico Community Survey.',
#   u'identifier': u'1990sf3',
#   u'mbox': u'pio@census.gov',
#   u'publisher': u'US Census Bureau',
#   u'references': [u'http://www.census.gov/developers/'],
#   u'spatial': u'US',
#   u'temporal': u'1990',
#   u'title': u'1990 Decennial: Summary File 3',
#   u'webService': u'http://api.census.gov/data/1990/sf3'},
#  {u'accessLevel': u'public',
#   u'c_dataset': [u'acs5', u'profile'],
#   u'c_documentationLink': u'http://www.census.gov/developers/',
#   u'c_examplesLink': u'http://api.census.gov/data/2012/acs5/profile/examples.json',
#   u'c_geographyLink': u'http://api.census.gov/data/2012/acs5/profile/geography.json',
#   u'c_isAggregate': True,
#   u'c_tagsLink': u'http://api.census.gov/data/2012/acs5/profile/tags.json',
#   u'c_variablesLink': u'http://api.census.gov/data/2012/acs5/profile/variables.json',
#   u'c_vintage': 2012,
#   u'contactPoint': u'Census Bureau Call Center',
#   u'description': u"The American Community Survey (ACS) is a nationwide survey designed to provide communities a fresh look at how they are changing. The ACS replaced the decennial census long form in 2010 and thereafter by collecting long form type information throughout the decade rather than only once every 10 years.  Questionnaires are mailed to a sample of addresses to obtain information about households -- that is, about each person and the housing unit itself.  The American Community Survey produces demographic, social, housing and economic estimates in the form of 1-year, 3-year and 5-year estimates based on population thresholds. The strength of the ACS is in estimating population and housing characteristics. It produces estimates for small areas, including census tracts and population subgroups.  Although the ACS produces population, demographic and housing unit estimates,it is the Census Bureau's Population Estimates Program that produces and disseminates the official estimates of the population for the nation, states, counties, cities and towns, and estimates of housing units for states and counties.  For 2010 and other decennial census years, the Decennial Census provides the official counts of population and housing units.",
#   u'identifier': u'2012acs5profile',
#   u'mbox': u'pio@census.gov',
#   u'publisher': u'US Census Bureau',
#   u'spatial': u'US',
#   u'temporal': u'2012',
#   u'title': u'2012 American Community Survey: 5-Year Profile Tables',
#   u'webService': u'http://api.census.gov/data/2012/acs5/profile'},
#  {u'accessLevel': u'public',
#   u'c_dataset': [u'sf1'],
#   u'c_documentationLink': u'http://www.census.gov/developers/',
#   u'c_examplesLink': u'http://api.census.gov/data/2010/sf1/examples.json',
#   u'c_geographyLink': u'http://api.census.gov/data/2010/sf1/geography.json',
#   u'c_isAggregate': True,
#   u'c_tagsLink': u'http://api.census.gov/data/2010/sf1/tags.json',
#   u'c_variablesLink': u'http://api.census.gov/data/2010/sf1/variables.json',
#   u'c_vintage': 2010,
#   u'contactPoint': u'Census Bureau Call Center',
#   u'description': u'Data files available from Census 2000 and the 2010 Census. This file presents 100-percent population and housing figures for the total population, for 63 race categories, and for many other race and Hispanic or Latino categories. This includes age, sex, households, household relationship, housing units, occupancy status, and tenure (whether the residence is owned or rented). Also included are selected characteristics for a limited number of race and Hispanic or Latino categories. The data are available for the U.S., regions, divisions, states, counties, county subdivisions, places, census tracts, block groups, blocks, metropolitan areas (2000), core based statistical areas (2010), American Indian and Alaska Native areas, tribal subdivisions, Hawaiian home lands, congressional districts, and ZIP Code Tabulation Areas. Data are available down to the block level for many tabulations, but only to the census-tract level for others. The 2010 Census SF 1 has some tables on the population in group quarters that are available only to the county level. Available on DVD and American FactFinder.  The Census 2000 Summary File 1 data were released in three stages. Individual state files and two national files were released. The state-level data were released first, followed by the Advance National File, which covered the same data subjects, but includes national level summary data for areas that cross state boundaries such as whole metropolitan areas, whole American Indian areas, etc. The Final National File contains the same data subjects and geographic areas as the Advance National File, but adds the first available urban/rural and urbanized area data. For the most current release dates for these files, see the "Census 2000 Release Schedule" link on the AFFAmerican FactFinder Main Page.  The 2010 Census Summaray File 1 data were released in stages. Individual state files and a national update were released in 2011. The SF 1 urban/rural update is planned for release in Fall 2012. This file contains the same data subjects as the previously released files, but for additional geography, including the urban and rural parts of the United States, regions, divisions, states, counties, and places; and urbanized areas and urban clusters. See the 2010 Census Data Products At A Glance',
#   u'identifier': u'2010sf1',
#   u'mbox': u'pio@census.gov',
#   u'publisher': u'US Census Bureau',
#   u'references': [u'http://www.census.gov/developers/'],
#   u'spatial': u'US',
#   u'temporal': u'2010',
#   u'title': u'2010 Decennial: Summary File 1',
#   u'webService': u'http://api.census.gov/data/2010/sf1'},
#  {u'accessLevel': u'public',
#   u'c_dataset': [u'sf3'],
#   u'c_documentationLink': u'http://www.census.gov/developers/',
#   u'c_geographyLink': u'http://api.census.gov/data/2000/sf3/geography.json',
#   u'c_isAggregate': True,
#   u'c_tagsLink': u'http://api.census.gov/data/2000/sf3/tags.json',
#   u'c_variablesLink': u'http://api.census.gov/data/2000/sf3/variables.json',
#   u'c_vintage': 2000,
#   u'contactPoint': u'Census Bureau Call Center',
#   u'description': u'This Census 2000 file presents data on the population and housing long form subjects such as income and education. It includes population totals for ancestry groups. It also includes selected characteristics for a limited number of race and Hispanic or Latino categories. The data are available for the U.S., regions, divisions, states, counties, county subdivisions, places, census tracts, block groups, metropolitan areas, American Indian and Alaska Native areas, tribal subdivisions, Hawaiian home lands, congressional districts, and Zip Code Tabulation Areas. Available on CD-ROM, DVD, and American FactFinder.  After Census 2000, data on these subjects were produced from the American Community Survey or the Puerto Rico Community Survey.',
#   u'identifier': u'2000sf3',
#   u'mbox': u'pio@census.gov',
#   u'publisher': u'US Census Bureau',
#   u'references': [u'http://www.census.gov/developers/'],
#   u'spatial': u'US',
#   u'temporal': u'2000',
#   u'title': u'2000 Decennial: Summary File 3',
#   u'webService': u'http://api.census.gov/data/2000/sf3'},
#  {u'accessLevel': u'public',
#   u'c_dataset': [u'acs1'],
#   u'c_documentationLink': u'http://www.census.gov/developers/',
#   u'c_geographyLink': u'http://api.census.gov/data/2012/acs1/geography.json',
#   u'c_isAggregate': True,
#   u'c_tagsLink': u'http://api.census.gov/data/2012/acs1/tags.json',
#   u'c_variablesLink': u'http://api.census.gov/data/2012/acs1/variables.json',
#   u'c_vintage': 2012,
#   u'contactPoint': u'Census Bureau Call Center',
#   u'description': u"The American Community Survey (ACS) is a nationwide survey designed to provide communities a fresh look at how they are changing. The ACS replaced the decennial census long form in 2010 and thereafter by collecting long form type information throughout the decade rather than only once every 10 years.  Questionnaires are mailed to a sample of addresses to obtain information about households -- that is, about each person and the housing unit itself.  The American Community Survey produces demographic, social, housing and economic estimates in the form of 1-year, 3-year and 5-year estimates based on population thresholds. The strength of the ACS is in estimating population and housing characteristics. It produces estimates for small areas, including census tracts and population subgroups.  Although the ACS produces population, demographic and housing unit estimates,it is the Census Bureau's Population Estimates Program that produces and disseminates the official estimates of the population for the nation, states, counties, cities and towns, and estimates of housing units for states and counties.  For 2010 and other decennial census years, the Decennial Census provides the official counts of population and housing units.",
#   u'identifier': u'2012acs1',
#   u'mbox': u'pio@census.gov',
#   u'publisher': u'US Census Bureau',
#   u'references': [u'http://www.census.gov/developers/'],
#   u'spatial': u'US',
#   u'temporal': u'2012',
#   u'title': u'2012 American Community Survey: 1-Year Estimates',
#   u'webService': u'http://api.census.gov/data/2012/acs1'},
#  {u'accessLevel': u'public',
#   u'c_dataset': [u'acs3'],
#   u'c_documentationLink': u'http://www.census.gov/developers/',
#   u'c_geographyLink': u'http://api.census.gov/data/2012/acs3/geography.json',
#   u'c_isAggregate': True,
#   u'c_tagsLink': u'http://api.census.gov/data/2012/acs3/tags.json',
#   u'c_variablesLink': u'http://api.census.gov/data/2012/acs3/variables.json',
#   u'c_vintage': 2012,
#   u'contactPoint': u'Census Bureau Call Center',
#   u'description': u"The American Community Survey (ACS) is a nationwide survey designed to provide communities a fresh look at how they are changing. The ACS replaced the decennial census long form in 2010 and thereafter by collecting long form type information throughout the decade rather than only once every 10 years.  Questionnaires are mailed to a sample of addresses to obtain information about households -- that is, about each person and the housing unit itself.  The American Community Survey produces demographic, social, housing and economic estimates in the form of 1-year, 3-year and 5-year estimates based on population thresholds. The strength of the ACS is in estimating population and housing characteristics. It produces estimates for small areas, including census tracts and population subgroups.  Although the ACS produces population, demographic and housing unit estimates,it is the Census Bureau's Population Estimates Program that produces and disseminates the official estimates of the population for the nation, states, counties, cities and towns, and estimates of housing units for states and counties.  For 2010 and other decennial census years, the Decennial Census provides the official counts of population and housing units.",
#   u'identifier': u'2012acs3',
#   u'mbox': u'pio@census.gov',
#   u'publisher': u'US Census Bureau',
#   u'references': [u'http://www.census.gov/developers/'],
#   u'spatial': u'US',
#   u'temporal': u'2012',
#   u'title': u'2012 American Community Survey: 3-Year Estimates',
#   u'webService': u'http://api.census.gov/data/2012/acs3'},
#  {u'accessLevel': u'public',
#   u'c_dataset': [u'acs5'],
#   u'c_documentationLink': u'http://www.census.gov/developers/',
#   u'c_geographyLink': u'http://api.census.gov/data/2011/acs5/geography.json',
#   u'c_isAggregate': True,
#   u'c_tagsLink': u'http://api.census.gov/data/2011/acs5/tags.json',
#   u'c_variablesLink': u'http://api.census.gov/data/2011/acs5/variables.json',
#   u'c_vintage': 2011,
#   u'contactPoint': u'Census Bureau Call Center',
#   u'description': u"The American Community Survey (ACS) is a nationwide survey designed to provide communities a fresh look at how they are changing. The ACS replaced the decennial census long form in 2010 and thereafter by collecting long form type information throughout the decade rather than only once every 10 years.  Questionnaires are mailed to a sample of addresses to obtain information about households -- that is, about each person and the housing unit itself.  The American Community Survey produces demographic, social, housing and economic estimates in the form of 1-year, 3-year and 5-year estimates based on population thresholds. The strength of the ACS is in estimating population and housing characteristics. It produces estimates for small areas, including census tracts and population subgroups.  Although the ACS produces population, demographic and housing unit estimates,it is the Census Bureau's Population Estimates Program that produces and disseminates the official estimates of the population for the nation, states, counties, cities and towns, and estimates of housing units for states and counties.  For 2010 and other decennial census years, the Decennial Census provides the official counts of population and housing units.",
#   u'identifier': u'2011acs5',
#   u'mbox': u'pio@census.gov',
#   u'publisher': u'US Census Bureau',
#   u'references': [u'http://www.census.gov/developers/'],
#   u'spatial': u'US',
#   u'temporal': u'2011',
#   u'title': u'2011 American Community Survey: 5-Year Estimates',
#   u'webService': u'http://api.census.gov/data/2011/acs5'},
#  {u'accessLevel': u'public',
#   u'c_dataset': [u'acs5'],
#   u'c_documentationLink': u'http://www.census.gov/developers/',
#   u'c_examplesLink': u'http://api.census.gov/data/2012/acs5/examples.json',
#   u'c_geographyLink': u'http://api.census.gov/data/2012/acs5/geography.json',
#   u'c_isAggregate': True,
#   u'c_tagsLink': u'http://api.census.gov/data/2012/acs5/tags.json',
#   u'c_variablesLink': u'http://api.census.gov/data/2012/acs5/variables.json',
#   u'c_vintage': 2012,
#   u'contactPoint': u'Census Bureau Call Center',
#   u'description': u"The American Community Survey (ACS) is a nationwide survey designed to provide communities a fresh look at how they are changing. The ACS replaced the decennial census long form in 2010 and thereafter by collecting long form type information throughout the decade rather than only once every 10 years.  Questionnaires are mailed to a sample of addresses to obtain information about households -- that is, about each person and the housing unit itself.  The American Community Survey produces demographic, social, housing and economic estimates in the form of 1-year, 3-year and 5-year estimates based on population thresholds. The strength of the ACS is in estimating population and housing characteristics. It produces estimates for small areas, including census tracts and population subgroups.  Although the ACS produces population, demographic and housing unit estimates,it is the Census Bureau's Population Estimates Program that produces and disseminates the official estimates of the population for the nation, states, counties, cities and towns, and estimates of housing units for states and counties.  For 2010 and other decennial census years, the Decennial Census provides the official counts of population and housing units.",
#   u'identifier': u'2012acs5',
#   u'mbox': u'pio@census.gov',
#   u'publisher': u'US Census Bureau',
#   u'references': [u'http://www.census.gov/developers/'],
#   u'spatial': u'US',
#   u'temporal': u'2012',
#   u'title': u'2012 American Community Survey: 5-Year Estimates',
#   u'webService': u'http://api.census.gov/data/2012/acs5'},
#  {u'accessLevel': u'public',
#   u'c_dataset': [u'acs1', u'profile'],
#   u'c_documentationLink': u'http://www.census.gov/developers/',
#   u'c_geographyLink': u'http://api.census.gov/data/2012/acs1/profile/geography.json',
#   u'c_isAggregate': True,
#   u'c_tagsLink': u'http://api.census.gov/data/2012/acs1/profile/tags.json',
#   u'c_variablesLink': u'http://api.census.gov/data/2012/acs1/profile/variables.json',
#   u'c_vintage': 2012,
#   u'contactPoint': u'Census Bureau Call Center',
#   u'description': u"The American Community Survey (ACS) is a nationwide survey designed to provide communities a fresh look at how they are changing. The ACS replaced the decennial census long form in 2010 and thereafter by collecting long form type information throughout the decade rather than only once every 10 years.  Questionnaires are mailed to a sample of addresses to obtain information about households -- that is, about each person and the housing unit itself.  The American Community Survey produces demographic, social, housing and economic estimates in the form of 1-year, 3-year and 5-year estimates based on population thresholds. The strength of the ACS is in estimating population and housing characteristics. It produces estimates for small areas, including census tracts and population subgroups.  Although the ACS produces population, demographic and housing unit estimates,it is the Census Bureau's Population Estimates Program that produces and disseminates the official estimates of the population for the nation, states, counties, cities and towns, and estimates of housing units for states and counties.  For 2010 and other decennial census years, the Decennial Census provides the official counts of population and housing units.",
#   u'identifier': u'2012acs1profile',
#   u'mbox': u'pio@census.gov',
#   u'publisher': u'US Census Bureau',
#   u'references': [u'http://www.census.gov/developers/'],
#   u'spatial': u'US',
#   u'temporal': u'2012',
#   u'title': u'2012 American Community Survey: 1-Year Profile Tables',
#   u'webService': u'http://api.census.gov/data/2012/acs1/profile'},
#  {u'accessLevel': u'public',
#   u'c_dataset': [u'acs3', u'profile'],
#   u'c_documentationLink': u'http://www.census.gov/developers/',
#   u'c_geographyLink': u'http://api.census.gov/data/2012/acs3/profile/geography.json',
#   u'c_isAggregate': True,
#   u'c_tagsLink': u'http://api.census.gov/data/2012/acs3/profile/tags.json',
#   u'c_variablesLink': u'http://api.census.gov/data/2012/acs3/profile/variables.json',
#   u'c_vintage': 2012,
#   u'contactPoint': u'Census Bureau Call Center',
#   u'description': u"The American Community Survey (ACS) is a nationwide survey designed to provide communities a fresh look at how they are changing. The ACS replaced the decennial census long form in 2010 and thereafter by collecting long form type information throughout the decade rather than only once every 10 years.  Questionnaires are mailed to a sample of addresses to obtain information about households -- that is, about each person and the housing unit itself.  The American Community Survey produces demographic, social, housing and economic estimates in the form of 1-year, 3-year and 5-year estimates based on population thresholds. The strength of the ACS is in estimating population and housing characteristics. It produces estimates for small areas, including census tracts and population subgroups.  Although the ACS produces population, demographic and housing unit estimates,it is the Census Bureau's Population Estimates Program that produces and disseminates the official estimates of the population for the nation, states, counties, cities and towns, and estimates of housing units for states and counties.  For 2010 and other decennial census years, the Decennial Census provides the official counts of population and housing units.",
#   u'identifier': u'2012acs3profile',
#   u'mbox': u'pio@census.gov',
#   u'publisher': u'US Census Bureau',
#   u'references': [u'http://www.census.gov/developers/'],
#   u'spatial': u'US',
#   u'temporal': u'2012',
#   u'title': u'2012 American Community Survey: 3-Year Profile Tables',
#   u'webService': u'http://api.census.gov/data/2012/acs3/profile'},
#  {u'accessLevel': u'public',
#   u'c_dataset': [u'sf1'],
#   u'c_documentationLink': u'http://www.census.gov/developers/',
#   u'c_geographyLink': u'http://api.census.gov/data/2000/sf1/geography.json',
#   u'c_isAggregate': True,
#   u'c_tagsLink': u'http://api.census.gov/data/2000/sf1/tags.json',
#   u'c_variablesLink': u'http://api.census.gov/data/2000/sf1/variables.json',
#   u'c_vintage': 2000,
#   u'contactPoint': u'Census Bureau Call Center',
#   u'description': u'Data files available from Census 2000 and the 2010 Census. This file presents 100-percent population and housing figures for the total population, for 63 race categories, and for many other race and Hispanic or Latino categories. This includes age, sex, households, household relationship, housing units, occupancy status, and tenure (whether the residence is owned or rented). Also included are selected characteristics for a limited number of race and Hispanic or Latino categories. The data are available for the U.S., regions, divisions, states, counties, county subdivisions, places, census tracts, block groups, blocks, metropolitan areas (2000), core based statistical areas (2010), American Indian and Alaska Native areas, tribal subdivisions, Hawaiian home lands, congressional districts, and ZIP Code Tabulation Areas. Data are available down to the block level for many tabulations, but only to the census-tract level for others. The 2010 Census SF 1 has some tables on the population in group quarters that are available only to the county level. Available on DVD and American FactFinder.  The Census 2000 Summary File 1 data were released in three stages. Individual state files and two national files were released. The state-level data were released first, followed by the Advance National File, which covered the same data subjects, but includes national level summary data for areas that cross state boundaries such as whole metropolitan areas, whole American Indian areas, etc. The Final National File contains the same data subjects and geographic areas as the Advance National File, but adds the first available urban/rural and urbanized area data. For the most current release dates for these files, see the "Census 2000 Release Schedule" link on the AFFAmerican FactFinder Main Page.  The 2010 Census Summaray File 1 data were released in stages. Individual state files and a national update were released in 2011. The SF 1 urban/rural update is planned for release in Fall 2012. This file contains the same data subjects as the previously released files, but for additional geography, including the urban and rural parts of the United States, regions, divisions, states, counties, and places; and urbanized areas and urban clusters. See the 2010 Census Data Products At A Glance',
#   u'identifier': u'2000sf1',
#   u'mbox': u'pio@census.gov',
#   u'publisher': u'US Census Bureau',
#   u'references': [u'http://www.census.gov/developers/'],
#   u'spatial': u'US',
#   u'temporal': u'2000',
#   u'title': u'2000 Decennial: Summary File 1',
#   u'webService': u'http://api.census.gov/data/2000/sf1'}]

# %%
len(api_json)
# Out:
# 14

# %%
[(api['c_vintage'], api['c_dataset'], api['c_variablesLink']) for api in api_json]
# Out:
# [(2010, [u'acs5'], u'http://api.census.gov/data/2010/acs5/variables.json'),
#  (1990, [u'sf1'], u'http://api.census.gov/data/1990/sf1/variables.json'),
#  (2011,
#   [u'acs1', u'cd113'],
#   u'http://api.census.gov/data/2011/acs1/cd113/variables.json'),
#  (1990, [u'sf3'], u'http://api.census.gov/data/1990/sf3/variables.json'),
#  (2012,
#   [u'acs5', u'profile'],
#   u'http://api.census.gov/data/2012/acs5/profile/variables.json'),
#  (2010, [u'sf1'], u'http://api.census.gov/data/2010/sf1/variables.json'),
#  (2000, [u'sf3'], u'http://api.census.gov/data/2000/sf3/variables.json'),
#  (2012, [u'acs1'], u'http://api.census.gov/data/2012/acs1/variables.json'),
#  (2012, [u'acs3'], u'http://api.census.gov/data/2012/acs3/variables.json'),
#  (2011, [u'acs5'], u'http://api.census.gov/data/2011/acs5/variables.json'),
#  (2012, [u'acs5'], u'http://api.census.gov/data/2012/acs5/variables.json'),
#  (2012,
#   [u'acs1', u'profile'],
#   u'http://api.census.gov/data/2012/acs1/profile/variables.json'),
#  (2012,
#   [u'acs3', u'profile'],
#   u'http://api.census.gov/data/2012/acs3/profile/variables.json'),
#  (2000, [u'sf1'], u'http://api.census.gov/data/2000/sf1/variables.json')]

# %% [markdown]
# # variables.json

# %%
import requests
url = "http://api.census.gov/data/2010/sf1/variables.json"
var_json = requests.get(url).json()
sorted(var_json['variables'].keys())
# Out:
# [u'AIANHH',
#  u'AIANHHCC',
#  u'AIANHHFP',
#  u'AIHHTLI',
#  u'AITS',
#  u'AITSCC',
#  u'AITSCE',
#  u'ANRC',
#  u'BLKGRP',
#  u'BLOCK',
#  u'CBSA',
#  u'CBSAPCI',
#  u'CD',
#  u'CD113',
#  u'CNECTA',
#  u'CONCIT',
#  u'CONCITSC',
#  u'COUNTY',
#  u'COUSUB',
#  u'CSA',
#  u'DIVISION',
#  u'GEOCOMP',
#  u'H00010001',
#  u'H0020001',
#  u'H0020002',
#  u'H0020003',
#  u'H0020004',
#  u'H0020005',
#  u'H0020006',
#  u'H0030001',
#  u'H0030002',
#  u'H0030003',
#  u'H0040001',
#  u'H0040002',
#  u'H0040003',
#  u'H0040004',
#  u'H0050001',
#  u'H0050002',
#  u'H0050003',
#  u'H0050004',
#  u'H0050005',
#  u'H0050006',
#  u'H0050007',
#  u'H0050008',
#  u'H0060001',
#  u'H0060002',
#  u'H0060003',
#  u'H0060004',
#  u'H0060005',
#  u'H0060006',
#  u'H0060007',
#  u'H0060008',
#  u'H0070001',
#  u'H0070002',
#  u'H0070003',
#  u'H0070004',
#  u'H0070005',
#  u'H0070006',
#  u'H0070007',
#  u'H0070008',
#  u'H0070009',
#  u'H0070010',
#  u'H0070011',
#  u'H0070012',
#  u'H0070013',
#  u'H0070014',
#  u'H0070015',
#  u'H0070016',
#  u'H0070017',
#  u'H0080001',
#  u'H0080002',
#  u'H0080003',
#  u'H0080004',
#  u'H0080005',
#  u'H0080006',
#  u'H0080007',
#  u'H0090001',
#  u'H0090002',
#  u'H0090003',
#  u'H0090004',
#  u'H0090005',
#  u'H0090006',
#  u'H0090007',
#  u'H0090008',
#  u'H0090009',
#  u'H0090010',
#  u'H0090011',
#  u'H0090012',
#  u'H0090013',
#  u'H0090014',
#  u'H0090015',
#  u'H0100001',
#  u'H0110001',
#  u'H0110002',
#  u'H0110003',
#  u'H0110004',
#  u'H011A0001',
#  u'H011A0002',
#  u'H011A0003',
#  u'H011A0004',
#  u'H011B0001',
#  u'H011B0002',
#  u'H011B0003',
#  u'H011B0004',
#  u'H011C0001',
#  u'H011C0002',
#  u'H011C0003',
#  u'H011C0004',
#  u'H011D0001',
#  u'H011D0002',
#  u'H011D0003',
#  u'H011D0004',
#  u'H011E0001',
#  u'H011E0002',
#  u'H011E0003',
#  u'H011E0004',
#  u'H011F0001',
#  u'H011F0002',
#  u'H011F0003',
#  u'H011F0004',
#  u'H011G0001',
#  u'H011G0002',
#  u'H011G0003',
#  u'H011G0004',
#  u'H011H0001',
#  u'H011H0002',
#  u'H011H0003',
#  u'H011H0004',
#  u'H011I0001',
#  u'H011I0002',
#  u'H011I0003',
#  u'H011I0004',
#  u'H0120001',
#  u'H0120002',
#  u'H0120003',
#  u'H012A0001',
#  u'H012A0002',
#  u'H012A0003',
#  u'H012B0001',
#  u'H012B0002',
#  u'H012B0003',
#  u'H012C0001',
#  u'H012C0002',
#  u'H012C0003',
#  u'H012D0001',
#  u'H012D0002',
#  u'H012D0003',
#  u'H012E0001',
#  u'H012E0002',
#  u'H012E0003',
#  u'H012F0001',
#  u'H012F0002',
#  u'H012F0003',
#  u'H012G0001',
#  u'H012G0002',
#  u'H012G0003',
#  u'H012H0001',
#  u'H012H0002',
#  u'H012H0003',
#  u'H012I0001',
#  u'H012I0002',
#  u'H012I0003',
#  u'H0130001',
#  u'H0130002',
#  u'H0130003',
#  u'H0130004',
#  u'H0130005',
#  u'H0130006',
#  u'H0130007',
#  u'H0130008',
#  u'H0140001',
#  u'H0140002',
#  u'H0140003',
#  u'H0140004',
#  u'H0140005',
#  u'H0140006',
#  u'H0140007',
#  u'H0140008',
#  u'H0140009',
#  u'H0140010',
#  u'H0140011',
#  u'H0140012',
#  u'H0140013',
#  u'H0140014',
#  u'H0140015',
#  u'H0140016',
#  u'H0140017',
#  u'H0150001',
#  u'H0150002',
#  u'H0150003',
#  u'H0150004',
#  u'H0150005',
#  u'H0150006',
#  u'H0150007',
#  u'H0160001',
#  u'H0160002',
#  u'H0160003',
#  u'H0160004',
#  u'H0160005',
#  u'H0160006',
#  u'H0160007',
#  u'H0160008',
#  u'H0160009',
#  u'H0160010',
#  u'H0160011',
#  u'H0160012',
#  u'H0160013',
#  u'H0160014',
#  u'H0160015',
#  u'H0160016',
#  u'H0160017',
#  u'H016A0001',
#  u'H016A0002',
#  u'H016A0003',
#  u'H016A0004',
#  u'H016A0005',
#  u'H016A0006',
#  u'H016A0007',
#  u'H016A0008',
#  u'H016A0009',
#  u'H016A0010',
#  u'H016A0011',
#  u'H016A0012',
#  u'H016A0013',
#  u'H016A0014',
#  u'H016A0015',
#  u'H016A0016',
#  u'H016A0017',
#  u'H016B0001',
#  u'H016B0002',
#  u'H016B0003',
#  u'H016B0004',
#  u'H016B0005',
#  u'H016B0006',
#  u'H016B0007',
#  u'H016B0008',
#  u'H016B0009',
#  u'H016B0010',
#  u'H016B0011',
#  u'H016B0012',
#  u'H016B0013',
#  u'H016B0014',
#  u'H016B0015',
#  u'H016B0016',
#  u'H016B0017',
#  u'H016C0001',
#  u'H016C0002',
#  u'H016C0003',
#  u'H016C0004',
#  u'H016C0005',
#  u'H016C0006',
#  u'H016C0007',
#  u'H016C0008',
#  u'H016C0009',
#  u'H016C0010',
#  u'H016C0011',
#  u'H016C0012',
#  u'H016C0013',
#  u'H016C0014',
#  u'H016C0015',
#  u'H016C0016',
#  u'H016C0017',
#  u'H016D0001',
#  u'H016D0002',
#  u'H016D0003',
#  u'H016D0004',
#  u'H016D0005',
#  u'H016D0006',
#  u'H016D0007',
#  u'H016D0008',
#  u'H016D0009',
#  u'H016D0010',
#  u'H016D0011',
#  u'H016D0012',
#  u'H016D0013',
#  u'H016D0014',
#  u'H016D0015',
#  u'H016D0016',
#  u'H016D0017',
#  u'H016E0001',
#  u'H016E0002',
#  u'H016E0003',
#  u'H016E0004',
#  u'H016E0005',
#  u'H016E0006',
#  u'H016E0007',
#  u'H016E0008',
#  u'H016E0009',
#  u'H016E0010',
#  u'H016E0011',
#  u'H016E0012',
#  u'H016E0013',
#  u'H016E0014',
#  u'H016E0015',
#  u'H016E0016',
#  u'H016E0017',
#  u'H016F0001',
#  u'H016F0002',
#  u'H016F0003',
#  u'H016F0004',
#  u'H016F0005',
#  u'H016F0006',
#  u'H016F0007',
#  u'H016F0008',
#  u'H016F0009',
#  u'H016F0010',
#  u'H016F0011',
#  u'H016F0012',
#  u'H016F0013',
#  u'H016F0014',
#  u'H016F0015',
#  u'H016F0016',
#  u'H016F0017',
#  u'H016G0001',
#  u'H016G0002',
#  u'H016G0003',
#  u'H016G0004',
#  u'H016G0005',
#  u'H016G0006',
#  u'H016G0007',
#  u'H016G0008',
#  u'H016G0009',
#  u'H016G0010',
#  u'H016G0011',
#  u'H016G0012',
#  u'H016G0013',
#  u'H016G0014',
#  u'H016G0015',
#  u'H016G0016',
#  u'H016G0017',
#  u'H016H0001',
#  u'H016H0002',
#  u'H016H0003',
#  u'H016H0004',
#  u'H016H0005',
#  u'H016H0006',
#  u'H016H0007',
#  u'H016H0008',
#  u'H016H0009',
#  u'H016H0010',
#  u'H016H0011',
#  u'H016H0012',
#  u'H016H0013',
#  u'H016H0014',
#  u'H016H0015',
#  u'H016H0016',
#  u'H016H0017',
#  u'H016I0001',
#  u'H016I0002',
#  u'H016I0003',
#  u'H016I0004',
#  u'H016I0005',
#  u'H016I0006',
#  u'H016I0007',
#  u'H016I0008',
#  u'H016I0009',
#  u'H016I0010',
#  u'H016I0011',
#  u'H016I0012',
#  u'H016I0013',
#  u'H016I0014',
#  u'H016I0015',
#  u'H016I0016',
#  u'H016I0017',
#  u'H0170001',
#  u'H0170002',
#  u'H0170003',
#  u'H0170004',
#  u'H0170005',
#  u'H0170006',
#  u'H0170007',
#  u'H0170008',
#  u'H0170009',
#  u'H0170010',
#  u'H0170011',
#  u'H0170012',
#  u'H0170013',
#  u'H0170014',
#  u'H0170015',
#  u'H0170016',
#  u'H0170017',
#  u'H0170018',
#  u'H0170019',
#  u'H0170020',
#  u'H0170021',
#  u'H017A0001',
#  u'H017A0002',
#  u'H017A0003',
#  u'H017A0004',
#  u'H017A0005',
#  u'H017A0006',
#  u'H017A0007',
#  u'H017A0008',
#  u'H017A0009',
#  u'H017A0010',
#  u'H017A0011',
#  u'H017A0012',
#  u'H017A0013',
#  u'H017A0014',
#  u'H017A0015',
#  u'H017A0016',
#  u'H017A0017',
#  u'H017A0018',
#  u'H017A0019',
#  u'H017A0020',
#  u'H017A0021',
#  u'H017B0001',
#  u'H017B0002',
#  u'H017B0003',
#  u'H017B0004',
#  u'H017B0005',
#  u'H017B0006',
#  u'H017B0007',
#  u'H017B0008',
#  u'H017B0009',
#  u'H017B0010',
#  u'H017B0011',
#  u'H017B0012',
#  u'H017B0013',
#  u'H017B0014',
#  u'H017B0015',
#  u'H017B0016',
#  u'H017B0017',
#  u'H017B0018',
#  u'H017B0019',
#  u'H017B0020',
#  u'H017B0021',
#  u'H017C0001',
#  u'H017C0002',
#  u'H017C0003',
#  u'H017C0004',
#  u'H017C0005',
#  u'H017C0006',
#  u'H017C0007',
#  u'H017C0008',
#  u'H017C0009',
#  u'H017C0010',
#  u'H017C0011',
#  u'H017C0012',
#  u'H017C0013',
#  u'H017C0014',
#  u'H017C0015',
#  u'H017C0016',
#  u'H017C0017',
#  u'H017C0018',
#  u'H017C0019',
#  u'H017C0020',
#  u'H017C0021',
#  u'H017D0001',
#  u'H017D0002',
#  u'H017D0003',
#  u'H017D0004',
#  u'H017D0005',
#  u'H017D0006',
#  u'H017D0007',
#  u'H017D0008',
#  u'H017D0009',
#  u'H017D0010',
#  u'H017D0011',
#  u'H017D0012',
#  u'H017D0013',
#  u'H017D0014',
#  u'H017D0015',
#  u'H017D0016',
#  u'H017D0017',
#  u'H017D0018',
#  u'H017D0019',
#  u'H017D0020',
#  u'H017D0021',
#  u'H017E0001',
#  u'H017E0002',
#  u'H017E0003',
#  u'H017E0004',
#  u'H017E0005',
#  u'H017E0006',
#  u'H017E0007',
#  u'H017E0008',
#  u'H017E0009',
#  u'H017E0010',
#  u'H017E0011',
#  u'H017E0012',
#  u'H017E0013',
#  u'H017E0014',
#  u'H017E0015',
#  u'H017E0016',
#  u'H017E0017',
#  u'H017E0018',
#  u'H017E0019',
#  u'H017E0020',
#  u'H017E0021',
#  u'H017F0001',
#  u'H017F0002',
#  u'H017F0003',
#  u'H017F0004',
#  u'H017F0005',
#  u'H017F0006',
#  u'H017F0007',
#  u'H017F0008',
#  u'H017F0009',
#  u'H017F0010',
#  u'H017F0011',
#  u'H017F0012',
#  u'H017F0013',
#  u'H017F0014',
#  u'H017F0015',
#  u'H017F0016',
#  u'H017F0017',
#  u'H017F0018',
#  u'H017F0019',
#  u'H017F0020',
#  u'H017F0021',
#  u'H017G0001',
#  u'H017G0002',
#  u'H017G0003',
#  u'H017G0004',
#  u'H017G0005',
#  u'H017G0006',
#  u'H017G0007',
#  u'H017G0008',
#  u'H017G0009',
#  u'H017G0010',
#  u'H017G0011',
#  u'H017G0012',
#  u'H017G0013',
#  u'H017G0014',
#  u'H017G0015',
#  u'H017G0016',
#  u'H017G0017',
#  u'H017G0018',
#  u'H017G0019',
#  u'H017G0020',
#  u'H017G0021',
#  u'H017H0001',
#  u'H017H0002',
#  u'H017H0003',
#  u'H017H0004',
#  u'H017H0005',
#  u'H017H0006',
#  u'H017H0007',
#  u'H017H0008',
#  u'H017H0009',
#  u'H017H0010',
#  u'H017H0011',
#  u'H017H0012',
#  u'H017H0013',
#  u'H017H0014',
#  u'H017H0015',
#  u'H017H0016',
#  u'H017H0017',
#  u'H017H0018',
#  u'H017H0019',
#  u'H017H0020',
#  u'H017H0021',
#  u'H017I0001',
#  u'H017I0002',
#  u'H017I0003',
#  u'H017I0004',
#  u'H017I0005',
#  u'H017I0006',
#  u'H017I0007',
#  u'H017I0008',
#  u'H017I0009',
#  u'H017I0010',
#  u'H017I0011',
#  u'H017I0012',
#  u'H017I0013',
#  u'H017I0014',
#  u'H017I0015',
#  u'H017I0016',
#  u'H017I0017',
#  u'H017I0018',
#  u'H017I0019',
#  u'H017I0020',
#  u'H017I0021',
#  u'H0180001',
#  u'H0180002',
#  u'H0180003',
#  u'H0180004',
#  u'H0180005',
#  u'H0180006',
#  u'H0180007',
#  u'H0180008',
#  u'H0180009',
#  u'H0180010',
#  u'H0180011',
#  u'H0180012',
#  u'H0180013',
#  u'H0180014',
#  u'H0180015',
#  u'H0180016',
#  u'H0180017',
#  u'H0180018',
#  u'H0180019',
#  u'H0180020',
#  u'H0180021',
#  u'H0180022',
#  u'H0180023',
#  u'H0180024',
#  u'H0180025',
#  u'H0180026',
#  u'H0180027',
#  u'H0180028',
#  u'H0180029',
#  u'H0180030',
#  u'H0180031',
#  u'H0180032',
#  u'H0180033',
#  u'H0180034',
#  u'H0180035',
#  u'H0180036',
#  u'H0180037',
#  u'H0180038',
#  u'H0180039',
#  u'H0180040',
#  u'H0180041',
#  u'H0180042',
#  u'H0180043',
#  u'H0180044',
#  u'H0180045',
#  u'H0180046',
#  u'H0180047',
#  u'H0180048',
#  u'H0180049',
#  u'H0180050',
#  u'H0180051',
#  u'H0180052',
#  u'H0180053',
#  u'H0180054',
#  u'H0180055',
#  u'H0180056',
#  u'H0180057',
#  u'H0180058',
#  u'H0180059',
#  u'H0180060',
#  u'H0180061',
#  u'H0180062',
#  u'H0180063',
#  u'H0180064',
#  u'H0180065',
#  u'H0180066',
#  u'H0180067',
#  u'H0180068',
#  u'H0180069',
#  u'H0190001',
#  u'H0190002',
#  u'H0190003',
#  u'H0190004',
#  u'H0190005',
#  u'H0190006',
#  u'H0190007',
#  u'H0200001',
#  u'H0200002',
#  u'H0200003',
#  u'H0210001',
#  u'H0210002',
#  u'H0210003',
#  u'H0220001',
#  u'H0220002',
#  u'H0220003',
#  u'HCT0010001',
#  u'HCT0010002',
#  u'HCT0010003',
#  u'HCT0010004',
#  u'HCT0010005',
#  u'HCT0010006',
#  u'HCT0010007',
#  u'HCT0010008',
#  u'HCT0010009',
#  u'HCT0010010',
#  u'HCT0010011',
#  u'HCT0010012',
#  u'HCT0010013',
#  u'HCT0010014',
#  u'HCT0010015',
#  u'HCT0010016',
#  u'HCT0010017',
#  u'HCT0010018',
#  u'HCT0010019',
#  u'HCT0010020',
#  u'HCT0010021',
#  u'HCT0010022',
#  u'HCT0010023',
#  u'HCT0010024',
#  u'HCT0010025',
#  u'HCT0010026',
#  u'HCT0010027',
#  u'HCT0010028',
#  u'HCT0010029',
#  u'HCT0010030',
#  u'HCT0010031',
#  u'HCT0010032',
#  u'HCT0010033',
#  u'HCT0010034',
#  u'HCT0010035',
#  u'HCT0020001',
#  u'HCT0020002',
#  u'HCT0020003',
#  u'HCT0020004',
#  u'HCT0020005',
#  u'HCT0020006',
#  u'HCT0020007',
#  u'HCT0020008',
#  u'HCT0020009',
#  u'HCT0020010',
#  u'HCT0020011',
#  u'HCT0020012',
#  u'HCT0020013',
#  u'HCT0030001',
#  u'HCT0030002',
#  u'HCT0030003',
#  u'HCT0030004',
#  u'HCT0030005',
#  u'HCT0030006',
#  u'HCT0030007',
#  u'HCT0030008',
#  u'HCT0030009',
#  u'HCT0030010',
#  u'HCT0030011',
#  u'HCT0030012',
#  u'HCT0030013',
#  u'HCT0040001',
#  u'HCT0040002',
#  u'HCT0040003',
#  u'HCT0040004',
#  u'HCT0040005',
#  u'HCT0040006',
#  u'HCT0040007',
#  u'HCT0040008',
#  u'HCT0040009',
#  u'HCT0040010',
#  u'HCT0040011',
#  u'HCT0040012',
#  u'HCT0040013',
#  u'LOGRECNO',
#  u'MEMI',
#  u'METDIV',
#  u'NAME',
#  u'NECTA',
#  u'NECTADIV',
#  u'NECTAPCI',
#  u'P0010001',
#  u'P0020001',
#  u'P0020002',
#  u'P0020003',
#  u'P0020004',
#  u'P0020005',
#  u'P0020006',
#  u'P0030001',
#  u'P0030002',
#  u'P0030003',
#  u'P0030004',
#  u'P0030005',
#  u'P0030006',
#  u'P0030007',
#  u'P0030008',
#  u'P0040001',
#  u'P0040002',
#  u'P0040003',
#  u'P0050001',
#  u'P0050002',
#  u'P0050003',
#  u'P0050004',
#  u'P0050005',
#  u'P0050006',
#  u'P0050007',
#  u'P0050008',
#  u'P0050009',
#  u'P0050010',
#  u'P0050011',
#  u'P0050012',
#  u'P0050013',
#  u'P0050014',
#  u'P0050015',
#  u'P0050016',
#  u'P0050017',
#  u'P0060001',
#  u'P0060002',
#  u'P0060003',
#  u'P0060004',
#  u'P0060005',
#  u'P0060006',
#  u'P0060007',
#  u'P0070001',
#  u'P0070002',
#  u'P0070003',
#  u'P0070004',
#  u'P0070005',
#  u'P0070006',
#  u'P0070007',
#  u'P0070008',
#  u'P0070009',
#  u'P0070010',
#  u'P0070011',
#  u'P0070012',
#  u'P0070013',
#  u'P0070014',
#  u'P0070015',
#  u'P0080001',
#  u'P0080002',
#  u'P0080003',
#  u'P0080004',
#  u'P0080005',
#  u'P0080006',
#  u'P0080007',
#  u'P0080008',
#  u'P0080009',
#  u'P0080010',
#  u'P0080011',
#  u'P0080012',
#  u'P0080013',
#  u'P0080014',
#  u'P0080015',
#  u'P0080016',
#  u'P0080017',
#  u'P0080018',
#  u'P0080019',
#  u'P0080020',
#  u'P0080021',
#  u'P0080022',
#  u'P0080023',
#  u'P0080024',
#  u'P0080025',
#  u'P0080026',
#  u'P0080027',
#  u'P0080028',
#  u'P0080029',
#  u'P0080030',
#  u'P0080031',
#  u'P0080032',
#  u'P0080033',
#  u'P0080034',
#  u'P0080035',
#  u'P0080036',
#  u'P0080037',
#  u'P0080038',
#  u'P0080039',
#  u'P0080040',
#  u'P0080041',
#  u'P0080042',
#  u'P0080043',
#  u'P0080044',
#  u'P0080045',
#  u'P0080046',
#  u'P0080047',
#  u'P0080048',
#  u'P0080049',
#  u'P0080050',
#  u'P0080051',
#  u'P0080052',
#  u'P0080053',
#  u'P0080054',
#  u'P0080055',
#  u'P0080056',
#  u'P0080057',
#  u'P0080058',
#  u'P0080059',
#  u'P0080060',
#  u'P0080061',
#  u'P0080062',
#  u'P0080063',
#  u'P0080064',
#  u'P0080065',
#  u'P0080066',
#  u'P0080067',
#  u'P0080068',
#  u'P0080069',
#  u'P0080070',
#  u'P0080071',
#  u'P0090001',
#  u'P0090002',
#  u'P0090003',
#  u'P0090004',
#  u'P0090005',
#  u'P0090006',
#  u'P0090007',
#  u'P0090008',
#  u'P0090009',
#  u'P0090010',
#  u'P0090011',
#  u'P0090012',
#  u'P0090013',
#  u'P0090014',
#  u'P0090015',
#  u'P0090016',
#  u'P0090017',
#  u'P0090018',
#  u'P0090019',
#  u'P0090020',
#  u'P0090021',
#  u'P0090022',
#  u'P0090023',
#  u'P0090024',
#  u'P0090025',
#  u'P0090026',
#  u'P0090027',
#  u'P0090028',
#  u'P0090029',
#  u'P0090030',
#  u'P0090031',
#  u'P0090032',
#  u'P0090033',
#  u'P0090034',
#  u'P0090035',
#  u'P0090036',
#  u'P0090037',
#  u'P0090038',
#  u'P0090039',
#  u'P0090040',
#  u'P0090041',
#  u'P0090042',
#  u'P0090043',
#  u'P0090044',
#  u'P0090045',
#  u'P0090046',
#  u'P0090047',
#  u'P0090048',
#  u'P0090049',
#  u'P0090050',
#  u'P0090051',
#  u'P0090052',
#  u'P0090053',
#  u'P0090054',
#  u'P0090055',
#  u'P0090056',
#  u'P0090057',
#  u'P0090058',
#  u'P0090059',
#  u'P0090060',
#  u'P0090061',
#  u'P0090062',
#  u'P0090063',
#  u'P0090064',
#  u'P0090065',
#  u'P0090066',
#  u'P0090067',
#  u'P0090068',
#  u'P0090069',
#  u'P0090070',
#  u'P0090071',
#  u'P0090072',
#  u'P0090073',
#  u'P0100001',
#  u'P0100002',
#  u'P0100003',
#  u'P0100004',
#  u'P0100005',
#  u'P0100006',
#  u'P0100007',
#  u'P0100008',
#  u'P0100009',
#  u'P0100010',
#  u'P0100011',
#  u'P0100012',
#  u'P0100013',
#  u'P0100014',
#  u'P0100015',
#  u'P0100016',
#  u'P0100017',
#  u'P0100018',
#  u'P0100019',
#  u'P0100020',
#  u'P0100021',
#  u'P0100022',
#  u'P0100023',
#  u'P0100024',
#  u'P0100025',
#  u'P0100026',
#  u'P0100027',
#  u'P0100028',
#  u'P0100029',
#  u'P0100030',
#  u'P0100031',
#  u'P0100032',
#  u'P0100033',
#  u'P0100034',
#  u'P0100035',
#  u'P0100036',
#  u'P0100037',
#  u'P0100038',
#  u'P0100039',
#  u'P0100040',
#  u'P0100041',
#  u'P0100042',
#  u'P0100043',
#  u'P0100044',
#  u'P0100045',
#  u'P0100046',
#  u'P0100047',
#  u'P0100048',
#  u'P0100049',
#  u'P0100050',
#  u'P0100051',
#  u'P0100052',
#  u'P0100053',
#  u'P0100054',
#  u'P0100055',
#  u'P0100056',
#  u'P0100057',
#  u'P0100058',
#  u'P0100059',
#  u'P0100060',
#  u'P0100061',
#  u'P0100062',
#  u'P0100063',
#  u'P0100064',
#  u'P0100065',
#  u'P0100066',
#  u'P0100067',
#  u'P0100068',
#  u'P0100069',
#  u'P0100070',
#  u'P0100071',
#  u'P0110001',
#  u'P0110002',
#  u'P0110003',
#  u'P0110004',
#  u'P0110005',
#  u'P0110006',
#  u'P0110007',
#  u'P0110008',
#  u'P0110009',
#  u'P0110010',
#  u'P0110011',
#  u'P0110012',
#  u'P0110013',
#  u'P0110014',
#  u'P0110015',
#  u'P0110016',
#  u'P0110017',
#  u'P0110018',
#  u'P0110019',
#  u'P0110020',
#  u'P0110021',
#  u'P0110022',
#  u'P0110023',
#  u'P0110024',
#  u'P0110025',
#  u'P0110026',
#  u'P0110027',
#  u'P0110028',
#  u'P0110029',
#  u'P0110030',
#  u'P0110031',
#  u'P0110032',
#  u'P0110033',
#  u'P0110034',
#  u'P0110035',
#  u'P0110036',
#  u'P0110037',
#  u'P0110038',
#  u'P0110039',
#  u'P0110040',
#  u'P0110041',
#  u'P0110042',
#  u'P0110043',
#  u'P0110044',
#  u'P0110045',
#  u'P0110046',
#  u'P0110047',
#  u'P0110048',
#  u'P0110049',
#  u'P0110050',
#  u'P0110051',
#  u'P0110052',
#  u'P0110053',
#  u'P0110054',
#  u'P0110055',
#  u'P0110056',
#  u'P0110057',
#  u'P0110058',
#  u'P0110059',
#  u'P0110060',
#  u'P0110061',
#  u'P0110062',
#  u'P0110063',
#  u'P0110064',
#  u'P0110065',
#  u'P0110066',
#  u'P0110067',
#  u'P0110068',
#  u'P0110069',
#  u'P0110070',
#  u'P0110071',
#  u'P0110072',
#  u'P0110073',
#  u'P0120001',
#  u'P0120002',
#  u'P0120003',
#  u'P0120004',
#  u'P0120005',
#  u'P0120006',
#  u'P0120007',
#  u'P0120008',
#  u'P0120009',
#  u'P0120010',
#  u'P0120011',
#  u'P0120012',
#  u'P0120013',
#  u'P0120014',
#  u'P0120015',
#  u'P0120016',
#  u'P0120017',
#  u'P0120018',
#  u'P0120019',
#  u'P0120020',
#  u'P0120021',
#  u'P0120022',
#  u'P0120023',
#  u'P0120024',
#  u'P0120025',
#  u'P0120026',
#  u'P0120027',
#  u'P0120028',
#  u'P0120029',
#  u'P0120030',
#  u'P0120031',
#  u'P0120032',
#  u'P0120033',
#  u'P0120034',
#  u'P0120035',
#  u'P0120036',
#  u'P0120037',
#  u'P0120038',
#  u'P0120039',
#  u'P0120040',
#  u'P0120041',
#  u'P0120042',
#  u'P0120043',
#  u'P0120044',
#  u'P0120045',
#  u'P0120046',
#  u'P0120047',
#  u'P0120048',
#  u'P0120049',
#  u'P012A001',
#  u'P012A002',
#  u'P012A003',
#  u'P012A004',
#  u'P012A005',
#  u'P012A006',
#  u'P012A007',
#  u'P012A008',
#  u'P012A009',
#  u'P012A010',
#  u'P012A011',
#  u'P012A012',
#  u'P012A013',
#  u'P012A014',
#  u'P012A015',
#  u'P012A016',
#  u'P012A017',
#  u'P012A018',
#  u'P012A019',
#  u'P012A020',
#  u'P012A021',
#  u'P012A022',
#  u'P012A023',
#  u'P012A024',
#  u'P012A025',
#  u'P012A026',
#  u'P012A027',
#  u'P012A028',
#  u'P012A029',
#  u'P012A030',
#  u'P012A031',
#  u'P012A032',
#  u'P012A033',
#  u'P012A034',
#  u'P012A035',
#  u'P012A036',
#  u'P012A037',
#  u'P012A038',
#  u'P012A039',
#  u'P012A040',
#  u'P012A041',
#  u'P012A042',
#  u'P012A043',
#  u'P012A044',
#  u'P012A045',
#  u'P012A046',
#  u'P012A047',
#  u'P012A048',
#  u'P012A049',
#  u'P012B001',
#  u'P012B002',
#  u'P012B003',
#  u'P012B004',
#  u'P012B005',
#  u'P012B006',
#  u'P012B007',
#  u'P012B008',
#  u'P012B009',
#  u'P012B010',
#  u'P012B011',
#  u'P012B012',
#  u'P012B013',
#  u'P012B014',
#  u'P012B015',
#  u'P012B016',
#  u'P012B017',
#  u'P012B018',
#  u'P012B019',
#  u'P012B020',
#  u'P012B021',
#  u'P012B022',
#  u'P012B023',
#  u'P012B024',
#  u'P012B025',
#  u'P012B026',
#  u'P012B027',
#  u'P012B028',
#  u'P012B029',
#  u'P012B030',
#  u'P012B031',
#  u'P012B032',
#  u'P012B033',
#  u'P012B034',
#  u'P012B035',
#  u'P012B036',
#  u'P012B037',
#  u'P012B038',
#  u'P012B039',
#  u'P012B040',
#  u'P012B041',
#  u'P012B042',
#  u'P012B043',
#  u'P012B044',
#  u'P012B045',
#  u'P012B046',
#  u'P012B047',
#  u'P012B048',
#  u'P012B049',
#  u'P012C001',
#  u'P012C002',
#  u'P012C003',
#  u'P012C004',
#  u'P012C005',
#  u'P012C006',
#  u'P012C007',
#  u'P012C008',
#  u'P012C009',
#  u'P012C010',
#  u'P012C011',
#  u'P012C012',
#  u'P012C013',
#  u'P012C014',
#  u'P012C015',
#  u'P012C016',
#  u'P012C017',
#  u'P012C018',
#  u'P012C019',
#  u'P012C020',
#  u'P012C021',
#  u'P012C022',
#  u'P012C023',
#  u'P012C024',
#  u'P012C025',
#  u'P012C026',
#  u'P012C027',
#  u'P012C028',
#  u'P012C029',
#  u'P012C030',
#  u'P012C031',
#  u'P012C032',
#  u'P012C033',
#  u'P012C034',
#  u'P012C035',
#  u'P012C036',
#  u'P012C037',
#  u'P012C038',
#  u'P012C039',
#  u'P012C040',
#  u'P012C041',
#  u'P012C042',
#  u'P012C043',
#  u'P012C044',
#  u'P012C045',
#  u'P012C046',
#  u'P012C047',
#  u'P012C048',
#  u'P012C049',
#  u'P012D001',
#  u'P012D002',
#  u'P012D003',
#  u'P012D004',
#  u'P012D005',
#  u'P012D006',
#  u'P012D007',
#  u'P012D008',
#  u'P012D009',
#  u'P012D010',
#  u'P012D011',
#  u'P012D012',
#  u'P012D013',
#  u'P012D014',
#  u'P012D015',
#  u'P012D016',
#  u'P012D017',
#  u'P012D018',
#  u'P012D019',
#  u'P012D020',
#  u'P012D021',
#  u'P012D022',
#  u'P012D023',
#  u'P012D024',
#  u'P012D025',
#  u'P012D026',
#  u'P012D027',
#  u'P012D028',
#  u'P012D029',
#  u'P012D030',
#  u'P012D031',
#  u'P012D032',
#  u'P012D033',
#  u'P012D034',
#  u'P012D035',
#  u'P012D036',
#  u'P012D037',
#  u'P012D038',
#  u'P012D039',
#  u'P012D040',
#  u'P012D041',
#  u'P012D042',
#  u'P012D043',
#  u'P012D044',
#  u'P012D045',
#  u'P012D046',
#  u'P012D047',
#  u'P012D048',
#  u'P012D049',
#  u'P012E001',
#  u'P012E002',
#  u'P012E003',
#  u'P012E004',
#  u'P012E005',
#  u'P012E006',
#  u'P012E007',
#  u'P012E008',
#  u'P012E009',
#  u'P012E010',
#  u'P012E011',
#  u'P012E012',
#  u'P012E013',
#  u'P012E014',
#  u'P012E015',
#  u'P012E016',
#  u'P012E017',
#  u'P012E018',
#  u'P012E019',
#  u'P012E020',
#  u'P012E021',
#  u'P012E022',
#  u'P012E023',
#  u'P012E024',
#  u'P012E025',
#  u'P012E026',
#  u'P012E027',
#  u'P012E028',
#  u'P012E029',
#  u'P012E030',
#  u'P012E031',
#  u'P012E032',
#  u'P012E033',
#  u'P012E034',
#  u'P012E035',
#  u'P012E036',
#  u'P012E037',
#  u'P012E038',
#  u'P012E039',
#  u'P012E040',
#  u'P012E041',
#  u'P012E042',
#  u'P012E043',
#  u'P012E044',
#  u'P012E045',
#  u'P012E046',
#  u'P012E047',
#  u'P012E048',
#  u'P012E049',
#  u'P012F001',
#  u'P012F002',
#  u'P012F003',
#  u'P012F004',
#  u'P012F005',
#  u'P012F006',
#  u'P012F007',
#  u'P012F008',
#  u'P012F009',
#  u'P012F010',
#  u'P012F011',
#  u'P012F012',
#  u'P012F013',
#  u'P012F014',
#  u'P012F015',
#  u'P012F016',
#  u'P012F017',
#  u'P012F018',
#  u'P012F019',
#  u'P012F020',
#  u'P012F021',
#  u'P012F022',
#  u'P012F023',
#  u'P012F024',
#  u'P012F025',
#  u'P012F026',
#  u'P012F027',
#  u'P012F028',
#  u'P012F029',
#  u'P012F030',
#  u'P012F031',
#  u'P012F032',
#  u'P012F033',
#  u'P012F034',
#  u'P012F035',
#  u'P012F036',
#  u'P012F037',
#  u'P012F038',
#  u'P012F039',
#  u'P012F040',
#  u'P012F041',
#  u'P012F042',
#  u'P012F043',
#  u'P012F044',
#  u'P012F045',
#  u'P012F046',
#  u'P012F047',
#  u'P012F048',
#  u'P012F049',
#  u'P012G001',
#  u'P012G002',
#  u'P012G003',
#  u'P012G004',
#  u'P012G005',
#  u'P012G006',
#  u'P012G007',
#  u'P012G008',
#  u'P012G009',
#  u'P012G010',
#  u'P012G011',
#  u'P012G012',
#  u'P012G013',
#  u'P012G014',
#  u'P012G015',
#  u'P012G016',
#  u'P012G017',
#  u'P012G018',
#  u'P012G019',
#  u'P012G020',
#  u'P012G021',
#  u'P012G022',
#  u'P012G023',
#  u'P012G024',
#  u'P012G025',
#  u'P012G026',
#  u'P012G027',
#  u'P012G028',
#  u'P012G029',
#  u'P012G030',
#  u'P012G031',
#  u'P012G032',
#  u'P012G033',
#  u'P012G034',
#  u'P012G035',
#  u'P012G036',
#  u'P012G037',
#  u'P012G038',
#  u'P012G039',
#  u'P012G040',
#  u'P012G041',
#  u'P012G042',
#  u'P012G043',
#  u'P012G044',
#  u'P012G045',
#  u'P012G046',
#  u'P012G047',
#  u'P012G048',
#  u'P012G049',
#  u'P012H001',
#  u'P012H002',
#  u'P012H003',
#  u'P012H004',
#  u'P012H005',
#  u'P012H006',
#  u'P012H007',
#  u'P012H008',
#  u'P012H009',
#  u'P012H010',
#  u'P012H011',
#  u'P012H012',
#  u'P012H013',
#  u'P012H014',
#  u'P012H015',
#  u'P012H016',
#  u'P012H017',
#  u'P012H018',
#  u'P012H019',
#  u'P012H020',
#  u'P012H021',
#  u'P012H022',
#  u'P012H023',
#  u'P012H024',
#  u'P012H025',
#  u'P012H026',
#  u'P012H027',
#  u'P012H028',
#  u'P012H029',
#  u'P012H030',
#  u'P012H031',
#  u'P012H032',
#  u'P012H033',
#  u'P012H034',
#  u'P012H035',
#  u'P012H036',
#  u'P012H037',
#  u'P012H038',
#  u'P012H039',
#  u'P012H040',
#  u'P012H041',
#  u'P012H042',
#  u'P012H043',
#  u'P012H044',
#  u'P012H045',
#  u'P012H046',
#  u'P012H047',
#  u'P012H048',
#  u'P012H049',
#  u'P012I001',
#  u'P012I002',
#  u'P012I003',
#  u'P012I004',
#  u'P012I005',
#  u'P012I006',
#  u'P012I007',
#  u'P012I008',
#  u'P012I009',
#  u'P012I010',
#  u'P012I011',
#  u'P012I012',
#  u'P012I013',
#  u'P012I014',
#  u'P012I015',
#  u'P012I016',
#  u'P012I017',
#  u'P012I018',
#  u'P012I019',
#  u'P012I020',
#  u'P012I021',
#  u'P012I022',
#  u'P012I023',
#  u'P012I024',
#  u'P012I025',
#  u'P012I026',
#  u'P012I027',
#  u'P012I028',
#  u'P012I029',
#  u'P012I030',
#  u'P012I031',
#  u'P012I032',
#  u'P012I033',
#  u'P012I034',
#  u'P012I035',
#  u'P012I036',
#  u'P012I037',
#  u'P012I038',
#  u'P012I039',
#  u'P012I040',
#  u'P012I041',
#  u'P012I042',
#  u'P012I043',
#  u'P012I044',
#  u'P012I045',
#  u'P012I046',
#  u'P012I047',
#  u'P012I048',
#  u'P012I049',
#  u'P0130001',
#  u'P0130002',
#  u'P0130003',
#  u'P013A001',
#  u'P013A002',
#  u'P013A003',
#  u'P013B001',
#  u'P013B002',
#  u'P013B003',
#  u'P013C001',
#  u'P013C002',
#  u'P013C003',
#  u'P013D001',
#  u'P013D002',
#  u'P013D003',
#  u'P013E001',
#  u'P013E002',
#  u'P013E003',
#  u'P013F001',
#  u'P013F002',
#  u'P013F003',
#  u'P013G001',
#  u'P013G002',
#  u'P013G003',
#  u'P013H001',
#  u'P013H002',
#  u'P013H003',
#  u'P013I001',
#  u'P013I002',
#  u'P013I003',
#  u'P0140001',
#  u'P0140002',
#  u'P0140003',
#  u'P0140004',
#  u'P0140005',
#  u'P0140006',
#  u'P0140007',
#  u'P0140008',
#  u'P0140009',
#  u'P0140010',
#  u'P0140011',
#  u'P0140012',
#  u'P0140013',
#  u'P0140014',
#  u'P0140015',
#  u'P0140016',
#  u'P0140017',
#  u'P0140018',
#  u'P0140019',
#  u'P0140020',
#  u'P0140021',
#  u'P0140022',
#  u'P0140023',
#  u'P0140024',
#  u'P0140025',
#  u'P0140026',
#  u'P0140027',
#  u'P0140028',
#  u'P0140029',
#  u'P0140030',
#  u'P0140031',
#  u'P0140032',
#  u'P0140033',
#  u'P0140034',
#  u'P0140035',
#  u'P0140036',
#  u'P0140037',
#  u'P0140038',
#  u'P0140039',
#  u'P0140040',
#  u'P0140041',
#  u'P0140042',
#  u'P0140043',
#  u'P0150001',
#  u'P0150002',
#  u'P0150003',
#  u'P0150004',
#  u'P0150005',
#  u'P0150006',
#  u'P0150007',
#  u'P0150008',
#  u'P0150009',
#  u'P0150010',
#  u'P0150011',
#  u'P0150012',
#  u'P0150013',
#  u'P0150014',
#  u'P0150015',
#  u'P0150016',
#  u'P0150017',
#  u'P0160001',
#  u'P0160002',
#  u'P0160003',
#  u'P016A001',
#  u'P016A002',
#  u'P016A003',
#  u'P016B001',
#  u'P016B002',
#  u'P016B003',
#  u'P016C001',
#  u'P016C002',
#  u'P016C003',
#  u'P016D001',
#  u'P016D002',
#  u'P016D003',
#  u'P016E001',
#  u'P016E002',
#  u'P016E003',
#  u'P016F001',
#  u'P016F002',
#  u'P016F003',
#  u'P016G001',
#  u'P016G002',
#  u'P016G003',
#  u'P016H001',
#  u'P016H002',
#  u'P016H003',
#  u'P016I001',
#  u'P016I002',
#  u'P016I003',
#  u'P0170001',
#  u'P0170002',
#  u'P0170003',
#  u'P017A001',
#  u'P017A002',
#  u'P017A003',
#  u'P017B001',
#  u'P017B002',
#  u'P017B003',
#  u'P017C001',
#  u'P017C002',
#  u'P017C003',
#  u'P017D001',
#  u'P017D002',
#  u'P017D003',
#  u'P017E001',
#  u'P017E002',
#  u'P017E003',
#  u'P017F001',
#  u'P017F002',
#  u'P017F003',
#  u'P017G001',
#  u'P017G002',
#  u'P017G003',
#  u'P017H001',
#  u'P017H002',
#  u'P017H003',
#  u'P017I001',
#  u'P017I002',
#  u'P017I003',
#  u'P0180001',
#  u'P0180002',
#  u'P0180003',
#  u'P0180004',
#  u'P0180005',
#  u'P0180006',
#  u'P0180007',
#  u'P0180008',
#  u'P0180009',
#  u'P018A001',
#  u'P018A002',
#  u'P018A003',
#  u'P018A004',
#  u'P018A005',
#  u'P018A006',
#  u'P018A007',
#  u'P018A008',
#  u'P018A009',
#  u'P018B001',
#  u'P018B002',
#  u'P018B003',
#  u'P018B004',
#  u'P018B005',
#  u'P018B006',
#  u'P018B007',
#  u'P018B008',
#  u'P018B009',
#  u'P018C001',
#  u'P018C002',
#  u'P018C003',
#  u'P018C004',
#  u'P018C005',
#  u'P018C006',
#  u'P018C007',
#  u'P018C008',
#  u'P018C009',
#  u'P018D001',
#  u'P018D002',
#  u'P018D003',
#  u'P018D004',
#  u'P018D005',
#  u'P018D006',
#  u'P018D007',
#  u'P018D008',
#  u'P018D009',
#  u'P018E001',
#  u'P018E002',
#  u'P018E003',
#  u'P018E004',
#  u'P018E005',
#  u'P018E006',
#  u'P018E007',
#  u'P018E008',
#  u'P018E009',
#  u'P018F001',
#  u'P018F002',
#  u'P018F003',
#  u'P018F004',
#  u'P018F005',
#  u'P018F006',
#  u'P018F007',
#  u'P018F008',
#  u'P018F009',
#  u'P018G001',
#  u'P018G002',
#  u'P018G003',
#  u'P018G004',
#  u'P018G005',
#  u'P018G006',
#  u'P018G007',
#  u'P018G008',
#  u'P018G009',
#  u'P018H001',
#  u'P018H002',
#  u'P018H003',
#  u'P018H004',
#  u'P018H005',
#  u'P018H006',
#  u'P018H007',
#  u'P018H008',
#  u'P018H009',
#  u'P018I001',
#  u'P018I002',
#  u'P018I003',
#  u'P018I004',
#  u'P018I005',
#  u'P018I006',
#  u'P018I007',
#  u'P018I008',
#  u'P018I009',
#  u'P0190001',
#  u'P0190002',
#  u'P0190003',
#  u'P0190004',
#  u'P0190005',
#  u'P0190006',
#  u'P0190007',
#  u'P0190008',
#  u'P0190009',
#  u'P0190010',
#  u'P0190011',
#  u'P0190012',
#  u'P0190013',
#  u'P0190014',
#  u'P0190015',
#  u'P0190016',
#  u'P0190017',
#  u'P0190018',
#  u'P0190019',
#  u'P0200001',
#  u'P0200002',
#  u'P0200003',
#  u'P0200004',
#  u'P0200005',
#  u'P0200006',
#  u'P0200007',
#  u'P0200008',
#  u'P0200009',
#  u'P0200010',
#  u'P0200011',
#  u'P0200012',
#  u'P0200013',
#  u'P0200014',
#  u'P0200015',
#  u'P0200016',
#  u'P0200017',
#  u'P0200018',
#  u'P0200019',
#  u'P0200020',
#  u'P0200021',
#  u'P0200022',
#  u'P0200023',
#  u'P0200024',
#  u'P0200025',
#  u'P0200026',
#  u'P0200027',
#  u'P0200028',
#  u'P0200029',
#  u'P0200030',
#  u'P0200031',
#  u'P0200032',
#  u'P0200033',
#  u'P0200034',
#  u'P0210001',
#  u'P0210002',
#  u'P0210003',
#  u'P0210004',
#  u'P0210005',
#  u'P0210006',
#  u'P0210007',
#  u'P0210008',
#  u'P0210009',
#  u'P0210010',
#  u'P0210011',
#  u'P0210012',
#  u'P0210013',
#  u'P0210014',
#  u'P0210015',
#  u'P0210016',
#  u'P0210017',
#  u'P0210018',
#  u'P0210019',
#  u'P0210020',
#  u'P0210021',
#  u'P0210022',
#  u'P0210023',
#  u'P0210024',
#  u'P0210025',
#  u'P0210026',
#  u'P0210027',
#  u'P0210028',
#  u'P0210029',
#  u'P0210030',
#  u'P0210031',
#  u'P0220001',
#  u'P0220002',
#  u'P0220003',
#  u'P0220004',
#  u'P0220005',
#  u'P0220006',
#  u'P0220007',
#  u'P0220008',
#  u'P0220009',
#  u'P0220010',
#  u'P0220011',
#  u'P0220012',
#  u'P0220013',
#  u'P0220014',
#  u'P0220015',
#  u'P0220016',
#  u'P0220017',
#  u'P0220018',
#  u'P0220019',
#  u'P0220020',
#  u'P0220021',
#  u'P0230001',
#  u'P0230002',
#  u'P0230003',
#  u'P0230004',
#  u'P0230005',
#  u'P0230006',
#  u'P0230007',
#  u'P0230008',
#  u'P0230009',
#  u'P0230010',
#  u'P0230011',
#  u'P0230012',
#  u'P0230013',
#  u'P0230014',
#  u'P0230015',
#  u'P0240001',
#  u'P0240002',
#  u'P0240003',
#  u'P0240004',
#  u'P0240005',
#  u'P0240006',
#  u'P0240007',
#  u'P0240008',
#  u'P0240009',
#  u'P0240010',
#  u'P0240011',
#  u'P0250001',
#  u'P0250002',
#  u'P0250003',
#  u'P0250004',
#  u'P0250005',
#  u'P0250006',
#  u'P0250007',
#  u'P0250008',
#  u'P0250009',
#  u'P0250010',
#  u'P0250011',
#  u'P0260001',
#  u'P0260002',
#  u'P0260003',
#  u'P0260004',
#  u'P0260005',
#  u'P0260006',
#  u'P0260007',
#  u'P0260008',
#  u'P0260009',
#  u'P0260010',
#  u'P0260011',
#  u'P0270001',
#  u'P0270002',
#  u'P0270003',
#  u'P0280001',
#  u'P0280002',
#  u'P0280003',
#  u'P0280004',
#  u'P0280005',
#  u'P0280006',
#  u'P0280007',
#  u'P0280008',
#  u'P0280009',
#  u'P0280010',
#  u'P0280011',
#  u'P0280012',
#  u'P0280013',
#  u'P0280014',
#  u'P0280015',
#  u'P0280016',
#  u'P028A001',
#  u'P028A002',
#  u'P028A003',
#  u'P028A004',
#  u'P028A005',
#  u'P028A006',
#  u'P028A007',
#  u'P028A008',
#  u'P028A009',
#  u'P028A010',
#  u'P028A011',
#  u'P028A012',
#  u'P028A013',
#  u'P028A014',
#  u'P028A015',
#  u'P028A016',
#  u'P028B001',
#  u'P028B002',
#  u'P028B003',
#  u'P028B004',
#  u'P028B005',
#  u'P028B006',
#  u'P028B007',
#  u'P028B008',
#  u'P028B009',
#  u'P028B010',
#  u'P028B011',
#  u'P028B012',
#  u'P028B013',
#  u'P028B014',
#  u'P028B015',
#  u'P028B016',
#  u'P028C001',
#  u'P028C002',
#  u'P028C003',
#  u'P028C004',
#  u'P028C005',
#  u'P028C006',
#  u'P028C007',
#  u'P028C008',
#  u'P028C009',
#  u'P028C010',
#  u'P028C011',
#  u'P028C012',
#  u'P028C013',
#  u'P028C014',
#  u'P028C015',
#  u'P028C016',
#  u'P028D001',
#  u'P028D002',
#  u'P028D003',
#  u'P028D004',
#  u'P028D005',
#  u'P028D006',
#  u'P028D007',
#  u'P028D008',
#  u'P028D009',
#  u'P028D010',
#  u'P028D011',
#  u'P028D012',
#  u'P028D013',
#  u'P028D014',
#  u'P028D015',
#  u'P028D016',
#  u'P028E001',
#  u'P028E002',
#  u'P028E003',
#  u'P028E004',
#  u'P028E005',
#  u'P028E006',
#  u'P028E007',
#  u'P028E008',
#  u'P028E009',
#  u'P028E010',
#  u'P028E011',
#  u'P028E012',
#  u'P028E013',
#  u'P028E014',
#  u'P028E015',
#  u'P028E016',
#  u'P028F001',
#  u'P028F002',
#  u'P028F003',
#  u'P028F004',
#  u'P028F005',
#  u'P028F006',
#  u'P028F007',
#  u'P028F008',
#  u'P028F009',
#  u'P028F010',
#  u'P028F011',
#  u'P028F012',
#  u'P028F013',
#  u'P028F014',
#  u'P028F015',
#  u'P028F016',
#  u'P028G001',
#  u'P028G002',
#  u'P028G003',
#  u'P028G004',
#  u'P028G005',
#  u'P028G006',
#  u'P028G007',
#  u'P028G008',
#  u'P028G009',
#  u'P028G010',
#  u'P028G011',
#  u'P028G012',
#  u'P028G013',
#  u'P028G014',
#  u'P028G015',
#  u'P028G016',
#  u'P028H001',
#  u'P028H002',
#  u'P028H003',
#  u'P028H004',
#  u'P028H005',
#  u'P028H006',
#  u'P028H007',
#  u'P028H008',
#  u'P028H009',
#  u'P028H010',
#  u'P028H011',
#  u'P028H012',
#  u'P028H013',
#  u'P028H014',
#  u'P028H015',
#  u'P028H016',
#  u'P028I001',
#  u'P028I002',
#  u'P028I003',
#  u'P028I004',
#  u'P028I005',
#  u'P028I006',
#  u'P028I007',
#  u'P028I008',
#  u'P028I009',
#  u'P028I010',
#  u'P028I011',
#  u'P028I012',
#  u'P028I013',
#  u'P028I014',
#  u'P028I015',
#  u'P028I016',
#  u'P0290001',
#  u'P0290002',
#  u'P0290003',
#  u'P0290004',
#  u'P0290005',
#  u'P0290006',
#  u'P0290007',
#  u'P0290008',
#  u'P0290009',
#  u'P0290010',
#  u'P0290011',
#  u'P0290012',
#  u'P0290013',
#  u'P0290014',
#  u'P0290015',
#  u'P0290016',
#  u'P0290017',
#  u'P0290018',
#  u'P0290019',
#  u'P0290020',
#  u'P0290021',
#  u'P0290022',
#  u'P0290023',
#  u'P0290024',
#  u'P0290025',
#  u'P0290026',
#  u'P0290027',
#  u'P0290028',
#  u'P029A001',
#  u'P029A002',
#  u'P029A003',
#  u'P029A004',
#  u'P029A005',
#  u'P029A006',
#  u'P029A007',
#  u'P029A008',
#  u'P029A009',
#  u'P029A010',
#  u'P029A011',
#  u'P029A012',
#  u'P029A013',
#  u'P029A014',
#  u'P029A015',
#  u'P029A016',
#  u'P029A017',
#  u'P029A018',
#  u'P029A019',
#  u'P029A020',
#  u'P029A021',
#  u'P029A022',
#  u'P029A023',
#  u'P029A024',
#  u'P029A025',
#  u'P029A026',
#  u'P029A027',
#  u'P029A028',
#  u'P029B001',
#  u'P029B002',
#  u'P029B003',
#  u'P029B004',
#  u'P029B005',
#  u'P029B006',
#  u'P029B007',
#  u'P029B008',
#  u'P029B009',
#  u'P029B010',
#  u'P029B011',
#  u'P029B012',
#  u'P029B013',
#  u'P029B014',
#  u'P029B015',
#  u'P029B016',
#  u'P029B017',
#  u'P029B018',
#  u'P029B019',
#  u'P029B020',
#  u'P029B021',
#  u'P029B022',
#  u'P029B023',
#  u'P029B024',
#  u'P029B025',
#  u'P029B026',
#  u'P029B027',
#  u'P029B028',
#  u'P029C001',
#  u'P029C002',
#  u'P029C003',
#  u'P029C004',
#  u'P029C005',
#  u'P029C006',
#  u'P029C007',
#  u'P029C008',
#  u'P029C009',
#  u'P029C010',
#  u'P029C011',
#  u'P029C012',
#  u'P029C013',
#  u'P029C014',
#  u'P029C015',
#  u'P029C016',
#  u'P029C017',
#  u'P029C018',
#  u'P029C019',
#  u'P029C020',
#  u'P029C021',
#  u'P029C022',
#  u'P029C023',
#  u'P029C024',
#  u'P029C025',
#  u'P029C026',
#  u'P029C027',
#  u'P029C028',
#  u'P029D001',
#  u'P029D002',
#  u'P029D003',
#  u'P029D004',
#  u'P029D005',
#  u'P029D006',
#  u'P029D007',
#  u'P029D008',
#  u'P029D009',
#  u'P029D010',
#  u'P029D011',
#  u'P029D012',
#  u'P029D013',
#  u'P029D014',
#  u'P029D015',
#  u'P029D016',
#  u'P029D017',
#  u'P029D018',
#  u'P029D019',
#  u'P029D020',
#  u'P029D021',
#  u'P029D022',
#  u'P029D023',
#  u'P029D024',
#  u'P029D025',
#  u'P029D026',
#  u'P029D027',
#  u'P029D028',
#  u'P029E001',
#  u'P029E002',
#  u'P029E003',
#  u'P029E004',
#  u'P029E005',
#  u'P029E006',
#  u'P029E007',
#  u'P029E008',
#  u'P029E009',
#  u'P029E010',
#  u'P029E011',
#  u'P029E012',
#  u'P029E013',
#  u'P029E014',
#  u'P029E015',
#  u'P029E016',
#  u'P029E017',
#  u'P029E018',
#  u'P029E019',
#  u'P029E020',
#  u'P029E021',
#  u'P029E022',
#  u'P029E023',
#  u'P029E024',
#  u'P029E025',
#  u'P029E026',
#  u'P029E027',
#  u'P029E028',
#  u'P029F001',
#  u'P029F002',
#  u'P029F003',
#  u'P029F004',
#  u'P029F005',
#  u'P029F006',
#  u'P029F007',
#  u'P029F008',
#  u'P029F009',
#  u'P029F010',
#  u'P029F011',
#  u'P029F012',
#  u'P029F013',
#  u'P029F014',
#  u'P029F015',
#  u'P029F016',
#  u'P029F017',
#  u'P029F018',
#  u'P029F019',
#  u'P029F020',
#  u'P029F021',
#  u'P029F022',
#  u'P029F023',
#  u'P029F024',
#  u'P029F025',
#  u'P029F026',
#  u'P029F027',
#  u'P029F028',
#  u'P029G001',
#  u'P029G002',
#  u'P029G003',
#  u'P029G004',
#  u'P029G005',
#  u'P029G006',
#  u'P029G007',
#  u'P029G008',
#  u'P029G009',
#  u'P029G010',
#  u'P029G011',
#  u'P029G012',
#  u'P029G013',
#  u'P029G014',
#  u'P029G015',
#  u'P029G016',
#  u'P029G017',
#  u'P029G018',
#  u'P029G019',
#  u'P029G020',
#  u'P029G021',
#  u'P029G022',
#  u'P029G023',
#  u'P029G024',
#  u'P029G025',
#  u'P029G026',
#  u'P029G027',
#  u'P029G028',
#  u'P029H001',
#  u'P029H002',
#  u'P029H003',
#  u'P029H004',
#  u'P029H005',
#  u'P029H006',
#  u'P029H007',
#  u'P029H008',
#  u'P029H009',
#  u'P029H010',
#  u'P029H011',
#  u'P029H012',
#  u'P029H013',
#  u'P029H014',
#  u'P029H015',
#  u'P029H016',
#  u'P029H017',
#  u'P029H018',
#  u'P029H019',
#  u'P029H020',
#  u'P029H021',
#  u'P029H022',
#  u'P029H023',
#  u'P029H024',
#  u'P029H025',
#  u'P029H026',
#  u'P029H027',
#  u'P029H028',
#  u'P029I001',
#  u'P029I002',
#  u'P029I003',
#  u'P029I004',
#  u'P029I005',
#  u'P029I006',
#  u'P029I007',
#  u'P029I008',
#  u'P029I009',
#  u'P029I010',
#  u'P029I011',
#  u'P029I012',
#  u'P029I013',
#  u'P029I014',
#  u'P029I015',
#  u'P029I016',
#  u'P029I017',
#  u'P029I018',
#  u'P029I019',
#  u'P029I020',
#  u'P029I021',
#  u'P029I022',
#  u'P029I023',
#  u'P029I024',
#  u'P029I025',
#  u'P029I026',
#  u'P029I027',
#  u'P029I028',
#  u'P0300001',
#  u'P0300002',
#  u'P0300003',
#  u'P0300004',
#  u'P0300005',
#  u'P0300006',
#  u'P0300007',
#  u'P0300008',
#  u'P0300009',
#  u'P0300010',
#  u'P0300011',
#  u'P0300012',
#  u'P0300013',
#  u'P0310001',
#  u'P0310002',
#  u'P0310003',
#  u'P0310004',
#  u'P0310005',
#  u'P0310006',
#  u'P0310007',
#  u'P0310008',
#  u'P0310009',
#  u'P0310010',
#  u'P0310011',
#  u'P0310012',
#  u'P0310013',
#  u'P0310014',
#  u'P0310015',
#  u'P0310016',
#  u'P031A001',
#  u'P031A002',
#  u'P031A003',
#  u'P031A004',
#  u'P031A005',
#  u'P031A006',
#  u'P031A007',
#  u'P031A008',
#  u'P031A009',
#  u'P031A010',
#  u'P031A011',
#  u'P031A012',
#  u'P031A013',
#  u'P031A014',
#  u'P031A015',
#  u'P031A016',
#  u'P031B001',
#  u'P031B002',
#  u'P031B003',
#  u'P031B004',
#  u'P031B005',
#  u'P031B006',
#  u'P031B007',
#  u'P031B008',
#  u'P031B009',
#  u'P031B010',
#  u'P031B011',
#  u'P031B012',
#  u'P031B013',
#  u'P031B014',
#  u'P031B015',
#  u'P031B016',
#  u'P031C001',
#  u'P031C002',
#  u'P031C003',
#  u'P031C004',
#  u'P031C005',
#  u'P031C006',
#  u'P031C007',
#  u'P031C008',
#  u'P031C009',
#  u'P031C010',
#  u'P031C011',
#  u'P031C012',
#  u'P031C013',
#  u'P031C014',
#  u'P031C015',
#  u'P031C016',
#  u'P031D001',
#  u'P031D002',
#  u'P031D003',
#  u'P031D004',
#  u'P031D005',
#  u'P031D006',
#  u'P031D007',
#  u'P031D008',
#  u'P031D009',
#  u'P031D010',
#  u'P031D011',
#  u'P031D012',
#  u'P031D013',
#  u'P031D014',
#  u'P031D015',
#  u'P031D016',
#  u'P031E001',
#  u'P031E002',
#  u'P031E003',
#  u'P031E004',
#  u'P031E005',
#  u'P031E006',
#  u'P031E007',
#  u'P031E008',
#  u'P031E009',
#  u'P031E010',
#  u'P031E011',
#  u'P031E012',
#  u'P031E013',
#  u'P031E014',
#  u'P031E015',
#  u'P031E016',
#  u'P031F001',
#  u'P031F002',
#  u'P031F003',
#  u'P031F004',
#  u'P031F005',
#  u'P031F006',
#  u'P031F007',
#  u'P031F008',
#  u'P031F009',
#  u'P031F010',
#  u'P031F011',
#  u'P031F012',
#  u'P031F013',
#  u'P031F014',
#  u'P031F015',
#  u'P031F016',
#  u'P031G001',
#  u'P031G002',
#  u'P031G003',
#  u'P031G004',
#  u'P031G005',
#  u'P031G006',
#  u'P031G007',
#  u'P031G008',
#  u'P031G009',
#  u'P031G010',
#  u'P031G011',
#  u'P031G012',
#  u'P031G013',
#  u'P031G014',
#  u'P031G015',
#  u'P031G016',
#  u'P031H001',
#  u'P031H002',
#  u'P031H003',
#  u'P031H004',
#  u'P031H005',
#  u'P031H006',
#  u'P031H007',
#  u'P031H008',
#  u'P031H009',
#  u'P031H010',
#  u'P031H011',
#  u'P031H012',
#  u'P031H013',
#  u'P031H014',
#  u'P031H015',
#  u'P031H016',
#  u'P031I001',
#  u'P031I002',
#  u'P031I003',
#  u'P031I004',
#  u'P031I005',
#  u'P031I006',
#  u'P031I007',
#  u'P031I008',
#  u'P031I009',
#  u'P031I010',
#  u'P031I011',
#  u'P031I012',
#  u'P031I013',
#  u'P031I014',
#  u'P031I015',
#  u'P031I016',
#  u'P0320001',
#  u'P0320002',
#  u'P0320003',
#  u'P0320004',
#  u'P0320005',
#  u'P0320006',
#  u'P0320007',
#  u'P0320008',
#  u'P0320009',
#  u'P0320010',
#  u'P0320011',
#  u'P0320012',
#  u'P0320013',
#  u'P0320014',
#  u'P0320015',
#  u'P0320016',
#  u'P0320017',
#  u'P0320018',
#  u'P0320019',
#  u'P0320020',
#  u'P0320021',
#  u'P0320022',
#  u'P0320023',
#  u'P0320024',
#  u'P0320025',
#  u'P0320026',
#  u'P0320027',
#  u'P0320028',
#  u'P0320029',
#  u'P0320030',
#  u'P0320031',
#  u'P0320032',
#  u'P0320033',
#  u'P0320034',
#  u'P0320035',
#  u'P0320036',
#  u'P0320037',
#  u'P0320038',
#  u'P0320039',
#  u'P0320040',
#  u'P0320041',
#  u'P0320042',
#  u'P0320043',
#  u'P0320044',
#  u'P0320045',
#  u'P0330001',
#  u'P0330002',
#  u'P0330003',
#  u'P0330004',
#  u'P0330005',
#  u'P0330006',
#  u'P0330007',
#  u'P0340001',
#  u'P0340002',
#  u'P0340003',
#  u'P0340004',
#  u'P0340005',
#  u'P0340006',
#  u'P0340007',
#  u'P0340008',
#  u'P0340009',
#  u'P0340010',
#  u'P0340011',
#  u'P0340012',
#  u'P0340013',
#  u'P0340014',
#  u'P0340015',
#  u'P0340016',
#  u'P0340017',
#  u'P0340018',
#  u'P0340019',
#  u'P0340020',
#  u'P0340021',
#  u'P0340022',
#  u'P034A001',
#  u'P034A002',
#  u'P034A003',
#  u'P034A004',
#  u'P034A005',
#  u'P034A006',
#  u'P034A007',
#  u'P034A008',
#  u'P034A009',
#  u'P034A010',
#  u'P034A011',
#  u'P034A012',
#  u'P034A013',
#  u'P034A014',
#  u'P034A015',
#  u'P034A016',
#  u'P034A017',
#  u'P034A018',
#  u'P034A019',
#  u'P034A020',
#  u'P034A021',
#  u'P034A022',
#  u'P034B001',
#  u'P034B002',
#  u'P034B003',
#  u'P034B004',
#  u'P034B005',
#  u'P034B006',
#  u'P034B007',
#  u'P034B008',
#  u'P034B009',
#  u'P034B010',
#  u'P034B011',
#  u'P034B012',
#  u'P034B013',
#  u'P034B014',
#  u'P034B015',
#  u'P034B016',
#  u'P034B017',
#  u'P034B018',
#  u'P034B019',
#  u'P034B020',
#  u'P034B021',
#  u'P034B022',
#  u'P034C001',
#  u'P034C002',
#  u'P034C003',
#  u'P034C004',
#  u'P034C005',
#  u'P034C006',
#  u'P034C007',
#  u'P034C008',
#  u'P034C009',
#  u'P034C010',
#  u'P034C011',
#  u'P034C012',
#  u'P034C013',
#  u'P034C014',
#  u'P034C015',
#  u'P034C016',
#  u'P034C017',
#  u'P034C018',
#  u'P034C019',
#  u'P034C020',
#  u'P034C021',
#  u'P034C022',
#  u'P034D001',
#  u'P034D002',
#  u'P034D003',
#  u'P034D004',
#  u'P034D005',
#  u'P034D006',
#  u'P034D007',
#  u'P034D008',
#  u'P034D009',
#  u'P034D010',
#  u'P034D011',
#  u'P034D012',
#  u'P034D013',
#  u'P034D014',
#  u'P034D015',
#  u'P034D016',
#  u'P034D017',
#  u'P034D018',
#  u'P034D019',
#  u'P034D020',
#  u'P034D021',
#  u'P034D022',
#  u'P034E001',
#  u'P034E002',
#  u'P034E003',
#  u'P034E004',
#  u'P034E005',
#  u'P034E006',
#  u'P034E007',
#  u'P034E008',
#  u'P034E009',
#  u'P034E010',
#  u'P034E011',
#  u'P034E012',
#  u'P034E013',
#  u'P034E014',
#  u'P034E015',
#  u'P034E016',
#  u'P034E017',
#  u'P034E018',
#  u'P034E019',
#  u'P034E020',
#  u'P034E021',
#  u'P034E022',
#  u'P034F001',
#  u'P034F002',
#  u'P034F003',
#  u'P034F004',
#  u'P034F005',
#  u'P034F006',
#  u'P034F007',
#  u'P034F008',
#  u'P034F009',
#  u'P034F010',
#  u'P034F011',
#  u'P034F012',
#  u'P034F013',
#  u'P034F014',
#  u'P034F015',
#  u'P034F016',
#  u'P034F017',
#  u'P034F018',
#  u'P034F019',
#  u'P034F020',
#  u'P034F021',
#  u'P034F022',
#  u'P034G001',
#  u'P034G002',
#  u'P034G003',
#  u'P034G004',
#  u'P034G005',
#  u'P034G006',
#  u'P034G007',
#  u'P034G008',
#  u'P034G009',
#  u'P034G010',
#  u'P034G011',
#  u'P034G012',
#  u'P034G013',
#  u'P034G014',
#  u'P034G015',
#  u'P034G016',
#  u'P034G017',
#  u'P034G018',
#  u'P034G019',
#  u'P034G020',
#  u'P034G021',
#  u'P034G022',
#  u'P034H001',
#  u'P034H002',
#  u'P034H003',
#  u'P034H004',
#  u'P034H005',
#  u'P034H006',
#  u'P034H007',
#  u'P034H008',
#  u'P034H009',
#  u'P034H010',
#  u'P034H011',
#  u'P034H012',
#  u'P034H013',
#  u'P034H014',
#  u'P034H015',
#  u'P034H016',
#  u'P034H017',
#  u'P034H018',
#  u'P034H019',
#  u'P034H020',
#  u'P034H021',
#  u'P034H022',
#  u'P034I001',
#  u'P034I002',
#  u'P034I003',
#  u'P034I004',
#  u'P034I005',
#  u'P034I006',
#  u'P034I007',
#  u'P034I008',
#  u'P034I009',
#  u'P034I010',
#  u'P034I011',
#  u'P034I012',
#  u'P034I013',
#  u'P034I014',
#  u'P034I015',
#  u'P034I016',
#  u'P034I017',
#  u'P034I018',
#  u'P034I019',
#  u'P034I020',
#  u'P034I021',
#  u'P034I022',
#  u'P0350001',
#  u'P035A001',
#  u'P035B001',
#  u'P035C001',
#  u'P035D001',
#  u'P035E001',
#  u'P035F001',
#  u'P035G001',
#  u'P035H001',
#  u'P035I001',
#  u'P0360001',
#  u'P0360002',
#  u'P0360003',
#  u'P036A001',
#  u'P036A002',
#  u'P036A003',
#  u'P036B001',
#  u'P036B002',
#  u'P036B003',
#  u'P036C001',
#  u'P036C002',
#  u'P036C003',
#  u'P036D001',
#  u'P036D002',
#  u'P036D003',
#  u'P036E001',
#  u'P036E002',
#  u'P036E003',
#  u'P036F001',
#  u'P036F002',
#  u'P036F003',
#  u'P036G001',
#  u'P036G002',
#  u'P036G003',
#  u'P036H001',
#  u'P036H002',
#  u'P036H003',
#  u'P036I001',
#  u'P036I002',
#  u'P036I003',
#  u'P0370001',
#  u'P0370002',
#  u'P0370003',
#  u'P037A001',
#  u'P037A002',
#  u'P037A003',
#  u'P037B001',
#  u'P037B002',
#  u'P037B003',
#  u'P037C001',
#  u'P037C002',
#  u'P037C003',
#  u'P037D001',
#  u'P037D002',
#  u'P037D003',
#  u'P037E001',
#  u'P037E002',
#  u'P037E003',
#  u'P037F001',
#  u'P037F002',
#  u'P037F003',
#  u'P037G001',
#  u'P037G002',
#  u'P037G003',
#  u'P037H001',
#  u'P037H002',
#  u'P037H003',
#  u'P037I001',
#  u'P037I002',
#  u'P037I003',
#  u'P0380001',
#  u'P0380002',
#  u'P0380003',
#  u'P0380004',
#  u'P0380005',
#  u'P0380006',
#  u'P0380007',
#  u'P0380008',
#  u'P0380009',
#  u'P0380010',
#  u'P0380011',
#  u'P0380012',
#  u'P0380013',
#  u'P0380014',
#  u'P0380015',
#  u'P0380016',
#  u'P0380017',
#  u'P0380018',
#  u'P0380019',
#  u'P0380020',
#  u'P038A001',
#  u'P038A002',
#  u'P038A003',
#  u'P038A004',
#  u'P038A005',
#  u'P038A006',
#  u'P038A007',
#  u'P038A008',
#  u'P038A009',
#  u'P038A010',
#  u'P038A011',
#  u'P038A012',
#  u'P038A013',
#  u'P038A014',
#  u'P038A015',
#  u'P038A016',
#  u'P038A017',
#  u'P038A018',
#  u'P038A019',
#  u'P038A020',
#  u'P038B001',
#  u'P038B002',
#  u'P038B003',
#  u'P038B004',
#  u'P038B005',
#  u'P038B006',
#  u'P038B007',
#  u'P038B008',
#  u'P038B009',
#  u'P038B010',
#  u'P038B011',
#  u'P038B012',
#  u'P038B013',
#  u'P038B014',
#  u'P038B015',
#  u'P038B016',
#  u'P038B017',
#  u'P038B018',
#  u'P038B019',
#  u'P038B020',
#  u'P038C001',
#  u'P038C002',
#  u'P038C003',
#  u'P038C004',
#  u'P038C005',
#  u'P038C006',
#  u'P038C007',
#  u'P038C008',
#  u'P038C009',
#  u'P038C010',
#  u'P038C011',
#  u'P038C012',
#  u'P038C013',
#  u'P038C014',
#  u'P038C015',
#  u'P038C016',
#  u'P038C017',
#  u'P038C018',
#  u'P038C019',
#  u'P038C020',
#  u'P038D001',
#  u'P038D002',
#  u'P038D003',
#  u'P038D004',
#  u'P038D005',
#  u'P038D006',
#  u'P038D007',
#  u'P038D008',
#  u'P038D009',
#  u'P038D010',
#  u'P038D011',
#  u'P038D012',
#  u'P038D013',
#  u'P038D014',
#  u'P038D015',
#  u'P038D016',
#  u'P038D017',
#  u'P038D018',
#  u'P038D019',
#  u'P038D020',
#  u'P038E001',
#  u'P038E002',
#  u'P038E003',
#  u'P038E004',
#  u'P038E005',
#  u'P038E006',
#  u'P038E007',
#  u'P038E008',
#  u'P038E009',
#  u'P038E010',
#  u'P038E011',
#  u'P038E012',
#  u'P038E013',
#  u'P038E014',
#  u'P038E015',
#  u'P038E016',
#  u'P038E017',
#  u'P038E018',
#  u'P038E019',
#  u'P038E020',
#  u'P038F001',
#  u'P038F002',
#  u'P038F003',
#  u'P038F004',
#  u'P038F005',
#  u'P038F006',
#  u'P038F007',
#  u'P038F008',
#  u'P038F009',
#  u'P038F010',
#  u'P038F011',
#  u'P038F012',
#  u'P038F013',
#  u'P038F014',
#  u'P038F015',
#  u'P038F016',
#  u'P038F017',
#  u'P038F018',
#  u'P038F019',
#  u'P038F020',
#  u'P038G001',
#  u'P038G002',
#  u'P038G003',
#  u'P038G004',
#  u'P038G005',
#  u'P038G006',
#  u'P038G007',
#  u'P038G008',
#  u'P038G009',
#  u'P038G010',
#  u'P038G011',
#  u'P038G012',
#  u'P038G013',
#  u'P038G014',
#  u'P038G015',
#  u'P038G016',
#  u'P038G017',
#  u'P038G018',
#  u'P038G019',
#  u'P038G020',
#  u'P038H001',
#  u'P038H002',
#  u'P038H003',
#  u'P038H004',
#  u'P038H005',
#  u'P038H006',
#  u'P038H007',
#  u'P038H008',
#  u'P038H009',
#  u'P038H010',
#  u'P038H011',
#  u'P038H012',
#  u'P038H013',
#  u'P038H014',
#  u'P038H015',
#  u'P038H016',
#  u'P038H017',
#  u'P038H018',
#  u'P038H019',
#  u'P038H020',
#  u'P038I001',
#  u'P038I002',
#  u'P038I003',
#  u'P038I004',
#  u'P038I005',
#  u'P038I006',
#  u'P038I007',
#  u'P038I008',
#  u'P038I009',
#  u'P038I010',
#  u'P038I011',
#  u'P038I012',
#  u'P038I013',
#  u'P038I014',
#  u'P038I015',
#  u'P038I016',
#  u'P038I017',
#  u'P038I018',
#  u'P038I019',
#  u'P038I020',
#  u'P0390001',
#  u'P0390002',
#  u'P0390003',
#  u'P0390004',
#  u'P0390005',
#  u'P0390006',
#  u'P0390007',
#  u'P0390008',
#  u'P0390009',
#  u'P0390010',
#  u'P0390011',
#  u'P0390012',
#  u'P0390013',
#  u'P0390014',
#  u'P0390015',
#  u'P0390016',
#  u'P0390017',
#  u'P0390018',
#  u'P0390019',
#  u'P0390020',
#  u'P039A001',
#  u'P039A002',
#  u'P039A003',
#  u'P039A004',
#  u'P039A005',
#  u'P039A006',
#  u'P039A007',
#  u'P039A008',
#  u'P039A009',
#  u'P039A010',
#  u'P039A011',
#  u'P039A012',
#  u'P039A013',
#  u'P039A014',
#  u'P039A015',
#  u'P039A016',
#  u'P039A017',
#  u'P039A018',
#  u'P039A019',
#  u'P039A020',
#  u'P039B001',
#  u'P039B002',
#  u'P039B003',
#  u'P039B004',
#  u'P039B005',
#  u'P039B006',
#  u'P039B007',
#  u'P039B008',
#  u'P039B009',
#  u'P039B010',
#  u'P039B011',
#  u'P039B012',
#  u'P039B013',
#  u'P039B014',
#  u'P039B015',
#  u'P039B016',
#  u'P039B017',
#  u'P039B018',
#  u'P039B019',
#  u'P039B020',
#  u'P039C001',
#  u'P039C002',
#  u'P039C003',
#  u'P039C004',
#  u'P039C005',
#  u'P039C006',
#  u'P039C007',
#  u'P039C008',
#  u'P039C009',
#  u'P039C010',
#  u'P039C011',
#  u'P039C012',
#  u'P039C013',
#  u'P039C014',
#  u'P039C015',
#  u'P039C016',
#  u'P039C017',
#  u'P039C018',
#  u'P039C019',
#  u'P039C020',
#  u'P039D001',
#  u'P039D002',
#  u'P039D003',
#  u'P039D004',
#  u'P039D005',
#  u'P039D006',
#  u'P039D007',
#  u'P039D008',
#  u'P039D009',
#  u'P039D010',
#  u'P039D011',
#  u'P039D012',
#  u'P039D013',
#  u'P039D014',
#  u'P039D015',
#  u'P039D016',
#  u'P039D017',
#  u'P039D018',
#  u'P039D019',
#  u'P039D020',
#  u'P039E001',
#  u'P039E002',
#  u'P039E003',
#  u'P039E004',
#  u'P039E005',
#  u'P039E006',
#  u'P039E007',
#  u'P039E008',
#  u'P039E009',
#  u'P039E010',
#  u'P039E011',
#  u'P039E012',
#  u'P039E013',
#  u'P039E014',
#  u'P039E015',
#  u'P039E016',
#  u'P039E017',
#  u'P039E018',
#  u'P039E019',
#  u'P039E020',
#  u'P039F001',
#  u'P039F002',
#  u'P039F003',
#  u'P039F004',
#  u'P039F005',
#  u'P039F006',
#  u'P039F007',
#  u'P039F008',
#  u'P039F009',
#  u'P039F010',
#  u'P039F011',
#  u'P039F012',
#  u'P039F013',
#  u'P039F014',
#  u'P039F015',
#  u'P039F016',
#  u'P039F017',
#  u'P039F018',
#  u'P039F019',
#  u'P039F020',
#  u'P039G001',
#  u'P039G002',
#  u'P039G003',
#  u'P039G004',
#  u'P039G005',
#  u'P039G006',
#  u'P039G007',
#  u'P039G008',
#  u'P039G009',
#  u'P039G010',
#  u'P039G011',
#  u'P039G012',
#  u'P039G013',
#  u'P039G014',
#  u'P039G015',
#  u'P039G016',
#  u'P039G017',
#  u'P039G018',
#  u'P039G019',
#  u'P039G020',
#  u'P039H001',
#  u'P039H002',
#  u'P039H003',
#  u'P039H004',
#  u'P039H005',
#  u'P039H006',
#  u'P039H007',
#  u'P039H008',
#  u'P039H009',
#  u'P039H010',
#  u'P039H011',
#  u'P039H012',
#  u'P039H013',
#  u'P039H014',
#  u'P039H015',
#  u'P039H016',
#  u'P039H017',
#  u'P039H018',
#  u'P039H019',
#  u'P039H020',
#  u'P039I001',
#  u'P039I002',
#  u'P039I003',
#  u'P039I004',
#  u'P039I005',
#  u'P039I006',
#  u'P039I007',
#  u'P039I008',
#  u'P039I009',
#  u'P039I010',
#  u'P039I011',
#  u'P039I012',
#  u'P039I013',
#  u'P039I014',
#  u'P039I015',
#  u'P039I016',
#  u'P039I017',
#  u'P039I018',
#  u'P039I019',
#  u'P039I020',
#  u'P0400001',
#  u'P0400002',
#  u'P0400003',
#  u'P0400004',
#  u'P0400005',
#  u'P0400006',
#  u'P0400007',
#  u'P0400008',
#  u'P0400009',
#  u'P0400010',
#  u'P0400011',
#  u'P0400012',
#  u'P0400013',
#  u'P0400014',
#  u'P0400015',
#  u'P0400016',
#  u'P0400017',
#  u'P0400018',
#  u'P0400019',
#  u'P0400020',
#  u'P0410001',
#  u'P0410002',
#  u'P0410003',
#  u'P0410004',
#  u'P0410005',
#  u'P0410006',
#  u'P0420001',
#  u'P0420002',
#  u'P0420003',
#  u'P0420004',
#  u'P0420005',
#  u'P0420006',
#  u'P0420007',
#  u'P0420008',
#  u'P0420009',
#  u'P0420010',
#  u'P0430001',
#  u'P0430002',
#  u'P0430003',
#  u'P0430004',
#  u'P0430005',
#  u'P0430006',
#  u'P0430007',
#  u'P0430008',
#  u'P0430009',
#  u'P0430010',
#  u'P0430011',
#  u'P0430012',
#  u'P0430013',
#  u'P0430014',
#  u'P0430015',
#  u'P0430016',
#  u'P0430017',
#  u'P0430018',
#  u'P0430019',
#  u'P0430020',
#  u'P0430021',
#  u'P0430022',
#  u'P0430023',
#  u'P0430024',
#  u'P0430025',
#  u'P0430026',
#  u'P0430027',
#  u'P0430028',
#  u'P0430029',
#  u'P0430030',
#  u'P0430031',
# ...
#  u'PCT013I026',
#  u'PCT013I027',
#  u'PCT013I028',
#  u'PCT013I029',
#  u'PCT013I030',
#  u'PCT013I031',
#  u'PCT013I032',
#  u'PCT013I033',
#  u'PCT013I034',
#  u'PCT013I035',
#  u'PCT013I036',
#  u'PCT013I037',
#  u'PCT013I038',
#  u'PCT013I039',
#  u'PCT013I040',
#  u'PCT013I041',
#  u'PCT013I042',
#  u'PCT013I043',
#  u'PCT013I044',
#  u'PCT013I045',
#  u'PCT013I046',
#  u'PCT013I047',
#  u'PCT013I048',
#  u'PCT013I049',
#  u'PCT0140001',
#  u'PCT0140002',
#  u'PCT0140003',
#  u'PCT014A001',
#  u'PCT014A002',
#  u'PCT014A003',
#  u'PCT014B001',
#  u'PCT014B002',
#  u'PCT014B003',
#  u'PCT014C001',
#  u'PCT014C002',
#  u'PCT014C003',
#  u'PCT014D001',
#  u'PCT014D002',
#  u'PCT014D003',
#  u'PCT014E001',
#  u'PCT014E002',
#  u'PCT014E003',
#  u'PCT014F001',
#  u'PCT014F002',
#  u'PCT014F003',
#  u'PCT014G001',
#  u'PCT014G002',
#  u'PCT014G003',
#  u'PCT014H001',
#  u'PCT014H002',
#  u'PCT014H003',
#  u'PCT014I001',
#  u'PCT014I002',
#  u'PCT014I003',
#  u'PCT0150001',
#  u'PCT0150002',
#  u'PCT0150003',
#  u'PCT0150004',
#  u'PCT0150005',
#  u'PCT0150006',
#  u'PCT0150007',
#  u'PCT0150008',
#  u'PCT0150009',
#  u'PCT0150010',
#  u'PCT0150011',
#  u'PCT0150012',
#  u'PCT0150013',
#  u'PCT0150014',
#  u'PCT0150015',
#  u'PCT0150016',
#  u'PCT0150017',
#  u'PCT0150018',
#  u'PCT0150019',
#  u'PCT0150020',
#  u'PCT0150021',
#  u'PCT0150022',
#  u'PCT0150023',
#  u'PCT0150024',
#  u'PCT0150025',
#  u'PCT0150026',
#  u'PCT0150027',
#  u'PCT0150028',
#  u'PCT0150029',
#  u'PCT0150030',
#  u'PCT0150031',
#  u'PCT0150032',
#  u'PCT0150033',
#  u'PCT0150034',
#  u'PCT0160001',
#  u'PCT0160002',
#  u'PCT0160003',
#  u'PCT0160004',
#  u'PCT0160005',
#  u'PCT0160006',
#  u'PCT0160007',
#  u'PCT0160008',
#  u'PCT0160009',
#  u'PCT0160010',
#  u'PCT0160011',
#  u'PCT0160012',
#  u'PCT0160013',
#  u'PCT0160014',
#  u'PCT0160015',
#  u'PCT0160016',
#  u'PCT0160017',
#  u'PCT0160018',
#  u'PCT0160019',
#  u'PCT0160020',
#  u'PCT0160021',
#  u'PCT0160022',
#  u'PCT0160023',
#  u'PCT0160024',
#  u'PCT0160025',
#  u'PCT0160026',
#  u'PCT0170001',
#  u'PCT0170002',
#  u'PCT0170003',
#  u'PCT0170004',
#  u'PCT0170005',
#  u'PCT0170006',
#  u'PCT0170007',
#  u'PCT0170008',
#  u'PCT0170009',
#  u'PCT0170010',
#  u'PCT0170011',
#  u'PCT0170012',
#  u'PCT0170013',
#  u'PCT0170014',
#  u'PCT0170015',
#  u'PCT0170016',
#  u'PCT0170017',
#  u'PCT0170018',
#  u'PCT0180001',
#  u'PCT0180002',
#  u'PCT0180003',
#  u'PCT0180004',
#  u'PCT0180005',
#  u'PCT0180006',
#  u'PCT0180007',
#  u'PCT0180008',
#  u'PCT0180009',
#  u'PCT0180010',
#  u'PCT0180011',
#  u'PCT0180012',
#  u'PCT0180013',
#  u'PCT0180014',
#  u'PCT0180015',
#  u'PCT0190001',
#  u'PCT0190002',
#  u'PCT0190003',
#  u'PCT0190004',
#  u'PCT0190005',
#  u'PCT0190006',
#  u'PCT0190007',
#  u'PCT0190008',
#  u'PCT0190009',
#  u'PCT0190010',
#  u'PCT0190011',
#  u'PCT019A001',
#  u'PCT019A002',
#  u'PCT019A003',
#  u'PCT019A004',
#  u'PCT019A005',
#  u'PCT019A006',
#  u'PCT019A007',
#  u'PCT019A008',
#  u'PCT019A009',
#  u'PCT019A010',
#  u'PCT019A011',
#  u'PCT019B001',
#  u'PCT019B002',
#  u'PCT019B003',
#  u'PCT019B004',
#  u'PCT019B005',
#  u'PCT019B006',
#  u'PCT019B007',
#  u'PCT019B008',
#  u'PCT019B009',
#  u'PCT019B010',
#  u'PCT019B011',
#  u'PCT019C001',
#  u'PCT019C002',
#  u'PCT019C003',
#  u'PCT019C004',
#  u'PCT019C005',
#  u'PCT019C006',
#  u'PCT019C007',
#  u'PCT019C008',
#  u'PCT019C009',
#  u'PCT019C010',
#  u'PCT019C011',
#  u'PCT019D001',
#  u'PCT019D002',
#  u'PCT019D003',
#  u'PCT019D004',
#  u'PCT019D005',
#  u'PCT019D006',
#  u'PCT019D007',
#  u'PCT019D008',
#  u'PCT019D009',
#  u'PCT019D010',
#  u'PCT019D011',
#  u'PCT019E001',
#  u'PCT019E002',
#  u'PCT019E003',
#  u'PCT019E004',
#  u'PCT019E005',
#  u'PCT019E006',
#  u'PCT019E007',
#  u'PCT019E008',
#  u'PCT019E009',
#  u'PCT019E010',
#  u'PCT019E011',
#  u'PCT019F001',
#  u'PCT019F002',
#  u'PCT019F003',
#  u'PCT019F004',
#  u'PCT019F005',
#  u'PCT019F006',
#  u'PCT019F007',
#  u'PCT019F008',
#  u'PCT019F009',
#  u'PCT019F010',
#  u'PCT019F011',
#  u'PCT019G001',
#  u'PCT019G002',
#  u'PCT019G003',
#  u'PCT019G004',
#  u'PCT019G005',
#  u'PCT019G006',
#  u'PCT019G007',
#  u'PCT019G008',
#  u'PCT019G009',
#  u'PCT019G010',
#  u'PCT019G011',
#  u'PCT019H001',
#  u'PCT019H002',
#  u'PCT019H003',
#  u'PCT019H004',
#  u'PCT019H005',
#  u'PCT019H006',
#  u'PCT019H007',
#  u'PCT019H008',
#  u'PCT019H009',
#  u'PCT019H010',
#  u'PCT019H011',
#  u'PCT019I001',
#  u'PCT019I002',
#  u'PCT019I003',
#  u'PCT019I004',
#  u'PCT019I005',
#  u'PCT019I006',
#  u'PCT019I007',
#  u'PCT019I008',
#  u'PCT019I009',
#  u'PCT019I010',
#  u'PCT019I011',
#  u'PCT0200001',
#  u'PCT0200002',
#  u'PCT0200003',
#  u'PCT0200004',
#  u'PCT0200005',
#  u'PCT0200006',
#  u'PCT0200007',
#  u'PCT0200008',
#  u'PCT0200009',
#  u'PCT0200010',
#  u'PCT0200011',
#  u'PCT0200012',
#  u'PCT0200013',
#  u'PCT0200014',
#  u'PCT0200015',
#  u'PCT0200016',
#  u'PCT0200017',
#  u'PCT0200018',
#  u'PCT0200019',
#  u'PCT0200020',
#  u'PCT0200021',
#  u'PCT0200022',
#  u'PCT0200023',
#  u'PCT0200024',
#  u'PCT0200025',
#  u'PCT0200026',
#  u'PCT0200027',
#  u'PCT0200028',
#  u'PCT0200029',
#  u'PCT0200030',
#  u'PCT0200031',
#  u'PCT0200032',
#  u'PCT020A001',
#  u'PCT020A002',
#  u'PCT020A003',
#  u'PCT020A004',
#  u'PCT020A005',
#  u'PCT020A006',
#  u'PCT020A007',
#  u'PCT020A008',
#  u'PCT020A009',
#  u'PCT020A010',
#  u'PCT020A011',
#  u'PCT020A012',
#  u'PCT020A013',
#  u'PCT020A014',
#  u'PCT020A015',
#  u'PCT020A016',
#  u'PCT020A017',
#  u'PCT020A018',
#  u'PCT020A019',
#  u'PCT020A020',
#  u'PCT020A021',
#  u'PCT020A022',
#  u'PCT020A023',
#  u'PCT020A024',
#  u'PCT020A025',
#  u'PCT020A026',
#  u'PCT020A027',
#  u'PCT020A028',
#  u'PCT020A029',
#  u'PCT020A030',
#  u'PCT020A031',
#  u'PCT020A032',
#  u'PCT020B001',
#  u'PCT020B002',
#  u'PCT020B003',
#  u'PCT020B004',
#  u'PCT020B005',
#  u'PCT020B006',
#  u'PCT020B007',
#  u'PCT020B008',
#  u'PCT020B009',
#  u'PCT020B010',
#  u'PCT020B011',
#  u'PCT020B012',
#  u'PCT020B013',
#  u'PCT020B014',
#  u'PCT020B015',
#  u'PCT020B016',
#  u'PCT020B017',
#  u'PCT020B018',
#  u'PCT020B019',
#  u'PCT020B020',
#  u'PCT020B021',
#  u'PCT020B022',
#  u'PCT020B023',
#  u'PCT020B024',
#  u'PCT020B025',
#  u'PCT020B026',
#  u'PCT020B027',
#  u'PCT020B028',
#  u'PCT020B029',
#  u'PCT020B030',
#  u'PCT020B031',
#  u'PCT020B032',
#  u'PCT020C001',
#  u'PCT020C002',
#  u'PCT020C003',
#  u'PCT020C004',
#  u'PCT020C005',
#  u'PCT020C006',
#  u'PCT020C007',
#  u'PCT020C008',
#  u'PCT020C009',
#  u'PCT020C010',
#  u'PCT020C011',
#  u'PCT020C012',
#  u'PCT020C013',
#  u'PCT020C014',
#  u'PCT020C015',
#  u'PCT020C016',
#  u'PCT020C017',
#  u'PCT020C018',
#  u'PCT020C019',
#  u'PCT020C020',
#  u'PCT020C021',
#  u'PCT020C022',
#  u'PCT020C023',
#  u'PCT020C024',
#  u'PCT020C025',
#  u'PCT020C026',
#  u'PCT020C027',
#  u'PCT020C028',
#  u'PCT020C029',
#  u'PCT020C030',
#  u'PCT020C031',
#  u'PCT020C032',
#  u'PCT020D001',
#  u'PCT020D002',
#  u'PCT020D003',
#  u'PCT020D004',
#  u'PCT020D005',
#  u'PCT020D006',
#  u'PCT020D007',
#  u'PCT020D008',
#  u'PCT020D009',
#  u'PCT020D010',
#  u'PCT020D011',
#  u'PCT020D012',
#  u'PCT020D013',
#  u'PCT020D014',
#  u'PCT020D015',
#  u'PCT020D016',
#  u'PCT020D017',
#  u'PCT020D018',
#  u'PCT020D019',
#  u'PCT020D020',
#  u'PCT020D021',
#  u'PCT020D022',
#  u'PCT020D023',
#  u'PCT020D024',
#  u'PCT020D025',
#  u'PCT020D026',
#  u'PCT020D027',
#  u'PCT020D028',
#  u'PCT020D029',
#  u'PCT020D030',
#  u'PCT020D031',
#  u'PCT020D032',
#  u'PCT020E001',
#  u'PCT020E002',
#  u'PCT020E003',
#  u'PCT020E004',
#  u'PCT020E005',
#  u'PCT020E006',
#  u'PCT020E007',
#  u'PCT020E008',
#  u'PCT020E009',
#  u'PCT020E010',
#  u'PCT020E011',
#  u'PCT020E012',
#  u'PCT020E013',
#  u'PCT020E014',
#  u'PCT020E015',
#  u'PCT020E016',
#  u'PCT020E017',
#  u'PCT020E018',
#  u'PCT020E019',
#  u'PCT020E020',
#  u'PCT020E021',
#  u'PCT020E022',
#  u'PCT020E023',
#  u'PCT020E024',
#  u'PCT020E025',
#  u'PCT020E026',
#  u'PCT020E027',
#  u'PCT020E028',
#  u'PCT020E029',
#  u'PCT020E030',
#  u'PCT020E031',
#  u'PCT020E032',
#  u'PCT020F001',
#  u'PCT020F002',
#  u'PCT020F003',
#  u'PCT020F004',
#  u'PCT020F005',
#  u'PCT020F006',
#  u'PCT020F007',
#  u'PCT020F008',
#  u'PCT020F009',
#  u'PCT020F010',
#  u'PCT020F011',
#  u'PCT020F012',
#  u'PCT020F013',
#  u'PCT020F014',
#  u'PCT020F015',
#  u'PCT020F016',
#  u'PCT020F017',
#  u'PCT020F018',
#  u'PCT020F019',
#  u'PCT020F020',
#  u'PCT020F021',
#  u'PCT020F022',
#  u'PCT020F023',
#  u'PCT020F024',
#  u'PCT020F025',
#  u'PCT020F026',
#  u'PCT020F027',
#  u'PCT020F028',
#  u'PCT020F029',
#  u'PCT020F030',
#  u'PCT020F031',
#  u'PCT020F032',
#  u'PCT020G001',
#  u'PCT020G002',
#  u'PCT020G003',
#  u'PCT020G004',
#  u'PCT020G005',
#  u'PCT020G006',
#  u'PCT020G007',
#  u'PCT020G008',
#  u'PCT020G009',
#  u'PCT020G010',
#  u'PCT020G011',
#  u'PCT020G012',
#  u'PCT020G013',
#  u'PCT020G014',
#  u'PCT020G015',
#  u'PCT020G016',
#  u'PCT020G017',
#  u'PCT020G018',
#  u'PCT020G019',
#  u'PCT020G020',
#  u'PCT020G021',
#  u'PCT020G022',
#  u'PCT020G023',
#  u'PCT020G024',
#  u'PCT020G025',
#  u'PCT020G026',
#  u'PCT020G027',
#  u'PCT020G028',
#  u'PCT020G029',
#  u'PCT020G030',
#  u'PCT020G031',
#  u'PCT020G032',
#  u'PCT020H001',
#  u'PCT020H002',
#  u'PCT020H003',
#  u'PCT020H004',
#  u'PCT020H005',
#  u'PCT020H006',
#  u'PCT020H007',
#  u'PCT020H008',
#  u'PCT020H009',
#  u'PCT020H010',
#  u'PCT020H011',
#  u'PCT020H012',
#  u'PCT020H013',
#  u'PCT020H014',
#  u'PCT020H015',
#  u'PCT020H016',
#  u'PCT020H017',
#  u'PCT020H018',
#  u'PCT020H019',
#  u'PCT020H020',
#  u'PCT020H021',
#  u'PCT020H022',
#  u'PCT020H023',
#  u'PCT020H024',
#  u'PCT020H025',
#  u'PCT020H026',
#  u'PCT020H027',
#  u'PCT020H028',
#  u'PCT020H029',
#  u'PCT020H030',
#  u'PCT020H031',
#  u'PCT020H032',
#  u'PCT020I001',
#  u'PCT020I002',
#  u'PCT020I003',
#  u'PCT020I004',
#  u'PCT020I005',
#  u'PCT020I006',
#  u'PCT020I007',
#  u'PCT020I008',
#  u'PCT020I009',
#  u'PCT020I010',
#  u'PCT020I011',
#  u'PCT020I012',
#  u'PCT020I013',
#  u'PCT020I014',
#  u'PCT020I015',
#  u'PCT020I016',
#  u'PCT020I017',
#  u'PCT020I018',
#  u'PCT020I019',
#  u'PCT020I020',
#  u'PCT020I021',
#  u'PCT020I022',
#  u'PCT020I023',
#  u'PCT020I024',
#  u'PCT020I025',
#  u'PCT020I026',
#  u'PCT020I027',
#  u'PCT020I028',
#  u'PCT020I029',
#  u'PCT020I030',
#  u'PCT020I031',
#  u'PCT020I032',
#  u'PCT0210001',
#  u'PCT0210002',
#  u'PCT0210003',
#  u'PCT0210004',
#  u'PCT0210005',
#  u'PCT0210006',
#  u'PCT0210007',
#  u'PCT0210008',
#  u'PCT0210009',
#  u'PCT0210010',
#  u'PCT0210011',
#  u'PCT0210012',
#  u'PCT0210013',
#  u'PCT0210014',
#  u'PCT0210015',
#  u'PCT0210016',
#  u'PCT0210017',
#  u'PCT0210018',
#  u'PCT0210019',
#  u'PCT0210020',
#  u'PCT0210021',
#  u'PCT0210022',
#  u'PCT0210023',
#  u'PCT0210024',
#  u'PCT0210025',
#  u'PCT0210026',
#  u'PCT0210027',
#  u'PCT0210028',
#  u'PCT0210029',
#  u'PCT0210030',
#  u'PCT0210031',
#  u'PCT0210032',
#  u'PCT0210033',
#  u'PCT0210034',
#  u'PCT0210035',
#  u'PCT0210036',
#  u'PCT0210037',
#  u'PCT0210038',
#  u'PCT0210039',
#  u'PCT0210040',
#  u'PCT0210041',
#  u'PCT0210042',
#  u'PCT0210043',
#  u'PCT0210044',
#  u'PCT0210045',
#  u'PCT0210046',
#  u'PCT0210047',
#  u'PCT0210048',
#  u'PCT0210049',
#  u'PCT0210050',
#  u'PCT0210051',
#  u'PCT0210052',
#  u'PCT0210053',
#  u'PCT0210054',
#  u'PCT0210055',
#  u'PCT0210056',
#  u'PCT0210057',
#  u'PCT0210058',
#  u'PCT0210059',
#  u'PCT0210060',
#  u'PCT0210061',
#  u'PCT0210062',
#  u'PCT0210063',
#  u'PCT0210064',
#  u'PCT0210065',
#  u'PCT0210066',
#  u'PCT0210067',
#  u'PCT0210068',
#  u'PCT0210069',
#  u'PCT0210070',
#  u'PCT0210071',
#  u'PCT0210072',
#  u'PCT0210073',
#  u'PCT0210074',
#  u'PCT0210075',
#  u'PCT0210076',
#  u'PCT0210077',
#  u'PCT0210078',
#  u'PCT0210079',
#  u'PCT0210080',
#  u'PCT0210081',
#  u'PCT0210082',
#  u'PCT0210083',
#  u'PCT0210084',
#  u'PCT0210085',
#  u'PCT0210086',
#  u'PCT0210087',
#  u'PCT0210088',
#  u'PCT0210089',
#  u'PCT0210090',
#  u'PCT0210091',
#  u'PCT0210092',
#  u'PCT0210093',
#  u'PCT0210094',
#  u'PCT0210095',
#  u'PCT0210096',
#  u'PCT0210097',
#  u'PCT0210098',
#  u'PCT0210099',
#  u'PCT0210100',
#  u'PCT0210101',
#  u'PCT0210102',
#  u'PCT0210103',
#  u'PCT0210104',
#  u'PCT0210105',
#  u'PCT0210106',
#  u'PCT0210107',
#  u'PCT0210108',
#  u'PCT0210109',
#  u'PCT0210110',
#  u'PCT0210111',
#  u'PCT0210112',
#  u'PCT0210113',
#  u'PCT0210114',
#  u'PCT0210115',
#  u'PCT0210116',
#  u'PCT0210117',
#  u'PCT0210118',
#  u'PCT0210119',
#  u'PCT0210120',
#  u'PCT0210121',
#  u'PCT0210122',
#  u'PCT0210123',
#  u'PCT0210124',
#  u'PCT0210125',
#  u'PCT0210126',
#  u'PCT0210127',
#  u'PCT0210128',
#  u'PCT0210129',
#  u'PCT0210130',
#  u'PCT0210131',
#  u'PCT0210132',
#  u'PCT0210133',
#  u'PCT0210134',
#  u'PCT0210135',
#  u'PCT0210136',
#  u'PCT0210137',
#  u'PCT0210138',
#  u'PCT0210139',
#  u'PCT0210140',
#  u'PCT0210141',
#  u'PCT0210142',
#  u'PCT0210143',
#  u'PCT0210144',
#  u'PCT0210145',
#  u'PCT0210146',
#  u'PCT0210147',
#  u'PCT0210148',
#  u'PCT0210149',
#  u'PCT0210150',
#  u'PCT0210151',
#  u'PCT0210152',
#  u'PCT0210153',
#  u'PCT0210154',
#  u'PCT0210155',
#  u'PCT0210156',
#  u'PCT0210157',
#  u'PCT0210158',
#  u'PCT0210159',
#  u'PCT0210160',
#  u'PCT0210161',
#  u'PCT0210162',
#  u'PCT0210163',
#  u'PCT0210164',
#  u'PCT0210165',
#  u'PCT0210166',
#  u'PCT0210167',
#  u'PCT0210168',
#  u'PCT0210169',
#  u'PCT0210170',
#  u'PCT0210171',
#  u'PCT0210172',
#  u'PCT0210173',
#  u'PCT0210174',
#  u'PCT0210175',
#  u'PCT0210176',
#  u'PCT0210177',
#  u'PCT0210178',
#  u'PCT0210179',
#  u'PCT0210180',
#  u'PCT0210181',
#  u'PCT0210182',
#  u'PCT0210183',
#  u'PCT0210184',
#  u'PCT0210185',
#  u'PCT0210186',
#  u'PCT0210187',
#  u'PCT0210188',
#  u'PCT0210189',
#  u'PCT0210190',
#  u'PCT0210191',
#  u'PCT0210192',
#  u'PCT0210193',
#  u'PCT0210194',
#  u'PCT0210195',
#  u'PCT0220001',
#  u'PCT0220002',
#  u'PCT0220003',
#  u'PCT0220004',
#  u'PCT0220005',
#  u'PCT0220006',
#  u'PCT0220007',
#  u'PCT0220008',
#  u'PCT0220009',
#  u'PCT0220010',
#  u'PCT0220011',
#  u'PCT0220012',
#  u'PCT0220013',
#  u'PCT0220014',
#  u'PCT0220015',
#  u'PCT0220016',
#  u'PCT0220017',
#  u'PCT0220018',
#  u'PCT0220019',
#  u'PCT0220020',
#  u'PCT0220021',
#  u'PCT022A001',
#  u'PCT022A002',
#  u'PCT022A003',
#  u'PCT022A004',
#  u'PCT022A005',
#  u'PCT022A006',
#  u'PCT022A007',
#  u'PCT022A008',
#  u'PCT022A009',
#  u'PCT022A010',
#  u'PCT022A011',
#  u'PCT022A012',
#  u'PCT022A013',
#  u'PCT022A014',
#  u'PCT022A015',
#  u'PCT022A016',
#  u'PCT022A017',
#  u'PCT022A018',
#  u'PCT022A019',
#  u'PCT022A020',
#  u'PCT022A021',
#  u'PCT022B001',
#  u'PCT022B002',
#  u'PCT022B003',
#  u'PCT022B004',
#  u'PCT022B005',
#  u'PCT022B006',
#  u'PCT022B007',
#  u'PCT022B008',
#  u'PCT022B009',
#  u'PCT022B010',
#  u'PCT022B011',
#  u'PCT022B012',
#  u'PCT022B013',
#  u'PCT022B014',
#  u'PCT022B015',
#  u'PCT022B016',
#  u'PCT022B017',
#  u'PCT022B018',
#  u'PCT022B019',
#  u'PCT022B020',
#  u'PCT022B021',
#  u'PCT022C001',
#  u'PCT022C002',
#  u'PCT022C003',
#  u'PCT022C004',
#  u'PCT022C005',
#  u'PCT022C006',
#  u'PCT022C007',
#  u'PCT022C008',
#  u'PCT022C009',
#  u'PCT022C010',
#  u'PCT022C011',
#  u'PCT022C012',
#  u'PCT022C013',
#  u'PCT022C014',
#  u'PCT022C015',
#  u'PCT022C016',
#  u'PCT022C017',
#  u'PCT022C018',
#  u'PCT022C019',
#  u'PCT022C020',
#  u'PCT022C021',
#  u'PCT022D001',
#  u'PCT022D002',
#  u'PCT022D003',
#  u'PCT022D004',
#  u'PCT022D005',
#  u'PCT022D006',
#  u'PCT022D007',
#  u'PCT022D008',
#  u'PCT022D009',
#  u'PCT022D010',
#  u'PCT022D011',
#  u'PCT022D012',
#  u'PCT022D013',
#  u'PCT022D014',
#  u'PCT022D015',
#  u'PCT022D016',
#  u'PCT022D017',
#  u'PCT022D018',
#  u'PCT022D019',
#  u'PCT022D020',
#  u'PCT022D021',
#  u'PCT022E001',
#  u'PCT022E002',
#  u'PCT022E003',
#  u'PCT022E004',
#  u'PCT022E005',
#  u'PCT022E006',
#  u'PCT022E007',
#  u'PCT022E008',
#  u'PCT022E009',
#  u'PCT022E010',
#  u'PCT022E011',
#  u'PCT022E012',
#  u'PCT022E013',
#  u'PCT022E014',
#  u'PCT022E015',
#  u'PCT022E016',
#  u'PCT022E017',
#  u'PCT022E018',
#  u'PCT022E019',
#  u'PCT022E020',
#  u'PCT022E021',
#  u'PCT022F001',
#  u'PCT022F002',
#  u'PCT022F003',
#  u'PCT022F004',
#  u'PCT022F005',
#  u'PCT022F006',
#  u'PCT022F007',
#  u'PCT022F008',
#  u'PCT022F009',
#  u'PCT022F010',
#  u'PCT022F011',
#  u'PCT022F012',
#  u'PCT022F013',
#  u'PCT022F014',
#  u'PCT022F015',
#  u'PCT022F016',
#  u'PCT022F017',
#  u'PCT022F018',
#  u'PCT022F019',
#  u'PCT022F020',
#  u'PCT022F021',
#  u'PCT022G001',
#  u'PCT022G002',
#  u'PCT022G003',
#  u'PCT022G004',
#  u'PCT022G005',
#  u'PCT022G006',
#  u'PCT022G007',
#  u'PCT022G008',
#  u'PCT022G009',
#  u'PCT022G010',
#  u'PCT022G011',
#  u'PCT022G012',
#  u'PCT022G013',
#  u'PCT022G014',
#  u'PCT022G015',
#  u'PCT022G016',
#  u'PCT022G017',
#  u'PCT022G018',
#  u'PCT022G019',
#  u'PCT022G020',
#  u'PCT022G021',
#  u'PCT022H001',
#  u'PCT022H002',
#  u'PCT022H003',
#  u'PCT022H004',
#  u'PCT022H005',
#  u'PCT022H006',
#  u'PCT022H007',
#  u'PCT022H008',
#  u'PCT022H009',
#  u'PCT022H010',
#  u'PCT022H011',
#  u'PCT022H012',
#  u'PCT022H013',
#  u'PCT022H014',
#  u'PCT022H015',
#  u'PCT022H016',
#  u'PCT022H017',
#  u'PCT022H018',
#  u'PCT022H019',
#  u'PCT022H020',
#  u'PCT022H021',
#  u'PCT022I001',
#  u'PCT022I002',
#  u'PCT022I003',
#  u'PCT022I004',
#  u'PCT022I005',
#  u'PCT022I006',
#  u'PCT022I007',
#  u'PCT022I008',
#  u'PCT022I009',
#  u'PCT022I010',
#  u'PCT022I011',
#  u'PCT022I012',
#  u'PCT022I013',
#  u'PCT022I014',
#  u'PCT022I015',
#  u'PCT022I016',
#  u'PCT022I017',
#  u'PCT022I018',
#  u'PCT022I019',
#  u'PCT022I020',
#  u'PCT022I021',
#  u'PLACE',
#  u'PLACECC',
#  u'REGION',
#  u'SDELEM',
#  u'SDSEC',
#  u'SDUNI',
#  u'SLDL',
#  u'SLDL2',
#  u'SLDL3',
#  u'SLDL4',
#  u'SLDU',
#  u'SLDU2',
#  u'SLDU3',
#  u'SLDU4',
#  u'STATE',
#  u'SUBMCD',
#  u'SUBMDCC',
#  u'SUMLEV',
#  u'TRACT',
#  u'UASC',
#  u'UATYPE',
#  u'UGA',
#  u'UR',
#  u'VTD',
#  u'ZCTA5']

# %%
var_json['variables']['P0050002']
# Out:
# {u'concept': u'P5. HISPANIC OR LATINO ORIGIN BY RACE [17]',
#  u'label': u'Not Hispanic or Latino:'}

# %%
from pandas import DataFrame
DataFrame(var_json['variables']).T
# Out:
#                                                      concept  \
# AIANHH                              Geographic Summary Level
# AIANHHCC                          Geographic Characteristics
# AIANHHFP                          Geographic Characteristics
# AIHHTLI                           Geographic Characteristics
# AITS                              Geographic Characteristics
# AITSCC                            Geographic Characteristics
# AITSCE                            Geographic Characteristics
# ANRC                              Geographic Characteristics
# BLKGRP                              Geographic Summary Level
# BLOCK                                                    NaN
# CBSA                                Geographic Summary Level
# CBSAPCI                           Geographic Characteristics
# CD                                  Geographic Summary Level
# CD113                             Geographic Characteristics
# CNECTA                            Geographic Characteristics
# CONCIT                              Geographic Summary Level
# CONCITSC                          Geographic Characteristics
# COUNTY                              Geographic Summary Level
# COUSUB                              Geographic Summary Level
# CSA                                 Geographic Summary Level
# DIVISION                            Geographic Summary Level
# GEOCOMP                           Geographic Characteristics
# H00010001                              H1. Housing Units [1]
# H0020001   H2. URBAN AND RURAL [6] (Urban/Rural Update only)
# H0020002   H2. URBAN AND RURAL [6] (Urban/Rural Update only)
# H0020003   H2. URBAN AND RURAL [6] (Urban/Rural Update only)
# H0020004   H2. URBAN AND RURAL [6] (Urban/Rural Update only)
# H0020005   H2. URBAN AND RURAL [6] (Urban/Rural Update only)
# H0020006   H2. URBAN AND RURAL [6] (Urban/Rural Update only)
# H0030001                            H3. Occupancy Status [3]
# H0030002                            H3. Occupancy Status [3]
# H0030003                            H3. Occupancy Status [3]
# H0040001                                      H4. TENURE [4]
# H0040002                                      H4. TENURE [4]
# H0040003                                      H4. TENURE [4]
# H0040004                                      H4. TENURE [4]
# H0050001                              H5. VACANCY STATUS [8]
# H0050002                              H5. VACANCY STATUS [8]
# H0050003                              H5. VACANCY STATUS [8]
# H0050004                              H5. VACANCY STATUS [8]
# H0050005                              H5. VACANCY STATUS [8]
# H0050006                              H5. VACANCY STATUS [8]
# H0050007                              H5. VACANCY STATUS [8]
# H0050008                              H5. VACANCY STATUS [8]
# H0060001                         H6. Race Of Householder [8]
# H0060002                         H6. Race Of Householder [8]
# H0060003                         H6. Race Of Householder [8]
# H0060004                         H6. Race Of Householder [8]
# H0060005                         H6. Race Of Householder [8]
# H0060006                         H6. Race Of Householder [8]
# H0060007                         H6. Race Of Householder [8]
# H0060008                         H6. Race Of Householder [8]
# H0070001   H7. HISPANIC OR LATINO ORIGIN OF HOUSEHOLDER B...
# H0070002   H7. HISPANIC OR LATINO ORIGIN OF HOUSEHOLDER B...
# H0070003   H7. HISPANIC OR LATINO ORIGIN OF HOUSEHOLDER B...
# H0070004   H7. HISPANIC OR LATINO ORIGIN OF HOUSEHOLDER B...
# H0070005   H7. HISPANIC OR LATINO ORIGIN OF HOUSEHOLDER B...
# H0070006   H7. HISPANIC OR LATINO ORIGIN OF HOUSEHOLDER B...
# H0070007   H7. HISPANIC OR LATINO ORIGIN OF HOUSEHOLDER B...
# H0070008   H7. HISPANIC OR LATINO ORIGIN OF HOUSEHOLDER B...
#                                                          ...
#
#                                                        label
# AIANHH                                      GEO PLACE HOLDER
# AIANHHCC                                    GEO PLACE HOLDER
# AIANHHFP                                    GEO PLACE HOLDER
# AIHHTLI                                     GEO PLACE HOLDER
# AITS                                        GEO PLACE HOLDER
# AITSCC                                      GEO PLACE HOLDER
# AITSCE                                      GEO PLACE HOLDER
# ANRC                                        GEO PLACE HOLDER
# BLKGRP                                      GEO PLACE HOLDER
# BLOCK                                       GEO PLACE HOLDER
# CBSA                                        GEO PLACE HOLDER
# CBSAPCI                                     GEO PLACE HOLDER
# CD                                          GEO PLACE HOLDER
# CD113                                       GEO PLACE HOLDER
# CNECTA                                      GEO PLACE HOLDER
# CONCIT                                      GEO PLACE HOLDER
# CONCITSC                                    GEO PLACE HOLDER
# COUNTY                                        County (FIPS))
# COUSUB                                      GEO PLACE HOLDER
# CSA                                         GEO PLACE HOLDER
# DIVISION                                    GEO PLACE HOLDER
# GEOCOMP                                     GEO PLACE HOLDER
# H00010001                                      Housing units
# H0020001                                       Housing units
# H0020002                                              Urban:
# H0020003                    Urban: !! Inside urbanized areas
# H0020004                     Urban: !! Inside urban clusters
# H0020005                      Rural !! Inside urban clusters
# H0020006   Not defined for this file !! Inside urban clus...
# H0030001                                       Housing units
# H0030002                                            Occupied
# H0030003                                              Vacant
# H0040001                              Occupied housing units
# H0040002                     Owned with a mortgage or a loan
# H0040003                                Owned free and clear
# H0040004                                     Renter occupied
# H0050001                                Vacant housing units
# H0050002                                            For rent
# H0050003                                Rented, not occupied
# H0050004                                       For sale only
# H0050005                                  Sold, not occupied
# H0050006       For seasonal, recreational, or occasional use
# H0050007                                 For migrant workers
# H0050008                                        Other vacant
# H0060001                              Occupied housing units
# H0060002                      Householder who is White alone
# H0060003   Householder who is Black or African American a...
# H0060004   Householder who is American Indian and Alaska ...
# H0060005                      Householder who is Asian alone
# H0060006   Householder who is Native Hawaiian and Other P...
# H0060007            Householder who is Some Other Race alone
# H0060008                Householder who is Two or More Races
# H0070001                              Occupied housing units
# H0070002                 Not Hispanic or Latino householder:
# H0070003   Not Hispanic or Latino householder: !! Househo...
# H0070004   Not Hispanic or Latino householder: !! Househo...
# H0070005   Not Hispanic or Latino householder: !! Househo...
# H0070006   Not Hispanic or Latino householder: !! Househo...
# H0070007   Not Hispanic or Latino householder: !! Househo...
# H0070008   Not Hispanic or Latino householder: !! Househo...
#                                                          ...
#
# [8966 rows x 2 columns]

# %% [markdown]
# # Plotting Age Distribution By Gender (Population Pyramid)

# %% [markdown]
# This example written by AJ Renold.

# %%
sf1_fields = c.sf1.fields(year=2010)

# Get the sf1 fields that are only P12 Sex By Age
gender_population_fields = sf1_fields.get('P12. Sex By Age [49]')

# Separate the by male and female
male_fields = { key: val for key, val in gender_population_fields.items() 
                                 if 'Male' in val and val != ' Male: ' }
female_fields = { key: val for key, val in gender_population_fields.items() 
                                   if 'Female' in val and val != ' Female: '}

# %%
# Query the census API with the gender_population_fields
query_results = c.sf1.get(('NAME', ','.join(gender_population_fields.keys())), geo={'for': 'state:*'})

# Create a DataFrame
gender_df = pd.DataFrame(query_results)

# %%
# Set the Index to the NAME column
gender_df = gender_df.set_index(gender_df['NAME'])

# %%
# Recast all numeric columns to be type int
for col in gender_df.columns:
    if col != "state" and col != "NAME":
        gender_df[col] = gender_df[col].astype(int)

# %%
from numpy import arange

def showPopulationPyramidPlot(df, state, male_fields, female_fields):
    
    # create a series with the row of the state
    s = Series(df.ix[state])
    #del s['NAME']
    #del s['state']
    
    # get the plot values and labels from the series
    male_list = sorted([ [key, s[key]] for key in s.keys() if key in male_fields ])
    female_list = sorted([ [key, s[key]] for key in s.keys() if key in female_fields ]) 
    
    # calculate the bar locations and the maximum value
    bar_ypos = arange(len(male_list))+.5
    max_val = max([ val for label, val in male_list + female_list ])
    
    # create the figures for the plots
    fig, (ax2, ax1) = plt.subplots(nrows=1, ncols=2, figsize=(18,8))
    fig.suptitle('Population Age Pyramid for {state}'.format(state=state), fontsize=14)
    
    # plot the male populations
    bar1 = ax1.barh(bar_ypos, [ val for label, val in male_list ], align='center')
    ax1.set_xlim((0,max_val))
    ax1.set_yticks(bar_ypos)
    ax1.set_yticklabels([ male_fields[label][male_fields[label].find('!!')+3:] for label, val in male_list ])
    ax1.set_xlabel('People')
    ax1.set_title('Male Population by Age')
    ax1.grid(True)
    
    # plot the the female populations
    bar2 = ax2.barh(bar_ypos,[ val for label, val in female_list ], align='center', color='red')
    ax2.set_yticks([])
    #ax2.yaxis.tick_right()
    ax2.set_xlim(ax1.get_xlim()[::-1]) # reverses the x axis direction
    ax2.set_xlabel('People')
    ax2.set_title('Female Population by Age')
    ax2.grid(True)
    
    plt.subplots_adjust(wspace=0.22, hspace=0.0)
    plt.show()

# %%
showPopulationPyramidPlot(gender_df, 'Illinois', male_fields, female_fields)
