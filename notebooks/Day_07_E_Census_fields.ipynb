# %%
# %pylab --no-import-all inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
#  import useful classes of pandas
import pandas as pd
from pandas import Series, DataFrame, Index

# %%
import settings
import census
import requests

c = census.Census(key=settings.CENSUS_KEY)

# %%
census.__version__
# Out:
# '0.7'

# %%
c.sf1.fields
# Out:
# <bound method SF1Client.fields of <census.core.SF1Client object at 0x10994bd90>>

# %% [markdown]
# # Fields in SF1

# %%
sf1_fields = c.sf1.fields(year=2010)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-e4444f43e956> in <module>()
# ----> 1 sf1_fields = c.sf1.fields(year=2010)
#
# /Users/raymondyee/anaconda/envs/myenv/lib/python2.7/site-packages/census/core.pyc in fields(self, year, flat)
#      86             raise CensusException('%s is not available for %s' % (self.dataset, year))
#      87
# ---> 88         resp = requests.get(fields_url)
#      89         doc = XML(resp.text)
#      90
#
# NameError: global name 'requests' is not defined

# %%
sorted(sf1_fields.keys())

# %% [markdown]
# Let's parse more of pieces that are in the fields

# %%
# let's just parse sf1.xml ourselves to get the concepts
# http://lxml.de/parsing.html

from lxml import etree
from itertools import islice
import re

def parse_concept_name(concept_name):
    if concept_name != 'Geographic Characteristics':
        m = re.search("(.+\.)\s+(.*)\s+(\[\d+\])",concept_name)
        if m: 
           return {'label':m.group(1),
                  'clean_name':m.group(2),
                  'num_vars':re.search("\[(\d+)\]", m.group(3)).group(1)
                  }
       # print m.groups()
        else:
           m1 = re.search("(.+\.)\s+(.*)\s+",concept_name)
           return {'label':m1.group(1),
                  'clean_name':m1.group(2),
                  'num_vars':0
                 }
    else:
        return None
    
def concepts_2010_sf1():
    # http://www.census.gov/developers/data/sf1.xml
    SF1_XML_PATH  = "/Users/raymondyee/D/Document/Working_with_Open_Data/working-open-data-2014/data/sf1.xml"

    doc = etree.parse(SF1_XML_PATH)
    for concept in doc.findall("//concept"):
        concept_name = concept.attrib['name']
        
        if concept_name != 'Geographic Characteristics':
            m = re.search("(.+\.)\s+(.*)\s+(\[\d+\])",concept_name)
            if m: 
               yield {'label':m.group(1),
                      'clean_name':m.group(2),
                      'num_vars':re.search("\[(\d+)\]", m.group(3)).group(1)
                      }
           # print m.groups()
            else:
               m1 = re.search("(.+\.)\s+(.*)\s+",concept_name)
               yield {'label':m1.group(1),
                      'clean_name':m1.group(2),
                      'num_vars':0
                     }
            
k = list(concepts_2010_sf1())

# %%
df = DataFrame(k, columns=('label','clean_name','num_vars'))
df.head()

# %%
import re

def sort_label(label):
    (l1, l2, l3) = re.search("([A-Z,a-z]+)(\d+)([A-Z,a-z]*)\.",label).groups()
    return l1 + " " + "{l2:03d}".format(l2=int(l2)) + l3

df['sort_label'] = df.label.apply(sort_label)

# %%
df[df.label.str.startswith("P5")]

# %%
# let's go right for the variables and generate a dict, DF

from lxml import etree
from itertools import islice
from collections import OrderedDict

SF1_XML_PATH  = "/Users/raymondyee/D/Document/Working_with_Open_Data/working-open-data-2014/data/sf1.xml"

doc = etree.parse(SF1_XML_PATH)
variables = doc.findall("//variable")

variables_dict = OrderedDict([(v.attrib['name'], 
                               {'concept':v.attrib['concept'],
                                'text': v.text
                                }) for v in variables])

# %%
variables_dict['P0050001']

# %%
def P005_range(n0,n1): 
    return tuple(('P005'+ "{i:04d}".format(i=i) for i in xrange(n0,n1)))

P005_vars = P005_range(1,18)
P005_vars_str = ",".join(P005_vars)

[(v,variables_dict[v]['text']) for v in P005_vars]

# %%
variables_df = DataFrame(variables_dict)
variables_df.head()

# %%
variables_df.T.concept.apply(parse_concept_name)

# %%
parse_concept_name(variables_dict['P0050001']['concept'])

# %% [markdown]
# # api.json

# %%
# http://www.census.gov/developers/

import requests
url = "http://api.census.gov/data.json"
api_json = requests.get(url).json()
api_json
# Out:
# [{u'accessLevel': u'public',
#   u'bureauCode': [u'006:07'],
#   u'c_dataset': [u'acs5'],
#   u'c_documentationLink': u'http://www.census.gov/developers/',
#   u'c_geographyLink': u'http://api.census.gov/data/2010/acs5/geography.json',
#   u'c_isAggregate': True,
#   u'c_tagsLink': u'http://api.census.gov/data/2010/acs5/tags.json',
#   u'c_variablesLink': u'http://api.census.gov/data/2010/acs5/variables.json',
#   u'c_vintage': 2010,
#   u'contactPoint': u'Census Bureau Call Center',
#   u'description': u"The American Community Survey (ACS) is a nationwide survey designed to provide communities a fresh look at how they are changing. The ACS replaced the decennial census long form in 2010 and thereafter by collecting long form type information throughout the decade rather than only once every 10 years.  Questionnaires are mailed to a sample of addresses to obtain information about households -- that is, about each person and the housing unit itself.  The American Community Survey produces demographic, social, housing and economic estimates in the form of 1-year, 3-year and 5-year estimates based on population thresholds. The strength of the ACS is in estimating population and housing characteristics. It produces estimates for small areas, including census tracts and population subgroups.  Although the ACS produces population, demographic and housing unit estimates,it is the Census Bureau's Population Estimates Program that produces and disseminates the official estimates of the population for the nation, states, counties, cities and towns, and estimates of housing units for states and counties.  For 2010 and other decennial census years, the Decennial Census provides the official counts of population and housing units.",
#   u'identifier': u'2010acs5',
#   u'mbox': u'pio@census.gov',
#   u'publisher': u'US Census Bureau',
#   u'references': [u'http://www.census.gov/developers/'],
#   u'spatial': u'US',
#   u'temporal': u'2010',
#   u'title': u'2010 American Community Survey: 5-Year Estimates',
#   u'webService': u'http://api.census.gov/data/2010/acs5'},
#  {u'accessLevel': u'public',
#   u'bureauCode': [u'006:07'],
#   u'c_dataset': [u'ewks'],
#   u'c_documentationLink': u'http://www.census.gov/developer/',
#   u'c_examplesLink': u'http://api.census.gov/data/2007/ewks/examples.json',
#   u'c_geographyLink': u'http://api.census.gov/data/2007/ewks/geography.json',
#   u'c_isAggregate': True,
#   u'c_variablesLink': u'http://api.census.gov/data/2007/ewks/variables.json',
#   u'c_vintage': 2007,
#   u'contactPoint': u'Economic Census Info',
#   u'description': u"The Economic Census is the U.S. Government's official five-year measure of American business and the economy. It is conducted by the U.S. Census Bureau, and response is required by law. In October through December 2012, forms were sent out to nearly 4 million businesses, including large, medium and small companies representing all U.S. locations and industries. Respondents were asked to provide a range of operational and performance data for their companies.",
#   u'identifier': u'EconCensusEWKS2007',
#   u'license': u'Public Domain',
#   u'mbox': u'econ.2012@census.gov',
#   u'modified': u'2010-10-31',
#   u'programCode': [u'006:007'],
#   u'publisher': u'U.S. Census Bureau',
#   u'references': [u'http://www.census.gov/developers/'],
#   u'spatial': u'United States',
#   u'temporal': u'January 1992 - Current',
#   u'title': u'2007 Economic Census - All Sectors: Economy-Wide Key Statistics',
#   u'webService': u'http://api.census.gov/data/2007/ewks'},
#  {u'accessLevel': u'public',
#   u'bureauCode': [u'006:07'],
#   u'c_dataset': [u'acs5'],
#   u'c_documentationLink': u'http://www.census.gov/developer/',
#   u'c_examplesLink': u'http://api.census.gov/data/2013/acs5/examples.json',
#   u'c_geographyLink': u'http://api.census.gov/data/2013/acs5/geography.json',
#   u'c_isAggregate': True,
#   u'c_tagsLink': u'http://api.census.gov/data/2013/acs5/tags.json',
#   u'c_variablesLink': u'http://api.census.gov/data/2013/acs5/variables.json',
#   u'c_vintage': 2013,
#   u'contactPoint': u'American Community Survey Office',
#   u'description': u"The American Community Survey (ACS) is a nationwide survey designed to provide communities a fresh look at how they are changing. The ACS replaced the decennial census long form in 2010 and thereafter by collecting long form type information throughout the decade rather than only once every 10 years. Questionnaires are mailed to a sample of addresses to obtain information about households -- that is, about each person and the housing unit itself. The American Community Survey produces demographic, social, housing and economic estimates in the form of 1-year, 3-year and 5-year estimates based on population thresholds. The strength of the ACS is in estimating population and housing characteristics. It produces estimates for small areas, including census tracts and population subgroups. Although the ACS produces population, demographic and housing unit estimates,it is the Census Bureau's Population Estimates Program that produces and disseminates the official estimates of the population for the nation, states, counties, cities and towns, and estimates of housing units for states and counties.  For 2010 and other decennial census years, the Decennial Census provides the official counts of population and housing units.",
#   u'identifier': u'ACSSF5Y2013',
#   u'keyword': [u'Income', u'Marital', u'Poverty'],
#   u'license': u'Public Domain',
#   u'mbox': u'acso.users.support@census.gov',
#   u'modified': u'2014-11-17',
#   u'programCode': [u'006:004'],
#   u'publisher': u'U.S. Census Bureau',
#   u'references': [u'http://www.census.gov/developers/'],
#   u'spatial': u'United States',
#   u'temporal': u'2009/2013',
#   u'title': u'2009-2013 American Community Survey 5-Year Estimates',
#   u'webService': u'http://api.census.gov/data/2013/acs5'},
#  {u'accessLevel': u'public',
#   u'bureauCode': [u'006:07'],
#   u'c_dataset': [u'acs3'],
#   u'c_documentationLink': u'http://www.census.gov/developer/',
#   u'c_examplesLink': u'http://api.census.gov/data/2013/acs3/examples.json',
#   u'c_geographyLink': u'http://api.census.gov/data/2013/acs3/geography.json',
#   u'c_isAggregate': True,
#   u'c_tagsLink': u'http://api.census.gov/data/2013/acs3/tags.json',
#   u'c_variablesLink': u'http://api.census.gov/data/2013/acs3/variables.json',
#   u'c_vintage': 2013,
#   u'contactPoint': u'American Community Survey Office',
#   u'description': u"The American Community Survey (ACS) is a nationwide survey designed to provide communities a fresh look at how they are changing. The ACS replaced the decennial census long form in 2010 and thereafter by collecting long form type information throughout the decade rather than only once every 10 years. Questionnaires are mailed to a sample of addresses to obtain information about households -- that is, about each person and the housing unit itself. The American Community Survey produces demographic, social, housing and economic estimates in the form of 1-year, 3-year and 5-year estimates based on population thresholds. The strength of the ACS is in estimating population and housing characteristics.  The 3-year data provide key estimates for each of the topic areas covered by the ACS for the nation, all 50 states, the District of Columbia, Puerto Rico, every congressional district, every metropolitan area, and all counties and places with populations of 20,000 or more.  Although the ACS produces population, demographic and housing unit estimates,it is the Census Bureau's Population Estimates Program that produces and disseminates the official estimates of the population for the nation, states, counties, cities and towns, and estimates of housing units for states and counties. For 2010 and other decennial census years, the Decennial Census provides the official counts of population and housing units.",
#   u'identifier': u'ACSSF3Y2013',
#   u'license': u'Public Domain',
#   u'mbox': u'acso.users.support@census.gov',
#   u'modified': u'2014-08-14',
#   u'programCode': [u'006:004'],
#   u'publisher': u'U.S. Census Bureau',
#   u'references': [u'http://www.census.gov/developers/'],
#   u'spatial': u'United States',
#   u'temporal': u'2011/2013',
#   u'title': u'2011-2013 American Community Survey - Summarized Data: 3-Year Summary File',
#   u'webService': u'http://api.census.gov/data/2013/acs3'},
#  {u'accessLevel': u'public',
#   u'bureauCode': [u'006:07'],
#   u'c_dataset': [u'eits', u'm3'],
#   u'c_documentationLink': u'http://www.census.gov/developers/',
#   u'c_geographyLink': u'http://api.census.gov/data/eits/m3/geography.json',
#   u'c_isTimeseries': True,
#   u'c_variablesLink': u'http://api.census.gov/data/eits/m3/variables.json',
#   u'contactPoint': u'Economic Indicators Mail List',
#   u'description': u"The U.S. Census Bureau.s economic indicator surveys provide monthly and quarterly data that are timely, reliable, and offer comprehensive measures of the U.S. economy. These surveys produce a variety of statistics covering construction, housing, international trade, retail trade, wholesale trade, services and manufacturing. The survey data provide measures of economic activity that allow analysis of economic performance and inform business investment and policy decisions. Other data included, which are not considered principal economic indicators, are the Quarterly Summary of State & Local Taxes, Quarterly Survey of Public Pensions, and the Manufactured Homes Survey.  For information on the reliability and use of the data, including important notes on estimation and sampling variance, seasonal adjustment, measures of sampling variability, and other information pertinent to the economic indicators, visit the individual programs' webpages - http://www.census.gov/cgi-bin/briefroom/BriefRm.",
#   u'identifier': u'eitsm3',
#   u'mbox': u'econ.indicators@census.gov',
#   u'publisher': u'US Census Bureau',
#   u'spatial': u'US',
#   u'temporal': u'2013',
#   u'title': u"Economic Indicators Time Series - Manufacturers' Shipments, Inventories, and Orders",
#   u'webService': u'http://api.census.gov/data/eits/m3'},
#  {u'accessLevel': u'public',
#   u'bureauCode': [u'006:07'],
#   u'c_dataset': [u'nonemp'],
#   u'c_documentationLink': u'http://www.census.gov/developer/',
#   u'c_examplesLink': u'http://api.census.gov/data/2011/nonemp/examples.json',
#   u'c_geographyLink': u'http://api.census.gov/data/2011/nonemp/geography.json',
#   u'c_isAggregate': True,
#   u'c_variablesLink': u'http://api.census.gov/data/2011/nonemp/variables.json',
#   u'c_vintage': 2011,
#   u'contactPoint': u'Nonemployer Statistics staff',
#   u'description': u"Nonemployer Statistics is an annual series that provides subnational economic data for businesses that have no paid employees and are subject to federal income tax. The data consist of the number of businesses and total receipts by industry. Most nonemployers are self-employed individuals operating unincorporated businesses (known as sole proprietorships), which may or may not be the owner's principal source of income. The majority of all business establishments in the United States are nonemployers, yet these firms average less than 4 percent of all sales and receipts nationally. Due to their small economic impact, these firms are excluded from most other Census Bureau business statistics (the primary exception being the Survey of Business Owners). The Nonemployers Statistics series is the primary resource available to study the scope and activities of nonemployers at a detailed geographic level. For complementary statistics on the firms that do have paid employees, refer to the County Business Patterns. Additional sources of data on small businesses include the Economic Census, and the Statistics of U.S. Businesses.",
#   u'identifier': u'NONEMP2011',
#   u'license': u'Public Domain',
#   u'mbox': u'epcd.nonemployer.statistics@census.gov',
#   u'modified': u'2015-01-29',
#   u'programCode': [u'006:007'],
#   u'publisher': u'U.S. Census Bureau',
#   u'references': [u'http://www.census.gov/developers/'],
#   u'spatial': u'United States',
#   u'temporal': u'2011/2011',
#   u'title': u'2011 Nonemployer Statistics: Non Employer Statistics',
#   u'webService': u'http://api.census.gov/data/2011/nonemp'},
#  {u'accessLevel': u'public',
#   u'bureauCode': [u'006:07'],
#   u'c_dataset': [u'sf1'],
#   u'c_documentationLink': u'http://www.census.gov/developers/',
#   u'c_geographyLink': u'http://api.census.gov/data/1990/sf1/geography.json',
#   u'c_isAggregate': True,
#   u'c_tagsLink': u'http://api.census.gov/data/1990/sf1/tags.json',
#   u'c_variablesLink': u'http://api.census.gov/data/1990/sf1/variables.json',
#   u'c_vintage': 1990,
#   u'contactPoint': u'Census Bureau Call Center',
#   u'description': u'Data files available from Census 2000 and the 2010 Census. This file presents 100-percent population and housing figures for the total population, for 63 race categories, and for many other race and Hispanic or Latino categories. This includes age, sex, households, household relationship, housing units, occupancy status, and tenure (whether the residence is owned or rented). Also included are selected characteristics for a limited number of race and Hispanic or Latino categories. The data are available for the U.S., regions, divisions, states, counties, county subdivisions, places, census tracts, block groups, blocks, metropolitan areas (2000), core based statistical areas (2010), American Indian and Alaska Native areas, tribal subdivisions, Hawaiian home lands, congressional districts, and ZIP Code Tabulation Areas. Data are available down to the block level for many tabulations, but only to the census-tract level for others. The 2010 Census SF 1 has some tables on the population in group quarters that are available only to the county level. Available on DVD and American FactFinder.  The Census 2000 Summary File 1 data were released in three stages. Individual state files and two national files were released. The state-level data were released first, followed by the Advance National File, which covered the same data subjects, but includes national level summary data for areas that cross state boundaries such as whole metropolitan areas, whole American Indian areas, etc. The Final National File contains the same data subjects and geographic areas as the Advance National File, but adds the first available urban/rural and urbanized area data. For the most current release dates for these files, see the "Census 2000 Release Schedule" link on the AFFAmerican FactFinder Main Page.  The 2010 Census Summaray File 1 data were released in stages. Individual state files and a national update were released in 2011. The SF 1 urban/rural update is planned for release in Fall 2012. This file contains the same data subjects as the previously released files, but for additional geography, including the urban and rural parts of the United States, regions, divisions, states, counties, and places; and urbanized areas and urban clusters. See the 2010 Census Data Products At A Glance',
#   u'identifier': u'1990sf1',
#   u'mbox': u'pio@census.gov',
#   u'publisher': u'U.S. Census Bureau',
#   u'references': [u'http://www.census.gov/developers/'],
#   u'spatial': u'US',
#   u'temporal': u'1990',
#   u'title': u'1990 Decennial: Summary File 1',
#   u'webService': u'http://api.census.gov/data/1990/sf1'},
#  {u'accessLevel': u'public',
#   u'bureauCode': [u'006:07'],
#   u'c_dataset': [u'cbp'],
#   u'c_documentationLink': u'http://www.census.gov/developer/',
#   u'c_examplesLink': u'http://api.census.gov/data/2008/cbp/examples.json',
#   u'c_geographyLink': u'http://api.census.gov/data/2008/cbp/geography.json',
#   u'c_isAggregate': True,
#   u'c_variablesLink': u'http://api.census.gov/data/2008/cbp/variables.json',
#   u'c_vintage': 2008,
#   u'contactPoint': u'CBP Staff',
#   u'description': u'County Business Patterns (CBP) is an annual series that provides economic data by industry at the U.S., State, County and Metropolitan Area levels. This series includes the number of establishments, employment during the week of March 12, first quarter payroll, and annual payroll. CBP provides statistics for businesses with paid employees for the U.S., Puerto Rico, and the Island Areas.',
#   u'identifier': u'CBP_2008',
#   u'license': u'Public Domain',
#   u'mbox': u'epcd.county.business.patterns@census.gov',
#   u'modified': u'2015-01-13',
#   u'programCode': [u'006:007'],
#   u'publisher': u'U.S. Census Bureau',
#   u'references': [u'http://www.census.gov/developers/'],
#   u'spatial': u'United States',
#   u'temporal': u'2008/2008',
#   u'title': u'2008 County Business Patterns: Business Patterns',
#   u'webService': u'http://api.census.gov/data/2008/cbp'},
#  {u'accessLevel': u'public',
#   u'bureauCode': [u'006:07'],
#   u'c_dataset': [u'pep', u'stchar6'],
#   u'c_documentationLink': u'http://www.census.gov/developer/',
#   u'c_examplesLink': u'http://api.census.gov/data/2013/pep/stchar6/examples.json',
#   u'c_geographyLink': u'http://api.census.gov/data/2013/pep/stchar6/geography.json',
#   u'c_isAggregate': True,
#   u'c_variablesLink': u'http://api.census.gov/data/2013/pep/stchar6/variables.json',
#   u'c_vintage': 2013,
#   u'contactPoint': u'Population Estimates Branch',
#   u'description': u"Annual State Resident Population Estimates for 6 Race Groups (5 Race Alone Groups and Two or More Races) by Age, Sex, and Hispanic Origin: April 1, 2010 to July 1, 2013 // File: 7/1/2013 State Characteristics Population Estimates // Source: U.S. Census Bureau, Population Division // Release Date: June 2014 // Note: The estimates are based on the 2010 Census and reflect changes to the April 1, 2010 population due to the Count Question Resolution program and geographic program revisions. Hispanic origin is considered an ethnicity, not a race. Hispanics may be of any race. Responses of 'Some Other Race' from the 2010 Census are modified. This results in differences between the population for specific race categories shown for the 2010 Census population in this file versus those in the original 2010 Census data. For more information, see http://www.census.gov/popest/data/historical/files/MRSF-01-US1.pdf. // For detailed information about the methods used to create the population estimates, see http://www.census.gov/popest/methodology/index.html. // Each year, the Census Bureau's Population Estimates Program (PEP) utilizes current data on births, deaths, and migration to calculate population change since the most recent decennial census, and produces a time series of estimates of population. The annual time series of estimates begins with the most recent decennial census data and extends to the vintage year. The vintage year (e.g., V2013) refers to the final year of the time series. The reference date for all estimates is July 1, unless otherwise specified. With each new issue of estimates, the Census Bureau revises estimates for years back to the last census. As each vintage of estimates includes all years since the most recent decennial census, the latest vintage of data available supersedes all previously produced estimates for those dates. The Population Estimates Program provides additional information including historical and intercensal estimates, evaluation estimates, demographic analysis, and research papers on its website: http://www.census.gov/popest/index.html.",
#   u'identifier': u'POPESTstchar62013',
#   u'license': u'Public Domain',
#   u'mbox': u'pop.population.estimates@census.gov',
#   u'modified': u'2014-10-22',
#   u'programCode': [u'006:008'],
#   u'publisher': u'U.S. Census Bureau',
#   u'references': [u'http://www.census.gov/developers/'],
#   u'spatial': u'United States',
#   u'temporal': u'April 1, 2010 - Current',
#   u'title': u'Vintage 2013 Population Estimates: State Population Estimates by Single Year of Age, Sex, 6 Races, and Hispanic Origin',
#   u'webService': u'http://api.census.gov/data/2013/pep/stchar6'},
#  {u'accessLevel': u'public',
#   u'bureauCode': [u'006:07'],
#   u'c_dataset': [u'ewks'],
#   u'c_documentationLink': u'http://www.census.gov/developer/',
#   u'c_examplesLink': u'http://api.census.gov/data/2012/ewks/examples.json',
#   u'c_geographyLink': u'http://api.census.gov/data/2012/ewks/geography.json',
#   u'c_isAggregate': True,
#   u'c_variablesLink': u'http://api.census.gov/data/2012/ewks/variables.json',
#   u'c_vintage': 2012,
#   u'contactPoint': u'Economic Census Info',
#   u'description': u"The Economic Census is the U.S. Government's official five-year measure of American business and the economy. It is conducted by the U.S. Census Bureau, and response is required by law. In October through December 2012, forms were sent out to nearly 4 million businesses, including large, medium and small companies representing all U.S. locations and industries. Respondents were asked to provide a range of operational and performance data for their companies.",
#   u'identifier': u'EconCensusEWKS2012',
#   u'license': u'Public Domain',
#   u'mbox': u'econ.2012@census.gov',
#   u'modified': u'2014-04-06',
#   u'programCode': [u'006:007'],
#   u'publisher': u'U.S. Census Bureau',
#   u'references': [u'http://www.census.gov/developers/'],
#   u'spatial': u'United States',
#   u'temporal': u'January 1992 - Current',
#   u'title': u'2012 Economic Census - All Sectors: Economy-Wide Key Statistics',
#   u'webService': u'http://api.census.gov/data/2012/ewks'},
#  {u'accessLevel': u'public',
#   u'bureauCode': [u'006:07'],
#   u'c_dataset': [u'bds', u'firms'],
#   u'c_documentationLink': u'http://www.census.gov/developer/',
#   u'c_examplesLink': u'http://api.census.gov/data/bds/firms/examples.json',
#   u'c_geographyLink': u'http://api.census.gov/data/bds/firms/geography.json',
#   u'c_isTimeseries': True,
#   u'c_variablesLink': u'http://api.census.gov/data/bds/firms/variables.json',
#   u'contactPoint': u'Javier Miranda',
#   u'description': u'The Business Dynamics Statistics (BDS) is a public use data set of annual aggregate statistics describing establishment openings and closings, firm startups, job creation and destruction by firm size, age, industrial sector, and state. For more information about the dataset set http://www.census.gov/ces/dataproducts/bds/index.html',
#   u'identifier': u'BDSFirms',
#   u'license': u'Public Domain',
#   u'mbox': u'ces.bds@census.gov',
#   u'modified': u'2014-09-09',
#   u'programCode': [u'006:007'],
#   u'publisher': u'U.S. Census Bureau',
#   u'references': [u'http://www.census.gov/developers/'],
#   u'spatial': u'United States',
#   u'temporal': u'1977 - Current',
#   u'title': u'Time Series Business Dynamics Statistics: Firm Statistics',
#   u'webService': u'http://api.census.gov/data/bds/firms'},
#  {u'accessLevel': u'public',
#   u'bureauCode': [u'006:07'],
#   u'c_dataset': [u'pep', u'housing'],
#   u'c_documentationLink': u'http://www.census.gov/developer/',
#   u'c_examplesLink': u'http://api.census.gov/data/2013/pep/housing/examples.json',
#   u'c_geographyLink': u'http://api.census.gov/data/2013/pep/housing/geography.json',
#   u'c_isAggregate': True,
#   u'c_variablesLink': u'http://api.census.gov/data/2013/pep/housing/variables.json',
#   u'c_vintage': 2013,
#   u'contactPoint': u'Population Estimates Branch',
#   u'description': u"Annual Housing Unit Estimates for the United States, States, and Counties: April 1, 2010 to July 1, 2013 // File: 7/1/2013 Housing Unit Estimates // Source: U.S. Census Bureau, Population Division // Release Date: May 2014 // Note: The estimates are based on the 2010 Census and reflect changes to the April 1, 2010 housing units due to the Count Question Resolution program and geographic program revisions. The estimates are based on the 2010 Census and reflect changes to the April 1, 2010 housing units due to the Count Question Resolution program and geographic program revisions. All geographic boundaries for the 2013 housing unit estimates series are as of January 1, 2013. For the housing unit estimates methodology statement, see http://www.census.gov/popest/methodology/index.html. // Each year, the Census Bureau's Population Estimates Program (PEP) utilizes current data on births, deaths, and migration to calculate population change since the most recent decennial census, and produces a time series of estimates of population. The annual time series of estimates begins with the most recent decennial census data and extends to the vintage year. The vintage year (e.g., V2013) refers to the final year of the time series. The reference date for all estimates is July 1, unless otherwise specified. With each new issue of estimates, the Census Bureau revises estimates for years back to the last census. As each vintage of estimates includes all years since the most recent decennial census, the latest vintage of data available supersedes all previously produced estimates for those dates. The Population Estimates Program provides additional information including historical and intercensal estimates, evaluation estimates, demographic analysis, and research papers on its website: http://www.census.gov/popest/index.html.",
#   u'identifier': u'POPESThousing2013',
#   u'license': u'Public Domain',
#   u'mbox': u'pop.population.estimates@census.gov',
#   u'modified': u'2014-10-22',
#   u'programCode': [u'006:008'],
#   u'publisher': u'U.S. Census Bureau',
#   u'references': [u'http://www.census.gov/developers/'],
#   u'spatial': u'United States',
#   u'temporal': u'April 1, 2010 - Current',
#   u'title': u'Vintage 2013 Population Estimates: Housing Unit Estimates for US, States, and Counties',
#   u'webService': u'http://api.census.gov/data/2013/pep/housing'},
#  {u'accessLevel': u'public',
#   u'bureauCode': [u'006:07'],
#   u'c_dataset': [u'eits', u'qss'],
#   u'c_documentationLink': u'http://www.census.gov/developers/',
#   u'c_geographyLink': u'http://api.census.gov/data/eits/qss/geography.json',
#   u'c_isTimeseries': True,
#   u'c_variablesLink': u'http://api.census.gov/data/eits/qss/variables.json',
#   u'contactPoint': u'Economic Indicators Mail List',
#   u'description': u"The U.S. Census Bureau.s economic indicator surveys provide monthly and quarterly data that are timely, reliable, and offer comprehensive measures of the U.S. economy. These surveys produce a variety of statistics covering construction, housing, international trade, retail trade, wholesale trade, services and manufacturing. The survey data provide measures of economic activity that allow analysis of economic performance and inform business investment and policy decisions. Other data included, which are not considered principal economic indicators, are the Quarterly Summary of State & Local Taxes, Quarterly Survey of Public Pensions, and the Manufactured Homes Survey.  For information on the reliability and use of the data, including important notes on estimation and sampling variance, seasonal adjustment, measures of sampling variability, and other information pertinent to the economic indicators, visit the individual programs' webpages - http://www.census.gov/cgi-bin/briefroom/BriefRm.",
#   u'identifier': u'eitsqss',
#   u'mbox': u'econ.indicators@census.gov',
#   u'publisher': u'US Census Bureau',
#   u'spatial': u'US',
#   u'temporal': u'2013',
#   u'title': u'Economic Indicators Time Series - Quarterly Services Survey',
#   u'webService': u'http://api.census.gov/data/eits/qss'},
#  {u'accessLevel': u'public',
#   u'bureauCode': [u'006:07'],
#   u'c_dataset': [u'eits', u'vip'],
#   u'c_documentationLink': u'http://www.census.gov/developers/',
#   u'c_examplesLink': u'http://api.census.gov/data/eits/vip/examples.json',
#   u'c_geographyLink': u'http://api.census.gov/data/eits/vip/geography.json',
#   u'c_isTimeseries': True,
#   u'c_variablesLink': u'http://api.census.gov/data/eits/vip/variables.json',
#   u'contactPoint': u'Economic Indicators Mail List',
#   u'description': u"The U.S. Census Bureau.s economic indicator surveys provide monthly and quarterly data that are timely, reliable, and offer comprehensive measures of the U.S. economy. These surveys produce a variety of statistics covering construction, housing, international trade, retail trade, wholesale trade, services and manufacturing. The survey data provide measures of economic activity that allow analysis of economic performance and inform business investment and policy decisions. Other data included, which are not considered principal economic indicators, are the Quarterly Summary of State & Local Taxes, Quarterly Survey of Public Pensions, and the Manufactured Homes Survey.  For information on the reliability and use of the data, including important notes on estimation and sampling variance, seasonal adjustment, measures of sampling variability, and other information pertinent to the economic indicators, visit the individual programs' webpages - http://www.census.gov/cgi-bin/briefroom/BriefRm.",
#   u'identifier': u'eitsvip',
#   u'mbox': u'econ.indicators@census.gov',
#   u'publisher': u'US Census Bureau',
#   u'spatial': u'US',
#   u'temporal': u'2013',
#   u'title': u'Economic Indicators Time Series - Construction Spending',
#   u'webService': u'http://api.census.gov/data/eits/vip'},
#  {u'accessLevel': u'public',
#   u'bureauCode': [u'006:07'],
#   u'c_dataset': [u'sf3'],
#   u'c_documentationLink': u'http://www.census.gov/developer/',
#   u'c_examplesLink': u'http://api.census.gov/data/1990/sf3/examples.json',
#   u'c_geographyLink': u'http://api.census.gov/data/1990/sf3/geography.json',
#   u'c_isAggregate': True,
#   u'c_tagsLink': u'http://api.census.gov/data/1990/sf3/tags.json',
#   u'c_variablesLink': u'http://api.census.gov/data/1990/sf3/variables.json',
#   u'c_vintage': 1990,
#   u'contactPoint': u'Customer Service Call Center',
#   u'description': u'The census of population and housing, taken by the Census Bureau in years ending in 0 (zero). Article I of the Constitution requires that a census be taken every ten years for the purpose of reapportioning the U.S. House of Representatives. Title 13 of the U. S. Code provides the authorization for conducting the census in Puerto Rico and the Island Areas. After each decennial census, the results are released to the public in a variety of ways, including publishing multiple series of reports titled Census of Population and Housing. The abbreviation for these reports was CPH for some decades (including 1990 and 2010) and PHC for some decades (including 1970 and 2000).',
#   u'identifier': u'DecennialSF31990',
#   u'license': u'Public Domain',
#   u'mbox': u'clmso@census.gov',
#   u'modified': u'2012-06-06',
#   u'programCode': [u'006:004'],
#   u'publisher': u'U.S. Census Bureau',
#   u'references': [u'http://www.census.gov/developers/'],
#   u'spatial': u'United States',
#   u'temporal': u'1990/1990',
#   u'title': u'1990 Decennial Census of Population and Housing - Summary File 3: Summary File 3',
#   u'webService': u'http://api.census.gov/data/1990/sf3'},
#  {u'accessLevel': u'public',
#   u'bureauCode': [u'006:07'],
#   u'c_dataset': [u'pep', u'monthlynatchar5'],
#   u'c_documentationLink': u'http://www.census.gov/developer/',
#   u'c_examplesLink': u'http://api.census.gov/data/2013/pep/monthlynatchar5/examples.json',
#   u'c_geographyLink': u'http://api.census.gov/data/2013/pep/monthlynatchar5/geography.json',
#   u'c_isAggregate': True,
#   u'c_variablesLink': u'http://api.census.gov/data/2013/pep/monthlynatchar5/variables.json',
#   u'c_vintage': 2013,
#   u'contactPoint': u'Population Estimates Branch',
#   u'description': u"Monthly Population Estimates by Universe, Age, Sex, 5 Races, and Hispanic Origin for the United States: April 1, 2010 to July 1, 2013 // File: 7/1/2013 National Population Estimates // Source: U.S. Census Bureau, Population Division // Release Date: June 2014 // Note: 'In combination' means in combination with one or more other races. The sum of the five race groups adds to more than the total population because individuals may report more than one race. The estimates are based on the 2010 Census and reflect changes to the April 1, 2010 population due to the Count Question Resolution program and geographic program revisions. Hispanic origin is considered an ethnicity, not a race. Hispanics may be of any race. Responses of 'Some Other Race' from the 2010 Census are modified. This results in differences between the population for specific race categories shown for the 2010 Census population in this file versus those in the original 2010 Census data. For more information, see http://www.census.gov/popest/data/historical/files/MRSF-01-US1.pdf. // Persons on active duty in the Armed Forces were not enumerated in the 2010 Census. Therefore, variables for the 2010 Census civilian, civilian noninstitutionalized, and resident population plus Armed Forces overseas populations cannot be derived and are not available on these files. // For detailed information about the methods used to create the population estimates, see http://www.census.gov/popest/methodology/index.html. // Each year, the Census Bureau's Population Estimates Program (PEP) utilizes current data on births, deaths, and migration to calculate population change since the most recent decennial census, and produces a time series of estimates of population. The annual time series of estimates begins with the most recent decennial census data and extends to the vintage year. The vintage year (e.g., V2013) refers to the final year of the time series. The reference date for all estimates is July 1, unless otherwise specified. With each new issue of estimates, the Census Bureau revises estimates for years back to the last census. As each vintage of estimates includes all years since the most recent decennial census, the latest vintage of data available supersedes all previously produced estimates for those dates. The Population Estimates Program provides additional information including historical and intercensal estimates, evaluation estimates, demographic analysis, and research papers on its website: http://www.census.gov/popest/index.html.",
#   u'identifier': u'POPESTmonthlynatchar52013',
#   u'license': u'Public Domain',
#   u'mbox': u'pop.population.estimates@census.gov',
#   u'modified': u'2014-10-22',
#   u'programCode': [u'006:008'],
#   u'publisher': u'U.S. Census Bureau',
#   u'references': [u'http://www.census.gov/developers/'],
#   u'spatial': u'United States',
#   u'temporal': u'April 1, 2010 - Current',
#   u'title': u'Vintage 2013 Population Estimates: National Monthly Population Estimates by Single Year of Age , Sex, 5 Races, Hispanic Origin, and Universe',
#   u'webService': u'http://api.census.gov/data/2013/pep/monthlynatchar5'},
#  {u'accessLevel': u'public',
#   u'bureauCode': [u'006:07'],
#   u'c_dataset': [u'eits', u'mtis'],
#   u'c_documentationLink': u'http://www.census.gov/developers/',
#   u'c_geographyLink': u'http://api.census.gov/data/eits/mtis/geography.json',
#   u'c_isTimeseries': True,
#   u'c_variablesLink': u'http://api.census.gov/data/eits/mtis/variables.json',
#   u'contactPoint': u'Economic Indicators Mail List',
#   u'description': u"The U.S. Census Bureau.s economic indicator surveys provide monthly and quarterly data that are timely, reliable, and offer comprehensive measures of the U.S. economy. These surveys produce a variety of statistics covering construction, housing, international trade, retail trade, wholesale trade, services and manufacturing. The survey data provide measures of economic activity that allow analysis of economic performance and inform business investment and policy decisions. Other data included, which are not considered principal economic indicators, are the Quarterly Summary of State & Local Taxes, Quarterly Survey of Public Pensions, and the Manufactured Homes Survey.  For information on the reliability and use of the data, including important notes on estimation and sampling variance, seasonal adjustment, measures of sampling variability, and other information pertinent to the economic indicators, visit the individual programs' webpages - http://www.census.gov/cgi-bin/briefroom/BriefRm.",
#   u'identifier': u'eitsmtis',
#   u'mbox': u'econ.indicators@census.gov',
#   u'publisher': u'US Census Bureau',
#   u'spatial': u'US',
#   u'temporal': u'2013',
#   u'title': u'Economic Indicators Time Series - Manufacturing and Trade Inventories and Sales',
#   u'webService': u'http://api.census.gov/data/eits/mtis'},
#  {u'accessLevel': u'public',
#   u'bureauCode': [u'006:07'],
#   u'c_dataset': [u'eits', u'qfr'],
#   u'c_documentationLink': u'http://www.census.gov/developers/',
#   u'c_geographyLink': u'http://api.census.gov/data/eits/qfr/geography.json',
#   u'c_isTimeseries': True,
#   u'c_variablesLink': u'http://api.census.gov/data/eits/qfr/variables.json',
#   u'contactPoint': u'Economic Indicators Mail List',
#   u'description': u"The U.S. Census Bureau.s economic indicator surveys provide monthly and quarterly data that are timely, reliable, and offer comprehensive measures of the U.S. economy. These surveys produce a variety of statistics covering construction, housing, international trade, retail trade, wholesale trade, services and manufacturing. The survey data provide measures of economic activity that allow analysis of economic performance and inform business investment and policy decisions. Other data included, which are not considered principal economic indicators, are the Quarterly Summary of State & Local Taxes, Quarterly Survey of Public Pensions, and the Manufactured Homes Survey.  For information on the reliability and use of the data, including important notes on estimation and sampling variance, seasonal adjustment, measures of sampling variability, and other information pertinent to the economic indicators, visit the individual programs' webpages - http://www.census.gov/cgi-bin/briefroom/BriefRm.",
#   u'identifier': u'eitsqfr',
#   u'mbox': u'econ.indicators@census.gov',
#   u'publisher': u'US Census Bureau',
#   u'spatial': u'US',
#   u'temporal': u'2013',
#   u'title': u'Economic Indicators Time Series - Quarterly Financial Report',
#   u'webService': u'http://api.census.gov/data/eits/qfr'},
#  {u'accessLevel': u'public',
#   u'bureauCode': [u'006:07'],
#   u'c_dataset': [u'eits', u'marts'],
#   u'c_documentationLink': u'http://www.census.gov/developers/',
#   u'c_geographyLink': u'http://api.census.gov/data/eits/marts/geography.json',
#   u'c_isTimeseries': True,
#   u'c_variablesLink': u'http://api.census.gov/data/eits/marts/variables.json',
#   u'contactPoint': u'Economic Indicators Mail List',
#   u'description': u"The U.S. Census Bureau.s economic indicator surveys provide monthly and quarterly data that are timely, reliable, and offer comprehensive measures of the U.S. economy. These surveys produce a variety of statistics covering construction, housing, international trade, retail trade, wholesale trade, services and manufacturing. The survey data provide measures of economic activity that allow analysis of economic performance and inform business investment and policy decisions. Other data included, which are not considered principal economic indicators, are the Quarterly Summary of State & Local Taxes, Quarterly Survey of Public Pensions, and the Manufactured Homes Survey.  For information on the reliability and use of the data, including important notes on estimation and sampling variance, seasonal adjustment, measures of sampling variability, and other information pertinent to the economic indicators, visit the individual programs' webpages - http://www.census.gov/cgi-bin/briefroom/BriefRm.",
#   u'identifier': u'eitsmarts',
#   u'mbox': u'econ.indicators@census.gov',
#   u'publisher': u'US Census Bureau',
#   u'spatial': u'US',
#   u'temporal': u'2013',
#   u'title': u'Economic Indicators Time Series - Advance Monthly Sales for Retail and Food Services',
#   u'webService': u'http://api.census.gov/data/eits/marts'},
#  {u'accessLevel': u'public',
#   u'bureauCode': [u'006:07'],
#   u'c_dataset': [u'eits', u'hv'],
#   u'c_documentationLink': u'http://www.census.gov/developers/',
#   u'c_geographyLink': u'http://api.census.gov/data/eits/hv/geography.json',
#   u'c_isTimeseries': True,
#   u'c_variablesLink': u'http://api.census.gov/data/eits/hv/variables.json',
#   u'contactPoint': u'Economic Indicators Mail List',
#   u'description': u"The U.S. Census Bureau.s economic indicator surveys provide monthly and quarterly data that are timely, reliable, and offer comprehensive measures of the U.S. economy. These surveys produce a variety of statistics covering construction, housing, international trade, retail trade, wholesale trade, services and manufacturing. The survey data provide measures of economic activity that allow analysis of economic performance and inform business investment and policy decisions. Other data included, which are not considered principal economic indicators, are the Quarterly Summary of State & Local Taxes, Quarterly Survey of Public Pensions, and the Manufactured Homes Survey.  For information on the reliability and use of the data, including important notes on estimation and sampling variance, seasonal adjustment, measures of sampling variability, and other information pertinent to the economic indicators, visit the individual programs' webpages - http://www.census.gov/cgi-bin/briefroom/BriefRm.",
#   u'identifier': u'eitshv',
#   u'mbox': u'econ.indicators@census.gov',
#   u'publisher': u'US Census Bureau',
#   u'spatial': u'US',
#   u'temporal': u'2013',
#   u'title': u'Economic Indicators Time Series - Housing Vacancies and Homeownership',
#   u'webService': u'http://api.census.gov/data/eits/hv'},
#  {u'accessLevel': u'public',
#   u'bureauCode': [u'006:07'],
#   u'c_dataset': [u'pep', u'prm'],
#   u'c_documentationLink': u'http://www.census.gov/developer/',
#   u'c_examplesLink': u'http://api.census.gov/data/2014/pep/prm/examples.json',
#   u'c_geographyLink': u'http://api.census.gov/data/2014/pep/prm/geography.json',
#   u'c_isAggregate': True,
#   u'c_variablesLink': u'http://api.census.gov/data/2014/pep/prm/variables.json',
#   u'c_vintage': 2014,
#   u'contactPoint': u'Population Estimates Branch',
#   u'description': u'Annual Resident Population Estimates for Puerto Rico Municipios // Source: U.S. Census Bureau, Population Division // Note: The estimates are based on the 2010 Census and reflect changes to the April 1, 2010 population due to the Count Question Resolution program and geographic program revisions. For detailed information about the methods used to create the population estimates, see http://www.census.gov/popest/methodology/index.html. // Each year, the Census Bureaus Population Estimates Program (PEP) utilizes current data on births, deaths, and migration to calculate population change since the most recent decennial census, and produces a time series of estimates of population. The annual time series of estimates begins with the most recent decennial census data and extends to the vintage year. The vintage year (e.g., V2014) refers to the final year of the time series. The reference date for all estimates is July 1, unless otherwise specified. With each new issue of estimates, the Census Bureau revises estimates for years back to the last census. As each vintage of estimates includes all years since the most recent decennial census, the latest vintage of data available supersedes all previously produced estimates for those dates. The Population Estimates Program provides additional information including historical and intercensal estimates, evaluation estimates, demographic analysis, and research papers on its website: http://www.census.gov/popest/index.html.',
#   u'identifier': u'POPESTprm2014',
#   u'license': u'Public Domain',
#   u'mbox': u'pop.population.estimates@census.gov',
#   u'modified': u'2015-03-12',
#   u'programCode': [u'006:008'],
#   u'publisher': u'U.S. Census Bureau',
#   u'references': [u'http://www.census.gov/developers/'],
#   u'spatial': u'United States',
#   u'temporal': u'April 1, 2010 - Current',
#   u'title': u'Vintage 2014 Population Estimates: Puerto Rico Municipios Total Population',
#   u'webService': u'http://api.census.gov/data/2014/pep/prm'},
#  {u'accessLevel': u'public',
#   u'bureauCode': [u'006:07'],
#   u'c_dataset': [u'pep', u'natstprc18'],
#   u'c_documentationLink': u'http://www.census.gov/developer/',
#   u'c_examplesLink': u'http://api.census.gov/data/2014/pep/natstprc18/examples.json',
#   u'c_geographyLink': u'http://api.census.gov/data/2014/pep/natstprc18/geography.json',
#   u'c_isAggregate': True,
#   u'c_variablesLink': u'http://api.census.gov/data/2014/pep/natstprc18/variables.json',
#   u'c_vintage': 2014,
#   u'contactPoint': u'Population Estimates Branch',
#   u'description': u"Estimates of the Total Resident Population and Resident Population Age 18 Years and Older for the United States, States, and Puerto Rico // File: State Characteristics Population Estimates // Source: U.S. Census Bureau, Population Division // Note: The estimates are based on the 2010 Census and reflect changes to the April 1, 2010 population due to the Count Question Resolution program and geographic program revisions. See Geographic Terms and Definitions at http://www.census.gov/popest/about/geo/terms.html for a list of the states that are included in each region and division. All geographic boundaries for these population estimates are as of January 1, 2013. // For detailed information about the methods used to create the population estimates, see http://www.census.gov/popest/methodology/index.html. // Each year, the Census Bureau's Population Estimates Program (PEP) utilizes current data on births, deaths, and migration to calculate population change since the most recent decennial census, and produces a time series of estimates of population. The annual time series of estimates begins with the most recent decennial census data and extends to the vintage year. The vintage year (e.g., V2013) refers to the final year of the time series. The reference date for all estimates is July 1, unless otherwise specified. With each new issue of estimates, the Census Bureau revises estimates for years back to the last census. As each vintage of estimates includes all years since the most recent decennial census, the latest vintage of data available supersedes all previously produced estimates for those dates. The Population Estimates Program provides additional information including historical and intercensal estimates, evaluation estimates, demographic analysis, and research papers on its website: http://www.census.gov/popest/index.html.",
#   u'identifier': u'POPESTnatstprc182014',
#   u'license': u'Public Domain',
#   u'mbox': u'pop.population.estimates@census.gov',
#   u'modified': u'2014-12-15',
#   u'programCode': [u'006:008'],
#   u'publisher': u'U.S. Census Bureau',
#   u'references': [u'http://www.census.gov/developers/'],
#   u'spatial': u'United States',
#   u'temporal': u'April 1, 2010 - Current',
#   u'title': u'Vintage 2014 Population Estimates: US, State, and PR Population Age 18+',
#   u'webService': u'http://api.census.gov/data/2014/pep/natstprc18'},
#  {u'accessLevel': u'public',
#   u'bureauCode': [u'006:07'],
#   u'c_dataset': [u'acs3', u'profile'],
#   u'c_documentationLink': u'http://www.census.gov/developer/',
#   u'c_examplesLink': u'http://api.census.gov/data/2013/acs3/profile/examples.json',
#   u'c_geographyLink': u'http://api.census.gov/data/2013/acs3/profile/geography.json',
#   u'c_isAggregate': True,
#   u'c_variablesLink': u'http://api.census.gov/data/2013/acs3/profile/variables.json',
#   u'c_vintage': 2013,
#   u'contactPoint': u'American Community Survey Office',
# ...
#   u'identifier': u'2000sf1',
#   u'mbox': u'pio@census.gov',
#   u'publisher': u'US Census Bureau',
#   u'references': [u'http://www.census.gov/developers/'],
#   u'spatial': u'US',
#   u'temporal': u'2000',
#   u'title': u'2000 Decennial: Summary File 1',
#   u'webService': u'http://api.census.gov/data/2000/sf1'},
#  {u'accessLevel': u'public',
#   u'bureauCode': [u'006:07'],
#   u'c_dataset': [u'nonemp'],
#   u'c_documentationLink': u'http://www.census.gov/developer/',
#   u'c_examplesLink': u'http://api.census.gov/data/2009/nonemp/examples.json',
#   u'c_geographyLink': u'http://api.census.gov/data/2009/nonemp/geography.json',
#   u'c_isAggregate': True,
#   u'c_variablesLink': u'http://api.census.gov/data/2009/nonemp/variables.json',
#   u'c_vintage': 2009,
#   u'contactPoint': u'Nonemployer Statistics staff',
#   u'description': u"Nonemployer Statistics is an annual series that provides subnational economic data for businesses that have no paid employees and are subject to federal income tax. The data consist of the number of businesses and total receipts by industry. Most nonemployers are self-employed individuals operating unincorporated businesses (known as sole proprietorships), which may or may not be the owner's principal source of income. The majority of all business establishments in the United States are nonemployers, yet these firms average less than 4 percent of all sales and receipts nationally. Due to their small economic impact, these firms are excluded from most other Census Bureau business statistics (the primary exception being the Survey of Business Owners). The Nonemployers Statistics series is the primary resource available to study the scope and activities of nonemployers at a detailed geographic level. For complementary statistics on the firms that do have paid employees, refer to the County Business Patterns. Additional sources of data on small businesses include the Economic Census, and the Statistics of U.S. Businesses.",
#   u'identifier': u'NONEMP2009',
#   u'license': u'Public Domain',
#   u'mbox': u'epcd.nonemployer.statistics@census.gov',
#   u'modified': u'2015-01-29',
#   u'programCode': [u'006:007'],
#   u'publisher': u'U.S. Census Bureau',
#   u'references': [u'http://www.census.gov/developers/'],
#   u'spatial': u'United States',
#   u'temporal': u'2009/2009',
#   u'title': u'2009 Nonemployer Statistics: Non Employer Statistics',
#   u'webService': u'http://api.census.gov/data/2009/nonemp'},
#  {u'accessLevel': u'public',
#   u'bureauCode': [u'006:07'],
#   u'c_dataset': [u'popproj', u'pop'],
#   u'c_documentationLink': u'http://www.census.gov/developer/',
#   u'c_examplesLink': u'http://api.census.gov/data/2012/popproj/pop/examples.json',
#   u'c_geographyLink': u'http://api.census.gov/data/2012/popproj/pop/geography.json',
#   u'c_isAggregate': True,
#   u'c_variablesLink': u'http://api.census.gov/data/2012/popproj/pop/variables.json',
#   u'c_vintage': 2012,
#   u'contactPoint': u'null',
#   u'description': u'Projected Population by Single Year of Age, Sex, Race, and Hispanic Origin for the United States: 2012 to 2060  File: 2012 National Population Projections  Source: U.S. Census Bureau, Population Division Release Date: December 2012  NOTE:  Hispanic origin is considered an ethnicity, not a race. Hispanics may be of any race.   The projections generally do not precisely agree with population estimates available elsewhere on the Census Bureau website for methodological reasons. Where both estimates and projections are available for a given time reference, we recommend that you use the population estimates as the measure of the current population.   For detailed information about the methods used to create the population projections, see  http://www.census.gov/population/projections/methodology/.  ***  The U.S. Census Bureau periodically produces projections of the United States resident population by age, sex, race, and Hispanic origin. Population projections are estimates of the population for future dates. They are typically based on an estimated population consistent with the most recent decennial census and are produced using the cohort-component method. Projections illustrate possible courses of population change based on assumptions about future births, deaths, net international migration, and domestic migration. In some cases, several series of projections are produced based on alternative assumptions for future fertility, life expectancy, net international migration, and (for state-level projections) state-to-state or domestic migration.  Additional information is available on the Population Projections website: http://www.census.gov/population/projections/.',
#   u'identifier': u'POPPROJPopVintage2012',
#   u'license': u'Public Domain',
#   u'mbox': u'null',
#   u'modified': u'2014-05-15',
#   u'programCode': [u'006:008'],
#   u'publisher': u'U.S. Census Bureau',
#   u'references': [u'http://www.census.gov/developers/'],
#   u'spatial': u'United States',
#   u'temporal': u'July 1, 2012 - July 1, 2060',
#   u'title': u'Vintage 2012 Population Projections: Projected Population by Single Year of Age',
#   u'webService': u'http://api.census.gov/data/2012/popproj/pop'},
#  {u'accessLevel': u'public',
#   u'bureauCode': [u'006:07'],
#   u'c_dataset': [u'eits', u'ressales'],
#   u'c_documentationLink': u'http://www.census.gov/developers/',
#   u'c_geographyLink': u'http://api.census.gov/data/eits/ressales/geography.json',
#   u'c_isTimeseries': True,
#   u'c_variablesLink': u'http://api.census.gov/data/eits/ressales/variables.json',
#   u'contactPoint': u'Economic Indicators Mail List',
#   u'description': u"The U.S. Census Bureau.s economic indicator surveys provide monthly and quarterly data that are timely, reliable, and offer comprehensive measures of the U.S. economy. These surveys produce a variety of statistics covering construction, housing, international trade, retail trade, wholesale trade, services and manufacturing. The survey data provide measures of economic activity that allow analysis of economic performance and inform business investment and policy decisions. Other data included, which are not considered principal economic indicators, are the Quarterly Summary of State & Local Taxes, Quarterly Survey of Public Pensions, and the Manufactured Homes Survey.  For information on the reliability and use of the data, including important notes on estimation and sampling variance, seasonal adjustment, measures of sampling variability, and other information pertinent to the economic indicators, visit the individual programs' webpages - http://www.census.gov/cgi-bin/briefroom/BriefRm.",
#   u'identifier': u'eitsresales',
#   u'mbox': u'econ.indicators@census.gov',
#   u'publisher': u'US Census Bureau',
#   u'spatial': u'US',
#   u'temporal': u'2013',
#   u'title': u'Economic Indicators Time Series - New Home Sales',
#   u'webService': u'http://api.census.gov/data/eits/ressales'},
#  {u'accessLevel': u'public',
#   u'bureauCode': [u'006:07'],
#   u'c_dataset': [u'ewks'],
#   u'c_documentationLink': u'http://www.census.gov/developer/',
#   u'c_examplesLink': u'http://api.census.gov/data/2002/ewks/examples.json',
#   u'c_geographyLink': u'http://api.census.gov/data/2002/ewks/geography.json',
#   u'c_isAggregate': True,
#   u'c_variablesLink': u'http://api.census.gov/data/2002/ewks/variables.json',
#   u'c_vintage': 2002,
#   u'contactPoint': u'Economic Census Info',
#   u'description': u"The Economic Census is the U.S. Government's official five-year measure of American business and the economy. It is conducted by the U.S. Census Bureau, and response is required by law. In October through December 2012, forms were sent out to nearly 4 million businesses, including large, medium and small companies representing all U.S. locations and industries. Respondents were asked to provide a range of operational and performance data for their companies.",
#   u'identifier': u'EconCensusEWKS2002',
#   u'license': u'Public Domain',
#   u'mbox': u'econ.2012@census.gov',
#   u'modified': u'2014-10-06',
#   u'programCode': [u'006:007'],
#   u'publisher': u'U.S. Census Bureau',
#   u'references': [u'http://www.census.gov/developers/'],
#   u'spatial': u'United States',
#   u'temporal': u'January 1992 - Current',
#   u'title': u'2002 Economic Census - All Sectors: Economy-Wide Key Statistics',
#   u'webService': u'http://api.census.gov/data/2002/ewks'},
#  {u'accessLevel': u'public',
#   u'bureauCode': [u'006:07'],
#   u'c_dataset': [u'pep', u'natstprc'],
#   u'c_documentationLink': u'http://www.census.gov/developer/',
#   u'c_examplesLink': u'http://api.census.gov/data/2014/pep/natstprc/examples.json',
#   u'c_geographyLink': u'http://api.census.gov/data/2014/pep/natstprc/geography.json',
#   u'c_isAggregate': True,
#   u'c_variablesLink': u'http://api.census.gov/data/2014/pep/natstprc/variables.json',
#   u'c_vintage': 2014,
#   u'contactPoint': u'Population Estimates Branch',
#   u'description': u"Annual Population Estimates, Estimated Components of Resident Population Change, and Rates of the Components of Resident Population Change for the United States, States, and Puerto Rico // File:  National and State Population Estimates // Source: U.S. Census Bureau, Population Division  // Note: Total population change includes a residual. This residual represents the change in population that cannot be attributed to any specific demographic component. See Population Estimates Terms and Definitions at http://www.census.gov/popest/about/terms.html. // Net international migration (except for Puerto Rico) includes the international migration of both native and foreign-born populations. Specifically, it includes: (a) the net international migration of the foreign born, (b) the net migration between the United States and Puerto Rico, (c) the net migration of natives to and from the United States, and (d) the net movement of the Armed Forces population between the United States and overseas. Net international migration for Puerto Rico includes the migration of native and foreign-born populations between the United States and Puerto Rico. // The estimates are based on the 2010 Census and reflect changes to the April 1, 2010 population due to the Count Question Resolution program and geographic program revisions. See Geographic Terms and Definitions at http://www.census.gov/popest/about/geo/terms.html for a list of the states that are included in each region and division. All geographic boundaries for these population estimates are as of January 1, 2013. // For detailed information about the methods used to create the population estimates, see http://www.census.gov/popest/methodology/index.html. // Each year, the Census Bureau's Population Estimates Program (PEP) utilizes current data on births, deaths, and migration to calculate population change since the most recent decennial census, and produces a time series of estimates of population. The annual time series of estimates begins with the most recent decennial census data and extends to the vintage year. The vintage year (e.g., V2013) refers to the final year of the time series. The reference date for all estimates is July 1, unless otherwise specified. With each new issue of estimates, the Census Bureau revises estimates for years back to the last census. As each vintage of estimates includes all years since the most recent decennial census, the latest vintage of data available supersedes all previously produced estimates for those dates. The Population Estimates Program provides additional information including historical and intercensal estimates, evaluation estimates, demographic analysis, and research papers on its website: http://www.census.gov/popest/index.html.",
#   u'identifier': u'POPESTnatstprc2014',
#   u'license': u'Public Domain',
#   u'mbox': u'pop.population.estimates@census.gov',
#   u'modified': u'2014-12-15',
#   u'programCode': [u'006:008'],
#   u'publisher': u'U.S. Census Bureau',
#   u'references': [u'http://www.census.gov/developers/'],
#   u'spatial': u'United States',
#   u'temporal': u'April 1, 2010 - Current',
#   u'title': u'Vintage 2014 Population Estimates: US, State, and PR Total Population and Components of Change',
#   u'webService': u'http://api.census.gov/data/2014/pep/natstprc'},
#  {u'accessLevel': u'public',
#   u'bureauCode': [u'006:07'],
#   u'c_dataset': [u'acs5', u'profile'],
#   u'c_documentationLink': u'http://www.census.gov/developer/',
#   u'c_examplesLink': u'http://api.census.gov/data/2013/acs5/profile/examples.json',
#   u'c_geographyLink': u'http://api.census.gov/data/2013/acs5/profile/geography.json',
#   u'c_isAggregate': True,
#   u'c_variablesLink': u'http://api.census.gov/data/2013/acs5/profile/variables.json',
#   u'c_vintage': 2013,
#   u'contactPoint': u'American Community Survey Office',
#   u'description': u"The American Community Survey (ACS) is a nationwide survey designed to provide communities a fresh look at how they are changing. The ACS replaced the decennial census long form in 2010 and thereafter by collecting long form type information throughout the decade rather than only once every 10 years. Questionnaires are mailed to a sample of addresses to obtain information about households -- that is, about each person and the housing unit itself. The American Community Survey produces demographic, social, housing and economic estimates in the form of 1-year, 3-year and 5-year estimates based on population thresholds. The strength of the ACS is in estimating population and housing characteristics. It produces estimates for small areas, including census tracts and population subgroups. Although the ACS produces population, demographic and housing unit estimates,it is the Census Bureau's Population Estimates Program that produces and disseminates the official estimates of the population for the nation, states, counties, cities and towns, and estimates of housing units for states and counties. For 2010 and other decennial census years, the Decennial Census provides the official counts of population and housing units.",
#   u'identifier': u'ACSProfile5Y2013',
#   u'license': u'Public Domain',
#   u'mbox': u'acso.users.support@census.gov',
#   u'modified': u'2014-11-03',
#   u'programCode': [u'006:004'],
#   u'publisher': u'U.S. Census Bureau',
#   u'references': [u'http://www.census.gov/developers/'],
#   u'spatial': u'United States',
#   u'temporal': u'2009/2013',
#   u'title': u'2009-2013 American Community Survey 5-Year Profiles',
#   u'webService': u'http://api.census.gov/data/2013/acs5/profile'}]

# %%
len(api_json)
# Out:
# 76

# %%
api_json[0].keys()
# Out:
# [u'publisher',
#  u'accessLevel',
#  u'c_dataset',
#  u'webService',
#  u'identifier',
#  u'title',
#  u'temporal',
#  u'spatial',
#  u'c_variablesLink',
#  u'c_documentationLink',
#  u'c_isAggregate',
#  u'bureauCode',
#  u'references',
#  u'c_geographyLink',
#  u'contactPoint',
#  u'c_tagsLink',
#  u'mbox',
#  u'c_vintage',
#  u'description']

# %%
[(api.get('c_vintage'), api.get('c_dataset'), api.get('c_variablesLink')) for api in api_json]
# Out:
# [(2010, [u'acs5'], u'http://api.census.gov/data/2010/acs5/variables.json'),
#  (2007, [u'ewks'], u'http://api.census.gov/data/2007/ewks/variables.json'),
#  (2013, [u'acs5'], u'http://api.census.gov/data/2013/acs5/variables.json'),
#  (2013, [u'acs3'], u'http://api.census.gov/data/2013/acs3/variables.json'),
#  (None,
#   [u'eits', u'm3'],
#   u'http://api.census.gov/data/eits/m3/variables.json'),
#  (2011, [u'nonemp'], u'http://api.census.gov/data/2011/nonemp/variables.json'),
#  (1990, [u'sf1'], u'http://api.census.gov/data/1990/sf1/variables.json'),
#  (2008, [u'cbp'], u'http://api.census.gov/data/2008/cbp/variables.json'),
#  (2013,
#   [u'pep', u'stchar6'],
#   u'http://api.census.gov/data/2013/pep/stchar6/variables.json'),
#  (2012, [u'ewks'], u'http://api.census.gov/data/2012/ewks/variables.json'),
#  (None,
#   [u'bds', u'firms'],
#   u'http://api.census.gov/data/bds/firms/variables.json'),
#  (2013,
#   [u'pep', u'housing'],
#   u'http://api.census.gov/data/2013/pep/housing/variables.json'),
#  (None,
#   [u'eits', u'qss'],
#   u'http://api.census.gov/data/eits/qss/variables.json'),
#  (None,
#   [u'eits', u'vip'],
#   u'http://api.census.gov/data/eits/vip/variables.json'),
#  (1990, [u'sf3'], u'http://api.census.gov/data/1990/sf3/variables.json'),
#  (2013,
#   [u'pep', u'monthlynatchar5'],
#   u'http://api.census.gov/data/2013/pep/monthlynatchar5/variables.json'),
#  (None,
#   [u'eits', u'mtis'],
#   u'http://api.census.gov/data/eits/mtis/variables.json'),
#  (None,
#   [u'eits', u'qfr'],
#   u'http://api.census.gov/data/eits/qfr/variables.json'),
#  (None,
#   [u'eits', u'marts'],
#   u'http://api.census.gov/data/eits/marts/variables.json'),
#  (None,
#   [u'eits', u'hv'],
#   u'http://api.census.gov/data/eits/hv/variables.json'),
#  (2014,
#   [u'pep', u'prm'],
#   u'http://api.census.gov/data/2014/pep/prm/variables.json'),
#  (2014,
#   [u'pep', u'natstprc18'],
#   u'http://api.census.gov/data/2014/pep/natstprc18/variables.json'),
#  (2013,
#   [u'acs3', u'profile'],
#   u'http://api.census.gov/data/2013/acs3/profile/variables.json'),
#  (2012,
#   [u'pubschlfin'],
#   u'http://api.census.gov/data/2012/pubschlfin/variables.json'),
#  (2012,
#   [u'acs5', u'profile'],
#   u'http://api.census.gov/data/2012/acs5/profile/variables.json'),
#  (2013, [u'acs1'], u'http://api.census.gov/data/2013/acs1/variables.json'),
#  (2013,
#   [u'pep', u'stchar5'],
#   u'http://api.census.gov/data/2013/pep/stchar5/variables.json'),
#  (2010, [u'sf1'], u'http://api.census.gov/data/2010/sf1/variables.json'),
#  (2012, [u'nonemp'], u'http://api.census.gov/data/2012/nonemp/variables.json'),
#  (2012,
#   [u'popproj', u'deaths'],
#   u'http://api.census.gov/data/2012/popproj/deaths/variables.json'),
#  (2013,
#   [u'pep', u'monthlynatchar6'],
#   u'http://api.census.gov/data/2013/pep/monthlynatchar6/variables.json'),
#  (2010, [u'cbp'], u'http://api.census.gov/data/2010/cbp/variables.json'),
#  (2000, [u'sf3'], u'http://api.census.gov/data/2000/sf3/variables.json'),
#  (2013,
#   [u'pep', u'cochar6'],
#   u'http://api.census.gov/data/2013/pep/cochar6/variables.json'),
#  (2012, [u'acs1'], u'http://api.census.gov/data/2012/acs1/variables.json'),
#  (2009, [u'cbp'], u'http://api.census.gov/data/2009/cbp/variables.json'),
#  (2012, [u'acs3'], u'http://api.census.gov/data/2012/acs3/variables.json'),
#  (None,
#   [u'eits', u'qtax'],
#   u'http://api.census.gov/data/eits/qtax/variables.json'),
#  (2013, [u'nonemp'], u'http://api.census.gov/data/2013/nonemp/variables.json'),
#  (2013,
#   [u'pep', u'natstprc18'],
#   u'http://api.census.gov/data/2013/pep/natstprc18/variables.json'),
#  (2013,
#   [u'acs1', u'profile'],
#   u'http://api.census.gov/data/2013/acs1/profile/variables.json'),
#  (2014,
#   [u'pep', u'housing'],
#   u'http://api.census.gov/data/2014/pep/housing/variables.json'),
#  (2013, [u'cbp'], u'http://api.census.gov/data/2013/cbp/variables.json'),
#  (2012,
#   [u'popproj', u'births'],
#   u'http://api.census.gov/data/2012/popproj/births/variables.json'),
#  (2013,
#   [u'pep', u'cochar5'],
#   u'http://api.census.gov/data/2013/pep/cochar5/variables.json'),
#  (None,
#   [u'eits', u'mrts'],
#   u'http://api.census.gov/data/eits/mrts/variables.json'),
#  (2008, [u'nonemp'], u'http://api.census.gov/data/2008/nonemp/variables.json'),
#  (2014,
#   [u'pep', u'subcty'],
#   u'http://api.census.gov/data/2014/pep/subcty/variables.json'),
#  (2013,
#   [u'pep', u'cty'],
#   u'http://api.census.gov/data/2013/pep/cty/variables.json'),
#  (2012,
#   [u'popproj', u'nim'],
#   u'http://api.census.gov/data/2012/popproj/nim/variables.json'),
#  (2012, [u'cbp'], u'http://api.census.gov/data/2012/cbp/variables.json'),
#  (2011, [u'acs5'], u'http://api.census.gov/data/2011/acs5/variables.json'),
#  (2011, [u'cbp'], u'http://api.census.gov/data/2011/cbp/variables.json'),
#  (None,
#   [u'eits', u'mhs'],
#   u'http://api.census.gov/data/eits/mhs/variables.json'),
#  (2012, [u'acs5'], u'http://api.census.gov/data/2012/acs5/variables.json'),
#  (2013,
#   [u'pep', u'prmagesex'],
#   u'http://api.census.gov/data/2013/pep/prmagesex/variables.json'),
#  (None,
#   [u'eits', u'mwts'],
#   u'http://api.census.gov/data/eits/mwts/variables.json'),
#  (2013,
#   [u'pep', u'prcagesex'],
#   u'http://api.census.gov/data/2013/pep/prcagesex/variables.json'),
#  (2011,
#   [u'acs1', u'cd113'],
#   u'http://api.census.gov/data/2011/acs1/cd113/variables.json'),
#  (2010, [u'nonemp'], u'http://api.census.gov/data/2010/nonemp/variables.json'),
#  (2012,
#   [u'acs1', u'profile'],
#   u'http://api.census.gov/data/2012/acs1/profile/variables.json'),
#  (None,
#   [u'eits', u'resconst'],
#   u'http://api.census.gov/data/eits/resconst/variables.json'),
#  (2013,
#   [u'pep', u'natstprc'],
#   u'http://api.census.gov/data/2013/pep/natstprc/variables.json'),
#  (2014,
#   [u'pep', u'cty'],
#   u'http://api.census.gov/data/2014/pep/cty/variables.json'),
#  (2013,
#   [u'pep', u'subcty'],
#   u'http://api.census.gov/data/2013/pep/subcty/variables.json'),
#  (2012,
#   [u'acs3', u'profile'],
#   u'http://api.census.gov/data/2012/acs3/profile/variables.json'),
#  (None,
#   [u'eits', u'qpr'],
#   u'http://api.census.gov/data/eits/qpr/variables.json'),
#  (None,
#   [u'eits', u'ftd'],
#   u'http://api.census.gov/data/eits/ftd/variables.json'),
#  (2013,
#   [u'pep', u'prm'],
#   u'http://api.census.gov/data/2013/pep/prm/variables.json'),
#  (2000, [u'sf1'], u'http://api.census.gov/data/2000/sf1/variables.json'),
#  (2009, [u'nonemp'], u'http://api.census.gov/data/2009/nonemp/variables.json'),
#  (2012,
#   [u'popproj', u'pop'],
#   u'http://api.census.gov/data/2012/popproj/pop/variables.json'),
#  (None,
#   [u'eits', u'ressales'],
#   u'http://api.census.gov/data/eits/ressales/variables.json'),
#  (2002, [u'ewks'], u'http://api.census.gov/data/2002/ewks/variables.json'),
#  (2014,
#   [u'pep', u'natstprc'],
#   u'http://api.census.gov/data/2014/pep/natstprc/variables.json'),
#  (2013,
#   [u'acs5', u'profile'],
#   u'http://api.census.gov/data/2013/acs5/profile/variables.json')]

# %% [markdown]
# # variables.json

# %%
import requests
url = "http://api.census.gov/data/2010/sf1/variables.json"
var_json = requests.get(url).json()
sorted(var_json['variables'].keys())
# Out:
# [u'AIANHH',
#  u'AIANHHCC',
#  u'AIANHHFP',
#  u'AIHHTLI',
#  u'AITS',
#  u'AITSCC',
#  u'AITSCE',
#  u'ANRC',
#  u'BLKGRP',
#  u'BLOCK',
#  u'CBSA',
#  u'CBSAPCI',
#  u'CD',
#  u'CD113',
#  u'CNECTA',
#  u'CONCIT',
#  u'CONCITSC',
#  u'COUNTY',
#  u'COUSUB',
#  u'CSA',
#  u'DIVISION',
#  u'GEOCOMP',
#  u'H00010001',
#  u'H0020001',
#  u'H0020002',
#  u'H0020003',
#  u'H0020004',
#  u'H0020005',
#  u'H0020006',
#  u'H0030001',
#  u'H0030002',
#  u'H0030003',
#  u'H0040001',
#  u'H0040002',
#  u'H0040003',
#  u'H0040004',
#  u'H0050001',
#  u'H0050002',
#  u'H0050003',
#  u'H0050004',
#  u'H0050005',
#  u'H0050006',
#  u'H0050007',
#  u'H0050008',
#  u'H0060001',
#  u'H0060002',
#  u'H0060003',
#  u'H0060004',
#  u'H0060005',
#  u'H0060006',
#  u'H0060007',
#  u'H0060008',
#  u'H0070001',
#  u'H0070002',
#  u'H0070003',
#  u'H0070004',
#  u'H0070005',
#  u'H0070006',
#  u'H0070007',
#  u'H0070008',
#  u'H0070009',
#  u'H0070010',
#  u'H0070011',
#  u'H0070012',
#  u'H0070013',
#  u'H0070014',
#  u'H0070015',
#  u'H0070016',
#  u'H0070017',
#  u'H0080001',
#  u'H0080002',
#  u'H0080003',
#  u'H0080004',
#  u'H0080005',
#  u'H0080006',
#  u'H0080007',
#  u'H0090001',
#  u'H0090002',
#  u'H0090003',
#  u'H0090004',
#  u'H0090005',
#  u'H0090006',
#  u'H0090007',
#  u'H0090008',
#  u'H0090009',
#  u'H0090010',
#  u'H0090011',
#  u'H0090012',
#  u'H0090013',
#  u'H0090014',
#  u'H0090015',
#  u'H0100001',
#  u'H0110001',
#  u'H0110002',
#  u'H0110003',
#  u'H0110004',
#  u'H011A0001',
#  u'H011A0002',
#  u'H011A0003',
#  u'H011A0004',
#  u'H011B0001',
#  u'H011B0002',
#  u'H011B0003',
#  u'H011B0004',
#  u'H011C0001',
#  u'H011C0002',
#  u'H011C0003',
#  u'H011C0004',
#  u'H011D0001',
#  u'H011D0002',
#  u'H011D0003',
#  u'H011D0004',
#  u'H011E0001',
#  u'H011E0002',
#  u'H011E0003',
#  u'H011E0004',
#  u'H011F0001',
#  u'H011F0002',
#  u'H011F0003',
#  u'H011F0004',
#  u'H011G0001',
#  u'H011G0002',
#  u'H011G0003',
#  u'H011G0004',
#  u'H011H0001',
#  u'H011H0002',
#  u'H011H0003',
#  u'H011H0004',
#  u'H011I0001',
#  u'H011I0002',
#  u'H011I0003',
#  u'H011I0004',
#  u'H0120001',
#  u'H0120002',
#  u'H0120003',
#  u'H012A0001',
#  u'H012A0002',
#  u'H012A0003',
#  u'H012B0001',
#  u'H012B0002',
#  u'H012B0003',
#  u'H012C0001',
#  u'H012C0002',
#  u'H012C0003',
#  u'H012D0001',
#  u'H012D0002',
#  u'H012D0003',
#  u'H012E0001',
#  u'H012E0002',
#  u'H012E0003',
#  u'H012F0001',
#  u'H012F0002',
#  u'H012F0003',
#  u'H012G0001',
#  u'H012G0002',
#  u'H012G0003',
#  u'H012H0001',
#  u'H012H0002',
#  u'H012H0003',
#  u'H012I0001',
#  u'H012I0002',
#  u'H012I0003',
#  u'H0130001',
#  u'H0130002',
#  u'H0130003',
#  u'H0130004',
#  u'H0130005',
#  u'H0130006',
#  u'H0130007',
#  u'H0130008',
#  u'H0140001',
#  u'H0140002',
#  u'H0140003',
#  u'H0140004',
#  u'H0140005',
#  u'H0140006',
#  u'H0140007',
#  u'H0140008',
#  u'H0140009',
#  u'H0140010',
#  u'H0140011',
#  u'H0140012',
#  u'H0140013',
#  u'H0140014',
#  u'H0140015',
#  u'H0140016',
#  u'H0140017',
#  u'H0150001',
#  u'H0150002',
#  u'H0150003',
#  u'H0150004',
#  u'H0150005',
#  u'H0150006',
#  u'H0150007',
#  u'H0160001',
#  u'H0160002',
#  u'H0160003',
#  u'H0160004',
#  u'H0160005',
#  u'H0160006',
#  u'H0160007',
#  u'H0160008',
#  u'H0160009',
#  u'H0160010',
#  u'H0160011',
#  u'H0160012',
#  u'H0160013',
#  u'H0160014',
#  u'H0160015',
#  u'H0160016',
#  u'H0160017',
#  u'H016A0001',
#  u'H016A0002',
#  u'H016A0003',
#  u'H016A0004',
#  u'H016A0005',
#  u'H016A0006',
#  u'H016A0007',
#  u'H016A0008',
#  u'H016A0009',
#  u'H016A0010',
#  u'H016A0011',
#  u'H016A0012',
#  u'H016A0013',
#  u'H016A0014',
#  u'H016A0015',
#  u'H016A0016',
#  u'H016A0017',
#  u'H016B0001',
#  u'H016B0002',
#  u'H016B0003',
#  u'H016B0004',
#  u'H016B0005',
#  u'H016B0006',
#  u'H016B0007',
#  u'H016B0008',
#  u'H016B0009',
#  u'H016B0010',
#  u'H016B0011',
#  u'H016B0012',
#  u'H016B0013',
#  u'H016B0014',
#  u'H016B0015',
#  u'H016B0016',
#  u'H016B0017',
#  u'H016C0001',
#  u'H016C0002',
#  u'H016C0003',
#  u'H016C0004',
#  u'H016C0005',
#  u'H016C0006',
#  u'H016C0007',
#  u'H016C0008',
#  u'H016C0009',
#  u'H016C0010',
#  u'H016C0011',
#  u'H016C0012',
#  u'H016C0013',
#  u'H016C0014',
#  u'H016C0015',
#  u'H016C0016',
#  u'H016C0017',
#  u'H016D0001',
#  u'H016D0002',
#  u'H016D0003',
#  u'H016D0004',
#  u'H016D0005',
#  u'H016D0006',
#  u'H016D0007',
#  u'H016D0008',
#  u'H016D0009',
#  u'H016D0010',
#  u'H016D0011',
#  u'H016D0012',
#  u'H016D0013',
#  u'H016D0014',
#  u'H016D0015',
#  u'H016D0016',
#  u'H016D0017',
#  u'H016E0001',
#  u'H016E0002',
#  u'H016E0003',
#  u'H016E0004',
#  u'H016E0005',
#  u'H016E0006',
#  u'H016E0007',
#  u'H016E0008',
#  u'H016E0009',
#  u'H016E0010',
#  u'H016E0011',
#  u'H016E0012',
#  u'H016E0013',
#  u'H016E0014',
#  u'H016E0015',
#  u'H016E0016',
#  u'H016E0017',
#  u'H016F0001',
#  u'H016F0002',
#  u'H016F0003',
#  u'H016F0004',
#  u'H016F0005',
#  u'H016F0006',
#  u'H016F0007',
#  u'H016F0008',
#  u'H016F0009',
#  u'H016F0010',
#  u'H016F0011',
#  u'H016F0012',
#  u'H016F0013',
#  u'H016F0014',
#  u'H016F0015',
#  u'H016F0016',
#  u'H016F0017',
#  u'H016G0001',
#  u'H016G0002',
#  u'H016G0003',
#  u'H016G0004',
#  u'H016G0005',
#  u'H016G0006',
#  u'H016G0007',
#  u'H016G0008',
#  u'H016G0009',
#  u'H016G0010',
#  u'H016G0011',
#  u'H016G0012',
#  u'H016G0013',
#  u'H016G0014',
#  u'H016G0015',
#  u'H016G0016',
#  u'H016G0017',
#  u'H016H0001',
#  u'H016H0002',
#  u'H016H0003',
#  u'H016H0004',
#  u'H016H0005',
#  u'H016H0006',
#  u'H016H0007',
#  u'H016H0008',
#  u'H016H0009',
#  u'H016H0010',
#  u'H016H0011',
#  u'H016H0012',
#  u'H016H0013',
#  u'H016H0014',
#  u'H016H0015',
#  u'H016H0016',
#  u'H016H0017',
#  u'H016I0001',
#  u'H016I0002',
#  u'H016I0003',
#  u'H016I0004',
#  u'H016I0005',
#  u'H016I0006',
#  u'H016I0007',
#  u'H016I0008',
#  u'H016I0009',
#  u'H016I0010',
#  u'H016I0011',
#  u'H016I0012',
#  u'H016I0013',
#  u'H016I0014',
#  u'H016I0015',
#  u'H016I0016',
#  u'H016I0017',
#  u'H0170001',
#  u'H0170002',
#  u'H0170003',
#  u'H0170004',
#  u'H0170005',
#  u'H0170006',
#  u'H0170007',
#  u'H0170008',
#  u'H0170009',
#  u'H0170010',
#  u'H0170011',
#  u'H0170012',
#  u'H0170013',
#  u'H0170014',
#  u'H0170015',
#  u'H0170016',
#  u'H0170017',
#  u'H0170018',
#  u'H0170019',
#  u'H0170020',
#  u'H0170021',
#  u'H017A0001',
#  u'H017A0002',
#  u'H017A0003',
#  u'H017A0004',
#  u'H017A0005',
#  u'H017A0006',
#  u'H017A0007',
#  u'H017A0008',
#  u'H017A0009',
#  u'H017A0010',
#  u'H017A0011',
#  u'H017A0012',
#  u'H017A0013',
#  u'H017A0014',
#  u'H017A0015',
#  u'H017A0016',
#  u'H017A0017',
#  u'H017A0018',
#  u'H017A0019',
#  u'H017A0020',
#  u'H017A0021',
#  u'H017B0001',
#  u'H017B0002',
#  u'H017B0003',
#  u'H017B0004',
#  u'H017B0005',
#  u'H017B0006',
#  u'H017B0007',
#  u'H017B0008',
#  u'H017B0009',
#  u'H017B0010',
#  u'H017B0011',
#  u'H017B0012',
#  u'H017B0013',
#  u'H017B0014',
#  u'H017B0015',
#  u'H017B0016',
#  u'H017B0017',
#  u'H017B0018',
#  u'H017B0019',
#  u'H017B0020',
#  u'H017B0021',
#  u'H017C0001',
#  u'H017C0002',
#  u'H017C0003',
#  u'H017C0004',
#  u'H017C0005',
#  u'H017C0006',
#  u'H017C0007',
#  u'H017C0008',
#  u'H017C0009',
#  u'H017C0010',
#  u'H017C0011',
#  u'H017C0012',
#  u'H017C0013',
#  u'H017C0014',
#  u'H017C0015',
#  u'H017C0016',
#  u'H017C0017',
#  u'H017C0018',
#  u'H017C0019',
#  u'H017C0020',
#  u'H017C0021',
#  u'H017D0001',
#  u'H017D0002',
#  u'H017D0003',
#  u'H017D0004',
#  u'H017D0005',
#  u'H017D0006',
#  u'H017D0007',
#  u'H017D0008',
#  u'H017D0009',
#  u'H017D0010',
#  u'H017D0011',
#  u'H017D0012',
#  u'H017D0013',
#  u'H017D0014',
#  u'H017D0015',
#  u'H017D0016',
#  u'H017D0017',
#  u'H017D0018',
#  u'H017D0019',
#  u'H017D0020',
#  u'H017D0021',
#  u'H017E0001',
#  u'H017E0002',
#  u'H017E0003',
#  u'H017E0004',
#  u'H017E0005',
#  u'H017E0006',
#  u'H017E0007',
#  u'H017E0008',
#  u'H017E0009',
#  u'H017E0010',
#  u'H017E0011',
#  u'H017E0012',
#  u'H017E0013',
#  u'H017E0014',
#  u'H017E0015',
#  u'H017E0016',
#  u'H017E0017',
#  u'H017E0018',
#  u'H017E0019',
#  u'H017E0020',
#  u'H017E0021',
#  u'H017F0001',
#  u'H017F0002',
#  u'H017F0003',
#  u'H017F0004',
#  u'H017F0005',
#  u'H017F0006',
#  u'H017F0007',
#  u'H017F0008',
#  u'H017F0009',
#  u'H017F0010',
#  u'H017F0011',
#  u'H017F0012',
#  u'H017F0013',
#  u'H017F0014',
#  u'H017F0015',
#  u'H017F0016',
#  u'H017F0017',
#  u'H017F0018',
#  u'H017F0019',
#  u'H017F0020',
#  u'H017F0021',
#  u'H017G0001',
#  u'H017G0002',
#  u'H017G0003',
#  u'H017G0004',
#  u'H017G0005',
#  u'H017G0006',
#  u'H017G0007',
#  u'H017G0008',
#  u'H017G0009',
#  u'H017G0010',
#  u'H017G0011',
#  u'H017G0012',
#  u'H017G0013',
#  u'H017G0014',
#  u'H017G0015',
#  u'H017G0016',
#  u'H017G0017',
#  u'H017G0018',
#  u'H017G0019',
#  u'H017G0020',
#  u'H017G0021',
#  u'H017H0001',
#  u'H017H0002',
#  u'H017H0003',
#  u'H017H0004',
#  u'H017H0005',
#  u'H017H0006',
#  u'H017H0007',
#  u'H017H0008',
#  u'H017H0009',
#  u'H017H0010',
#  u'H017H0011',
#  u'H017H0012',
#  u'H017H0013',
#  u'H017H0014',
#  u'H017H0015',
#  u'H017H0016',
#  u'H017H0017',
#  u'H017H0018',
#  u'H017H0019',
#  u'H017H0020',
#  u'H017H0021',
#  u'H017I0001',
#  u'H017I0002',
#  u'H017I0003',
#  u'H017I0004',
#  u'H017I0005',
#  u'H017I0006',
#  u'H017I0007',
#  u'H017I0008',
#  u'H017I0009',
#  u'H017I0010',
#  u'H017I0011',
#  u'H017I0012',
#  u'H017I0013',
#  u'H017I0014',
#  u'H017I0015',
#  u'H017I0016',
#  u'H017I0017',
#  u'H017I0018',
#  u'H017I0019',
#  u'H017I0020',
#  u'H017I0021',
#  u'H0180001',
#  u'H0180002',
#  u'H0180003',
#  u'H0180004',
#  u'H0180005',
#  u'H0180006',
#  u'H0180007',
#  u'H0180008',
#  u'H0180009',
#  u'H0180010',
#  u'H0180011',
#  u'H0180012',
#  u'H0180013',
#  u'H0180014',
#  u'H0180015',
#  u'H0180016',
#  u'H0180017',
#  u'H0180018',
#  u'H0180019',
#  u'H0180020',
#  u'H0180021',
#  u'H0180022',
#  u'H0180023',
#  u'H0180024',
#  u'H0180025',
#  u'H0180026',
#  u'H0180027',
#  u'H0180028',
#  u'H0180029',
#  u'H0180030',
#  u'H0180031',
#  u'H0180032',
#  u'H0180033',
#  u'H0180034',
#  u'H0180035',
#  u'H0180036',
#  u'H0180037',
#  u'H0180038',
#  u'H0180039',
#  u'H0180040',
#  u'H0180041',
#  u'H0180042',
#  u'H0180043',
#  u'H0180044',
#  u'H0180045',
#  u'H0180046',
#  u'H0180047',
#  u'H0180048',
#  u'H0180049',
#  u'H0180050',
#  u'H0180051',
#  u'H0180052',
#  u'H0180053',
#  u'H0180054',
#  u'H0180055',
#  u'H0180056',
#  u'H0180057',
#  u'H0180058',
#  u'H0180059',
#  u'H0180060',
#  u'H0180061',
#  u'H0180062',
#  u'H0180063',
#  u'H0180064',
#  u'H0180065',
#  u'H0180066',
#  u'H0180067',
#  u'H0180068',
#  u'H0180069',
#  u'H0190001',
#  u'H0190002',
#  u'H0190003',
#  u'H0190004',
#  u'H0190005',
#  u'H0190006',
#  u'H0190007',
#  u'H0200001',
#  u'H0200002',
#  u'H0200003',
#  u'H0210001',
#  u'H0210002',
#  u'H0210003',
#  u'H0220001',
#  u'H0220002',
#  u'H0220003',
#  u'HCT0010001',
#  u'HCT0010002',
#  u'HCT0010003',
#  u'HCT0010004',
#  u'HCT0010005',
#  u'HCT0010006',
#  u'HCT0010007',
#  u'HCT0010008',
#  u'HCT0010009',
#  u'HCT0010010',
#  u'HCT0010011',
#  u'HCT0010012',
#  u'HCT0010013',
#  u'HCT0010014',
#  u'HCT0010015',
#  u'HCT0010016',
#  u'HCT0010017',
#  u'HCT0010018',
#  u'HCT0010019',
#  u'HCT0010020',
#  u'HCT0010021',
#  u'HCT0010022',
#  u'HCT0010023',
#  u'HCT0010024',
#  u'HCT0010025',
#  u'HCT0010026',
#  u'HCT0010027',
#  u'HCT0010028',
#  u'HCT0010029',
#  u'HCT0010030',
#  u'HCT0010031',
#  u'HCT0010032',
#  u'HCT0010033',
#  u'HCT0010034',
#  u'HCT0010035',
#  u'HCT0020001',
#  u'HCT0020002',
#  u'HCT0020003',
#  u'HCT0020004',
#  u'HCT0020005',
#  u'HCT0020006',
#  u'HCT0020007',
#  u'HCT0020008',
#  u'HCT0020009',
#  u'HCT0020010',
#  u'HCT0020011',
#  u'HCT0020012',
#  u'HCT0020013',
#  u'HCT0030001',
#  u'HCT0030002',
#  u'HCT0030003',
#  u'HCT0030004',
#  u'HCT0030005',
#  u'HCT0030006',
#  u'HCT0030007',
#  u'HCT0030008',
#  u'HCT0030009',
#  u'HCT0030010',
#  u'HCT0030011',
#  u'HCT0030012',
#  u'HCT0030013',
#  u'HCT0040001',
#  u'HCT0040002',
#  u'HCT0040003',
#  u'HCT0040004',
#  u'HCT0040005',
#  u'HCT0040006',
#  u'HCT0040007',
#  u'HCT0040008',
#  u'HCT0040009',
#  u'HCT0040010',
#  u'HCT0040011',
#  u'HCT0040012',
#  u'HCT0040013',
#  u'LOGRECNO',
#  u'MEMI',
#  u'METDIV',
#  u'NAME',
#  u'NECTA',
#  u'NECTADIV',
#  u'NECTAPCI',
#  u'P0010001',
#  u'P0020001',
#  u'P0020002',
#  u'P0020003',
#  u'P0020004',
#  u'P0020005',
#  u'P0020006',
#  u'P0030001',
#  u'P0030002',
#  u'P0030003',
#  u'P0030004',
#  u'P0030005',
#  u'P0030006',
#  u'P0030007',
#  u'P0030008',
#  u'P0040001',
#  u'P0040002',
#  u'P0040003',
#  u'P0050001',
#  u'P0050002',
#  u'P0050003',
#  u'P0050004',
#  u'P0050005',
#  u'P0050006',
#  u'P0050007',
#  u'P0050008',
#  u'P0050009',
#  u'P0050010',
#  u'P0050011',
#  u'P0050012',
#  u'P0050013',
#  u'P0050014',
#  u'P0050015',
#  u'P0050016',
#  u'P0050017',
#  u'P0060001',
#  u'P0060002',
#  u'P0060003',
#  u'P0060004',
#  u'P0060005',
#  u'P0060006',
#  u'P0060007',
#  u'P0070001',
#  u'P0070002',
#  u'P0070003',
#  u'P0070004',
#  u'P0070005',
#  u'P0070006',
#  u'P0070007',
#  u'P0070008',
#  u'P0070009',
#  u'P0070010',
#  u'P0070011',
#  u'P0070012',
#  u'P0070013',
#  u'P0070014',
#  u'P0070015',
#  u'P0080001',
#  u'P0080002',
#  u'P0080003',
#  u'P0080004',
#  u'P0080005',
#  u'P0080006',
#  u'P0080007',
#  u'P0080008',
#  u'P0080009',
#  u'P0080010',
#  u'P0080011',
#  u'P0080012',
#  u'P0080013',
#  u'P0080014',
#  u'P0080015',
#  u'P0080016',
#  u'P0080017',
#  u'P0080018',
#  u'P0080019',
#  u'P0080020',
#  u'P0080021',
#  u'P0080022',
#  u'P0080023',
#  u'P0080024',
#  u'P0080025',
#  u'P0080026',
#  u'P0080027',
#  u'P0080028',
#  u'P0080029',
#  u'P0080030',
#  u'P0080031',
#  u'P0080032',
#  u'P0080033',
#  u'P0080034',
#  u'P0080035',
#  u'P0080036',
#  u'P0080037',
#  u'P0080038',
#  u'P0080039',
#  u'P0080040',
#  u'P0080041',
#  u'P0080042',
#  u'P0080043',
#  u'P0080044',
#  u'P0080045',
#  u'P0080046',
#  u'P0080047',
#  u'P0080048',
#  u'P0080049',
#  u'P0080050',
#  u'P0080051',
#  u'P0080052',
#  u'P0080053',
#  u'P0080054',
#  u'P0080055',
#  u'P0080056',
#  u'P0080057',
#  u'P0080058',
#  u'P0080059',
#  u'P0080060',
#  u'P0080061',
#  u'P0080062',
#  u'P0080063',
#  u'P0080064',
#  u'P0080065',
#  u'P0080066',
#  u'P0080067',
#  u'P0080068',
#  u'P0080069',
#  u'P0080070',
#  u'P0080071',
#  u'P0090001',
#  u'P0090002',
#  u'P0090003',
#  u'P0090004',
#  u'P0090005',
#  u'P0090006',
#  u'P0090007',
#  u'P0090008',
#  u'P0090009',
#  u'P0090010',
#  u'P0090011',
#  u'P0090012',
#  u'P0090013',
#  u'P0090014',
#  u'P0090015',
#  u'P0090016',
#  u'P0090017',
#  u'P0090018',
#  u'P0090019',
#  u'P0090020',
#  u'P0090021',
#  u'P0090022',
#  u'P0090023',
#  u'P0090024',
#  u'P0090025',
#  u'P0090026',
#  u'P0090027',
#  u'P0090028',
#  u'P0090029',
#  u'P0090030',
#  u'P0090031',
#  u'P0090032',
#  u'P0090033',
#  u'P0090034',
#  u'P0090035',
#  u'P0090036',
#  u'P0090037',
#  u'P0090038',
#  u'P0090039',
#  u'P0090040',
#  u'P0090041',
#  u'P0090042',
#  u'P0090043',
#  u'P0090044',
#  u'P0090045',
#  u'P0090046',
#  u'P0090047',
#  u'P0090048',
#  u'P0090049',
#  u'P0090050',
#  u'P0090051',
#  u'P0090052',
#  u'P0090053',
#  u'P0090054',
#  u'P0090055',
#  u'P0090056',
#  u'P0090057',
#  u'P0090058',
#  u'P0090059',
#  u'P0090060',
#  u'P0090061',
#  u'P0090062',
#  u'P0090063',
#  u'P0090064',
#  u'P0090065',
#  u'P0090066',
#  u'P0090067',
#  u'P0090068',
#  u'P0090069',
#  u'P0090070',
#  u'P0090071',
#  u'P0090072',
#  u'P0090073',
#  u'P0100001',
#  u'P0100002',
#  u'P0100003',
#  u'P0100004',
#  u'P0100005',
#  u'P0100006',
#  u'P0100007',
#  u'P0100008',
#  u'P0100009',
#  u'P0100010',
#  u'P0100011',
#  u'P0100012',
#  u'P0100013',
#  u'P0100014',
#  u'P0100015',
#  u'P0100016',
#  u'P0100017',
#  u'P0100018',
#  u'P0100019',
#  u'P0100020',
#  u'P0100021',
#  u'P0100022',
#  u'P0100023',
#  u'P0100024',
#  u'P0100025',
#  u'P0100026',
#  u'P0100027',
#  u'P0100028',
#  u'P0100029',
#  u'P0100030',
#  u'P0100031',
#  u'P0100032',
#  u'P0100033',
#  u'P0100034',
#  u'P0100035',
#  u'P0100036',
#  u'P0100037',
#  u'P0100038',
#  u'P0100039',
#  u'P0100040',
#  u'P0100041',
#  u'P0100042',
#  u'P0100043',
#  u'P0100044',
#  u'P0100045',
#  u'P0100046',
#  u'P0100047',
#  u'P0100048',
#  u'P0100049',
#  u'P0100050',
#  u'P0100051',
#  u'P0100052',
#  u'P0100053',
#  u'P0100054',
#  u'P0100055',
#  u'P0100056',
#  u'P0100057',
#  u'P0100058',
#  u'P0100059',
#  ...]

# %%
var_json['variables']['P0050002']
# Out:
# {u'concept': u'P5. HISPANIC OR LATINO ORIGIN BY RACE [17]',
#  u'label': u'Not Hispanic or Latino:'}

# %%
from pandas import DataFrame
DataFrame(var_json['variables']).T
# Out:
#                                                       concept  \
# AIANHH                               Geographic Summary Level
# AIANHHCC                           Geographic Characteristics
# AIANHHFP                           Geographic Characteristics
# AIHHTLI                            Geographic Characteristics
# AITS                               Geographic Characteristics
# AITSCC                             Geographic Characteristics
# AITSCE                             Geographic Characteristics
# ANRC                               Geographic Characteristics
# BLKGRP                               Geographic Summary Level
# BLOCK                                                     NaN
# CBSA                                 Geographic Summary Level
# CBSAPCI                            Geographic Characteristics
# CD                                   Geographic Summary Level
# CD113                              Geographic Characteristics
# CNECTA                             Geographic Characteristics
# CONCIT                               Geographic Summary Level
# CONCITSC                           Geographic Characteristics
# COUNTY                               Geographic Summary Level
# COUSUB                               Geographic Summary Level
# CSA                                  Geographic Summary Level
# DIVISION                             Geographic Summary Level
# GEOCOMP                            Geographic Characteristics
# H00010001                               H1. Housing Units [1]
# H0020001    H2. URBAN AND RURAL [6] (Urban/Rural Update only)
# H0020002    H2. URBAN AND RURAL [6] (Urban/Rural Update only)
# H0020003    H2. URBAN AND RURAL [6] (Urban/Rural Update only)
# H0020004    H2. URBAN AND RURAL [6] (Urban/Rural Update only)
# H0020005    H2. URBAN AND RURAL [6] (Urban/Rural Update only)
# H0020006    H2. URBAN AND RURAL [6] (Urban/Rural Update only)
# H0030001                             H3. Occupancy Status [3]
# ...                                                       ...
# PCT022I020  PCT22I. GROUP QUARTERS POPULATION BY SEX BY GR...
# PCT022I021  PCT22I. GROUP QUARTERS POPULATION BY SEX BY GR...
# PLACE                                Geographic Summary Level
# PLACECC                            Geographic Characteristics
# REGION                               Geographic Summary Level
# SDELEM                               Geographic Summary Level
# SDSEC                                Geographic Summary Level
# SDUNI                                Geographic Summary Level
# SLDL                                 Geographic Summary Level
# SLDL2                              Geographic Characteristics
# SLDL3                              Geographic Characteristics
# SLDL4                              Geographic Characteristics
# SLDU                                 Geographic Summary Level
# SLDU2                              Geographic Characteristics
# SLDU3                              Geographic Characteristics
# SLDU4                              Geographic Characteristics
# STATE                                Geographic Summary Level
# SUBMCD                               Geographic Summary Level
# SUBMCDCC                                                  NaN
# SUMLEV                             Geographic Characteristics
# TRACT                                Geographic Summary Level
# UASC                               Geographic Characteristics
# UATYPE                             Geographic Characteristics
# UGA                                Geographic Characteristics
# UR                                 Geographic Characteristics
# VTD                                Geographic Characteristics
# ZCTA5                              Geographic Characteristics
# for                        Census API Geography Specification
# gnis                       Census API Geography Specification
# in                         Census API Geography Specification
#
#                                                         label predicateOnly  \
# AIANHH                                       GEO PLACE HOLDER           NaN
# AIANHHCC                                     GEO PLACE HOLDER           NaN
# AIANHHFP                                     GEO PLACE HOLDER           NaN
# AIHHTLI                                      GEO PLACE HOLDER           NaN
# AITS                                         GEO PLACE HOLDER           NaN
# AITSCC                                       GEO PLACE HOLDER           NaN
# AITSCE                                       GEO PLACE HOLDER           NaN
# ANRC                                         GEO PLACE HOLDER           NaN
# BLKGRP                                       GEO PLACE HOLDER           NaN
# BLOCK                                        GEO PLACE HOLDER           NaN
# CBSA                                         GEO PLACE HOLDER           NaN
# CBSAPCI                                      GEO PLACE HOLDER           NaN
# CD                                           GEO PLACE HOLDER           NaN
# CD113                                        GEO PLACE HOLDER           NaN
# CNECTA                                       GEO PLACE HOLDER           NaN
# CONCIT                                       GEO PLACE HOLDER           NaN
# CONCITSC                                     GEO PLACE HOLDER           NaN
# COUNTY                                         County (FIPS))           NaN
# COUSUB                                       GEO PLACE HOLDER           NaN
# CSA                                          GEO PLACE HOLDER           NaN
# DIVISION                                     GEO PLACE HOLDER           NaN
# GEOCOMP                                      GEO PLACE HOLDER           NaN
# H00010001                                       Housing units           NaN
# H0020001                                        Housing units           NaN
# H0020002                                               Urban:           NaN
# H0020003                     Urban: !! Inside urbanized areas           NaN
# H0020004                      Urban: !! Inside urban clusters           NaN
# H0020005                       Rural !! Inside urban clusters           NaN
# H0020006    Not defined for this file !! Inside urban clus...           NaN
# H0030001                                        Housing units           NaN
# ...                                                       ...           ...
# PCT022I020  Female: !! Noninstitutionalized population (50...           NaN
# PCT022I021  Female: !! Noninstitutionalized population (50...           NaN
# PLACE                                           Place (FIPS))           NaN
# PLACECC                                      GEO PLACE HOLDER           NaN
# REGION                                       GEO PLACE HOLDER           NaN
# SDELEM                                       GEO PLACE HOLDER           NaN
# SDSEC                                        GEO PLACE HOLDER           NaN
# SDUNI                                        GEO PLACE HOLDER           NaN
# SLDL                                         GEO PLACE HOLDER           NaN
# SLDL2                                        GEO PLACE HOLDER           NaN
# SLDL3                                        GEO PLACE HOLDER           NaN
# SLDL4                                        GEO PLACE HOLDER           NaN
# SLDU                                         GEO PLACE HOLDER           NaN
# SLDU2                                        GEO PLACE HOLDER           NaN
# SLDU3                                        GEO PLACE HOLDER           NaN
# SLDU4                                        GEO PLACE HOLDER           NaN
# STATE                                            State (FIPS)           NaN
# SUBMCD                                       GEO PLACE HOLDER           NaN
# SUBMCDCC                                     GEO PLACE HOLDER           NaN
# SUMLEV                                          Summary Level           NaN
# TRACT                                           Tract (FIPS))           NaN
# UASC                                         GEO PLACE HOLDER           NaN
# UATYPE                                       GEO PLACE HOLDER           NaN
# UGA                                          GEO PLACE HOLDER           NaN
# UR                                           GEO PLACE HOLDER           NaN
# VTD                                          GEO PLACE HOLDER           NaN
# ZCTA5                                        GEO PLACE HOLDER           NaN
# for                              Census API FIPS 'for' clause          True
# gnis                                   Census API GNIS clause          True
# in                                Census API FIPS 'in' clause          True
#
#            predicateType
# AIANHH               NaN
# AIANHHCC             NaN
# AIANHHFP             NaN
# AIHHTLI              NaN
# AITS                 NaN
# AITSCC               NaN
# AITSCE               NaN
# ANRC                 NaN
# BLKGRP               NaN
# BLOCK                NaN
# CBSA                 NaN
# CBSAPCI              NaN
# CD                   NaN
# CD113                NaN
# CNECTA               NaN
# CONCIT               NaN
# CONCITSC             NaN
# COUNTY               NaN
# COUSUB               NaN
# CSA                  NaN
# DIVISION             NaN
# GEOCOMP              int
# H00010001            NaN
# H0020001             NaN
# H0020002             NaN
# H0020003             NaN
# H0020004             NaN
# H0020005             NaN
# H0020006             NaN
# H0030001             NaN
# ...                  ...
# PCT022I020           NaN
# PCT022I021           NaN
# PLACE                NaN
# PLACECC              NaN
# REGION               NaN
# SDELEM               NaN
# SDSEC                NaN
# SDUNI                NaN
# SLDL                 NaN
# SLDL2                NaN
# SLDL3                NaN
# SLDL4                NaN
# SLDU                 NaN
# SLDU2                NaN
# SLDU3                NaN
# SLDU4                NaN
# STATE                NaN
# SUBMCD               NaN
# SUBMCDCC             NaN
# SUMLEV               NaN
# TRACT                NaN
# UASC                 NaN
# UATYPE               NaN
# UGA                  NaN
# UR                   NaN
# VTD                  NaN
# ZCTA5                NaN
# for             fips-for
# gnis                gnis
# in               fips-in
#
# [8969 rows x 4 columns]

# %% [markdown]
# # Plotting Age Distribution By Gender (Population Pyramid)

# %% [markdown]
# This example written by AJ Renold.

# %%
sf1_fields = c.sf1.fields(year=2010)

# Get the sf1 fields that are only P12 Sex By Age
gender_population_fields = sf1_fields.get('P12. Sex By Age [49]')

# Separate the by male and female
male_fields = { key: val for key, val in gender_population_fields.items() 
                                 if 'Male' in val and val != ' Male: ' }
female_fields = { key: val for key, val in gender_population_fields.items() 
                                   if 'Female' in val and val != ' Female: '}
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-dc3b3cc82a46> in <module>()
# ----> 1 sf1_fields = c.sf1.fields(year=2010)
#       2
#       3 # Get the sf1 fields that are only P12 Sex By Age
#       4 gender_population_fields = sf1_fields.get('P12. Sex By Age [49]')
#       5
#
# /Users/raymondyee/anaconda/envs/myenv/lib/python2.7/site-packages/census/core.pyc in fields(self, year, flat)
#      86             raise CensusException('%s is not available for %s' % (self.dataset, year))
#      87
# ---> 88         resp = requests.get(fields_url)
#      89         doc = XML(resp.text)
#      90
#
# NameError: global name 'requests' is not defined

# %%
# Query the census API with the gender_population_fields
query_results = c.sf1.get(('NAME', ','.join(gender_population_fields.keys())), geo={'for': 'state:*'})

# Create a DataFrame
gender_df = pd.DataFrame(query_results)

# %%
# Set the Index to the NAME column
gender_df = gender_df.set_index(gender_df['NAME'])

# %%
# Recast all numeric columns to be type int
for col in gender_df.columns:
    if col != "state" and col != "NAME":
        gender_df[col] = gender_df[col].astype(int)

# %%
from numpy import arange

def showPopulationPyramidPlot(df, state, male_fields, female_fields):
    
    # create a series with the row of the state
    s = Series(df.ix[state])
    #del s['NAME']
    #del s['state']
    
    # get the plot values and labels from the series
    male_list = sorted([ [key, s[key]] for key in s.keys() if key in male_fields ])
    female_list = sorted([ [key, s[key]] for key in s.keys() if key in female_fields ]) 
    
    # calculate the bar locations and the maximum value
    bar_ypos = arange(len(male_list))+.5
    max_val = max([ val for label, val in male_list + female_list ])
    
    # create the figures for the plots
    fig, (ax2, ax1) = plt.subplots(nrows=1, ncols=2, figsize=(18,8))
    fig.suptitle('Population Age Pyramid for {state}'.format(state=state), fontsize=14)
    
    # plot the male populations
    bar1 = ax1.barh(bar_ypos, [ val for label, val in male_list ], align='center')
    ax1.set_xlim((0,max_val))
    ax1.set_yticks(bar_ypos)
    ax1.set_yticklabels([ male_fields[label][male_fields[label].find('!!')+3:] for label, val in male_list ])
    ax1.set_xlabel('People')
    ax1.set_title('Male Population by Age')
    ax1.grid(True)
    
    # plot the the female populations
    bar2 = ax2.barh(bar_ypos,[ val for label, val in female_list ], align='center', color='red')
    ax2.set_yticks([])
    #ax2.yaxis.tick_right()
    ax2.set_xlim(ax1.get_xlim()[::-1]) # reverses the x axis direction
    ax2.set_xlabel('People')
    ax2.set_title('Female Population by Age')
    ax2.grid(True)
    
    plt.subplots_adjust(wspace=0.22, hspace=0.0)
    plt.show()

# %%
showPopulationPyramidPlot(gender_df, 'Illinois', male_fields, female_fields)
