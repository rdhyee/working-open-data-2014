# %% [markdown]
# I recommend using Folium (see [Day_23_B_folium-ipython.ipynb](Day_23_B_folium-ipython.ipynb)) instead of trying to get Google Maps working in the Notebook for the course.  Should be easier.
#
# This notebook is a demonstration of plotting airport data we get from the project on airport data.

# %%
# http://nbviewer.ipython.org/gist/bburky/7763555/folium-ipython.ipynb

from IPython.display import HTML
import folium

def inline_map(map):
    """
    Embeds the HTML source of the map directly into the IPython notebook.
    
    This method will not work if the map depends on any files (json data). Also this uses
    the HTML5 srcdoc attribute, which may not be supported in all browsers.
    """
    map._build_map()
    return HTML('<iframe srcdoc="{srcdoc}" style="width: 100%; height: 510px; border: none"></iframe>'.format(srcdoc=map.HTML.replace('"', '&quot;')))

def embed_map(map, path="map.html"):
    """
    Embeds a linked iframe to the map into the IPython notebook.
    
    Note: this method will not capture the source of the map into the notebook.
    This method should work for all maps (as long as they use relative urls).
    """
    map.create_map(path=path)
    return HTML('<iframe src="files/{path}" style="width: 100%; height: 510px; border: none"></iframe>'.format(path=path))

# %%
import json
from itertools import islice

airports = []
# skip first line, which is a header row
for rec in islice(open("../data/airport_data.json"), 1, None):
    airports.append(json.loads(rec))

airports[:2]
# Out:
# [{u'Origin': u'ABE',
#   u'Origin_airport': u'Lehigh Valley International',
#   u'Origin_city': u'Allentown',
#   u'Origin_lat': u'40.65236278',
#   u'Origin_long': u'-75.44040167',
#   u'TotalFlights': u'278'},
#  {u'Origin': u'ABQ',
#   u'Origin_airport': u'Albuquerque International',
#   u'Origin_city': u'Albuquerque',
#   u'Origin_lat': u'35.04022222',
#   u'Origin_long': u'-106.6091944',
#   u'TotalFlights': u'2863'}]

# %%
airport_map = folium.Map(location=[40, -99], zoom_start=4)

for airport in islice(airports,None):
    lat =  float(airport['Origin_lat'])
    lon = float(airport['Origin_long'])
    label = str(airport['Origin_airport'])  # don't know why str necessary here
    airport_map.simple_marker([lat,lon],popup=label)

inline_map(airport_map)
# Out:
# <iframe srcdoc="<!DOCTYPE html>
# <head>
#    <link rel=&quot;stylesheet&quot; href=&quot;http://cdn.leafletjs.com/leaflet-0.5/leaflet.css&quot; />
#    <script src=&quot;http://cdn.leafletjs.com/leaflet-0.5/leaflet.js&quot;></script>
#
#
#
#
#
#
# <style>
#
# #map {
#   position:absolute;
#   top:0;
#   bottom:0;
#   right:0;
#   left:0;
# }
#
# </style>
# </head>
# <body>
#
#         <div id=&quot;map&quot; style=&quot;width: 960px; height: 500px&quot;></div>
#
# <script>
#
#
#
# var map = L.map('map').setView([40, -99], 4);
#
# L.tileLayer('http://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png', {
#     maxZoom: 18,
#     attribution: 'Map data (c) <a href=&quot;http://openstreetmap.org&quot;>OpenStreetMap</a> contributors'
# }).addTo(map);
#
#
# var marker_1 = L.marker([40.65236278, -75.44040167]);
# marker_1.bindPopup(&quot;Lehigh Valley International&quot;);
# map.addLayer(marker_1)
#
# var marker_2 = L.marker([35.04022222, -106.6091944]);
# marker_2.bindPopup(&quot;Albuquerque International&quot;);
# map.addLayer(marker_2)
#
# var marker_3 = L.marker([40.97811528, -124.1086189]);
# marker_3.bindPopup(&quot;Arcata&quot;);
# map.addLayer(marker_3)
#
# var marker_4 = L.marker([39.45758333, -74.57716667]);
# marker_4.bindPopup(&quot;Atlantic City International&quot;);
# map.addLayer(marker_4)
#
# var marker_5 = L.marker([31.32737167, -92.54855611]);
# marker_5.bindPopup(&quot;Alexandria International&quot;);
# map.addLayer(marker_5)
#
# var marker_6 = L.marker([42.74811944, -73.80297861]);
# marker_6.bindPopup(&quot;Albany Cty&quot;);
# map.addLayer(marker_6)
#
# var marker_7 = L.marker([35.2193725, -101.7059272]);
# marker_7.bindPopup(&quot;Amarillo International&quot;);
# map.addLayer(marker_7)
#
# var marker_8 = L.marker([61.17432028, -149.9961856]);
# marker_8.bindPopup(&quot;Ted Stevens Anchorage International&quot;);
# map.addLayer(marker_8)
#
# var marker_9 = L.marker([39.22316, -106.868845]);
# marker_9.bindPopup(&quot;Aspen-Pitkin Co/Sardy &quot;);
# map.addLayer(marker_9)
#
# var marker_10 = L.marker([33.64044444, -84.42694444]);
# marker_10.bindPopup(&quot;William B Hartsfield-Atlanta Intl&quot;);
# map.addLayer(marker_10)
#
# var marker_11 = L.marker([44.25740806, -88.51947556]);
# marker_11.bindPopup(&quot;Outagamie County Regional&quot;);
# map.addLayer(marker_11)
#
# var marker_12 = L.marker([30.19453278, -97.66987194]);
# marker_12.bindPopup(&quot;Austin-Bergstrom International&quot;);
# map.addLayer(marker_12)
#
# var marker_13 = L.marker([35.43619444, -82.54180556]);
# marker_13.bindPopup(&quot;Asheville Regional&quot;);
# map.addLayer(marker_13)
#
# var marker_14 = L.marker([41.33814944, -75.7242675]);
# marker_14.bindPopup(&quot;Wilkes-Barre/Scranton Intl&quot;);
# map.addLayer(marker_14)
#
# var marker_15 = L.marker([42.234875, -85.5520575]);
# marker_15.bindPopup(&quot;Kalamazoo County&quot;);
# map.addLayer(marker_15)
#
# var marker_16 = L.marker([41.93887417, -72.68322833]);
# marker_16.bindPopup(&quot;Bradley International&quot;);
# map.addLayer(marker_16)
#
# var marker_17 = L.marker([35.43359806, -119.0567681]);
# marker_17.bindPopup(&quot;Meadows &quot;);
# map.addLayer(marker_17)
#
# var marker_18 = L.marker([44.80744444, -68.82813889]);
# marker_18.bindPopup(&quot;Bangor International&quot;);
# map.addLayer(marker_18)
#
# var marker_19 = L.marker([33.56294306, -86.75354972]);
# marker_19.bindPopup(&quot;Birmingham International&quot;);
# map.addLayer(marker_19)
#
# var marker_20 = L.marker([45.8076625, -108.5428611]);
# marker_20.bindPopup(&quot;Billings Logan Intl&quot;);
# map.addLayer(marker_20)
#
# var marker_21 = L.marker([46.77411111, -100.7467222]);
# marker_21.bindPopup(&quot;Bismarck Municipal&quot;);
# map.addLayer(marker_21)
#
# var marker_22 = L.marker([48.79275, -122.5375278]);
# marker_22.bindPopup(&quot;Bellingham Intl&quot;);
# map.addLayer(marker_22)
#
# var marker_23 = L.marker([40.47798556, -88.91595278]);
# marker_23.bindPopup(&quot;Central Illinois Regional&quot;);
# map.addLayer(marker_23)
#
# var marker_24 = L.marker([36.12447667, -86.67818222]);
# marker_24.bindPopup(&quot;Nashville International&quot;);
# map.addLayer(marker_24)
#
# var marker_25 = L.marker([43.56444444, -116.2227778]);
# marker_25.bindPopup(&quot;Boise Air Terminal&quot;);
# map.addLayer(marker_25)
#
# var marker_26 = L.marker([42.3643475, -71.00517917]);
# marker_26.bindPopup(&quot;Gen Edw L Logan Intl&quot;);
# map.addLayer(marker_26)
#
# var marker_27 = L.marker([29.95083333, -94.02069444]);
# marker_27.bindPopup(&quot;Southeast Texas Regional&quot;);
# map.addLayer(marker_27)
#
# var marker_28 = L.marker([25.90683333, -97.42586111]);
# marker_28.bindPopup(&quot;Brownsville/S.Padre Island International&quot;);
# map.addLayer(marker_28)
#
# var marker_29 = L.marker([45.95479528, -112.49746]);
# marker_29.bindPopup(&quot;Bert Mooney&quot;);
# map.addLayer(marker_29)
#
# var marker_30 = L.marker([30.53316083, -91.14963444]);
# marker_30.bindPopup(&quot;Baton Rouge Metropolitan, Ryan &quot;);
# map.addLayer(marker_30)
#
# var marker_31 = L.marker([44.47300361, -73.1503125]);
# marker_31.bindPopup(&quot;Burlington International&quot;);
# map.addLayer(marker_31)
#
# var marker_32 = L.marker([42.94052472, -78.73216667]);
# marker_32.bindPopup(&quot;Buffalo Niagara Intl&quot;);
# map.addLayer(marker_32)
#
# var marker_33 = L.marker([34.20061917, -118.3584969]);
# marker_33.bindPopup(&quot;Burbank-Glendale-Pasadena&quot;);
# map.addLayer(marker_33)
#
# var marker_34 = L.marker([39.17540167, -76.66819833]);
# marker_34.bindPopup(&quot;Baltimore-Washington International&quot;);
# map.addLayer(marker_34)
#
# var marker_35 = L.marker([45.77690139, -111.1530072]);
# marker_35.bindPopup(&quot;Gallatin &quot;);
# map.addLayer(marker_35)
#
# var marker_36 = L.marker([33.93884, -81.11953944]);
# marker_36.bindPopup(&quot;Columbia Metropolitan&quot;);
# map.addLayer(marker_36)
#
# var marker_37 = L.marker([40.91631194, -81.44246556]);
# marker_37.bindPopup(&quot;Akron-Canton Regional&quot;);
# map.addLayer(marker_37)
#
# var marker_38 = L.marker([37.70097028, -113.098575]);
# marker_38.bindPopup(&quot;Cedar City Muni&quot;);
# map.addLayer(marker_38)
#
# var marker_39 = L.marker([41.78015722, -124.2365333]);
# marker_39.bindPopup(&quot;Jack McNamara &quot;);
# map.addLayer(marker_39)
#
# var marker_40 = L.marker([35.03526833, -85.20378778]);
# marker_40.bindPopup(&quot;Lovell &quot;);
# map.addLayer(marker_40)
#
# var marker_41 = L.marker([32.89864639, -80.04050583]);
# marker_41.bindPopup(&quot;Charleston AFB/International&quot;);
# map.addLayer(marker_41)
#
# var marker_42 = L.marker([39.79538278, -121.8584231]);
# marker_42.bindPopup(&quot;Chico Municipal&quot;);
# map.addLayer(marker_42)
#
# var marker_43 = L.marker([41.88458833, -91.71087222]);
# marker_43.bindPopup(&quot;Eastern Iowa &quot;);
# map.addLayer(marker_43)
#
# var marker_44 = L.marker([41.41089417, -81.84939667]);
# marker_44.bindPopup(&quot;Cleveland-Hopkins Intl&quot;);
# map.addLayer(marker_44)
#
# var marker_45 = L.marker([30.58858944, -96.36382417]);
# marker_45.bindPopup(&quot;Easterwood &quot;);
# map.addLayer(marker_45)
#
# var marker_46 = L.marker([35.21401111, -80.94312583]);
# marker_46.bindPopup(&quot;Charlotte/Douglas International&quot;);
# map.addLayer(marker_46)
#
# var marker_47 = L.marker([39.99798528, -82.89188278]);
# marker_47.bindPopup(&quot;Port Columbus Intl&quot;);
# map.addLayer(marker_47)
#
# var marker_48 = L.marker([44.52019417, -109.0237961]);
# marker_48.bindPopup(&quot;Yellowstone Regional&quot;);
# map.addLayer(marker_48)
#
# var marker_49 = L.marker([38.80580556, -104.70025]);
# marker_49.bindPopup(&quot;City of Colorado Springs Muni&quot;);
# map.addLayer(marker_49)
#
# var marker_50 = L.marker([42.90835556, -106.4644661]);
# marker_50.bindPopup(&quot;Natrona County Intl&quot;);
# map.addLayer(marker_50)
#
# var marker_51 = L.marker([27.77036083, -97.50121528]);
# marker_51.bindPopup(&quot;Corpus Christi International&quot;);
# map.addLayer(marker_51)
#
# var marker_52 = L.marker([38.37315083, -81.59318972]);
# marker_52.bindPopup(&quot;Yeager&quot;);
# map.addLayer(marker_52)
#
# var marker_53 = L.marker([39.04614278, -84.6621725]);
# marker_53.bindPopup(&quot;Cincinnati Northern Kentucky Intl&quot;);
# map.addLayer(marker_53)
#
# var marker_54 = L.marker([44.77761917, -89.66677944]);
# marker_54.bindPopup(&quot;Central Wisconsin&quot;);
# map.addLayer(ma
