# %%
# our usual pylab import
# %pylab --no-import-all inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# # Goal

# %% [markdown]
# For background, see [Mapping Census Data](http://www.udel.edu/johnmack/frec682/census/), including the
# [scan of the 10-question form](http://www.udel.edu/johnmack/frec682/census/census_form.png).  Keep in mind what people were asked and the range of data available in the census.
#
# Using the census API to get an understanding of some of the geographic entities in the **2010 census**.  We'll specifically be using the variable `P0010001`, the total population.
#
# What you will do in this notebook:
#
#  * Sum the population of the **states** (or state-like entity like DC) to get the total population of the **nation**
#  * Add up the **counties** for each **state** and validate the sums
#  * Add up the **census tracts** for each **county** and validate the sums
#
# We will make use of `pandas` in this notebook.

# %% [markdown]
# I often have the following [diagram](http://www.census.gov/geo/reference/pdfs/geodiagram.pdf) in mind to help understand the relationship among entities.  Also use the [list of example URLs](http://api.census.gov/data/2010/sf1/geo.html)  -- it'll come in handy.

# %% [markdown]
# <a href="http://www.flickr.com/photos/raymondyee/12297467734/" title="Census Geographic Hierarchies by Raymond Yee, on Flickr"><img src="http://farm4.staticflickr.com/3702/12297467734_af8882d310_c.jpg" width="618" height="800" alt="Census Geographic Hierarchies"></a>

# %% [markdown]
# # Working out the geographical hierarchy for Cafe Milano

# %% [markdown]
# It's helpful to have a concrete instance of a place to work with, especially when dealing with rather intangible entities like census tracts, block groups, and blocks.  You can use the [American FactFinder](http://factfinder2.census.gov/faces/nav/jsf/pages/index.xhtml) site to look up for any given US address the corresponding census geographies.
#
# Let's use Cafe Milano in Berkeley as an example. You can verify the following results by typing in the address into http://factfinder2.census.gov/faces/nav/jsf/pages/searchresults.xhtml?refresh=t.
#
# https://www.evernote.com/shard/s1/sh/dc0bfb96-4965-4fbf-bc28-c9d4d0080782/2bd8c92a045d62521723347d62fa2b9d
#
# 2522 Bancroft Way, BERKELEY, CA, 94704
#
# * State: California
# * County: Alameda County
# * County Subdivision: Berkeley CCD, Alameda County, California
# * Census Tract: Census Tract 4228, Alameda County, California
# * Block Group: Block Group 1, Census Tract 4228, Alameda County, California
# * Block: Block 1001, Block Group 1, Census Tract 4228, Alameda County, California

# %%
# YouTube video I made on how to use the American Factfinder site to look up addresses
from IPython.display import YouTubeVideo
YouTubeVideo('HeXcliUx96Y')
# Out:
#         <iframe
#             width="400"
#             height=300"
#             src="http://www.youtube.com/embed/HeXcliUx96Y"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
#  standard numpy, pandas, matplotlib imports

import numpy as np
import matplotlib.pyplot as plt
from pandas import DataFrame, Series, Index
import pandas as pd

# %%
# check that CENSUS_KEY is defined
import census
import us

import requests

import settings
assert settings.CENSUS_KEY is not None

# %% [markdown]
# The census documentation has example URLs but needs your API key to work.  In this notebook, we'll use the IPython notebook HTML display mechanism to help out.

# %%
c = census.Census(key=settings.CENSUS_KEY)

# %% [markdown]
# Note:  we can use `c.sf1` to access 2010 census (SF1: Census Summary File 1 (2010, 2000, 1990) available in API -- 2010 is the default)
#
# see documentation: [sunlightlabs/census](https://github.com/sunlightlabs/census)

# %% [markdown]
# # Summing up populations by state

# %% [markdown]
# Let's make a `DataFrame` named `states_df` with columns `NAME`, `P0010001` (for population), and `state` (to hold the FIPS code).  **Make sure to exclude Puerto Rico.**

# %%
# call the API and instantiate `df`
df = DataFrame(c.sf1.get('NAME,P0010001', geo={'for':'state:*'}))
# convert the population to integer
df['P0010001'] = df['P0010001'].astype(np.int)
df.head()
# Out:
#          NAME  P0010001 state
# 0     Alabama   4779736    01
# 1      Alaska    710231    02
# 2     Arizona   6392017    04
# 3    Arkansas   2915918    05
# 4  California  37253956    06

# %% [markdown]
# You can filter Puerto Rico (PR) in a number of ways -- use the way you're most comfortable with.
#
# Optional fun: filter PR in the following way
#
# * calculate a `np.array` holding the the fips of the states
# * then use [numpy.in1d](http://docs.scipy.org/doc/numpy/reference/generated/numpy.in1d.html), which is a analogous to the [in](http://stackoverflow.com/a/3437130/7782) operator to test membership in a list

# %%
states_fips = np.array([state.fips for state in us.states.STATES])
states_df = df[np.in1d(df.state,states_fips)]

# %% [markdown]
# If `states_df` is calculated properly, the following asserts will pass silently.

# %%
# check that we have three columns
assert set(states_df.columns) == set((u'NAME', u'P0010001', u'state'))

# check that the total 2010 census population is correct
assert np.sum(states_df.P0010001) == 308745538 

# check that the number of states+DC is 51
assert len(states_df) == 51

# %% [markdown]
# # Counties

# %% [markdown]
# Looking at http://api.census.gov/data/2010/sf1/geo.html, we see
#
#     state-county: http://api.census.gov/data/2010/sf1?get=P0010001&for=county:*
#
# if we want to grab all counties in one go, or you can grab counties state-by-state:
#
#     http://api.census.gov/data/2010/sf1?get=P0010001&for=county:*&in=state:06
#
# for all counties in the state with FIPS code `06` (which is what state?)

# %%
# Here's a way to use translate 
# http://api.census.gov/data/2010/sf1?get=P0010001&for=county:*
# into a call using the census.Census object

r = c.sf1.get('NAME,P0010001', geo={'for':'county:*'})

# ask yourself what len(r) means and what it should be
len(r)
# Out:
# 3221

# %%
# let's try out one of the `census` object convenience methods
# instead of using `c.sf1.get`

r = c.sf1.state_county('NAME,P0010001',census.ALL,census.ALL)
r
# Out:
# [{u'NAME': u'Autauga County',
#   u'P0010001': u'54571',
#   u'county': u'001',
#   u'state': u'01'},
#  {u'NAME': u'Baldwin County',
#   u'P0010001': u'182265',
#   u'county': u'003',
#   u'state': u'01'},
#  {u'NAME': u'Barbour County',
#   u'P0010001': u'27457',
#   u'county': u'005',
#   u'state': u'01'},
#  {u'NAME': u'Bibb County',
#   u'P0010001': u'22915',
#   u'county': u'007',
#   u'state': u'01'},
#  {u'NAME': u'Blount County',
#   u'P0010001': u'57322',
#   u'county': u'009',
#   u'state': u'01'},
#  {u'NAME': u'Bullock County',
#   u'P0010001': u'10914',
#   u'county': u'011',
#   u'state': u'01'},
#  {u'NAME': u'Butler County',
#   u'P0010001': u'20947',
#   u'county': u'013',
#   u'state': u'01'},
#  {u'NAME': u'Calhoun County',
#   u'P0010001': u'118572',
#   u'county': u'015',
#   u'state': u'01'},
#  {u'NAME': u'Chambers County',
#   u'P0010001': u'34215',
#   u'county': u'017',
#   u'state': u'01'},
#  {u'NAME': u'Cherokee County',
#   u'P0010001': u'25989',
#   u'county': u'019',
#   u'state': u'01'},
#  {u'NAME': u'Chilton County',
#   u'P0010001': u'43643',
#   u'county': u'021',
#   u'state': u'01'},
#  {u'NAME': u'Choctaw County',
#   u'P0010001': u'13859',
#   u'county': u'023',
#   u'state': u'01'},
#  {u'NAME': u'Clarke County',
#   u'P0010001': u'25833',
#   u'county': u'025',
#   u'state': u'01'},
#  {u'NAME': u'Clay County',
#   u'P0010001': u'13932',
#   u'county': u'027',
#   u'state': u'01'},
#  {u'NAME': u'Cleburne County',
#   u'P0010001': u'14972',
#   u'county': u'029',
#   u'state': u'01'},
#  {u'NAME': u'Coffee County',
#   u'P0010001': u'49948',
#   u'county': u'031',
#   u'state': u'01'},
#  {u'NAME': u'Colbert County',
#   u'P0010001': u'54428',
#   u'county': u'033',
#   u'state': u'01'},
#  {u'NAME': u'Conecuh County',
#   u'P0010001': u'13228',
#   u'county': u'035',
#   u'state': u'01'},
#  {u'NAME': u'Coosa County',
#   u'P0010001': u'11539',
#   u'county': u'037',
#   u'state': u'01'},
#  {u'NAME': u'Covington County',
#   u'P0010001': u'37765',
#   u'county': u'039',
#   u'state': u'01'},
#  {u'NAME': u'Crenshaw County',
#   u'P0010001': u'13906',
#   u'county': u'041',
#   u'state': u'01'},
#  {u'NAME': u'Cullman County',
#   u'P0010001': u'80406',
#   u'county': u'043',
#   u'state': u'01'},
#  {u'NAME': u'Dale County',
#   u'P0010001': u'50251',
#   u'county': u'045',
#   u'state': u'01'},
#  {u'NAME': u'Dallas County',
#   u'P0010001': u'43820',
#   u'county': u'047',
#   u'state': u'01'},
#  {u'NAME': u'DeKalb County',
#   u'P0010001': u'71109',
#   u'county': u'049',
#   u'state': u'01'},
#  {u'NAME': u'Elmore County',
#   u'P0010001': u'79303',
#   u'county': u'051',
#   u'state': u'01'},
#  {u'NAME': u'Escambia County',
#   u'P0010001': u'38319',
#   u'county': u'053',
#   u'state': u'01'},
#  {u'NAME': u'Etowah County',
#   u'P0010001': u'104430',
#   u'county': u'055',
#   u'state': u'01'},
#  {u'NAME': u'Fayette County',
#   u'P0010001': u'17241',
#   u'county': u'057',
#   u'state': u'01'},
#  {u'NAME': u'Franklin County',
#   u'P0010001': u'31704',
#   u'county': u'059',
#   u'state': u'01'},
#  {u'NAME': u'Geneva County',
#   u'P0010001': u'26790',
#   u'county': u'061',
#   u'state': u'01'},
#  {u'NAME': u'Greene County',
#   u'P0010001': u'9045',
#   u'county': u'063',
#   u'state': u'01'},
#  {u'NAME': u'Hale County',
#   u'P0010001': u'15760',
#   u'county': u'065',
#   u'state': u'01'},
#  {u'NAME': u'Henry County',
#   u'P0010001': u'17302',
#   u'county': u'067',
#   u'state': u'01'},
#  {u'NAME': u'Houston County',
#   u'P0010001': u'101547',
#   u'county': u'069',
#   u'state': u'01'},
#  {u'NAME': u'Jackson County',
#   u'P0010001': u'53227',
#   u'county': u'071',
#   u'state': u'01'},
#  {u'NAME': u'Jefferson County',
#   u'P0010001': u'658466',
#   u'county': u'073',
#   u'state': u'01'},
#  {u'NAME': u'Lamar County',
#   u'P0010001': u'14564',
#   u'county': u'075',
#   u'state': u'01'},
#  {u'NAME': u'Lauderdale County',
#   u'P0010001': u'92709',
#   u'county': u'077',
#   u'state': u'01'},
#  {u'NAME': u'Lawrence County',
#   u'P0010001': u'34339',
#   u'county': u'079',
#   u'state': u'01'},
#  {u'NAME': u'Lee County',
#   u'P0010001': u'140247',
#   u'county': u'081',
#   u'state': u'01'},
#  {u'NAME': u'Limestone County',
#   u'P0010001': u'82782',
#   u'county': u'083',
#   u'state': u'01'},
#  {u'NAME': u'Lowndes County',
#   u'P0010001': u'11299',
#   u'county': u'085',
#   u'state': u'01'},
#  {u'NAME': u'Macon County',
#   u'P0010001': u'21452',
#   u'county': u'087',
#   u'state': u'01'},
#  {u'NAME': u'Madison County',
#   u'P0010001': u'334811',
#   u'county': u'089',
#   u'state': u'01'},
#  {u'NAME': u'Marengo County',
#   u'P0010001': u'21027',
#   u'county': u'091',
#   u'state': u'01'},
#  {u'NAME': u'Marion County',
#   u'P0010001': u'30776',
#   u'county': u'093',
#   u'state': u'01'},
#  {u'NAME': u'Marshall County',
#   u'P0010001': u'93019',
#   u'county': u'095',
#   u'state': u'01'},
#  {u'NAME': u'Mobile County',
#   u'P0010001': u'412992',
#   u'county': u'097',
#   u'state': u'01'},
#  {u'NAME': u'Monroe County',
#   u'P0010001': u'23068',
#   u'county': u'099',
#   u'state': u'01'},
#  {u'NAME': u'Montgomery County',
#   u'P0010001': u'229363',
#   u'county': u'101',
#   u'state': u'01'},
#  {u'NAME': u'Morgan County',
#   u'P0010001': u'119490',
#   u'county': u'103',
#   u'state': u'01'},
#  {u'NAME': u'Perry County',
#   u'P0010001': u'10591',
#   u'county': u'105',
#   u'state': u'01'},
#  {u'NAME': u'Pickens County',
#   u'P0010001': u'19746',
#   u'county': u'107',
#   u'state': u'01'},
#  {u'NAME': u'Pike County',
#   u'P0010001': u'32899',
#   u'county': u'109',
#   u'state': u'01'},
#  {u'NAME': u'Randolph County',
#   u'P0010001': u'22913',
#   u'county': u'111',
#   u'state': u'01'},
#  {u'NAME': u'Russell County',
#   u'P0010001': u'52947',
#   u'county': u'113',
#   u'state': u'01'},
#  {u'NAME': u'St. Clair County',
#   u'P0010001': u'83593',
#   u'county': u'115',
#   u'state': u'01'},
#  {u'NAME': u'Shelby County',
#   u'P0010001': u'195085',
#   u'county': u'117',
#   u'state': u'01'},
#  {u'NAME': u'Sumter County',
#   u'P0010001': u'13763',
#   u'county': u'119',
#   u'state': u'01'},
#  {u'NAME': u'Talladega County',
#   u'P0010001': u'82291',
#   u'county': u'121',
#   u'state': u'01'},
#  {u'NAME': u'Tallapoosa County',
#   u'P0010001': u'41616',
#   u'county': u'123',
#   u'state': u'01'},
#  {u'NAME': u'Tuscaloosa County',
#   u'P0010001': u'194656',
#   u'county': u'125',
#   u'state': u'01'},
#  {u'NAME': u'Walker County',
#   u'P0010001': u'67023',
#   u'county': u'127',
#   u'state': u'01'},
#  {u'NAME': u'Washington County',
#   u'P0010001': u'17581',
#   u'county': u'129',
#   u'state': u'01'},
#  {u'NAME': u'Wilcox County',
#   u'P0010001': u'11670',
#   u'county': u'131',
#   u'state': u'01'},
#  {u'NAME': u'Winston County',
#   u'P0010001': u'24484',
#   u'county': u'133',
#   u'state': u'01'},
#  {u'NAME': u'Aleutians East Borough',
#   u'P0010001': u'3141',
#   u'county': u'013',
#   u'state': u'02'},
#  {u'NAME': u'Aleutians West Census Area',
#   u'P0010001': u'5561',
#   u'county': u'016',
#   u'state': u'02'},
#  {u'NAME': u'Anchorage Municipality',
#   u'P0010001': u'291826',
#   u'county': u'020',
#   u'state': u'02'},
#  {u'NAME': u'Bethel Census Area',
#   u'P0010001': u'17013',
#   u'county': u'050',
#   u'state': u'02'},
#  {u'NAME': u'Bristol Bay Borough',
#   u'P0010001': u'997',
#   u'county': u'060',
#   u'state': u'02'},
#  {u'NAME': u'Denali Borough',
#   u'P0010001': u'1826',
#   u'county': u'068',
#   u'state': u'02'},
#  {u'NAME': u'Dillingham Census Area',
#   u'P0010001': u'4847',
#   u'county': u'070',
#   u'state': u'02'},
#  {u'NAME': u'Fairbanks North Star Borough',
#   u'P0010001': u'97581',
#   u'county': u'090',
#   u'state': u'02'},
#  {u'NAME': u'Haines Borough',
#   u'P0010001': u'2508',
#   u'county': u'100',
#   u'state': u'02'},
#  {u'NAME': u'Hoonah-Angoon Census Area',
#   u'P0010001': u'2150',
#   u'county': u'105',
#   u'state': u'02'},
#  {u'NAME': u'Juneau City and Borough',
#   u'P0010001': u'31275',
#   u'county': u'110',
#   u'state': u'02'},
#  {u'NAME': u'Kenai Peninsula Borough',
#   u'P0010001': u'55400',
#   u'county': u'122',
#   u'state': u'02'},
#  {u'NAME': u'Ketchikan Gateway Borough',
#   u'P0010001': u'13477',
#   u'county': u'130',
#   u'state': u'02'},
#  {u'NAME': u'Kodiak Island Borough',
#   u'P0010001': u'13592',
#   u'county': u'150',
#   u'state': u'02'},
#  {u'NAME': u'Lake and Peninsula Borough',
#   u'P0010001': u'1631',
#   u'county': u'164',
#   u'state': u'02'},
#  {u'NAME': u'Matanuska-Susitna Borough',
#   u'P0010001': u'88995',
#   u'county': u'170',
#   u'state': u'02'},
#  {u'NAME': u'Nome Census Area',
#   u'P0010001': u'9492',
#   u'county': u'180',
#   u'state': u'02'},
#  {u'NAME': u'North Slope Borough',
#   u'P0010001': u'9430',
#   u'county': u'185',
#   u'state': u'02'},
#  {u'NAME': u'Northwest Arctic Borough',
#   u'P0010001': u'7523',
#   u'county': u'188',
#   u'state': u'02'},
#  {u'NAME': u'Petersburg Census Area',
#   u'P0010001': u'3815',
#   u'county': u'195',
#   u'state': u'02'},
#  {u'NAME': u'Prince of Wales-Hyder Census Area',
#   u'P0010001': u'5559',
#   u'county': u'198',
#   u'state': u'02'},
#  {u'NAME': u'Sitka City and Borough',
#   u'P0010001': u'8881',
#   u'county': u'220',
#   u'state': u'02'},
#  {u'NAME': u'Skagway Municipality',
#   u'P0010001': u'968',
#   u'county': u'230',
#   u'state': u'02'},
#  {u'NAME': u'Southeast Fairbanks Census Area',
#   u'P0010001': u'7029',
#   u'county': u'240',
#   u'state': u'02'},
#  {u'NAME': u'Valdez-Cordova Census Area',
#   u'P0010001': u'9636',
#   u'county': u'261',
#   u'state': u'02'},
#  {u'NAME': u'Wade Hampton Census Area',
#   u'P0010001': u'7459',
#   u'county': u'270',
#   u'state': u'02'},
#  {u'NAME': u'Wrangell City and Borough',
#   u'P0010001': u'2369',
#   u'county': u'275',
#   u'state': u'02'},
#  {u'NAME': u'Yakutat City and Borough',
#   u'P0010001': u'662',
#   u'county': u'282',
#   u'state': u'02'},
#  {u'NAME': u'Yukon-Koyukuk Census Area',
#   u'P0010001': u'5588',
#   u'county': u'290',
#   u'state': u'02'},
#  {u'NAME': u'Apache County',
#   u'P0010001': u'71518',
#   u'county': u'001',
#   u'state': u'04'},
#  {u'NAME': u'Cochise County',
#   u'P0010001': u'131346',
#   u'county': u'003',
#   u'state': u'04'},
#  {u'NAME': u'Coconino County',
#   u'P0010001': u'134421',
#   u'county': u'005',
#   u'state': u'04'},
#  {u'NAME': u'Gila County',
#   u'P0010001': u'53597',
#   u'county': u'007',
#   u'state': u'04'},
#  {u'NAME': u'Graham County',
#   u'P0010001': u'37220',
#   u'county': u'009',
#   u'state': u'04'},
#  {u'NAME': u'Greenlee County',
#   u'P0010001': u'8437',
#   u'county': u'011',
#   u'state': u'04'},
#  {u'NAME': u'La Paz County',
#   u'P0010001': u'20489',
#   u'county': u'012',
#   u'state': u'04'},
#  {u'NAME': u'Maricopa County',
#   u'P0010001': u'3817117',
#   u'county': u'013',
#   u'state': u'04'},
#  {u'NAME': u'Mohave County',
#   u'P0010001': u'200186',
#   u'county': u'015',
#   u'state': u'04'},
#  {u'NAME': u'Navajo County',
#   u'P0010001': u'107449',
#   u'county': u'017',
#   u'state': u'04'},
#  {u'NAME': u'Pima County',
#   u'P0010001': u'980263',
#   u'county': u'019',
#   u'state': u'04'},
#  {u'NAME': u'Pinal County',
#   u'P0010001': u'375770',
#   u'county': u'021',
#   u'state': u'04'},
#  {u'NAME': u'Santa Cruz County',
#   u'P0010001': u'47420',
#   u'county': u'023',
#   u'state': u'04'},
#  {u'NAME': u'Yavapai County',
#   u'P0010001': u'211033',
#   u'county': u'025',
#   u'state': u'04'},
#  {u'NAME': u'Yuma County',
#   u'P0010001': u'195751',
#   u'county': u'027',
#   u'state': u'04'},
#  {u'NAME': u'Arkansas County',
#   u'P0010001': u'19019',
#   u'county': u'001',
#   u'state': u'05'},
#  {u'NAME': u'Ashley County',
#   u'P0010001': u'21853',
#   u'county': u'003',
#   u'state': u'05'},
#  {u'NAME': u'Baxter County',
#   u'P0010001': u'41513',
#   u'county': u'005',
#   u'state': u'05'},
#  {u'NAME': u'Benton County',
#   u'P0010001': u'221339',
#   u'county': u'007',
#   u'state': u'05'},
#  {u'NAME': u'Boone County',
#   u'P0010001': u'36903',
#   u'county': u'009',
#   u'state': u'05'},
#  {u'NAME': u'Bradley County',
#   u'P0010001': u'11508',
#   u'county': u'011',
#   u'state': u'05'},
#  {u'NAME': u'Calhoun County',
#   u'P0010001': u'5368',
#   u'county': u'013',
#   u'state': u'05'},
#  {u'NAME': u'Carroll County',
#   u'P0010001': u'27446',
#   u'county': u'015',
#   u'state': u'05'},
#  {u'NAME': u'Chicot County',
#   u'P0010001': u'11800',
#   u'county': u'017',
#   u'state': u'05'},
#  {u'NAME': u'Clark County',
#   u'P0010001': u'22995',
#   u'county': u'019',
#   u'state': u'05'},
#  {u'NAME': u'Clay County',
#   u'P0010001': u'16083',
#   u'county': u'021',
#   u'state': u'05'},
#  {u'NAME': u'Cleburne County',
#   u'P0010001': u'25970',
#   u'county': u'023',
#   u'state': u'05'},
#  {u'NAME': u'Cleveland County',
#   u'P0010001': u'8689',
#   u'county': u'025',
#   u'state': u'05'},
#  {u'NAME': u'Columbia County',
#   u'P0010001': u'24552',
#   u'county': u'027',
#   u'state': u'05'},
#  {u'NAME': u'Conway County',
#   u'P0010001': u'21273',
#   u'county': u'029',
#   u'state': u'05'},
#  {u'NAME': u'Craighead County',
#   u'P0010001': u'96443',
#   u'county': u'031',
#   u'state': u'05'},
#  {u'NAME': u'Crawford County',
#   u'P0010001': u'61948',
#   u'county': u'033',
#   u'state': u'05'},
#  {u'NAME': u'Crittenden County',
#   u'P0010001': u'50902',
#   u'county': u'035',
#   u'state': u'05'},
#  {u'NAME': u'Cross County',
#   u'P0010001': u'17870',
#   u'county': u'037',
#   u'state': u'05'},
#  {u'NAME': u'Dallas County',
#   u'P0010001': u'8116',
#   u'county': u'039',
#   u'state': u'05'},
#  {u'NAME': u'Desha County',
#   u'P0010001': u'13008',
#   u'county': u'041',
#   u'state': u'05'},
#  {u'NAME': u'Drew County',
#   u'P0010001': u'18509',
#   u'county': u'043',
#   u'state': u'05'},
#  {u'NAME': u'Faulkner County',
#   u'P0010001': u'113237',
#   u'county': u'045',
#   u'state': u'05'},
#  {u'NAME': u'Franklin County',
#   u'P0010001': u'18125',
#   u'county': u'047',
#   u'state': u'05'},
#  {u'NAME': u'Fulton County',
#   u'P0010001': u'12245',
#   u'county': u'049',
#   u'state': u'05'},
#  {u'NAME': u'Garland County',
#   u'P0010001': u'96024',
#   u'county': u'051',
#   u'state': u'05'},
#  {u'NAME': u'Grant County',
#   u'P0010001': u'17853',
#   u'county': u'053',
#   u'state': u'05'},
#  {u'NAME': u'Greene County',
#   u'P0010001': u'42090',
#   u'county': u'055',
#   u'state': u'05'},
#  {u'NAME': u'Hempstead County',
#   u'P0010001': u'22609',
#   u'county': u'057',
#   u'state': u'05'},
#  {u'NAME': u'Hot Spring County',
#   u'P0010001': u'32923',
#   u'county': u'059',
#   u'state': u'05'},
#  {u'NAME': u'Howard County',
#   u'P0010001': u'13789',
#   u'county': u'061',
#   u'state': u'05'},
#  {u'NAME': u'Independence County',
#   u'P0010001': u'36647',
#   u'county': u'063',
#   u'state': u'05'},
#  {u'NAME': u'Izard County',
#   u'P0010001': u'13696',
#   u'county': u'065',
#   u'state': u'05'},
#  {u'NAME': u'Jackson County',
#   u'P0010001': u'17997',
#   u'county': u'067',
#   u'state': u'05'},
#  {u'NAME': u'Jefferson County',
#   u'P0010001': u'77435',
#   u'county': u'069',
#   u'state': u'05'},
#  {u'NAME': u'Johnson County',
#   u'P0010001': u'25540',
#   u'county': u'071',
#   u'state': u'05'},
#  {u'NAME': u'Lafayette County',
#   u'P0010001': u'7645',
#   u'county': u'073',
#   u'state': u'05'},
#  {u'NAME': u'Lawrence County',
#   u'P0010001': u'17415',
#   u'county': u'075',
#   u'state': u'05'},
#  {u'NAME': u'Lee County',
#   u'P0010001': u'10424',
#   u'county': u'077',
#   u'state': u'05'},
#  {u'NAME': u'Lincoln County',
#   u'P0010001': u'14134',
#   u'county': u'079',
#   u'state': u'05'},
#  {u'NAME': u'Little River County',
#   u'P0010001': u'13171',
#   u'county': u'081',
#   u'state': u'05'},
#  {u'NAME': u'Logan County',
#   u'P0010001': u'22353',
#   u'county': u'083',
#   u'state': u'05'},
#  {u'NAME': u'Lonoke County',
#   u'P0010001': u'68356',
#   u'county': u'085',
#   u'state': u'05'},
#  {u'NAME': u'Madison County',
#   u'P0010001': u'15717',
#   u'county': u'087',
#   u'state': u'05'},
#  {u'NAME': u'Marion County',
#   u'P0010001': u'16653',
#   u'county': u'089',
#   u'state': u'05'},
#  {u'NAME': u'Miller County',
#   u'P0010001': u'43462',
#   u'county': u'091',
#   u'state': u'05'},
#  {u'NAME': u'Mississippi County',
#   u'P0010001': u'46480',
#   u'county': u'093',
#   u'state': u'05'},
#  {u'NAME': u'Monroe County',
#   u'P0010001': u'8149',
#   u'county': u'095',
#   u'state': u'05'},
#  {u'NAME': u'Montgomery County',
#   u'P0010001': u'9487',
#   u'county': u'097',
#   u'state': u'05'},
#  {u'NAME': u'Nevada County',
#   u'P0010001': u'8997',
#   u'county': u'099',
#   u'state': u'05'},
#  {u'NAME': u'Newton County',
#   u'P0010001': u'8330',
#   u'county': u'101',
#   u'state': u'05'},
#  {u'NAME': u'Ouachita County',
#   u'P0010001': u'26120',
#   u'county': u'103',
#   u'state': u'05'},
#  {u'NAME': u'Perry County',
#   u'P0010001': u'10445',
#   u'county': u'105',
#   u'state': u'05'},
#  {u'NAME': u'Phillips County',
#   u'P0010001': u'21757',
#   u'county': u'107',
#   u'state': u'05'},
#  {u'NAME': u'Pike County',
#   u'P0010001': u'11291',
#   u'county': u'109',
#   u'state': u'05'},
#  {u'NAME': u'Poinsett County',
#   u'P0010001': u'24583',
#   u'county': u'111',
#   u'state': u'05'},
#  {u'NAME': u'Polk County',
#   u'P0010001': u'20662',
#   u'county': u'113',
#   u'state': u'05'},
#  {u'NAME': u'Pope County',
#   u'P0010001': u'61754',
#   u'county': u'115',
#   u'state': u'05'},
#  {u'NAME': u'Prairie County',
#   u'P0010001': u'8715',
#   u'county': u'117',
#   u'state': u'05'},
#  {u'NAME': u'Pulaski County',
#   u'P0010001': u'382748',
#   u'county': u'119',
#   u'state': u'05'},
#  {u'NAME': u'Randolph County',
#   u'P0010001': u'17969',
#   u'county': u'121',
#   u'state': u'05'},
#  {u'NAME': u'St. Francis County',
#   u'P0010001': u'28258',
#   u'county': u'123',
#   u'state': u'05'},
#  {u'NAME': u'Saline County',
#   u'P0010001': u'107118',
#   u'county': u'125',
#   u'state': u'05'},
#  {u'NAME': u'Scott County',
#   u'P0010001': u'11233',
#   u'county': u'127',
#   u'state': u'05'},
#  {u'NAME': u'Searcy County',
#   u'P0010001': u'8195',
#   u'county': u'129',
#   u'state': u'05'},
#  {u'NAME': u'Sebastian County',
#   u'P0010001': u'125744',
#   u'county': u'131',
#   u'state': u'05'},
#  {u'NAME': u'Sevier County',
#   u'P0010001': u'17058',
#   u'county': u'133',
#   u'state': u'05'},
#  {u'NAME': u'Sharp County',
#   u'P0010001': u'17264',
#   u'county': u'135',
#   u'state': u'05'},
#  {u'NAME': u'Stone County',
#   u'P0010001': u'12394',
#   u'county': u'137',
#   u'state': u'05'},
#  {u'NAME': u'Union County',
#   u'P0010001': u'41639',
#   u'county': u'139',
#   u'state': u'05'},
#  {u'NAME': u'Van Buren County',
#   u'P0010001': u'17295',
#   u'county': u'141',
#   u'state': u'05'},
#  {u'NAME': u'Washington County',
#   u'P0010001': u'203065',
#   u'county': u'143',
#   u'state': u'05'},
#  {u'NAME': u'White County',
#   u'P0010001': u'77076',
#   u'county': u'145',
#   u'state': u'05'},
#  {u'NAME': u'Woodruff County',
#   u'P0010001': u'7260',
#   u'county': u'147',
#   u'state': u'05'},
#  {u'NAME': u'Yell County',
#   u'P0010001': u'22185',
#   u'county': u'149',
#   u'state': u'05'},
#  {u'NAME': u'Alameda County',
#   u'P0010001': u'1510271',
#   u'county': u'001',
#   u'state': u'06'},
#  {u'NAME': u'Alpine County',
#   u'P0010001': u'1175',
#   u'county': u'003',
#   u'state': u'06'},
#  {u'NAME': u'Amador County',
#   u'P0010001': u'38091',
#   u'county': u'005',
#   u'state': u'06'},
#  {u'NAME': u'Butte County',
#   u'P0010001': u'220000',
#   u'county': u'007',
#   u'state': u'06'},
#  {u'NAME': u'Calaveras County',
#   u'P0010001': u'45578',
#   u'county': u'009',
#   u'state': u'06'},
#  {u'NAME': u'Colusa County',
#   u'P0010001': u'21419',
#   u'county': u'011',
#   u'state': u'06'},
#  {u'NAME': u'Contra Costa County',
#   u'P0010001': u'1049025',
#   u'county': u'013',
#   u'state': u'06'},
#  {u'NAME': u'Del Norte County',
#   u'P0010001': u'28610',
#   u'county': u'015',
#   u'state': u'06'},
#  {u'NAME': u'El Dorado County',
#   u'P0010001': u'181058',
#   u'county': u'017',
#   u'state': u'06'},
#  {u'NAME': u'Fresno County',
#   u'P0010001': u'930450',
#   u'county': u'019',
#   u'state': u'06'},
#  {u'NAME': u'Glenn County',
#   u'P0010001': u'28122',
#   u'county': u'021',
#   u'state': u'06'},
#  {u'NAME': u'Humboldt County',
#   u'P0010001': u'134623',
#   u'county': u'023',
#   u'state': u'06'},
#  {u'NAME': u'Imperial County',
#   u'P0010001': u'174528',
#   u'county': u'025',
#   u'state': u'06'},
#  {u'NAME': u'Inyo County',
#   u'P0010001': u'18546',
#   u'county': u'027',
#   u'state': u'06'},
#  {u'NAME': u'Kern County',
#   u'P0010001': u'839631',
#   u'county': u'029',
#   u'state': u'06'},
#  {u'NAME': u'Kings County',
#   u'P0010001': u'152982',
#   u'county': u'031',
#   u'state': u'06'},
#  {u'NAME': u'Lake County',
#   u'P0010001': u'64665',
#   u'county': u'033',
#   u'state': u'06'},
#  {u'NAME': u'Lassen County',
#   u'P0010001': u'34895',
#   u'county': u'035',
#   u'state': u'06'},
#  {u'NAME': u'Los Angeles County',
#   u'P0010001': u'9818605',
#   u'county': u'037',
#   u'state': u'06'},
#  {u'NAME': u'Madera County',
#   u'P0010001': u'150865',
#   u'county': u'039',
#   u'state': u'06'},
#  {u'NAME': u'Marin County',
#   u'P0010001': u'252409',
#   u'county': u'041',
#   u'state': u'06'},
#  {u'NAME': u'Mariposa County',
#   u'P0010001': u'18251',
#   u'county': u'043',
#   u'state': u'06'},
#  {u'NAME': u'Mendocino County',
#   u'P0010001': u'87841',
#   u'county': u'045',
#   u'state': u'06'},
#  {u'NAME': u'Merced County',
#   u'P0010001': u'255793',
#   u'county': u'047',
#   u'state': u'06'},
#  {u'NAME': u'Modoc County',
#   u'P0010001': u'9686',
#   u'county': u'049',
#   u'state': u'06'},
#  {u'NAME': u'Mono County',
#   u'P0010001': u'14202',
#   u'county': u'051',
#   u'state': u'06'},
#  {u'NAME': u'Monterey County',
#   u'P0010001': u'415057',
#   u'county': u'053',
#   u'state': u'06'},
#  {u'NAME': u'Napa County',
#   u'P0010001': u'136484',
#   u'county': u'055',
#   u'state': u'06'},
#  {u'NAME': u'Nevada County',
#   u'P0010001': u'98764',
#   u'county': u'057',
#   u'state': u'06'},
#  {u'NAME': u'Orange County',
#   u'P0010001': u'3010232',
#   u'county': u'059',
#   u'state': u'06'},
#  {u'NAME': u'Placer County',
#   u'P0010001': u'348432',
#   u'county': u'061',
#   u'state': u'06'},
#  {u'NAME': u'Plumas County',
#   u'P0010001': u'20007',
#   u'county': u'063',
#   u'state': u'06'},
#  {u'NAME': u'Riverside County',
#   u'P0010001': u'2189641',
#   u'county': u'065',
#   u'state': u'06'},
#  {u'NAME': u'Sacramento County',
#   u'P0010001': u'1418788',
#   u'county': u'067',
#   u'state': u'06'},
#  {u'NAME': u'San Benito County',
#   u'P0010001': u'55269',
#   u'county': u'069',
#   u'state': u'06'},
#  {u'NAME': u'San Bernardino County',
#   u'P0010001': u'2035210',
#   u'county': u'071',
#   u'state': u'06'},
#  {u'NAME': u'San Diego County',
#   u'P0010001': u'3095313',
#   u'county': u'073',
#   u'state': u'06'},
#  {u'NAME': u'San Francisco County',
#   u'P0010001': u'805235',
#   u'county': u'075',
#   u'state': u'06'},
#  {u'NAME': u'San Joaquin County',
#   u'P0010001': u'685306',
#   u'county': u'077',
#   u'state': u'06'},
#  {u'NAME': u'San Luis Obispo County',
#   u'P0010001': u'269637',
#   u'county': u'079',
#   u'state': u'06'},
#  {u'NAME': u'San Mateo County',
#   u'P0010001': u'718451',
#   u'county': u'081',
#   u'state': u'06'},
#  {u'NAME': u'Santa Barbara County',
#   u'P0010001': u'423895',
#   u'county': u'083',
#   u'state': u'06'},
#  {u'NAME': u'Santa Clara County',
#   u'P0010001': u'1781642',
#   u'county': u'085',
#   u'state': u'06'},
#  {u'NAME': u'Santa Cruz County',
#   u'P0010001': u'262382',
#   u'county': u'087',
#   u'state': u'06'},
#  {u'NAME': u'Shasta County',
#   u'P0010001': u'177223',
#   u'county': u'089',
#   u'state': u'06'},
#  {u'NAME': u'Sierra County',
#   u'P0010001': u'3240',
#   u'county': u'091',
#   u'state': u'06'},
#  {u'NAME': u'Siskiyou County',
#   u'P0010001': u'44900',
#   u'county': u'093',
#   u'state': u'06'},
#  {u'NAME': u'Solano County',
#   u'P0010001': u'413344',
#   u'county': u'095',
#   u'state': u'06'},
#  {u'NAME': u'Sonoma County',
#   u'P0010001': u'483878',
#   u'county': u'097',
#   u'state': u'06'},
#  {u'NAME': u'Stanislaus County',
#   u'P0010001': u'514453',
#   u'county': u'099',
#   u'state': u'06'},
#  {u'NAME': u'Sutter County',
#   u'P0010001': u'94737',
#   u'county': u'101',
#   u'state': u'06'},
#  {u'NAME': u'Tehama County',
#   u'P0010001': u'63463',
#   u'county': u'103',
#   u'state': u'06'},
#  {u'NAME': u'Trinity County',
#   u'P0010001': u'13786',
#   u'county': u'105',
#   u'state': u'06'},
#  {u'NAME': u'Tulare County',
#   u'P0010001': u'442179',
#   u'county': u'107',
#   u'state': u'06'},
#  {u'NAME': u'Tuolumne County',
#   u'P0010001': u'55365',
#   u'county': u'109',
#   u'state': u'06'},
#  {u'NAME': u'Ventura County',
#   u'P0010001': u'823318',
#   u'county': u'111',
#   u'state': u'06'},
#  {u'NAME': u'Yolo County',
#   u'P0010001': u'200849',
#   u'county': u'113',
#   u'state': u'06'},
#  {u'NAME': u'Yuba County',
#   u'P0010001': u'72155',
#   u'county': u'115',
#   u'state': u'06'},
#  {u'NAME': u'Adams County',
#   u'P0010001': u'441603',
#   u'county': u'001',
#   u'state': u'08'},
#  {u'NAME': u'Alamosa County',
#   u'P0010001': u'15445',
#   u'county': u'003',
#   u'state': u'08'},
#  {u'NAME': u'Arapahoe County',
#   u'P0010001': u'572003',
#   u'county': u'005',
#   u'state': u'08'},
#  {u'NAME': u'Archuleta County',
#   u'P0010001': u'12084',
#   u'county': u'007',
#   u'state': u'08'},
#  {u'NAME': u'Baca County',
#   u'P0010001': u'3788',
#   u'county': u'009',
#   u'state': u'08'},
#  {u'NAME': u'Bent County',
#   u'P0010001': u'6499',
#   u'county': u'011',
#   u'state': u'08'},
#  {u'NAME': u'Boulder County',
#   u'P0010001': u'294567',
#   u'county': u'013',
#   u'state': u'08'},
#  {u'NAME': u'Broomfield County',
#   u'P0010001': u'55889',
#   u'county': u'014',
#   u'state': u'08'},
#  {u'NAME': u'Chaffee County',
#   u'P0010001': u'17809',
#   u'county': u'015',
#   u'state': u'08'},
#  {u'NAME': u'Cheyenne County',
#   u'P0010001': u'1836',
#   u'county': u'017',
#   u'state': u'08'},
#  {u'NAME': u'Clear Creek County',
#   u'P0010001': u'9088',
#   u'county': u'019',
#   u'state': u'08'},
#  {u'NAME': u'Conejos County',
#   u'P0010001': u'8256',
#   u'county': u'021',
#   u'state': u'08'},
#  {u'NAME': u'Costilla County',
#   u'P0010001': u'3524',
#   u'county': u'023',
#   u'state': u'08'},
#  {u'NAME': u'Crowley County',
#   u'P0010001': u'5823',
#   u'county': u'025',
#   u'state': u'08'},
#  {u'NAME': u'Custer County',
#   u'P0010001': u'4255',
#   u'county': u'027',
#   u'state': u'08'},
#  {u'NAME': u'Delta County',
#   u'P0010001': u'30952',
#   u'county': u'029',
#   u'state': u'08'},
#  {u'NAME': u'Denver County',
#   u'P0010001': u'600158',
#   u'county': u'031',
#   u'state': u'08'},
#  {u'NAME': u'Dolores County',
#   u'P0010001': u'2064',
#   u'county': u'033',
#   u'state': u'08'},
#  {u'NAME': u'Douglas County',
#   u'P0010001': u'285465',
#   u'county': u'035',
#   u'state': u'08'},
#  {u'NAME': u'Eagle County',
#   u'P0010001': u'52197',
#   u'county': u'037',
#   u'state': u'08'},
#  {u'NAME': u'Elbert County',
#   u'P0010001': u'23086',
#   u'county': u'039',
#   u'state': u'08'},
#  {u'NAME': u'El Paso County',
#   u'P0010001': u'622263',
#   u'county': u'041',
#   u'state': u'08'},
#  {u'NAME': u'Fremont County',
#   u'P0010001': u'46824',
#   u'county': u'043',
#   u'state': u'08'},
#  {u'NAME': u'Garfield County',
#   u'P0010001': u'56389',
#   u'county': u'045',
#   u'state': u'08'},
#  {u'NAME': u'Gilpin County',
#   u'P0010001': u'5441',
#   u'county': u'047',
#   u'state': u'08'},
#  {u'NAME': u'Grand County',
#   u'P0010001': u'14843',
#   u'county': u'049',
#   u'state': u'08'},
#  {u'NAME': u'Gunnison County',
#   u'P0010001': u'15324',
#   u'county': u'051',
#   u'state': u'08'},
#  {u'NAME': u'Hinsdale County',
#   u'P0010001': u'843',
#   u'county': u'053',
#   u'state': u'08'},
#  {u'NAME': u'Huerfano County',
#   u'P0010001': u'6711',
#   u'county': u'055',
#   u'state': u'08'},
#  {u'NAME': u'Jackson County',
#   u'P0010001': u'1394',
#   u'county': u'057',
#   u'state': u'08'},
#  {u'NAME': u'Jefferson County',
#   u'P0010001': u'534543',
#   u'county': u'059',
#   u'state': u'08'},
#  {u'NAME': u'Kiowa County',
#   u'P0010001': u'1398',
#   u'county': u'061',
#   u'state': u'08'},
#  {u'NAME': u'Kit Carson County',
#   u'P0010001': u'8270',
#   u'county': u'063',
#   u'state': u'08'},
#  {u'NAME': u'Lake County',
#   u'P0010001': u'7310',
#   u'county': u'065',
#   u'state': u'08'},
#  {u'NAME': u'La Plata County',
#   u'P0010001': u'51334',
#   u'county': u'067',
#   u'state': u'08'},
#  {u'NAME': u'Larimer County',
#   u'P0010001': u'299630',
#   u'county': u'069',
#   u'state': u'08'},
#  {u'NAME': u'Las Animas County',
#   u'P0010001': u'15507',
#   u'county': u'071',
#   u'state': u'08'},
#  {u'NAME': u'Lincoln County',
#   u'P0010001': u'5467',
#   u'county': u'073',
#   u'state': u'08'},
#  {u'NAME': u'Logan County',
#   u'P0010001': u'22709',
#   u'county': u'075',
#   u'state': u'08'},
#  {u'NAME': u'Mesa County',
#   u'P0010001': u'146723',
#   u'county': u'077',
#   u'state': u'08'},
#  {u'NAME': u'Mineral County',
#   u'P0010001': u'712',
#   u'county': u'079',
#   u'state': u'08'},
#  {u'NAME': u'Moffat County',
#   u'P0010001': u'13795',
#   u'county': u'081',
#   u'state': u'08'},
#  {u'NAME': u'Montezuma County',
#   u'P0010001': u'25535',
#   u'county': u'083',
#   u'state': u'08'},
#  {u'NAME': u'Montrose County',
#   u'P0010001': u'41276',
#   u'county': u'085',
#   u'state': u'08'},
#  {u'NAME': u'Morgan County',
#   u'P0010001': u'28159',
#   u'county': u'087',
#   u'state': u'08'},
#  {u'NAME': u'Otero County',
#   u'P0010001': u'18831',
#   u'county': u'089',
#   u'state': u'08'},
#  {u'NAME': u'Ouray County',
#   u'P0010001': u'4436',
#   u'county': u'091',
#   u'state': u'08'},
#  {u'NAME': u'Park County',
#   u'P0010001': u'16206',
#   u'county': u'093',
#   u'state': u'08'},
#  {u'NAME': u'Phillips County',
#   u'P0010001': u'4442',
#   u'county': u'095',
#   u'state': u'08'},
#  {u'NAME': u'Pitkin County',
#   u'P0010001': u'17148',
#   u'county': u'097',
#   u'state': u'08'},
#  {u'NAME': u'Prowers County',
#   u'P0010001': u'12551',
#   u'county': u'099',
#   u'state': u'08'},
#  {u'NAME': u'Pueblo County',
#   u'P0010001': u'159063',
#   u'county': u'101',
#   u'state': u'08'},
#  {u'NAME': u'Rio Blanco County',
#   u'P0010001': u'6666',
#   u'county': u'103',
#   u'state': u'08'},
#  {u'NAME': u'Rio Grande County',
#   u'P0010001': u'11982',
#   u'county': u'105',
#   u'state': u'08'},
#  {u'NAME': u'Routt County',
#   u'P0010001': u'23509',
#   u'county': u'107',
#   u'state': u'08'},
#  {u'NAME': u'Saguache County',
#   u'P0010001': u'6108',
#   u'county': u'109',
#   u'state': u'08'},
#  {u'NAME': u'San Juan County',
#   u'P0010001': u'699',
#   u'county': u'111',
#   u'state': u'08'},
#  {u'NAME': u'San Miguel County',
#   u'P0010001': u'7359',
#   u'county': u'113',
#   u'state': u'08'},
#  {u'NAME': u'Sedgwick County',
#   u'P0010001': u'2379',
#   u'county': u'115',
#   u'state': u'08'},
#  {u'NAME': u'Summit County',
#   u'P0010001': u'27994',
#   u'county': u'117',
#   u'state': u'08'},
#  {u'NAME': u'Teller County',
#   u'P0010001': u'23350',
#   u'county': u'119',
#   u'state': u'08'},
#  {u'NAME': u'Washington County',
#   u'P0010001': u'4814',
#   u'county': u'121',
#   u'state': u'08'},
#  {u'NAME': u'Weld County',
#   u'P0010001': u'252825',
#   u'county': u'123',
#   u'state': u'08'},
#  {u'NAME': u'Yuma County',
#   u'P0010001': u'10043',
#   u'county': u'125',
#   u'state': u'08'},
#  {u'NAME': u'Fairfield County',
#   u'P0010001': u'916829',
#   u'county': u'001',
#   u'state': u'09'},
#  {u'NAME': u'Hartford County',
#   u'P0010001': u'894014',
#   u'county': u'003',
#   u'state': u'09'},
#  {u'NAME': u'Litchfield County',
#   u'P0010001': u'189927',
#   u'county': u'005',
#   u'state': u'09'},
#  {u'NAME': u'Middlesex County',
#   u'P0010001': u'165676',
#   u'county': u'007',
#   u'state': u'09'},
#  {u'NAME': u'New Haven County',
#   u'P0010001': u'862477',
#   u'county': u'009',
#   u'state': u'09'},
#  {u'NAME': u'New London County',
#   u'P0010001': u'274055',
#   u'county': u'011',
#   u'state': u'09'},
#  {u'NAME': u'Tolland County',
#   u'P0010001': u'152691',
#   u'county': u'013',
#   u'state': u'09'},
#  {u'NAME': u'Windham County',
#   u'P0010001': u'118428',
#   u'county': u'015',
#   u'state': u'09'},
#  {u'NAME': u'Kent County',
#   u'P0010001': u'162310',
#   u'county': u'001',
#   u'state': u'10'},
#  {u'NAME': u'New Castle County',
#   u'P0010001': u'538479',
#   u'county': u'003',
#   u'state': u'10'},
#  {u'NAME': u'Sussex County',
#   u'P0010001': u'197145',
#   u'county': u'005',
#   u'state': u'10'},
#  {u'NAME': u'District of Columbia',
#   u'P0010001': u'601723',
#   u'county': u'001',
#   u'state': u'11'},
#  {u'NAME': u'Alachua County',
#   u'P0010001': u'247336',
#   u'county': u'001',
#   u'state': u'12'},
#  {u'NAME': u'Baker County',
#   u'P0010001': u'27115',
#   u'county': u'003',
#   u'state': u'12'},
#  {u'NAME': u'Bay County',
#   u'P0010001': u'168852',
#   u'county': u'005',
#   u'state': u'12'},
#  {u'NAME': u'Bradford County',
#   u'P0010001': u'28520',
#   u'county': u'007',
#   u'state': u'12'},
#  {u'NAME': u'Brevard County',
#   u'P0010001': u'543376',
#   u'county': u'009',
#   u'state': u'12'},
#  {u'NAME': u'Broward County',
#   u'P0010001': u'1748066',
#   u'county': u'011',
#   u'state': u'12'},
#  {u'NAME': u'Calhoun County',
#   u'P0010001': u'14625',
#   u'county': u'013',
#   u'state': u'12'},
#  {u'NAME': u'Charlotte County',
#   u'P0010001': u'159978',
#   u'county': u'015',
#   u'state': u'12'},
#  {u'NAME': u'Citrus County',
#   u'P0010001': u'141236',
#   u'county': u'017',
#   u'state': u'12'},
#  {u'NAME': u'Clay County',
#   u'P0010001': u'190865',
#   u'county': u'019',
#   u'state': u'12'},
#  {u'NAME': u'Collier County',
#   u'P0010001': u'321520',
#   u'county': u'021',
#   u'state': u'12'},
#  {u'NAME': u'Columbia County',
#   u'P0010001': u'67531',
#   u'county': u'023',
#   u'state': u'12'},
#  {u'NAME': u'DeSoto County',
#   u'P0010001': u'34862',
#   u'county': u'027',
#   u'state': u'12'},
#  {u'NAME': u'Dixie County',
#   u'P0010001': u'16422',
#   u'county': u'029',
#   u'state': u'12'},
#  {u'NAME': u'Duval County',
#   u'P0010001': u'864263',
#   u'county': u'031',
#   u'state': u'12'},
#  {u'NAME': u'Escambia County',
#   u'P0010001': u'297619',
#   u'county': u'033',
#   u'state': u'12'},
#  {u'NAME': u'Flagler County',
#   u'P0010001': u'95696',
#   u'county': u'035',
#   u'state': u'12'},
#  {u'NAME': u'Franklin County',
#   u'P0010001': u'11549',
#   u'county': u'037',
#   u'state': u'12'},
#  {u'NAME': u'Gadsden County',
#   u'P0010001': u'46389',
#   u'county': u'039',
#   u'state': u'12'},
#  {u'NAME': u'Gilchrist County',
#   u'P0010001': u'16939',
#   u'county': u'041',
#   u'state': u'12'},
#  {u'NAME': u'Glades County',
#   u'P0010001': u'12884',
#   u'county': u'043',
#   u'state': u'12'},
#  {u'NAME': u'Gulf County',
#   u'P0010001': u'15863',
#   u'county': u'045',
#   u'state': u'12'},
#  {u'NAME': u'Hamilton County',
#   u'P0010001': u'14799',
#   u'county': u'047',
#   u'state': u'12'},
#  {u'NAME': u'Hardee County',
#   u'P0010001': u'27731',
#   u'county': u'049',
#   u'state': u'12'},
#  {u'NAME': u'Hendry County',
#   u'P0010001': u'39140',
#   u'county': u'051',
#   u'state': u'12'},
#  {u'NAME': u'Hernando County',
#   u'P0010001': u'172778',
#   u'county': u'053',
#   u'state': u'12'},
#  {u'NAME': u'Highlands County',
#   u'P0010001': u'98786',
#   u'county': u'055',
#   u'state': u'12'},
#  {u'NAME': u'Hillsborough County',
#   u'P0010001': u'1229226',
#   u'county': u'057',
#   u'state': u'12'},
#  {u'NAME': u'Holmes County',
#   u'P0010001': u'19927',
#   u'county': u'059',
#   u'state': u'12'},
#  {u'NAME': u'Indian River County',
#   u'P0010001': u'138028',
#   u'county': u'061',
#   u'state': u'12'},
#  {u'NAME': u'Jackson County',
#   u'P0010001': u'49746',
#   u'county': u'063',
#   u'state': u'12'},
#  {u'NAME': u'Jefferson County',
#   u'P0010001': u'14761',
#   u'county': u'065',
#   u'state': u'12'},
#  {u'NAME': u'Lafayette County',
#   u'P0010001': u'8870',
#   u'county': u'067',
#   u'state': u'12'},
#  {u'NAME': u'Lake County',
#   u'P0010001': u'297052',
#   u'county': u'069',
#   u'state': u'12'},
#  {u'NAME': u'Lee County',
#   u'P0010001': u'618754',
#   u'county': u'071',
#   u'state': u'12'},
#  {u'NAME': u'Leon County',
#   u'P0010001': u'275487',
#   u'county': u'073',
#   u'state': u'12'},
#  {u'NAME': u'Levy County',
#   u'P0010001': u'40801',
#   u'county': u'075',
#   u'state': u'12'},
#  {u'NAME': u'Liberty County',
#   u'P0010001': u'8365',
#   u'county': u'077',
#   u'state': u'12'},
#  {u'NAME': u'Madison County',
#   u'P0010001': u'19224',
#   u'county': u'079',
#   u'state': u'12'},
#  {u'NAME': u'Manatee County',
#   u'P0010001': u'322833',
#   u'county': u'081',
#   u'state': u'12'},
#  {u'NAME': u'Marion County',
#   u'P0010001': u'331298',
#   u'county': u'083',
#   u'state': u'12'},
#  {u'NAME': u'Martin County',
#   u'P0010001': u'146318',
#   u'county': u'085',
#   u'state': u'12'},
#  {u'NAME': u'Miami-Dade County',
#   u'P0010001': u'2496435',
#   u'county': u'086',
#   u'state': u'12'},
#  {u'NAME': u'Monroe County',
#   u'P0010001': u'73090',
#   u'county': u'087',
#   u'state': u'12'},
#  {u'NAME': u'Nassau County',
#   u'P0010001': u'73314',
#   u'county': u'089',
#   u'state': u'12'},
#  {u'NAME': u'Okaloosa County',
#   u'P0010001': u'180822',
#   u'county': u'091',
#   u'state': u'12'},
#  {u'NAME': u'Okeechobee County',
#   u'P0010001': u'39996',
#   u'county': u'093',
#   u'state': u'12'},
#  {u'NAME': u'Orange County',
#   u'P0010001': u'1145956',
#   u'county': u'095',
#   u'state': u'12'},
#  {u'NAME': u'Osceola County',
#   u'P0010001': u'268685',
#   u'county': u'097',
#   u'state': u'12'},
#  {u'NAME': u'Palm Beach County',
#   u'P0010001': u'1320134',
#   u'county': u'099',
#   u'state': u'12'},
#  {u'NAME': u'Pasco County',
#   u'P0010001': u'464697',
#   u'county': u'101',
#   u'state': u'12'},
#  {u'NAME': u'Pinellas County',
#   u'P0010001': u'916542',
#   u'county': u'103',
#   u'state': u'12'},
#  {u'NAME': u'Polk County',
#   u'P0010001': u'602095',
#   u'county': u'105',
#   u'state': u'12'},
#  {u'NAME': u'Putnam County',
#   u'P0010001': u'74364',
#   u'county': u'107',
#   u'state': u'12'},
#  {u'NAME': u'St. Johns County',
#   u'P0010001': u'190039',
#   u'county': u'109',
#   u'state': u'12'},
#  {u'NAME': u'St. Lucie County',
#   u'P0010001': u'277789',
#   u'county': u'111',
#   u'state': u'12'},
#  {u'NAME': u'Santa Rosa County',
#   u'P0010001': u'151372',
#   u'county': u'113',
#   u'state': u'12'},
#  {u'NAME': u'Sarasota County',
#   u'P0010001': u'379448',
#   u'county': u'115',
#   u'state': u'12'},
#  {u'NAME': u'Seminole County',
#   u'P0010001': u'422718',
#   u'county': u'117',
#   u'state': u'12'},
#  {u'NAME': u'Sumter County',
#   u'P0010001': u'93420',
#   u'county': u'119',
#   u'state': u'12'},
#  {u'NAME': u'Suwannee County',
#   u'P0010001': u'41551',
#   u'county': u'121',
#   u'state': u'12'},
#  {u'NAME': u'Taylor County',
#   u'P0010001': u'22570',
#   u'county': u'123',
#   u'state': u'12'},
#  {u'NAME': u'Union County',
#   u'P0010001': u'15535',
#   u'county': u'125',
#   u'state': u'12'},
#  {u'NAME': u'Volusia County',
#   u'P0010001': u'494593',
#   u'county': u'127',
#   u'state': u'12'},
#  {u'NAME': u'Wakulla County',
#   u'P0010001': u'30776',
#   u'county': u'129',
#   u'state': u'12'},
#  {u'NAME': u'Walton County',
#   u'P0010001': u'55043',
#   u'county': u'131',
#   u'state': u'12'},
#  {u'NAME': u'Washington County',
#   u'P0010001': u'24896',
#   u'county': u'133',
#   u'state': u'12'},
#  {u'NAME': u'Appling County',
#   u'P0010001': u'18236',
#   u'county': u'001',
#   u'state': u'13'},
#  {u'NAME': u'Atkinson County',
#   u'P0010001': u'8375',
#   u'county': u'003',
#   u'state': u'13'},
#  {u'NAME': u'Bacon County',
#   u'P0010001': u'11096',
#   u'county': u'005',
#   u'state': u'13'},
#  {u'NAME': u'Baker County',
#   u'P0010001': u'3451',
#   u'county': u'007',
#   u'state': u'13'},
#  {u'NAME': u'Baldwin County',
#   u'P0010001': u'45720',
#   u'county': u'009',
#   u'state': u'13'},
#  {u'NAME': u'Banks County',
#   u'P0010001': u'18395',
#   u'county': u'011',
#   u'state': u'13'},
#  {u'NAME': u'Barrow County',
#   u'P0010001': u'69367',
#   u'county': u'013',
#   u'state': u'13'},
#  {u'NAME': u'Bartow County',
#   u'P0010001': u'100157',
#   u'county': u'015',
#   u'state': u'13'},
#  {u'NAME': u'Ben Hill County',
#   u'P0010001': u'17634',
#   u'county': u'017',
#   u'state': u'13'},
#  {u'NAME': u'Berrien County',
#   u'P0010001': u'19286',
#   u'county': u'019',
#   u'state': u'13'},
#  {u'NAME': u'Bibb County',
#   u'P0010001': u'155547',
#   u'county': u'021',
#   u'state': u'13'},
#  {u'NAME': u'Bleckley County',
#   u'P0010001': u'13063',
#   u'county': u'023',
#   u'state': u'13'},
#  {u'NAME': u'Brantley County',
#   u'P0010001': u'18411',
#   u'county': u'025',
#   u'state': u'13'},
#  {u'NAME': u'Brooks County',
#   u'P0010001': u'16243',
#   u'county': u'027',
#   u'state': u'13'},
#  {u'NAME': u'Bryan County',
#   u'P0010001': u'30233',
#   u'county': u'029',
#   u'state': u'13'},
#  {u'NAME': u'Bulloch County',
#   u'P0010001': u'70217',
#   u'county': u'031',
#   u'state': u'13'},
#  {u'NAME': u'Burke County',
#   u'P0010001': u'23316',
#   u'county': u'033',
#   u'state': u'13'},
#  {u'NAME': u'Butts County',
#   u'P0010001': u'23655',
#   u'county': u'035',
#   u'state': u'13'},
#  {u'NAME': u'Calhoun County',
#   u'P0010001': u'6694',
#   u'county': u'037',
#   u'state': u'13'},
#  {u'NAME': u'Camden County',
#   u'P0010001': u'50513',
#   u'county': u'039',
#   u'state': u'13'},
#  {u'NAME': u'Candler County',
#   u'P0010001': u'10998',
#   u'county': u'043',
#   u'state': u'13'},
#  {u'NAME': u'Carroll County',
#   u'P0010001': u'110527',
#   u'county': u'045',
#   u'state': u'13'},
#  {u'NAME': u'Catoosa County',
#   u'P0010001': u'63942',
#   u'county': u'047',
#   u'state': u'13'},
#  {u'NAME': u'Charlton County',
#   u'P0010001': u'12171',
#   u'county': u'049',
#   u'state': u'13'},
#  {u'NAME': u'Chatham County',
#   u'P0010001': u'265128',
#   u'county': u'051',
#   u'state': u'13'},
#  {u'NAME': u'Chattahoochee County',
#   u'P0010001': u'11267',
#   u'county': u'053',
#   u'state': u'13'},
#  {u'NAME': u'Chattooga County',
#   u'P0010001': u'26015',
#   u'county': u'055',
#   u'state': u'13'},
#  {u'NAME': u'Cherokee County',
#   u'P0010001': u'214346',
#   u'county': u'057',
#   u'state': u'13'},
#  {u'NAME': u'Clarke County',
#   u'P0010001': u'116714',
#   u'county': u'059',
#   u'state': u'13'},
#  {u'NAME': u'Clay County',
#   u'P0010001': u'3183',
#   u'county': u'061',
#   u'state': u'13'},
#  {u'NAME': u'Clayton County',
#   u'P0010001': u'259424',
#   u'county': u'063',
#   u'state': u'13'},
#  {u'NAME': u'Clinch County',
#   u'P0010001': u'6798',
#   u'county': u'065',
#   u'state': u'13'},
#  {u'NAME': u'Cobb County',
#   u'P0010001': u'688078',
#   u'county': u'067',
#   u'state': u'13'},
#  {u'NAME': u'Coffee County',
#   u'P0010001': u'42356',
#   u'county': u'069',
#   u'state': u'13'},
#  {u'NAME': u'Colquitt County',
#   u'P0010001': u'45498',
#   u'county': u'071',
#   u'state': u'13'},
#  {u'NAME': u'Columbia County',
#   u'P0010001': u'124053',
#   u'county': u'073',
#   u'state': u'13'},
#  {u'NAME': u'Cook County',
#   u'P0010001': u'17212',
#   u'county': u'075',
#   u'state': u'13'},
#  {u'NAME': u'Coweta County',
#   u'P0010001': u'127317',
#   u'county': u'077',
#   u'state': u'13'},
#  {u'NAME': u'Crawford County',
#   u'P0010001': u'12630',
#   u'county': u'079',
#   u'state': u'13'},
#  {u'NAME': u'Crisp County',
#   u'P0010001': u'23439',
#   u'county': u'081',
#   u'state': u'13'},
#  {u'NAME': u'Dade County',
#   u'P0010001': u'16633',
#   u'county': u'083',
#   u'state': u'13'},
#  {u'NAME': u'Dawson County',
#   u'P0010001': u'22330',
#   u'county': u'085',
#   u'state': u'13'},
#  {u'NAME': u'Decatur County',
#   u'P0010001': u'27842',
#   u'county': u'087',
#   u'state': u'13'},
#  {u'NAME': u'DeKalb County',
#   u'P0010001': u'691893',
#   u'county': u'089',
#   u'state': u'13'},
#  {u'NAME': u'Dodge County',
#   u'P0010001': u'21796',
#   u'county': u'091',
#   u'state': u'13'},
#  {u'NAME': u'Dooly County',
#   u'P0010001': u'14918',
#   u'county': u'093',
#   u'state': u'13'},
#  {u'NAME': u'Dougherty County',
#   u'P0010001': u'94565',
#   u'county': u'095',
#   u'state': u'13'},
#  {u'NAME': u'Douglas County',
#   u'P0010001': u'132403',
#   u'county': u'097',
#   u'state': u'13'},
#  {u'NAME': u'Early County',
#   u'P0010001': u'11008',
#   u'county': u'099',
#   u'state': u'13'},
#  {u'NAME': u'Echols County',
#   u'P0010001': u'4034',
#   u'county': u'101',
#   u'state': u'13'},
#  {u'NAME': u'Effingham County',
#   u'P0010001': u'52250',
#   u'county': u'103',
#   u'state': u'13'},
#  {u'NAME': u'Elbert County',
#   u'P0010001': u'20166',
#   u'county': u'105',
#   u'state': u'13'},
#  {u'NAME': u'Emanuel County',
#   u'P0010001': u'22598',
#   u'county': u'107',
#   u'state': u'13'},
#  {u'NAME': u'Evans County',
#   u'P0010001': u'11000',
#   u'county': u'109',
#   u'state': u'13'},
#  {u'NAME': u'Fannin County',
#   u'P0010001': u'23682',
#   u'county': u'111',
#   u'state': u'13'},
#  {u'NAME': u'Fayette County',
#   u'P0010001': u'106567',
#   u'county': u'113',
#   u'state': u'13'},
#  {u'NAME': u'Floyd County',
#   u'P0010001': u'96317',
#   u'county': u'115',
#   u'state': u'13'},
#  {u'NAME': u'Forsyth County',
#   u'P0010001': u'175511',
#   u'county': u'117',
#   u'state': u'13'},
#  {u'NAME': u'Franklin County',
#   u'P0010001': u'22084',
#   u'county': u'119',
#   u'state': u'13'},
#  {u'NAME': u'Fulton County',
#   u'P0010001': u'920581',
#   u'county': u'121',
#   u'state': u'13'},
#  {u'NAME': u'Gilmer County',
#   u'P0010001': u'28292',
#   u'county': u'123',
#   u'state': u'13'},
#  {u'NAME': u'Glascock County',
#   u'P0010001': u'3082',
#   u'county': u'125',
#   u'state': u'13'},
#  {u'NAME': u'Glynn County',
#   u'P0010001': u'79626',
#   u'county': u'127',
#   u'state': u'13'},
#  {u'NAME': u'Gordon County',
#   u'P0010001': u'55186',
#   u'county': u'129',
#   u'state': u'13'},
#  {u'NAME': u'Grady County',
#   u'P0010001': u'25011',
#   u'county': u'131',
#   u'state': u'13'},
#  {u'NAME': u'Greene County',
#   u'P0010001': u'15994',
#   u'county': u'133',
#   u'state': u'13'},
#  {u'NAME': u'Gwinnett County',
#   u'P0010001': u'805321',
#   u'county': u'135',
#   u'state': u'13'},
#  {u'NAME': u'Habersham County',
#   u'P0010001': u'43041',
#   u'county': u'137',
#   u'state': u'13'},
#  {u'NAME': u'Hall County',
#   u'P0010001': u'179684',
#   u'county': u'139',
#   u'state': u'13'},
#  {u'NAME': u'Hancock County',
#   u'P0010001': u'9429',
#   u'county': u'141',
#   u'state': u'13'},
#  {u'NAME': u'Haralson County',
#   u'P0010001': u'28780',
#   u'county': u'143',
#   u'state': u'13'},
#  {u'NAME': u'Harris County',
#   u'P0010001': u'32024',
#   u'county': u'145',
#   u'state': u'13'},
#  {u'NAME': u'Hart County',
#   u'P0010001': u'25213',
#   u'county': u'147',
#   u'state': u'13'},
#  {u'NAME': u'Heard County',
#   u'P0010001': u'11834',
#   u'county': u'149',
#   u'state': u'13'},
#  {u'NAME': u'Henry County',
#   u'P0010001': u'203922',
#   u'county': u'151',
#   u'state': u'13'},
#  {u'NAME': u'Houston County',
#   u'P0010001': u'139900',
#   u'county': u'153',
#   u'state': u'13'},
#  {u'NAME': u'Irwin County',
#   u'P0010001': u'9538',
#   u'county': u'155',
#   u'state': u'13'},
#  {u'NAME': u'Jackson County',
#   u'P0010001': u'60485',
#   u'county': u'157',
#   u'state': u'13'},
#  {u'NAME': u'Jasper County',
#   u'P0010001': u'13900',
#   u'county': u'159',
#   u'state': u'13'},
#  {u'NAME': u'Jeff Davis County',
#   u'P0010001': u'15068',
#   u'county': u'161',
#   u'state': u'13'},
#  {u'NAME': u'Jefferson County',
#   u'P0010001': u'16930',
#   u'county': u'163',
#   u'state': u'13'},
#  {u'NAME': u'Jenkins County',
#   u'P0010001': u'8340',
#   u'county': u'165',
#   u'state': u'13'},
#  {u'NAME': u'Johnson County',
#   u'P0010001': u'9980',
#   u'county': u'167',
#   u'state': u'13'},
#  {u'NAME': u'Jones County',
#   u'P0010001': u'28669',
#   u'county': u'169',
#   u'state': u'13'},
#  {u'NAME': u'Lamar County',
#   u'P0010001': u'18317',
#   u'county': u'171',
#   u'state': u'13'},
#  {u'NAME': u'Lanier County',
#   u'P0010001': u'10078',
#   u'county': u'173',
#   u'state': u'13'},
#  {u'NAME': u'Laurens County',
#   u'P0010001': u'48434',
#   u'county': u'175',
#   u'state': u'13'},
#  {u'NAME': u'Lee County',
#   u'P0010001': u'28298',
#   u'county': u'177',
#   u'state': u'13'},
#  {u'NAME': u'Liberty County',
#   u'P0010001': u'63453',
#   u'county': u'179',
#   u'state': u'13'},
#  {u'NAME': u'Lincoln County',
#   u'P0010001': u'7996',
#   u'county': u'181',
#   u'state': u'13'},
#  {u'NAME': u'Long County',
#   u'P0010001': u'14464',
#   u'county': u'183',
#   u'state': u'13'},
#  {u'NAME': u'Lowndes County',
#   u'P0010001': u'109233',
#   u'county': u'185',
#   u'state': u'13'},
#  {u'NAME': u'Lumpkin County',
#   u'P0010001': u'29966',
#   u'county': u'187',
#   u'state': u'13'},
#  {u'NAME': u'McDuffie County',
#   u'P0010001': u'21875',
#   u'county': u'189',
#   u'state': u'13'},
#  {u'NAME': u'McIntosh County',
#   u'P0010001': u'14333',
#   u'county': u'191',
#   u'state': u'13'},
#  {u'NAME': u'Macon County',
#   u'P0010001': u'14740',
#   u'county': u'193',
#   u'state': u'13'},
#  {u'NAME': u'Madison County',
#   u'P0010001': u'28120',
#   u'county': u'195',
#   u'state': u'13'},
#  {u'NAME': u'Marion County',
#   u'P0010001': u'8742',
#   u'county': u'197',
#   u'state': u'13'},
#  {u'NAME': u'Meriwether County',
#   u'P0010001': u'21992',
#   u'county': u'199',
#   u'state': u'13'},
#  {u'NAME': u'Miller County',
#   u'P0010001': u'6125',
#   u'county': u'201',
#   u'state': u'13'},
#  {u'NAME': u'Mitchell County',
#   u'P0010001': u'23498',
#   u'county': u'205',
#   u'state': u'13'},
#  {u'NAME': u'Monroe County',
#   u'P0010001': u'26424',
#   u'county': u'207',
#   u'state': u'13'},
#  {u'NAME': u'Montgomery County',
#   u'P0010001': u'9123',
#   u'county': u'209',
#   u'state': u'13'},
#  {u'NAME': u'Morgan County',
#   u'P0010001': u'17868',
#   u'county': u'211',
#   u'state': u'13'},
#  {u'NAME': u'Murray County',
#   u'P0010001': u'39628',
#   u'county': u'213',
#   u'state': u'13'},
#  {u'NAME': u'Muscogee County',
#   u'P0010001': u'189885',
#   u'county': u'215',
#   u'state': u'13'},
#  {u'NAME': u'Newton County',
#   u'P0010001': u'99958',
#   u'county': u'217',
#   u'state': u'13'},
#  {u'NAME': u'Oconee County',
#   u'P0010001': u'32808',
#   u'county': u'219',
#   u'state': u'13'},
#  {u'NAME': u'Oglethorpe County',
#   u'P0010001': u'14899',
#   u'county': u'221',
#   u'state': u'13'},
#  {u'NAME': u'Paulding County',
#   u'P0010001': u'142324',
#   u'county': u'223',
#   u'state': u'13'},
# ...
#  {u'NAME': u'Columbia County',
#   u'P0010001': u'56833',
#   u'county': u'021',
#   u'state': u'55'},
#  {u'NAME': u'Crawford County',
#   u'P0010001': u'16644',
#   u'county': u'023',
#   u'state': u'55'},
#  {u'NAME': u'Dane County',
#   u'P0010001': u'488073',
#   u'county': u'025',
#   u'state': u'55'},
#  {u'NAME': u'Dodge County',
#   u'P0010001': u'88759',
#   u'county': u'027',
#   u'state': u'55'},
#  {u'NAME': u'Door County',
#   u'P0010001': u'27785',
#   u'county': u'029',
#   u'state': u'55'},
#  {u'NAME': u'Douglas County',
#   u'P0010001': u'44159',
#   u'county': u'031',
#   u'state': u'55'},
#  {u'NAME': u'Dunn County',
#   u'P0010001': u'43857',
#   u'county': u'033',
#   u'state': u'55'},
#  {u'NAME': u'Eau Claire County',
#   u'P0010001': u'98736',
#   u'county': u'035',
#   u'state': u'55'},
#  {u'NAME': u'Florence County',
#   u'P0010001': u'4423',
#   u'county': u'037',
#   u'state': u'55'},
#  {u'NAME': u'Fond du Lac County',
#   u'P0010001': u'101633',
#   u'county': u'039',
#   u'state': u'55'},
#  {u'NAME': u'Forest County',
#   u'P0010001': u'9304',
#   u'county': u'041',
#   u'state': u'55'},
#  {u'NAME': u'Grant County',
#   u'P0010001': u'51208',
#   u'county': u'043',
#   u'state': u'55'},
#  {u'NAME': u'Green County',
#   u'P0010001': u'36842',
#   u'county': u'045',
#   u'state': u'55'},
#  {u'NAME': u'Green Lake County',
#   u'P0010001': u'19051',
#   u'county': u'047',
#   u'state': u'55'},
#  {u'NAME': u'Iowa County',
#   u'P0010001': u'23687',
#   u'county': u'049',
#   u'state': u'55'},
#  {u'NAME': u'Iron County',
#   u'P0010001': u'5916',
#   u'county': u'051',
#   u'state': u'55'},
#  {u'NAME': u'Jackson County',
#   u'P0010001': u'20449',
#   u'county': u'053',
#   u'state': u'55'},
#  {u'NAME': u'Jefferson County',
#   u'P0010001': u'83686',
#   u'county': u'055',
#   u'state': u'55'},
#  {u'NAME': u'Juneau County',
#   u'P0010001': u'26664',
#   u'county': u'057',
#   u'state': u'55'},
#  {u'NAME': u'Kenosha County',
#   u'P0010001': u'166426',
#   u'county': u'059',
#   u'state': u'55'},
#  {u'NAME': u'Kewaunee County',
#   u'P0010001': u'20574',
#   u'county': u'061',
#   u'state': u'55'},
#  {u'NAME': u'La Crosse County',
#   u'P0010001': u'114638',
#   u'county': u'063',
#   u'state': u'55'},
#  {u'NAME': u'Lafayette County',
#   u'P0010001': u'16836',
#   u'county': u'065',
#   u'state': u'55'},
#  {u'NAME': u'Langlade County',
#   u'P0010001': u'19977',
#   u'county': u'067',
#   u'state': u'55'},
#  {u'NAME': u'Lincoln County',
#   u'P0010001': u'28743',
#   u'county': u'069',
#   u'state': u'55'},
#  {u'NAME': u'Manitowoc County',
#   u'P0010001': u'81442',
#   u'county': u'071',
#   u'state': u'55'},
#  {u'NAME': u'Marathon County',
#   u'P0010001': u'134063',
#   u'county': u'073',
#   u'state': u'55'},
#  {u'NAME': u'Marinette County',
#   u'P0010001': u'41749',
#   u'county': u'075',
#   u'state': u'55'},
#  {u'NAME': u'Marquette County',
#   u'P0010001': u'15404',
#   u'county': u'077',
#   u'state': u'55'},
#  {u'NAME': u'Menominee County',
#   u'P0010001': u'4232',
#   u'county': u'078',
#   u'state': u'55'},
#  {u'NAME': u'Milwaukee County',
#   u'P0010001': u'947735',
#   u'county': u'079',
#   u'state': u'55'},
#  {u'NAME': u'Monroe County',
#   u'P0010001': u'44673',
#   u'county': u'081',
#   u'state': u'55'},
#  {u'NAME': u'Oconto County',
#   u'P0010001': u'37660',
#   u'county': u'083',
#   u'state': u'55'},
#  {u'NAME': u'Oneida County',
#   u'P0010001': u'35998',
#   u'county': u'085',
#   u'state': u'55'},
#  {u'NAME': u'Outagamie County',
#   u'P0010001': u'176695',
#   u'county': u'087',
#   u'state': u'55'},
#  {u'NAME': u'Ozaukee County',
#   u'P0010001': u'86395',
#   u'county': u'089',
#   u'state': u'55'},
#  {u'NAME': u'Pepin County',
#   u'P0010001': u'7469',
#   u'county': u'091',
#   u'state': u'55'},
#  {u'NAME': u'Pierce County',
#   u'P0010001': u'41019',
#   u'county': u'093',
#   u'state': u'55'},
#  {u'NAME': u'Polk County',
#   u'P0010001': u'44205',
#   u'county': u'095',
#   u'state': u'55'},
#  {u'NAME': u'Portage County',
#   u'P0010001': u'70019',
#   u'county': u'097',
#   u'state': u'55'},
#  {u'NAME': u'Price County',
#   u'P0010001': u'14159',
#   u'county': u'099',
#   u'state': u'55'},
#  {u'NAME': u'Racine County',
#   u'P0010001': u'195408',
#   u'county': u'101',
#   u'state': u'55'},
#  {u'NAME': u'Richland County',
#   u'P0010001': u'18021',
#   u'county': u'103',
#   u'state': u'55'},
#  {u'NAME': u'Rock County',
#   u'P0010001': u'160331',
#   u'county': u'105',
#   u'state': u'55'},
#  {u'NAME': u'Rusk County',
#   u'P0010001': u'14755',
#   u'county': u'107',
#   u'state': u'55'},
#  {u'NAME': u'St. Croix County',
#   u'P0010001': u'84345',
#   u'county': u'109',
#   u'state': u'55'},
#  {u'NAME': u'Sauk County',
#   u'P0010001': u'61976',
#   u'county': u'111',
#   u'state': u'55'},
#  {u'NAME': u'Sawyer County',
#   u'P0010001': u'16557',
#   u'county': u'113',
#   u'state': u'55'},
#  {u'NAME': u'Shawano County',
#   u'P0010001': u'41949',
#   u'county': u'115',
#   u'state': u'55'},
#  {u'NAME': u'Sheboygan County',
#   u'P0010001': u'115507',
#   u'county': u'117',
#   u'state': u'55'},
#  {u'NAME': u'Taylor County',
#   u'P0010001': u'20689',
#   u'county': u'119',
#   u'state': u'55'},
#  {u'NAME': u'Trempealeau County',
#   u'P0010001': u'28816',
#   u'county': u'121',
#   u'state': u'55'},
#  {u'NAME': u'Vernon County',
#   u'P0010001': u'29773',
#   u'county': u'123',
#   u'state': u'55'},
#  {u'NAME': u'Vilas County',
#   u'P0010001': u'21430',
#   u'county': u'125',
#   u'state': u'55'},
#  {u'NAME': u'Walworth County',
#   u'P0010001': u'102228',
#   u'county': u'127',
#   u'state': u'55'},
#  {u'NAME': u'Washburn County',
#   u'P0010001': u'15911',
#   u'county': u'129',
#   u'state': u'55'},
#  {u'NAME': u'Washington County',
#   u'P0010001': u'131887',
#   u'county': u'131',
#   u'state': u'55'},
#  {u'NAME': u'Waukesha County',
#   u'P0010001': u'389891',
#   u'county': u'133',
#   u'state': u'55'},
#  {u'NAME': u'Waupaca County',
#   u'P0010001': u'52410',
#   u'county': u'135',
#   u'state': u'55'},
#  {u'NAME': u'Waushara County',
#   u'P0010001': u'24496',
#   u'county': u'137',
#   u'state': u'55'},
#  {u'NAME': u'Winnebago County',
#   u'P0010001': u'166994',
#   u'county': u'139',
#   u'state': u'55'},
#  {u'NAME': u'Wood County',
#   u'P0010001': u'74749',
#   u'county': u'141',
#   u'state': u'55'},
#  {u'NAME': u'Albany County',
#   u'P0010001': u'36299',
#   u'county': u'001',
#   u'state': u'56'},
#  {u'NAME': u'Big Horn County',
#   u'P0010001': u'11668',
#   u'county': u'003',
#   u'state': u'56'},
#  {u'NAME': u'Campbell County',
#   u'P0010001': u'46133',
#   u'county': u'005',
#   u'state': u'56'},
#  {u'NAME': u'Carbon County',
#   u'P0010001': u'15885',
#   u'county': u'007',
#   u'state': u'56'},
#  {u'NAME': u'Converse County',
#   u'P0010001': u'13833',
#   u'county': u'009',
#   u'state': u'56'},
#  {u'NAME': u'Crook County',
#   u'P0010001': u'7083',
#   u'county': u'011',
#   u'state': u'56'},
#  {u'NAME': u'Fremont County',
#   u'P0010001': u'40123',
#   u'county': u'013',
#   u'state': u'56'},
#  {u'NAME': u'Goshen County',
#   u'P0010001': u'13249',
#   u'county': u'015',
#   u'state': u'56'},
#  {u'NAME': u'Hot Springs County',
#   u'P0010001': u'4812',
#   u'county': u'017',
#   u'state': u'56'},
#  {u'NAME': u'Johnson County',
#   u'P0010001': u'8569',
#   u'county': u'019',
#   u'state': u'56'},
#  {u'NAME': u'Laramie County',
#   u'P0010001': u'91738',
#   u'county': u'021',
#   u'state': u'56'},
#  {u'NAME': u'Lincoln County',
#   u'P0010001': u'18106',
#   u'county': u'023',
#   u'state': u'56'},
#  {u'NAME': u'Natrona County',
#   u'P0010001': u'75450',
#   u'county': u'025',
#   u'state': u'56'},
#  {u'NAME': u'Niobrara County',
#   u'P0010001': u'2484',
#   u'county': u'027',
#   u'state': u'56'},
#  {u'NAME': u'Park County',
#   u'P0010001': u'28205',
#   u'county': u'029',
#   u'state': u'56'},
#  {u'NAME': u'Platte County',
#   u'P0010001': u'8667',
#   u'county': u'031',
#   u'state': u'56'},
#  {u'NAME': u'Sheridan County',
#   u'P0010001': u'29116',
#   u'county': u'033',
#   u'state': u'56'},
#  {u'NAME': u'Sublette County',
#   u'P0010001': u'10247',
#   u'county': u'035',
#   u'state': u'56'},
#  {u'NAME': u'Sweetwater County',
#   u'P0010001': u'43806',
#   u'county': u'037',
#   u'state': u'56'},
#  {u'NAME': u'Teton County',
#   u'P0010001': u'21294',
#   u'county': u'039',
#   u'state': u'56'},
#  {u'NAME': u'Uinta County',
#   u'P0010001': u'21118',
#   u'county': u'041',
#   u'state': u'56'},
#  {u'NAME': u'Washakie County',
#   u'P0010001': u'8533',
#   u'county': u'043',
#   u'state': u'56'},
#  {u'NAME': u'Weston County',
#   u'P0010001': u'7208',
#   u'county': u'045',
#   u'state': u'56'},
#  {u'NAME': u'Adjuntas Municipio',
#   u'P0010001': u'19483',
#   u'county': u'001',
#   u'state': u'72'},
#  {u'NAME': u'Aguada Municipio',
#   u'P0010001': u'41959',
#   u'county': u'003',
#   u'state': u'72'},
#  {u'NAME': u'Aguadilla Municipio',
#   u'P0010001': u'60949',
#   u'county': u'005',
#   u'state': u'72'},
#  {u'NAME': u'Aguas Buenas Municipio',
#   u'P0010001': u'28659',
#   u'county': u'007',
#   u'state': u'72'},
#  {u'NAME': u'Aibonito Municipio',
#   u'P0010001': u'25900',
#   u'county': u'009',
#   u'state': u'72'},
#  {u'NAME': u'A\xf1asco Municipio',
#   u'P0010001': u'29261',
#   u'county': u'011',
#   u'state': u'72'},
#  {u'NAME': u'Arecibo Municipio',
#   u'P0010001': u'96440',
#   u'county': u'013',
#   u'state': u'72'},
#  {u'NAME': u'Arroyo Municipio',
#   u'P0010001': u'19575',
#   u'county': u'015',
#   u'state': u'72'},
#  {u'NAME': u'Barceloneta Municipio',
#   u'P0010001': u'24816',
#   u'county': u'017',
#   u'state': u'72'},
#  {u'NAME': u'Barranquitas Municipio',
#   u'P0010001': u'30318',
#   u'county': u'019',
#   u'state': u'72'},
#  {u'NAME': u'Bayam\xf3n Municipio',
#   u'P0010001': u'208116',
#   u'county': u'021',
#   u'state': u'72'},
#  {u'NAME': u'Cabo Rojo Municipio',
#   u'P0010001': u'50917',
#   u'county': u'023',
#   u'state': u'72'},
#  {u'NAME': u'Caguas Municipio',
#   u'P0010001': u'142893',
#   u'county': u'025',
#   u'state': u'72'},
#  {u'NAME': u'Camuy Municipio',
#   u'P0010001': u'35159',
#   u'county': u'027',
#   u'state': u'72'},
#  {u'NAME': u'Can\xf3vanas Municipio',
#   u'P0010001': u'47648',
#   u'county': u'029',
#   u'state': u'72'},
#  {u'NAME': u'Carolina Municipio',
#   u'P0010001': u'176762',
#   u'county': u'031',
#   u'state': u'72'},
#  {u'NAME': u'Cata\xf1o Municipio',
#   u'P0010001': u'28140',
#   u'county': u'033',
#   u'state': u'72'},
#  {u'NAME': u'Cayey Municipio',
#   u'P0010001': u'48119',
#   u'county': u'035',
#   u'state': u'72'},
#  {u'NAME': u'Ceiba Municipio',
#   u'P0010001': u'13631',
#   u'county': u'037',
#   u'state': u'72'},
#  {u'NAME': u'Ciales Municipio',
#   u'P0010001': u'18782',
#   u'county': u'039',
#   u'state': u'72'},
#  {u'NAME': u'Cidra Municipio',
#   u'P0010001': u'43480',
#   u'county': u'041',
#   u'state': u'72'},
#  {u'NAME': u'Coamo Municipio',
#   u'P0010001': u'40512',
#   u'county': u'043',
#   u'state': u'72'},
#  {u'NAME': u'Comer\xedo Municipio',
#   u'P0010001': u'20778',
#   u'county': u'045',
#   u'state': u'72'},
#  {u'NAME': u'Corozal Municipio',
#   u'P0010001': u'37142',
#   u'county': u'047',
#   u'state': u'72'},
#  {u'NAME': u'Culebra Municipio',
#   u'P0010001': u'1818',
#   u'county': u'049',
#   u'state': u'72'},
#  {u'NAME': u'Dorado Municipio',
#   u'P0010001': u'38165',
#   u'county': u'051',
#   u'state': u'72'},
#  {u'NAME': u'Fajardo Municipio',
#   u'P0010001': u'36993',
#   u'county': u'053',
#   u'state': u'72'},
#  {u'NAME': u'Florida Municipio',
#   u'P0010001': u'12680',
#   u'county': u'054',
#   u'state': u'72'},
#  {u'NAME': u'Gu\xe1nica Municipio',
#   u'P0010001': u'19427',
#   u'county': u'055',
#   u'state': u'72'},
#  {u'NAME': u'Guayama Municipio',
#   u'P0010001': u'45362',
#   u'county': u'057',
#   u'state': u'72'},
#  {u'NAME': u'Guayanilla Municipio',
#   u'P0010001': u'21581',
#   u'county': u'059',
#   u'state': u'72'},
#  {u'NAME': u'Guaynabo Municipio',
#   u'P0010001': u'97924',
#   u'county': u'061',
#   u'state': u'72'},
#  {u'NAME': u'Gurabo Municipio',
#   u'P0010001': u'45369',
#   u'county': u'063',
#   u'state': u'72'},
#  {u'NAME': u'Hatillo Municipio',
#   u'P0010001': u'41953',
#   u'county': u'065',
#   u'state': u'72'},
#  {u'NAME': u'Hormigueros Municipio',
#   u'P0010001': u'17250',
#   u'county': u'067',
#   u'state': u'72'},
#  {u'NAME': u'Humacao Municipio',
#   u'P0010001': u'58466',
#   u'county': u'069',
#   u'state': u'72'},
#  {u'NAME': u'Isabela Municipio',
#   u'P0010001': u'45631',
#   u'county': u'071',
#   u'state': u'72'},
#  {u'NAME': u'Jayuya Municipio',
#   u'P0010001': u'16642',
#   u'county': u'073',
#   u'state': u'72'},
#  {u'NAME': u'Juana D\xedaz Municipio',
#   u'P0010001': u'50747',
#   u'county': u'075',
#   u'state': u'72'},
#  {u'NAME': u'Juncos Municipio',
#   u'P0010001': u'40290',
#   u'county': u'077',
#   u'state': u'72'},
#  {u'NAME': u'Lajas Municipio',
#   u'P0010001': u'25753',
#   u'county': u'079',
#   u'state': u'72'},
#  {u'NAME': u'Lares Municipio',
#   u'P0010001': u'30753',
#   u'county': u'081',
#   u'state': u'72'},
#  {u'NAME': u'Las Mar\xedas Municipio',
#   u'P0010001': u'9881',
#   u'county': u'083',
#   u'state': u'72'},
#  {u'NAME': u'Las Piedras Municipio',
#   u'P0010001': u'38675',
#   u'county': u'085',
#   u'state': u'72'},
#  {u'NAME': u'Lo\xedza Municipio',
#   u'P0010001': u'30060',
#   u'county': u'087',
#   u'state': u'72'},
#  {u'NAME': u'Luquillo Municipio',
#   u'P0010001': u'20068',
#   u'county': u'089',
#   u'state': u'72'},
#  {u'NAME': u'Manat\xed Municipio',
#   u'P0010001': u'44113',
#   u'county': u'091',
#   u'state': u'72'},
#  {u'NAME': u'Maricao Municipio',
#   u'P0010001': u'6276',
#   u'county': u'093',
#   u'state': u'72'},
#  {u'NAME': u'Maunabo Municipio',
#   u'P0010001': u'12225',
#   u'county': u'095',
#   u'state': u'72'},
#  {u'NAME': u'Mayag\xfcez Municipio',
#   u'P0010001': u'89080',
#   u'county': u'097',
#   u'state': u'72'},
#  {u'NAME': u'Moca Municipio',
#   u'P0010001': u'40109',
#   u'county': u'099',
#   u'state': u'72'},
#  {u'NAME': u'Morovis Municipio',
#   u'P0010001': u'32610',
#   u'county': u'101',
#   u'state': u'72'},
#  {u'NAME': u'Naguabo Municipio',
#   u'P0010001': u'26720',
#   u'county': u'103',
#   u'state': u'72'},
#  {u'NAME': u'Naranjito Municipio',
#   u'P0010001': u'30402',
#   u'county': u'105',
#   u'state': u'72'},
#  {u'NAME': u'Orocovis Municipio',
#   u'P0010001': u'23423',
#   u'county': u'107',
#   u'state': u'72'},
#  {u'NAME': u'Patillas Municipio',
#   u'P0010001': u'19277',
#   u'county': u'109',
#   u'state': u'72'},
#  {u'NAME': u'Pe\xf1uelas Municipio',
#   u'P0010001': u'24282',
#   u'county': u'111',
#   u'state': u'72'},
#  {u'NAME': u'Ponce Municipio',
#   u'P0010001': u'166327',
#   u'county': u'113',
#   u'state': u'72'},
#  {u'NAME': u'Quebradillas Municipio',
#   u'P0010001': u'25919',
#   u'county': u'115',
#   u'state': u'72'},
#  {u'NAME': u'Rinc\xf3n Municipio',
#   u'P0010001': u'15200',
#   u'county': u'117',
#   u'state': u'72'},
#  {u'NAME': u'R\xedo Grande Municipio',
#   u'P0010001': u'54304',
#   u'county': u'119',
#   u'state': u'72'},
#  {u'NAME': u'Sabana Grande Municipio',
#   u'P0010001': u'25265',
#   u'county': u'121',
#   u'state': u'72'},
#  {u'NAME': u'Salinas Municipio',
#   u'P0010001': u'31078',
#   u'county': u'123',
#   u'state': u'72'},
#  {u'NAME': u'San Germ\xe1n Municipio',
#   u'P0010001': u'35527',
#   u'county': u'125',
#   u'state': u'72'},
#  {u'NAME': u'San Juan Municipio',
#   u'P0010001': u'395326',
#   u'county': u'127',
#   u'state': u'72'},
#  {u'NAME': u'San Lorenzo Municipio',
#   u'P0010001': u'41058',
#   u'county': u'129',
#   u'state': u'72'},
#  {u'NAME': u'San Sebasti\xe1n Municipio',
#   u'P0010001': u'42430',
#   u'county': u'131',
#   u'state': u'72'},
#  {u'NAME': u'Santa Isabel Municipio',
#   u'P0010001': u'23274',
#   u'county': u'133',
#   u'state': u'72'},
#  {u'NAME': u'Toa Alta Municipio',
#   u'P0010001': u'74066',
#   u'county': u'135',
#   u'state': u'72'},
#  {u'NAME': u'Toa Baja Municipio',
#   u'P0010001': u'89609',
#   u'county': u'137',
#   u'state': u'72'},
#  {u'NAME': u'Trujillo Alto Municipio',
#   u'P0010001': u'74842',
#   u'county': u'139',
#   u'state': u'72'},
#  {u'NAME': u'Utuado Municipio',
#   u'P0010001': u'33149',
#   u'county': u'141',
#   u'state': u'72'},
#  {u'NAME': u'Vega Alta Municipio',
#   u'P0010001': u'39951',
#   u'county': u'143',
#   u'state': u'72'},
#  {u'NAME': u'Vega Baja Municipio',
#   u'P0010001': u'59662',
#   u'county': u'145',
#   u'state': u'72'},
#  {u'NAME': u'Vieques Municipio',
#   u'P0010001': u'9301',
#   u'county': u'147',
#   u'state': u'72'},
#  {u'NAME': u'Villalba Municipio',
#   u'P0010001': u'26073',
#   u'county': u'149',
#   u'state': u'72'},
#  {u'NAME': u'Yabucoa Municipio',
#   u'P0010001': u'37941',
#   u'county': u'151',
#   u'state': u'72'},
#  {u'NAME': u'Yauco Municipio',
#   u'P0010001': u'42043',
#   u'county': u'153',
#   u'state': u'72'}]

# %%
# convert the json from the API into a DataFrame
# coerce to integer the P0010001 column

df = DataFrame(r)
df['P0010001'] = df['P0010001'].astype('int')

# display the first records
df.head()
# Out:
#              NAME  P0010001 county state
# 0  Autauga County     54571    001    01
# 1  Baldwin County    182265    003    01
# 2  Barbour County     27457    005    01
# 3     Bibb County     22915    007    01
# 4   Blount County     57322    009    01

# %%
# calculate the total population 
# what happens when you google the number you get?

np.sum(df['P0010001'])
# Out:
# 312471327

# %%
# often you can use dot notation to access a DataFrame column
df.P0010001.head()
# Out:
# 0     54571
# 1    182265
# 2     27457
# 3     22915
# 4     57322
# Name: P0010001, dtype: int64

# %%
# let's filter out PR -- what's the total population now
sum(df[np.in1d(df.state, states_fips)].P0010001)
# Out:
# 308745538

# %%
# fall back to non-Pandas solution if you need ton
np.sum([int(county['P0010001']) for county in r if county['state'] in states_fips])
# Out:
# 308745538

# %%
# construct counties_df with only 50 states + DC
counties_df = df[np.in1d(df.state, states_fips)]
len(counties_df)
# Out:
# 3143

# %%
set(counties_df.columns) == set(df.columns)
# Out:
# True

# %% [markdown]
# Check properties of `counties_df`

# %%
# number of counties
assert len(counties_df) == 3143 #3143 county/county-equivs in US

# %%
# check that the total population by adding all counties == population by adding all states

assert np.sum(counties_df['P0010001']) == np.sum(states_df.P0010001)

# %%
# check we have same columns between counties_df and df
set(counties_df.columns) == set(df.columns)
# Out:
# True

# %% [markdown]
# # Using FIPS code as the Index

# %% [markdown]
# From [Mapping Census Data](http://www.udel.edu/johnmack/frec682/census/):
#
# * Each state (SUMLEV = 040) has a 2-digit FIPS ID; Delaware's is 10.
# * Each county (SUMLEV = 050) within a state has a 3-digit FIPS ID, appended to the 2-digit state ID. New Castle County, Delaware, has FIPS ID 10003.
# * Each Census Tract (SUMLEV = 140) within a county has a 6-digit ID, appended to the county code. The Tract in New Castle County DE that contains most of the the UD campus has FIPS ID 10003014502.
# * Each Block Group (SUMLEV = 150) within a Tract has a single digit ID appended to the Tract ID. The center of campus in the northwest corner of the tract is Block Group100030145022.
# * Each Block (SUMLEV = 750) within a Block Group is identified by three more digits appended to the Block Group ID. Pearson Hall is located in Block 100030145022009.

# %%
# take a look at the current structure of counties_df

counties_df.head()
# Out:
#              NAME  P0010001 county state
# 0  Autauga County     54571    001    01
# 1  Baldwin County    182265    003    01
# 2  Barbour County     27457    005    01
# 3     Bibb County     22915    007    01
# 4   Blount County     57322    009    01

# %%
# reindex states_df by state FIPS
# http://pandas.pydata.org/pandas-docs/dev/generated/pandas.DataFrame.set_index.html

states_df.set_index(keys='state', inplace=True)
states_df.head()
# Out:
#              NAME  P0010001
# state
# 01        Alabama   4779736
# 02         Alaska    710231
# 04        Arizona   6392017
# 05       Arkansas   2915918
# 06     California  37253956

# %%
# display the result of using set_index
counties_df.head()
# Out:
#              NAME  P0010001 county state
# 0  Autauga County     54571    001    01
# 1  Baldwin County    182265    003    01
# 2  Barbour County     27457    005    01
# 3     Bibb County     22915    007    01
# 4   Blount County     57322    009    01

# %%
# http://manishamde.github.io/blog/2013/03/07/pandas-and-python-top-10/#create

counties_df['FIPS'] = counties_df.apply(lambda s:s['state'] + s['county'], axis=1)
counties_df.set_index('FIPS', inplace=True)

# %%
counties_df.head()
# Out:
#                  NAME  P0010001 county state
# FIPS
# 01001  Autauga County     54571    001    01
# 01003  Baldwin County    182265    003    01
# 01005  Barbour County     27457    005    01
# 01007     Bibb County     22915    007    01
# 01009   Blount County     57322    009    01

# %%
counties_df.groupby('state').sum().head()
# Out:
#        P0010001
# state
# 01      4779736
# 02       710231
# 04      6392017
# 05      2915918
# 06     37253956

# %%
states_df.P0010001.head()
# Out:
# state
# 01        4779736
# 02         710231
# 04        6392017
# 05        2915918
# 06       37253956
# Name: P0010001, dtype: int64

# %%
# now we're ready to compare for each state, if you add all the counties, do you get the same
# population?
# not that you can do .agg('sum') instead of .sum()
# look at http://pandas.pydata.org/pandas-docs/dev/groupby.html to learn more about agg

np.all(states_df.P0010001 == counties_df.groupby('state').agg('sum').P0010001)
# Out:
# True

# %% [markdown]
# # Counties in California

# %% [markdown]
# Let's look at home: California state and Alameda County

# %%
# boolean indexing to pull up California
states_df[states_df.NAME == 'California']
# Out:
#              NAME  P0010001
# state
# 06     California  37253956

# %%
# use .ix -- most general indexing 
# http://pandas.pydata.org/pandas-docs/dev/indexing.html#different-choices-for-indexing-loc-iloc-and-ix
states_df.ix['06']
# Out:
# NAME        California
# P0010001      37253956
# Name: 06, dtype: object

# %%
# California counties

counties_df[counties_df.state=='06']
# Out:
#                          NAME  P0010001 county state
# FIPS
# 06001          Alameda County   1510271    001    06
# 06003           Alpine County      1175    003    06
# 06005           Amador County     38091    005    06
# 06007            Butte County    220000    007    06
# 06009        Calaveras County     45578    009    06
# 06011           Colusa County     21419    011    06
# 06013     Contra Costa County   1049025    013    06
# 06015        Del Norte County     28610    015    06
# 06017        El Dorado County    181058    017    06
# 06019           Fresno County    930450    019    06
# 06021            Glenn County     28122    021    06
# 06023         Humboldt County    134623    023    06
# 06025         Imperial County    174528    025    06
# 06027             Inyo County     18546    027    06
# 06029             Kern County    839631    029    06
# 06031            Kings County    152982    031    06
# 06033             Lake County     64665    033    06
# 06035           Lassen County     34895    035    06
# 06037      Los Angeles County   9818605    037    06
# 06039           Madera County    150865    039    06
# 06041            Marin County    252409    041    06
# 06043         Mariposa County     18251    043    06
# 06045        Mendocino County     87841    045    06
# 06047           Merced County    255793    047    06
# 06049            Modoc County      9686    049    06
# 06051             Mono County     14202    051    06
# 06053         Monterey County    415057    053    06
# 06055             Napa County    136484    055    06
# 06057           Nevada County     98764    057    06
# 06059           Orange County   3010232    059    06
# 06061           Placer County    348432    061    06
# 06063           Plumas County     20007    063    06
# 06065        Riverside County   2189641    065    06
# 06067       Sacramento County   1418788    067    06
# 06069       San Benito County     55269    069    06
# 06071   San Bernardino County   2035210    071    06
# 06073        San Diego County   3095313    073    06
# 06075    San Francisco County    805235    075    06
# 06077      San Joaquin County    685306    077    06
# 06079  San Luis Obispo County    269637    079    06
# 06081        San Mateo County    718451    081    06
# 06083    Santa Barbara County    423895    083    06
# 06085      Santa Clara County   1781642    085    06
# 06087       Santa Cruz County    262382    087    06
# 06089           Shasta County    177223    089    06
# 06091           Sierra County      3240    091    06
# 06093         Siskiyou County     44900    093    06
# 06095           Solano County    413344    095    06
# 06097           Sonoma County    483878    097    06
# 06099       Stanislaus County    514453    099    06
# 06101           Sutter County     94737    101    06
# 06103           Tehama County     63463    103    06
# 06105          Trinity County     13786    105    06
# 06107           Tulare County    442179    107    06
# 06109         Tuolumne County     55365    109    06
# 06111          Ventura County    823318    111    06
# 06113             Yolo County    200849    113    06
# 06115             Yuba County     72155    115    06

# %%
counties_df[counties_df.NAME == 'Alameda County']
# Out:
#                  NAME  P0010001 county state
# FIPS
# 06001  Alameda County   1510271    001    06

# %%
counties_df[counties_df.NAME == 'Alameda County']['P0010001']
# Out:
# FIPS
# 06001    1510271
# Name: P0010001, dtype: int64

# %% [markdown]
# Different ways to read off the population of Alameda County -- still looking for the best way

# %%
counties_df[counties_df.NAME == 'Alameda County']['P0010001'].to_dict().values()[0]
# Out:
# 1510271

# %%
list(counties_df[counties_df.NAME == 'Alameda County']['P0010001'].iteritems())[0][1]
# Out:
# 1510271

# %%
int(counties_df[counties_df.NAME == 'Alameda County']['P0010001'].values)
# Out:
# 1510271

# %% [markdown]
# If you know the FIPS code for Alameda County, just read off the population using `.ix`

# %%
# this is like accessing a cell in a spreadsheet -- row, col

ALAMEDA_COUNTY_FIPS = '06001'

counties_df.ix[ALAMEDA_COUNTY_FIPS,'P0010001']
# Out:
# 1510271

# %% [markdown]
# # Reading off all the tracts in Alameda County

# %%
counties_df.ix[ALAMEDA_COUNTY_FIPS,'county']
# Out:
# u'001'

# %%
# http://api.census.gov/data/2010/sf1/geo.html
# state-county-tract

geo = {'for': 'tract:*', 
       'in': 'state:%s county:%s' % (us.states.CA.fips, 
                                     counties_df.ix[ALAMEDA_COUNTY_FIPS,'county'])}
        
r = c.sf1.get('NAME,P0010001', geo=geo)

# %%
alameda_county_tracts_df.apply(lambda s: s['state']+s['county']+s['tract'], axis=1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-40-37aa2941bffa> in <module>()
# ----> 1 alameda_county_tracts_df.apply(lambda s: s['state']+s['county']+s['tract'], axis=1)
#
# NameError: name 'alameda_county_tracts_df' is not defined

# %%
#use state_county_tract to make a DataFrame

alameda_county_tracts_df = DataFrame(r)
alameda_county_tracts_df['P0010001'] = alameda_county_tracts_df['P0010001'].astype('int')
alameda_county_tracts_df['FIPS'] = alameda_county_tracts_df.apply(lambda s: s['state']+s['county']+s['tract'], axis=1)
alameda_county_tracts_df.head()

# %%
alameda_county_tracts_df.P0010001.sum()

# %%
# Cafe Milano is in tract 4228
MILANO_TRACT_ID = '422800'
alameda_county_tracts_df[alameda_county_tracts_df.tract==MILANO_TRACT_ID]

# %% [markdown]
# # Using Generators to yield all the tracts in the country

# %% [markdown]
# http://www.jeffknupp.com/blog/2013/04/07/improve-your-python-yield-and-generators-explained/

# %%
import time
import us

from itertools import islice

def census_tracts(variable=('NAME','P0010001'), sleep_time=1.0):
    
    for state in us.states.STATES:
        print state
        for tract in c.sf1.get(variable, 
                    geo={'for':"tract:*", 
                        'in':'state:{state_fips}'.format(state_fips=state.fips)
                        }):
            yield tract
        # don't hit the API more than once a second    
        time.sleep(sleep_time)
 
# limit the number of tracts we crawl for until we're reading to get all of them        
tracts_df = DataFrame(list(islice(census_tracts(), 100)))
tracts_df['P0010001'] = tracts_df['P0010001'].astype('int')

# %%
tracts_df.head()

# %% [markdown]
# # Compare with Tabulations

# %% [markdown]
# We can compare the total number of tracts we calculate to:
#
# https://www.census.gov/geo/maps-data/data/tallies/tractblock.html
#
# and
#
# https://www.census.gov/geo/maps-data/data/docs/geo_tallies/Tract_Block2010.txt
